# %%
# pip install sktime
# Out:
# Collecting sktime
#   Downloading sktime-0.37.0-py3-none-any.whl.metadata (34 kB)
# Collecting joblib<1.5,>=1.2.0 (from sktime)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy<2.3,>=1.21 in /usr/local/lib/python3.11/dist-packages (from sktime) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from sktime) (24.2)
# Requirement already satisfied: pandas<2.3.0,>=1.1 in /usr/local/lib/python3.11/dist-packages (from sktime) (2.2.2)
# Collecting scikit-base<0.13.0,>=0.6.1 (from sktime)
#   Downloading scikit_base-0.12.3-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: scikit-learn<1.7.0,>=0.24 in /usr/local/lib/python3.11/dist-packages (from sktime) (1.6.1)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in /usr/local/lib/python3.11/dist-packages (from sktime) (1.15.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.1->sktime) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.1->sktime) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.1->sktime) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<1.7.0,>=0.24->sktime) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<2.3.0,>=1.1->sktime) (1.17.0)
# Downloading sktime-0.37.0-py3-none-any.whl (37.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.0/37.0 MB 48.3 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 23.8 MB/s eta 0:00:00
# Downloading scikit_base-0.12.3-py3-none-any.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.5/145.5 kB 14.5 MB/s eta 0:00:00
# Installing collected packages: scikit-base, joblib, sktime
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.1
#     Uninstalling joblib-1.5.1:
#       Successfully uninstalled joblib-1.5.1
# Successfully installed joblib-1.4.2 scikit-base-0.12.3 sktime-0.37.0

# %%
# pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from scikeras) (3.8.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from scikeras) (1.6.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.16.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras>=3.2.0->scikeras) (4.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
# pip install scikit-learn==1.5.2
# Out:
# Collecting scikit-learn==1.5.2
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (3.6.0)
# Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 68.9 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# Successfully installed scikit-learn-1.5.2

# %%
from keras.src import optimizers
from keras.src.utils import plot_model
from keras.src.models import Sequential, Model
from keras.src.layers.convolutional.conv1d import Conv1D
from keras.src.layers.pooling.max_pooling1d import MaxPooling1D
from keras.src.layers import Dense, LSTM, RepeatVector, TimeDistributed, Flatten
from keras.src import metrics
from keras.layers import Input
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, date
import sklearn
from sklearn.model_selection import train_test_split

import math
from sklearn.preprocessing import MinMaxScaler

from datetime import datetime as dt, date, timedelta
# from meteostat import Point, Daily

# %%
# data = pd.read_csv('/content/preprocessed_main_data_dki1_kemayoran.csv')
data = pd.read_csv('./preprocessed_main_data_dki1_kemayoran_v2.csv', sep=';')
data = data.set_index('tanggal')
data
# Out:
#             pm10  pm25   so2    co    o3   no2  Tavg  RH_avg    RR   ss  \
# tanggal
# 2023-01-01  44.0  55.0  47.0  10.0  24.0   9.0  26.3    87.0  14.5  0.0
# 2023-01-02  32.0  43.0  52.0   9.0  24.0   8.0  27.5    81.0  31.5  0.7
# 2023-01-03  31.0  35.0  49.0   9.0  12.0   7.0  26.6    82.0   0.5  0.0
# 2023-01-04  30.0  47.0  53.0  11.0  15.0   9.0  26.4    86.0   2.4  2.1
# 2023-01-05  38.0  50.0  50.0  13.0  26.0  11.0  27.4    83.0  35.3  4.9
# ...          ...   ...   ...   ...   ...   ...   ...     ...   ...  ...
# 2024-10-27  54.0  78.0  19.0  23.0  34.0  31.0  30.1    71.0   0.0  8.0
# 2024-10-28  60.0  83.0  10.0  26.0  37.0  36.0  30.2    67.0   0.0  8.0
# 2024-10-29  59.0  75.0  11.0  28.0  29.0  41.0  30.8    69.0   0.0  0.6
# 2024-10-30  62.0  86.0  11.0  27.0  36.0  44.0  30.9    65.0   0.0  6.5
# 2024-10-31  59.0  78.0  11.0  28.0  29.0  45.0  30.4    70.0   0.0  6.5
#
#             ff_avg  DDD_CAR_cos  DDD_CAR_sin
# tanggal
# 2023-01-01     1.0     0.000000     0.000000
# 2023-01-02     2.0     0.707107    -0.707107
# 2023-01-03     1.0     0.000000     0.000000
# 2023-01-04     1.0     0.000000     0.000000
# 2023-01-05     2.0     0.000000     0.000000
# ...            ...          ...          ...
# 2024-10-27     2.0     0.000000     0.000000
# 2024-10-28     1.0     0.000000     0.000000
# 2024-10-29     1.0     0.000000     0.000000
# 2024-10-30     1.0     0.000000     0.000000
# 2024-10-31     1.0     0.000000     0.000000
#
# [731 rows x 13 columns]

# %%
WINDOW_SIZE = 7
HORIZON = 7

scaler_x = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

# %%
# train = 92
# val   = 4
# test  = 4
# feats = polutan only

features = ['pm10', 'pm25', 'so2', 'co', 'o3', 'no2']

targets = ['pm25']

data_x = data[features]
data_y = data[targets]

data_x_scaled = scaler_x.fit_transform(data_x)
data_y_scaled = scaler_y.fit_transform(data_y)

X = []
y = []

for i in range(len(data) - WINDOW_SIZE - HORIZON + 1):
    X.append(data_x_scaled[i:i+WINDOW_SIZE])
    y.append(data_y_scaled[i+WINDOW_SIZE:i+WINDOW_SIZE + HORIZON])

training_data_len = math.ceil(len(X)* 0.92)

#splitting train
x_train = X[:training_data_len]
y_train = y[:training_data_len]

# Val set
val_test_len = len(X[training_data_len:])
val_len = math.ceil(val_test_len/2)

x_val = X[training_data_len: training_data_len+val_len]
y_val = y[training_data_len: training_data_len+val_len]

# Test set
x_test = X[training_data_len+val_len: ]
y_test = y[training_data_len+val_len: ]

# Reshaping
x_train, y_train = np.array(x_train), np.array(y_train)

x_val, y_val = np.array(x_val), np.array(y_val)

x_test, y_test = np.array(x_test), np.array(y_test)

y_train = y_train.reshape((y_train.shape[0], y_train.shape[1]))
y_val = y_val.reshape((y_val.shape[0], y_val.shape[1]))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1]))

# %%
x_train.shape, x_val.shape, x_test.shape
# ((575, 7, 11), (72, 7, 11), (71, 7, 11))
# Out:
# ((661, 7, 6), (29, 7, 6), (28, 7, 6))

# %%
y_train.shape, y_val.shape, y_test.shape
# ((575, 7, 1), (72, 7, 1), (71, 7, 1))
# Out:
# ((661, 7), (29, 7), (28, 7))

# %%
y_train
# Out:
# array([[0.34821429, 0.25892857, 0.30357143, ..., 0.52678571, 0.60714286,
#         0.53571429],
#        [0.25892857, 0.30357143, 0.49107143, ..., 0.60714286, 0.53571429,
#         0.41964286],
#        [0.30357143, 0.49107143, 0.52678571, ..., 0.53571429, 0.41964286,
#         0.26785714],
#        ...,
#        [0.50892857, 0.22321429, 0.32142857, ..., 0.625     , 0.60714286,
#         0.40178571],
#        [0.22321429, 0.32142857, 0.38392857, ..., 0.60714286, 0.40178571,
#         0.61607143],
#        [0.32142857, 0.38392857, 0.625     , ..., 0.40178571, 0.61607143,
#         0.46428571]])

# %%
scaler_y.inverse_transform(y_train)
# Out:
# array([[49., 39., 44., ..., 69., 78., 70.],
#        [39., 44., 65., ..., 78., 70., 57.],
#        [44., 65., 69., ..., 70., 57., 40.],
#        ...,
#        [67., 35., 46., ..., 80., 78., 55.],
#        [35., 46., 53., ..., 78., 55., 79.],
#        [46., 53., 80., ..., 55., 79., 62.]])

# %% [markdown]
# # Define Evaluate Error

# %%
from math import sqrt
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# MASE implemented courtesy of sktime - https://github.com/alan-turing-institute/sktime/blob/ee7a06843a44f4aaec7582d847e36073a9ab0566/sktime/performance_metrics/forecasting/_functions.py#L16
# def mean_absolute_scaled_error(y_true, y_pred):
#   """
#   Implement MASE (assuming no seasonality of data).
#   """
#   mae = tf.reduce_mean(tf.abs(y_true - y_pred))

#   # Find MAE of naive forecast (no seasonality)
#   mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1])) # our seasonality is 1 day (hence the shifting of 1 day)

#   return mae / mae_naive_no_season

def mean_absolute_percentage_error(y_true, y_pred):
  y_true, y_pred = np.array(y_true), np.array(y_pred)
  return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def evaluate_preds(y_true, y_pred):
  # Make sure float32 (for metric calculations)
  # y_true = tf.cast(y_true, dtype=tf.float32)
  # y_pred = tf.cast(y_pred, dtype=tf.float32)

  # Calculate various metrics
  mape = mean_absolute_percentage_error(y_true, y_pred)

  y_pred = y_pred.reshape(y_pred.shape[0], -1)
  y_true = y_true.reshape(y_true.shape[0], -1)

  mae = mean_absolute_error(y_true, y_pred)
  mse = mean_squared_error(y_true, y_pred) # puts and emphasis on outliers (all errors get squared)
  rmse = sqrt(mse)
  # mase = mean_absolute_scaled_error(y_true, y_pred)
  # print(mae, mse, rmse, mape, mase)

  return {
          "Mean Squared Error: ": mse,
          "Mean Absolute Error: ": mae,
          "Root Mean Absolute Error: ": rmse,
          "Mean Absolute Percentage Error: ": mape
          # "mase": mase.numpy()
          }

# %% [markdown]
# # CNN Only

# %% [markdown]
# ## model 1 (64)

# %%
lr = 0.0003

model_cnn_1 = Sequential()
model_cnn_1.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_1.add(Flatten())
model_cnn_1.add(Dense(7))
model_cnn_1.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_1.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 7, 64)          │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 448)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 7)              │         3,143 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,591 (14.03 KB)
#  Trainable params: 3,591 (14.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_1.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.1583 - mean_absolute_error: 0.3491 - mean_absolute_percentage_error: 62.3506 - root_mean_squared_error: 0.3948 - val_loss: 0.0605 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 18052466.0000 - val_root_mean_squared_error: 0.2460
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0300 - mean_absolute_error: 0.1334 - mean_absolute_percentage_error: 35.2644 - root_mean_squared_error: 0.1732 - val_loss: 0.0587 - val_mean_absolute_error: 0.1971 - val_mean_absolute_percentage_error: 17601498.0000 - val_root_mean_squared_error: 0.2423
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0255 - mean_absolute_error: 0.1246 - mean_absolute_percentage_error: 32.2389 - root_mean_squared_error: 0.1597 - val_loss: 0.0567 - val_mean_absolute_error: 0.1976 - val_mean_absolute_percentage_error: 16690315.0000 - val_root_mean_squared_error: 0.2382
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0223 - mean_absolute_error: 0.1155 - mean_absolute_percentage_error: 29.6008 - root_mean_squared_error: 0.1494 - val_loss: 0.0562 - val_mean_absolute_error: 0.1954 - val_mean_absolute_percentage_error: 17241568.0000 - val_root_mean_squared_error: 0.2370
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0226 - mean_absolute_error: 0.1170 - mean_absolute_percentage_error: 30.0772 - root_mean_squared_error: 0.1502 - val_loss: 0.0568 - val_mean_absolute_error: 0.1976 - val_mean_absolute_percentage_error: 16754570.0000 - val_root_mean_squared_error: 0.2383
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0213 - mean_absolute_error: 0.1133 - mean_absolute_percentage_error: 27.9893 - root_mean_squared_error: 0.1460 - val_loss: 0.0571 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 16719596.0000 - val_root_mean_squared_error: 0.2389
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0200 - mean_absolute_error: 0.1101 - mean_absolute_percentage_error: 28.4328 - root_mean_squared_error: 0.1414 - val_loss: 0.0580 - val_mean_absolute_error: 0.2008 - val_mean_absolute_percentage_error: 16541153.0000 - val_root_mean_squared_error: 0.2408
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0192 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 26.9938 - root_mean_squared_error: 0.1385 - val_loss: 0.0592 - val_mean_absolute_error: 0.2044 - val_mean_absolute_percentage_error: 16360196.0000 - val_root_mean_squared_error: 0.2434
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0201 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 27.7588 - root_mean_squared_error: 0.1416 - val_loss: 0.0604 - val_mean_absolute_error: 0.2075 - val_mean_absolute_percentage_error: 15983097.0000 - val_root_mean_squared_error: 0.2459
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0197 - mean_absolute_error: 0.1092 - mean_absolute_percentage_error: 27.3248 - root_mean_squared_error: 0.1404 - val_loss: 0.0610 - val_mean_absolute_error: 0.2092 - val_mean_absolute_percentage_error: 15893310.0000 - val_root_mean_squared_error: 0.2470
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0199 - mean_absolute_error: 0.1100 - mean_absolute_percentage_error: 28.6139 - root_mean_squared_error: 0.1410 - val_loss: 0.0605 - val_mean_absolute_error: 0.2074 - val_mean_absolute_percentage_error: 16328506.0000 - val_root_mean_squared_error: 0.2459
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0189 - mean_absolute_error: 0.1064 - mean_absolute_percentage_error: 26.8134 - root_mean_squared_error: 0.1373 - val_loss: 0.0624 - val_mean_absolute_error: 0.2125 - val_mean_absolute_percentage_error: 15539891.0000 - val_root_mean_squared_error: 0.2499
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0187 - mean_absolute_error: 0.1069 - mean_absolute_percentage_error: 26.0751 - root_mean_squared_error: 0.1369 - val_loss: 0.0644 - val_mean_absolute_error: 0.2161 - val_mean_absolute_percentage_error: 15164732.0000 - val_root_mean_squared_error: 0.2537
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0195 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 26.3508 - root_mean_squared_error: 0.1397 - val_loss: 0.0629 - val_mean_absolute_error: 0.2128 - val_mean_absolute_percentage_error: 15675151.0000 - val_root_mean_squared_error: 0.2507
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0181 - mean_absolute_error: 0.1048 - mean_absolute_percentage_error: 26.9537 - root_mean_squared_error: 0.1345 - val_loss: 0.0634 - val_mean_absolute_error: 0.2143 - val_mean_absolute_percentage_error: 15651306.0000 - val_root_mean_squared_error: 0.2517
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0188 - mean_absolute_error: 0.1069 - mean_absolute_percentage_error: 27.2072 - root_mean_squared_error: 0.1369 - val_loss: 0.0629 - val_mean_absolute_error: 0.2138 - val_mean_absolute_percentage_error: 15981079.0000 - val_root_mean_squared_error: 0.2508
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0175 - mean_absolute_error: 0.1026 - mean_absolute_percentage_error: 26.2272 - root_mean_squared_error: 0.1321 - val_loss: 0.0632 - val_mean_absolute_error: 0.2139 - val_mean_absolute_percentage_error: 16041749.0000 - val_root_mean_squared_error: 0.2514
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0180 - mean_absolute_error: 0.1044 - mean_absolute_percentage_error: 26.5630 - root_mean_squared_error: 0.1341 - val_loss: 0.0629 - val_mean_absolute_error: 0.2132 - val_mean_absolute_percentage_error: 16424138.0000 - val_root_mean_squared_error: 0.2509
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0186 - mean_absolute_error: 0.1067 - mean_absolute_percentage_error: 26.9155 - root_mean_squared_error: 0.1365 - val_loss: 0.0636 - val_mean_absolute_error: 0.2154 - val_mean_absolute_percentage_error: 16049205.0000 - val_root_mean_squared_error: 0.2523
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0170 - mean_absolute_error: 0.1014 - mean_absolute_percentage_error: 24.6406 - root_mean_squared_error: 0.1305 - val_loss: 0.0649 - val_mean_absolute_error: 0.2175 - val_mean_absolute_percentage_error: 15669102.0000 - val_root_mean_squared_error: 0.2547

# %%
y_pred = model_cnn_1.predict(x_test)
evaluation_cnn_1 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_1
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# {'Mean Squared Error: ': np.float64(308.99187142125805),
#  'Mean Absolute Error: ': np.float64(13.681984979279187),
#  'Root Mean Absolute Error: ': 17.578164620382246,
#  'Mean Absolute Percentage Error: ': np.float64(24.58539616498866)}

# %%
loss, mae, mape, rmse = model_cnn_1.evaluate(x_test, y_test)
print("model cnn 1")
print("Mean Absolute Error:", mae)
print("Mean Square Error:", loss)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0246 - mean_absolute_error: 0.1222 - mean_absolute_percentage_error: 31.0923 - root_mean_squared_error: 0.1569
# model cnn 1
# Mean Absolute Error: 0.12216057628393173
# Mean Square Error: 0.024632642045617104
# Mean Absolute Percentage Error: 31.092294692993164
# Root Mean Squared Error: 0.15694789588451385

# %% [markdown]
# ## model 2 (128 & 32)
#  erornya tinggi

# %%
lr = 0.0003

model_cnn_2 = Sequential()
model_cnn_2.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_2.add(Conv1D(filters=32, kernel_size=1, activation='relu'))
model_cnn_2.add(Flatten())
model_cnn_2.add(Dense(7))
model_cnn_2.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_2.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_1 (Conv1D)               │ (None, 7, 128)         │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 7, 32)          │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,599 (25.78 KB)
#  Trainable params: 6,599 (25.78 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_2.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.2313 - mean_absolute_error: 0.4330 - mean_absolute_percentage_error: 76.6534 - root_mean_squared_error: 0.4771 - val_loss: 0.0687 - val_mean_absolute_error: 0.2127 - val_mean_absolute_percentage_error: 17182568.0000 - val_root_mean_squared_error: 0.2620
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0372 - mean_absolute_error: 0.1514 - mean_absolute_percentage_error: 37.7572 - root_mean_squared_error: 0.1927 - val_loss: 0.0599 - val_mean_absolute_error: 0.2030 - val_mean_absolute_percentage_error: 15622445.0000 - val_root_mean_squared_error: 0.2448
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0262 - mean_absolute_error: 0.1298 - mean_absolute_percentage_error: 30.1337 - root_mean_squared_error: 0.1618 - val_loss: 0.0570 - val_mean_absolute_error: 0.1972 - val_mean_absolute_percentage_error: 16886262.0000 - val_root_mean_squared_error: 0.2387
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0228 - mean_absolute_error: 0.1163 - mean_absolute_percentage_error: 32.1284 - root_mean_squared_error: 0.1509 - val_loss: 0.0567 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 15947112.0000 - val_root_mean_squared_error: 0.2382
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0232 - mean_absolute_error: 0.1205 - mean_absolute_percentage_error: 29.8489 - root_mean_squared_error: 0.1524 - val_loss: 0.0557 - val_mean_absolute_error: 0.1941 - val_mean_absolute_percentage_error: 16721626.0000 - val_root_mean_squared_error: 0.2360
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0225 - mean_absolute_error: 0.1166 - mean_absolute_percentage_error: 30.2601 - root_mean_squared_error: 0.1500 - val_loss: 0.0564 - val_mean_absolute_error: 0.1959 - val_mean_absolute_percentage_error: 16209673.0000 - val_root_mean_squared_error: 0.2375
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0213 - mean_absolute_error: 0.1138 - mean_absolute_percentage_error: 28.0346 - root_mean_squared_error: 0.1459 - val_loss: 0.0575 - val_mean_absolute_error: 0.1978 - val_mean_absolute_percentage_error: 15903510.0000 - val_root_mean_squared_error: 0.2397
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0222 - mean_absolute_error: 0.1168 - mean_absolute_percentage_error: 29.0507 - root_mean_squared_error: 0.1490 - val_loss: 0.0564 - val_mean_absolute_error: 0.1955 - val_mean_absolute_percentage_error: 16436526.0000 - val_root_mean_squared_error: 0.2374
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0197 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 28.0616 - root_mean_squared_error: 0.1400 - val_loss: 0.0578 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 15857450.0000 - val_root_mean_squared_error: 0.2404
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0222 - mean_absolute_error: 0.1162 - mean_absolute_percentage_error: 32.0962 - root_mean_squared_error: 0.1489 - val_loss: 0.0570 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 16336419.0000 - val_root_mean_squared_error: 0.2388
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0207 - mean_absolute_error: 0.1129 - mean_absolute_percentage_error: 28.1892 - root_mean_squared_error: 0.1440 - val_loss: 0.0562 - val_mean_absolute_error: 0.1959 - val_mean_absolute_percentage_error: 16296540.0000 - val_root_mean_squared_error: 0.2370
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0197 - mean_absolute_error: 0.1089 - mean_absolute_percentage_error: 27.7026 - root_mean_squared_error: 0.1402 - val_loss: 0.0601 - val_mean_absolute_error: 0.2037 - val_mean_absolute_percentage_error: 15307394.0000 - val_root_mean_squared_error: 0.2452
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0193 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 27.8931 - root_mean_squared_error: 0.1388 - val_loss: 0.0581 - val_mean_absolute_error: 0.1991 - val_mean_absolute_percentage_error: 15865514.0000 - val_root_mean_squared_error: 0.2409
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0200 - mean_absolute_error: 0.1104 - mean_absolute_percentage_error: 28.6226 - root_mean_squared_error: 0.1414 - val_loss: 0.0563 - val_mean_absolute_error: 0.1964 - val_mean_absolute_percentage_error: 16489533.0000 - val_root_mean_squared_error: 0.2373
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0194 - mean_absolute_error: 0.1086 - mean_absolute_percentage_error: 28.4429 - root_mean_squared_error: 0.1393 - val_loss: 0.0569 - val_mean_absolute_error: 0.1975 - val_mean_absolute_percentage_error: 16251860.0000 - val_root_mean_squared_error: 0.2385
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0186 - mean_absolute_error: 0.1056 - mean_absolute_percentage_error: 27.3904 - root_mean_squared_error: 0.1365 - val_loss: 0.0569 - val_mean_absolute_error: 0.1982 - val_mean_absolute_percentage_error: 15990777.0000 - val_root_mean_squared_error: 0.2386
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0194 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 28.0323 - root_mean_squared_error: 0.1393 - val_loss: 0.0582 - val_mean_absolute_error: 0.2004 - val_mean_absolute_percentage_error: 15792011.0000 - val_root_mean_squared_error: 0.2413
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0191 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 27.6956 - root_mean_squared_error: 0.1380 - val_loss: 0.0577 - val_mean_absolute_error: 0.1997 - val_mean_absolute_percentage_error: 15838592.0000 - val_root_mean_squared_error: 0.2401
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0193 - mean_absolute_error: 0.1077 - mean_absolute_percentage_error: 27.5741 - root_mean_squared_error: 0.1387 - val_loss: 0.0586 - val_mean_absolute_error: 0.2019 - val_mean_absolute_percentage_error: 15664234.0000 - val_root_mean_squared_error: 0.2422
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0178 - mean_absolute_error: 0.1039 - mean_absolute_percentage_error: 25.6984 - root_mean_squared_error: 0.1333 - val_loss: 0.0582 - val_mean_absolute_error: 0.2010 - val_mean_absolute_percentage_error: 15707422.0000 - val_root_mean_squared_error: 0.2413

# %%
y_pred = model_cnn_2.predict(x_test)

evaluation_cnn_2 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_2
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# {'Mean Squared Error: ': np.float64(308.7728270587435),
#  'Mean Absolute Error: ': np.float64(13.709325790405273),
#  'Root Mean Absolute Error: ': 17.571932934618875,
#  'Mean Absolute Percentage Error: ': np.float64(24.22289758217828)}

# %%
loss, mae, mape, rmse = model_cnn_2.evaluate(x_test, y_test)
print("model cnn 2")
print("Mean Absolute Error:", mae)
print("Mean Square Error:", loss)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0246 - mean_absolute_error: 0.1224 - mean_absolute_percentage_error: 30.5350 - root_mean_squared_error: 0.1569
# model cnn 2
# Mean Absolute Error: 0.12240468710660934
# Mean Square Error: 0.024615181609988213
# Mean Absolute Percentage Error: 30.53500747680664
# Root Mean Squared Error: 0.15689225494861603

# %% [markdown]
# ## model 3 (64 64)

# %%
lr = 0.0003

model_cnn_3 = Sequential()
model_cnn_3.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_3.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_3.add(Flatten())
model_cnn_3.add(Dense(7))
model_cnn_3.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_3.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)               │ (None, 7, 64)          │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 7, 64)          │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 448)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │         3,143 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,751 (30.28 KB)
#  Trainable params: 7,751 (30.28 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_3.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.2732 - mean_absolute_error: 0.4739 - mean_absolute_percentage_error: 86.2499 - root_mean_squared_error: 0.5185 - val_loss: 0.0610 - val_mean_absolute_error: 0.2022 - val_mean_absolute_percentage_error: 16936624.0000 - val_root_mean_squared_error: 0.2470
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0338 - mean_absolute_error: 0.1444 - mean_absolute_percentage_error: 36.9854 - root_mean_squared_error: 0.1835 - val_loss: 0.0573 - val_mean_absolute_error: 0.1991 - val_mean_absolute_percentage_error: 15920376.0000 - val_root_mean_squared_error: 0.2394
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0255 - mean_absolute_error: 0.1264 - mean_absolute_percentage_error: 30.5112 - root_mean_squared_error: 0.1596 - val_loss: 0.0569 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 16898604.0000 - val_root_mean_squared_error: 0.2385
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0210 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 29.1093 - root_mean_squared_error: 0.1449 - val_loss: 0.0562 - val_mean_absolute_error: 0.1980 - val_mean_absolute_percentage_error: 16525101.0000 - val_root_mean_squared_error: 0.2370
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0209 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 27.3960 - root_mean_squared_error: 0.1446 - val_loss: 0.0562 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 16711840.0000 - val_root_mean_squared_error: 0.2370
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0213 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 28.1183 - root_mean_squared_error: 0.1458 - val_loss: 0.0564 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 16290216.0000 - val_root_mean_squared_error: 0.2376
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0215 - mean_absolute_error: 0.1143 - mean_absolute_percentage_error: 28.9873 - root_mean_squared_error: 0.1465 - val_loss: 0.0563 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 16538496.0000 - val_root_mean_squared_error: 0.2372
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0191 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 26.2816 - root_mean_squared_error: 0.1382 - val_loss: 0.0564 - val_mean_absolute_error: 0.1978 - val_mean_absolute_percentage_error: 16263194.0000 - val_root_mean_squared_error: 0.2374
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0213 - mean_absolute_error: 0.1132 - mean_absolute_percentage_error: 27.6613 - root_mean_squared_error: 0.1458 - val_loss: 0.0565 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 16425149.0000 - val_root_mean_squared_error: 0.2376
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0200 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 26.6451 - root_mean_squared_error: 0.1412 - val_loss: 0.0568 - val_mean_absolute_error: 0.1994 - val_mean_absolute_percentage_error: 15958868.0000 - val_root_mean_squared_error: 0.2384
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0187 - mean_absolute_error: 0.1067 - mean_absolute_percentage_error: 26.2332 - root_mean_squared_error: 0.1367 - val_loss: 0.0567 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 16202380.0000 - val_root_mean_squared_error: 0.2381
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0185 - mean_absolute_error: 0.1049 - mean_absolute_percentage_error: 26.2137 - root_mean_squared_error: 0.1358 - val_loss: 0.0567 - val_mean_absolute_error: 0.1999 - val_mean_absolute_percentage_error: 16121874.0000 - val_root_mean_squared_error: 0.2381
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0194 - mean_absolute_error: 0.1082 - mean_absolute_percentage_error: 27.0757 - root_mean_squared_error: 0.1394 - val_loss: 0.0571 - val_mean_absolute_error: 0.2012 - val_mean_absolute_percentage_error: 15852988.0000 - val_root_mean_squared_error: 0.2390
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0201 - mean_absolute_error: 0.1096 - mean_absolute_percentage_error: 27.9447 - root_mean_squared_error: 0.1419 - val_loss: 0.0567 - val_mean_absolute_error: 0.2010 - val_mean_absolute_percentage_error: 15942633.0000 - val_root_mean_squared_error: 0.2382
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0187 - mean_absolute_error: 0.1053 - mean_absolute_percentage_error: 26.9745 - root_mean_squared_error: 0.1367 - val_loss: 0.0571 - val_mean_absolute_error: 0.2017 - val_mean_absolute_percentage_error: 15590140.0000 - val_root_mean_squared_error: 0.2390
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0184 - mean_absolute_error: 0.1052 - mean_absolute_percentage_error: 26.2175 - root_mean_squared_error: 0.1356 - val_loss: 0.0578 - val_mean_absolute_error: 0.2033 - val_mean_absolute_percentage_error: 15121929.0000 - val_root_mean_squared_error: 0.2405
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0191 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 27.2650 - root_mean_squared_error: 0.1383 - val_loss: 0.0572 - val_mean_absolute_error: 0.2020 - val_mean_absolute_percentage_error: 15516945.0000 - val_root_mean_squared_error: 0.2391
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0192 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 26.5100 - root_mean_squared_error: 0.1385 - val_loss: 0.0572 - val_mean_absolute_error: 0.2024 - val_mean_absolute_percentage_error: 15472589.0000 - val_root_mean_squared_error: 0.2392
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0193 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 26.9554 - root_mean_squared_error: 0.1389 - val_loss: 0.0570 - val_mean_absolute_error: 0.2031 - val_mean_absolute_percentage_error: 15410817.0000 - val_root_mean_squared_error: 0.2388
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0181 - mean_absolute_error: 0.1042 - mean_absolute_percentage_error: 26.8437 - root_mean_squared_error: 0.1344 - val_loss: 0.0577 - val_mean_absolute_error: 0.2042 - val_mean_absolute_percentage_error: 15218638.0000 - val_root_mean_squared_error: 0.2401

# %%
y_pred = model_cnn_3.predict(x_test)

evaluation_cnn_3 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_3
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# {'Mean Squared Error: ': np.float64(323.158230720397),
#  'Mean Absolute Error: ': np.float64(14.176996386781031),
#  'Root Mean Absolute Error: ': 17.976602313017803,
#  'Mean Absolute Percentage Error: ': np.float64(25.360192021301597)}

# %%
loss, mae, mape, rmse = model_cnn_3.evaluate(x_test, y_test)
print("model cnn 3")
print("Mean Absolute Error:", mae)
print("Mean Square Error:", loss)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0258 - mean_absolute_error: 0.1266 - mean_absolute_percentage_error: 32.0247 - root_mean_squared_error: 0.1605
# model cnn 3
# Mean Absolute Error: 0.12658031284809113
# Mean Square Error: 0.025761974975466728
# Mean Absolute Percentage Error: 32.02472686767578
# Root Mean Squared Error: 0.16050536930561066

# %% [markdown]
# ## model 4 (256 64)

# %%
lr = 0.0003

model_cnn_4 = Sequential()
model_cnn_4.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_4.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_4.add(Flatten())
model_cnn_4.add(Dense(7))
model_cnn_4.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_4.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_5 (Conv1D)               │ (None, 7, 256)         │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 7, 64)          │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 448)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │         3,143 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,383 (83.53 KB)
#  Trainable params: 21,383 (83.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_4.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.1699 - mean_absolute_error: 0.3553 - mean_absolute_percentage_error: 64.8792 - root_mean_squared_error: 0.4051 - val_loss: 0.0570 - val_mean_absolute_error: 0.1920 - val_mean_absolute_percentage_error: 18386642.0000 - val_root_mean_squared_error: 0.2388
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0292 - mean_absolute_error: 0.1361 - mean_absolute_percentage_error: 34.7164 - root_mean_squared_error: 0.1709 - val_loss: 0.0534 - val_mean_absolute_error: 0.1922 - val_mean_absolute_percentage_error: 15137688.0000 - val_root_mean_squared_error: 0.2311
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0242 - mean_absolute_error: 0.1206 - mean_absolute_percentage_error: 31.4427 - root_mean_squared_error: 0.1556 - val_loss: 0.0570 - val_mean_absolute_error: 0.1988 - val_mean_absolute_percentage_error: 14233034.0000 - val_root_mean_squared_error: 0.2387
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0233 - mean_absolute_error: 0.1214 - mean_absolute_percentage_error: 28.0426 - root_mean_squared_error: 0.1526 - val_loss: 0.0529 - val_mean_absolute_error: 0.1919 - val_mean_absolute_percentage_error: 15439492.0000 - val_root_mean_squared_error: 0.2301
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0211 - mean_absolute_error: 0.1125 - mean_absolute_percentage_error: 29.2445 - root_mean_squared_error: 0.1451 - val_loss: 0.0528 - val_mean_absolute_error: 0.1927 - val_mean_absolute_percentage_error: 15533870.0000 - val_root_mean_squared_error: 0.2297
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0206 - mean_absolute_error: 0.1111 - mean_absolute_percentage_error: 29.3941 - root_mean_squared_error: 0.1436 - val_loss: 0.0542 - val_mean_absolute_error: 0.1962 - val_mean_absolute_percentage_error: 15006656.0000 - val_root_mean_squared_error: 0.2328
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0203 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 28.8588 - root_mean_squared_error: 0.1423 - val_loss: 0.0543 - val_mean_absolute_error: 0.1969 - val_mean_absolute_percentage_error: 15114957.0000 - val_root_mean_squared_error: 0.2329
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0202 - mean_absolute_error: 0.1094 - mean_absolute_percentage_error: 27.1829 - root_mean_squared_error: 0.1420 - val_loss: 0.0553 - val_mean_absolute_error: 0.1994 - val_mean_absolute_percentage_error: 14964959.0000 - val_root_mean_squared_error: 0.2352
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0205 - mean_absolute_error: 0.1101 - mean_absolute_percentage_error: 27.4363 - root_mean_squared_error: 0.1430 - val_loss: 0.0562 - val_mean_absolute_error: 0.2017 - val_mean_absolute_percentage_error: 14758307.0000 - val_root_mean_squared_error: 0.2371
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0191 - mean_absolute_error: 0.1074 - mean_absolute_percentage_error: 27.7648 - root_mean_squared_error: 0.1383 - val_loss: 0.0576 - val_mean_absolute_error: 0.2050 - val_mean_absolute_percentage_error: 14519380.0000 - val_root_mean_squared_error: 0.2400
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0187 - mean_absolute_error: 0.1067 - mean_absolute_percentage_error: 26.6423 - root_mean_squared_error: 0.1369 - val_loss: 0.0555 - val_mean_absolute_error: 0.2005 - val_mean_absolute_percentage_error: 15379058.0000 - val_root_mean_squared_error: 0.2355
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0184 - mean_absolute_error: 0.1043 - mean_absolute_percentage_error: 26.0444 - root_mean_squared_error: 0.1356 - val_loss: 0.0579 - val_mean_absolute_error: 0.2056 - val_mean_absolute_percentage_error: 14905862.0000 - val_root_mean_squared_error: 0.2405
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0184 - mean_absolute_error: 0.1050 - mean_absolute_percentage_error: 25.9268 - root_mean_squared_error: 0.1355 - val_loss: 0.0564 - val_mean_absolute_error: 0.2035 - val_mean_absolute_percentage_error: 15516804.0000 - val_root_mean_squared_error: 0.2375
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0183 - mean_absolute_error: 0.1046 - mean_absolute_percentage_error: 25.7443 - root_mean_squared_error: 0.1353 - val_loss: 0.0579 - val_mean_absolute_error: 0.2065 - val_mean_absolute_percentage_error: 15052441.0000 - val_root_mean_squared_error: 0.2407
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0172 - mean_absolute_error: 0.1011 - mean_absolute_percentage_error: 26.3580 - root_mean_squared_error: 0.1310 - val_loss: 0.0571 - val_mean_absolute_error: 0.2044 - val_mean_absolute_percentage_error: 15529652.0000 - val_root_mean_squared_error: 0.2389
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0181 - mean_absolute_error: 0.1045 - mean_absolute_percentage_error: 26.7797 - root_mean_squared_error: 0.1345 - val_loss: 0.0578 - val_mean_absolute_error: 0.2061 - val_mean_absolute_percentage_error: 15349743.0000 - val_root_mean_squared_error: 0.2405
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0163 - mean_absolute_error: 0.0986 - mean_absolute_percentage_error: 23.6782 - root_mean_squared_error: 0.1276 - val_loss: 0.0602 - val_mean_absolute_error: 0.2105 - val_mean_absolute_percentage_error: 14686453.0000 - val_root_mean_squared_error: 0.2454
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0182 - mean_absolute_error: 0.1048 - mean_absolute_percentage_error: 26.3313 - root_mean_squared_error: 0.1348 - val_loss: 0.0591 - val_mean_absolute_error: 0.2080 - val_mean_absolute_percentage_error: 15139838.0000 - val_root_mean_squared_error: 0.2430
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0169 - mean_absolute_error: 0.1006 - mean_absolute_percentage_error: 24.0327 - root_mean_squared_error: 0.1300 - val_loss: 0.0611 - val_mean_absolute_error: 0.2115 - val_mean_absolute_percentage_error: 14677387.0000 - val_root_mean_squared_error: 0.2471
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0177 - mean_absolute_error: 0.1032 - mean_absolute_percentage_error: 26.3004 - root_mean_squared_error: 0.1329 - val_loss: 0.0587 - val_mean_absolute_error: 0.2071 - val_mean_absolute_percentage_error: 15668887.0000 - val_root_mean_squared_error: 0.2422

# %%
y_pred = model_cnn_4.predict(x_test)

evaluation_cnn_4 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_4
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# {'Mean Squared Error: ': np.float64(313.0978174914591),
#  'Mean Absolute Error: ': np.float64(13.376624593929368),
#  'Root Mean Absolute Error: ': 17.694570282757905,
#  'Mean Absolute Percentage Error: ': np.float64(24.57933044941292)}

# %%
loss, mae, mape, rmse = model_cnn_4.evaluate(x_test, y_test)
print("model cnn 4")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0250 - mean_absolute_error: 0.1194 - mean_absolute_percentage_error: 31.2132 - root_mean_squared_error: 0.1580
# model cnn 4
# Mean Square Error: 0.02495996467769146
# Mean Absolute Error: 0.11943414062261581
# Mean Absolute Percentage Error: 31.213199615478516
# Root Mean Squared Error: 0.15798722207546234

# %% [markdown]
# ## model 5 (256 256)

# %%
lr = 0.0003

model_cnn_5 = Sequential()
model_cnn_5.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_5.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_5.add(Flatten())
model_cnn_5.add(Dense(7))
model_cnn_5.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_5.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_7 (Conv1D)               │ (None, 7, 256)         │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 7, 256)         │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 1792)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 7)              │        12,551 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,135 (313.03 KB)
#  Trainable params: 80,135 (313.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_5.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.1417 - mean_absolute_error: 0.3103 - mean_absolute_percentage_error: 60.4543 - root_mean_squared_error: 0.3668 - val_loss: 0.0678 - val_mean_absolute_error: 0.2205 - val_mean_absolute_percentage_error: 12332160.0000 - val_root_mean_squared_error: 0.2604
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0285 - mean_absolute_error: 0.1373 - mean_absolute_percentage_error: 29.9086 - root_mean_squared_error: 0.1687 - val_loss: 0.0551 - val_mean_absolute_error: 0.1987 - val_mean_absolute_percentage_error: 14878694.0000 - val_root_mean_squared_error: 0.2348
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0214 - mean_absolute_error: 0.1154 - mean_absolute_percentage_error: 26.6933 - root_mean_squared_error: 0.1461 - val_loss: 0.0542 - val_mean_absolute_error: 0.1966 - val_mean_absolute_percentage_error: 15635992.0000 - val_root_mean_squared_error: 0.2328
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0195 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 27.1027 - root_mean_squared_error: 0.1395 - val_loss: 0.0544 - val_mean_absolute_error: 0.1974 - val_mean_absolute_percentage_error: 15400520.0000 - val_root_mean_squared_error: 0.2332
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0207 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 30.1087 - root_mean_squared_error: 0.1436 - val_loss: 0.0549 - val_mean_absolute_error: 0.1987 - val_mean_absolute_percentage_error: 15425213.0000 - val_root_mean_squared_error: 0.2342
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0196 - mean_absolute_error: 0.1082 - mean_absolute_percentage_error: 26.9252 - root_mean_squared_error: 0.1401 - val_loss: 0.0553 - val_mean_absolute_error: 0.2001 - val_mean_absolute_percentage_error: 15511350.0000 - val_root_mean_squared_error: 0.2352
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0197 - mean_absolute_error: 0.1082 - mean_absolute_percentage_error: 28.0995 - root_mean_squared_error: 0.1404 - val_loss: 0.0570 - val_mean_absolute_error: 0.2039 - val_mean_absolute_percentage_error: 14697818.0000 - val_root_mean_squared_error: 0.2387
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0195 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 28.2399 - root_mean_squared_error: 0.1397 - val_loss: 0.0594 - val_mean_absolute_error: 0.2072 - val_mean_absolute_percentage_error: 14416001.0000 - val_root_mean_squared_error: 0.2436
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0186 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 26.9359 - root_mean_squared_error: 0.1363 - val_loss: 0.0590 - val_mean_absolute_error: 0.2083 - val_mean_absolute_percentage_error: 14560607.0000 - val_root_mean_squared_error: 0.2429
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0190 - mean_absolute_error: 0.1071 - mean_absolute_percentage_error: 26.6977 - root_mean_squared_error: 0.1376 - val_loss: 0.0587 - val_mean_absolute_error: 0.2076 - val_mean_absolute_percentage_error: 15104446.0000 - val_root_mean_squared_error: 0.2423
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0177 - mean_absolute_error: 0.1027 - mean_absolute_percentage_error: 25.4954 - root_mean_squared_error: 0.1331 - val_loss: 0.0595 - val_mean_absolute_error: 0.2083 - val_mean_absolute_percentage_error: 15328332.0000 - val_root_mean_squared_error: 0.2440
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0179 - mean_absolute_error: 0.1045 - mean_absolute_percentage_error: 27.7402 - root_mean_squared_error: 0.1339 - val_loss: 0.0603 - val_mean_absolute_error: 0.2108 - val_mean_absolute_percentage_error: 15297110.0000 - val_root_mean_squared_error: 0.2456
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0178 - mean_absolute_error: 0.1038 - mean_absolute_percentage_error: 25.5159 - root_mean_squared_error: 0.1335 - val_loss: 0.0618 - val_mean_absolute_error: 0.2127 - val_mean_absolute_percentage_error: 15631819.0000 - val_root_mean_squared_error: 0.2486
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0168 - mean_absolute_error: 0.1000 - mean_absolute_percentage_error: 24.1438 - root_mean_squared_error: 0.1298 - val_loss: 0.0634 - val_mean_absolute_error: 0.2156 - val_mean_absolute_percentage_error: 14878542.0000 - val_root_mean_squared_error: 0.2517
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0173 - mean_absolute_error: 0.1024 - mean_absolute_percentage_error: 25.9139 - root_mean_squared_error: 0.1316 - val_loss: 0.0627 - val_mean_absolute_error: 0.2147 - val_mean_absolute_percentage_error: 15531647.0000 - val_root_mean_squared_error: 0.2503
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0168 - mean_absolute_error: 0.1014 - mean_absolute_percentage_error: 24.6129 - root_mean_squared_error: 0.1295 - val_loss: 0.0654 - val_mean_absolute_error: 0.2204 - val_mean_absolute_percentage_error: 14673928.0000 - val_root_mean_squared_error: 0.2558
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0167 - mean_absolute_error: 0.1006 - mean_absolute_percentage_error: 24.0328 - root_mean_squared_error: 0.1292 - val_loss: 0.0662 - val_mean_absolute_error: 0.2194 - val_mean_absolute_percentage_error: 15167701.0000 - val_root_mean_squared_error: 0.2572
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0168 - mean_absolute_error: 0.1019 - mean_absolute_percentage_error: 25.5924 - root_mean_squared_error: 0.1297 - val_loss: 0.0662 - val_mean_absolute_error: 0.2211 - val_mean_absolute_percentage_error: 14875223.0000 - val_root_mean_squared_error: 0.2572
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0165 - mean_absolute_error: 0.0998 - mean_absolute_percentage_error: 24.8873 - root_mean_squared_error: 0.1286 - val_loss: 0.0674 - val_mean_absolute_error: 0.2221 - val_mean_absolute_percentage_error: 14956441.0000 - val_root_mean_squared_error: 0.2596
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0167 - mean_absolute_error: 0.1010 - mean_absolute_percentage_error: 25.9322 - root_mean_squared_error: 0.1293 - val_loss: 0.0647 - val_mean_absolute_error: 0.2167 - val_mean_absolute_percentage_error: 16545503.0000 - val_root_mean_squared_error: 0.2543

# %%
y_pred = model_cnn_5.predict(x_test)
evaluation_cnn_5 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_5
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a0094dd6520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# {'Mean Squared Error: ': np.float64(355.96332819572086),
#  'Mean Absolute Error: ': np.float64(14.09022483047174),
#  'Root Mean Absolute Error: ': 18.86699043821565,
#  'Mean Absolute Percentage Error: ': np.float64(26.77810370094048)}

# %%
loss, mae, mape, rmse = model_cnn_5.evaluate(x_test, y_test)
print("model cnn 5")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0284 - mean_absolute_error: 0.1258 - mean_absolute_percentage_error: 34.1703 - root_mean_squared_error: 0.1685
# model cnn 5
# Mean Square Error: 0.028377173468470573
# Mean Absolute Error: 0.1258055716753006
# Mean Absolute Percentage Error: 34.170265197753906
# Root Mean Squared Error: 0.16845525801181793

# %% [markdown]
# ## model 6 (128 256)

# %%
lr = 0.0003

model_cnn_6 = Sequential()
model_cnn_6.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_6.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_6.add(Flatten())
model_cnn_6.add(Dense(7))
model_cnn_6.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_6.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_9 (Conv1D)               │ (None, 7, 128)         │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 7, 256)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 1792)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 7)              │        12,551 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 46,471 (181.53 KB)
#  Trainable params: 46,471 (181.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_6.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1791 - mean_absolute_error: 0.3525 - mean_absolute_percentage_error: 66.5076 - root_mean_squared_error: 0.4126 - val_loss: 0.0572 - val_mean_absolute_error: 0.2035 - val_mean_absolute_percentage_error: 14315307.0000 - val_root_mean_squared_error: 0.2392
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0290 - mean_absolute_error: 0.1372 - mean_absolute_percentage_error: 30.0903 - root_mean_squared_error: 0.1702 - val_loss: 0.0559 - val_mean_absolute_error: 0.1951 - val_mean_absolute_percentage_error: 17221068.0000 - val_root_mean_squared_error: 0.2364
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0225 - mean_absolute_error: 0.1155 - mean_absolute_percentage_error: 29.2166 - root_mean_squared_error: 0.1500 - val_loss: 0.0558 - val_mean_absolute_error: 0.1989 - val_mean_absolute_percentage_error: 14718574.0000 - val_root_mean_squared_error: 0.2362
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0200 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 28.3555 - root_mean_squared_error: 0.1416 - val_loss: 0.0550 - val_mean_absolute_error: 0.1983 - val_mean_absolute_percentage_error: 15176781.0000 - val_root_mean_squared_error: 0.2345
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0198 - mean_absolute_error: 0.1098 - mean_absolute_percentage_error: 27.2091 - root_mean_squared_error: 0.1408 - val_loss: 0.0569 - val_mean_absolute_error: 0.2027 - val_mean_absolute_percentage_error: 14615943.0000 - val_root_mean_squared_error: 0.2384
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0193 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 27.3778 - root_mean_squared_error: 0.1391 - val_loss: 0.0574 - val_mean_absolute_error: 0.2039 - val_mean_absolute_percentage_error: 14618354.0000 - val_root_mean_squared_error: 0.2395
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0185 - mean_absolute_error: 0.1057 - mean_absolute_percentage_error: 26.7865 - root_mean_squared_error: 0.1358 - val_loss: 0.0557 - val_mean_absolute_error: 0.2015 - val_mean_absolute_percentage_error: 15007556.0000 - val_root_mean_squared_error: 0.2360
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0184 - mean_absolute_error: 0.1057 - mean_absolute_percentage_error: 26.8657 - root_mean_squared_error: 0.1356 - val_loss: 0.0565 - val_mean_absolute_error: 0.2037 - val_mean_absolute_percentage_error: 15168198.0000 - val_root_mean_squared_error: 0.2378
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0194 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 27.4228 - root_mean_squared_error: 0.1391 - val_loss: 0.0583 - val_mean_absolute_error: 0.2062 - val_mean_absolute_percentage_error: 14513801.0000 - val_root_mean_squared_error: 0.2414
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0181 - mean_absolute_error: 0.1047 - mean_absolute_percentage_error: 25.3692 - root_mean_squared_error: 0.1344 - val_loss: 0.0573 - val_mean_absolute_error: 0.2052 - val_mean_absolute_percentage_error: 15192344.0000 - val_root_mean_squared_error: 0.2394
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0171 - mean_absolute_error: 0.1018 - mean_absolute_percentage_error: 25.9557 - root_mean_squared_error: 0.1307 - val_loss: 0.0577 - val_mean_absolute_error: 0.2050 - val_mean_absolute_percentage_error: 15016402.0000 - val_root_mean_squared_error: 0.2402
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0176 - mean_absolute_error: 0.1027 - mean_absolute_percentage_error: 25.5291 - root_mean_squared_error: 0.1327 - val_loss: 0.0587 - val_mean_absolute_error: 0.2065 - val_mean_absolute_percentage_error: 15082677.0000 - val_root_mean_squared_error: 0.2422
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0182 - mean_absolute_error: 0.1053 - mean_absolute_percentage_error: 25.5370 - root_mean_squared_error: 0.1348 - val_loss: 0.0588 - val_mean_absolute_error: 0.2077 - val_mean_absolute_percentage_error: 14913619.0000 - val_root_mean_squared_error: 0.2426
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0177 - mean_absolute_error: 0.1028 - mean_absolute_percentage_error: 25.3015 - root_mean_squared_error: 0.1330 - val_loss: 0.0583 - val_mean_absolute_error: 0.2072 - val_mean_absolute_percentage_error: 15302208.0000 - val_root_mean_squared_error: 0.2415
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0170 - mean_absolute_error: 0.1007 - mean_absolute_percentage_error: 25.2300 - root_mean_squared_error: 0.1304 - val_loss: 0.0614 - val_mean_absolute_error: 0.2112 - val_mean_absolute_percentage_error: 14129804.0000 - val_root_mean_squared_error: 0.2478
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0172 - mean_absolute_error: 0.1027 - mean_absolute_percentage_error: 24.9074 - root_mean_squared_error: 0.1310 - val_loss: 0.0590 - val_mean_absolute_error: 0.2076 - val_mean_absolute_percentage_error: 15283711.0000 - val_root_mean_squared_error: 0.2430
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0177 - mean_absolute_error: 0.1029 - mean_absolute_percentage_error: 25.2695 - root_mean_squared_error: 0.1329 - val_loss: 0.0634 - val_mean_absolute_error: 0.2138 - val_mean_absolute_percentage_error: 13746033.0000 - val_root_mean_squared_error: 0.2518
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0173 - mean_absolute_error: 0.1026 - mean_absolute_percentage_error: 25.3734 - root_mean_squared_error: 0.1317 - val_loss: 0.0591 - val_mean_absolute_error: 0.2076 - val_mean_absolute_percentage_error: 15562223.0000 - val_root_mean_squared_error: 0.2430
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0179 - mean_absolute_error: 0.1046 - mean_absolute_percentage_error: 27.8970 - root_mean_squared_error: 0.1337 - val_loss: 0.0624 - val_mean_absolute_error: 0.2133 - val_mean_absolute_percentage_error: 13772672.0000 - val_root_mean_squared_error: 0.2498
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0168 - mean_absolute_error: 0.1011 - mean_absolute_percentage_error: 24.3740 - root_mean_squared_error: 0.1294 - val_loss: 0.0601 - val_mean_absolute_error: 0.2093 - val_mean_absolute_percentage_error: 14878068.0000 - val_root_mean_squared_error: 0.2451

# %%
y_pred = model_cnn_6.predict(x_test)
evaluation_cnn_6 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_6
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a0094ab34c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# {'Mean Squared Error: ': np.float64(297.0202223430667),
#  'Mean Absolute Error: ': np.float64(13.155551307055415),
#  'Root Mean Absolute Error: ': 17.23427463930718,
#  'Mean Absolute Percentage Error: ': np.float64(24.11833917255041)}

# %%
# y_pred = model_cnn_6.predict(x_test)
loss, mae, mape, rmse = model_cnn_6.evaluate(x_test, y_test)
print("model cnn 6")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0237 - mean_absolute_error: 0.1175 - mean_absolute_percentage_error: 30.6376 - root_mean_squared_error: 0.1539
# model cnn 6
# Mean Square Error: 0.023678269237279892
# Mean Absolute Error: 0.11746027320623398
# Mean Absolute Percentage Error: 30.63763999938965
# Root Mean Squared Error: 0.15387745201587677

# %% [markdown]
# ## model 7 (256 128)

# %%
lr = 0.0003

model_cnn_7 = Sequential()
model_cnn_7.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_7.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_7.add(Flatten())
model_cnn_7.add(Dense(7))
model_cnn_7.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_7.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_11 (Conv1D)              │ (None, 7, 256)         │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_12 (Conv1D)              │ (None, 7, 128)         │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 896)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 7)              │         6,279 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,967 (160.03 KB)
#  Trainable params: 40,967 (160.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_7.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.1958 - mean_absolute_error: 0.3777 - mean_absolute_percentage_error: 69.3925 - root_mean_squared_error: 0.4329 - val_loss: 0.0549 - val_mean_absolute_error: 0.1958 - val_mean_absolute_percentage_error: 15031019.0000 - val_root_mean_squared_error: 0.2343
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0271 - mean_absolute_error: 0.1326 - mean_absolute_percentage_error: 30.1458 - root_mean_squared_error: 0.1645 - val_loss: 0.0542 - val_mean_absolute_error: 0.1949 - val_mean_absolute_percentage_error: 15482912.0000 - val_root_mean_squared_error: 0.2329
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0221 - mean_absolute_error: 0.1147 - mean_absolute_percentage_error: 29.7923 - root_mean_squared_error: 0.1487 - val_loss: 0.0551 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 14136838.0000 - val_root_mean_squared_error: 0.2347
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0200 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 28.0498 - root_mean_squared_error: 0.1413 - val_loss: 0.0555 - val_mean_absolute_error: 0.1983 - val_mean_absolute_percentage_error: 14204781.0000 - val_root_mean_squared_error: 0.2357
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0199 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 27.9304 - root_mean_squared_error: 0.1411 - val_loss: 0.0556 - val_mean_absolute_error: 0.1998 - val_mean_absolute_percentage_error: 14461095.0000 - val_root_mean_squared_error: 0.2357
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0199 - mean_absolute_error: 0.1098 - mean_absolute_percentage_error: 28.1907 - root_mean_squared_error: 0.1412 - val_loss: 0.0560 - val_mean_absolute_error: 0.2007 - val_mean_absolute_percentage_error: 14377629.0000 - val_root_mean_squared_error: 0.2366
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0189 - mean_absolute_error: 0.1065 - mean_absolute_percentage_error: 26.9164 - root_mean_squared_error: 0.1373 - val_loss: 0.0568 - val_mean_absolute_error: 0.2020 - val_mean_absolute_percentage_error: 14285694.0000 - val_root_mean_squared_error: 0.2384
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0185 - mean_absolute_error: 0.1053 - mean_absolute_percentage_error: 25.9671 - root_mean_squared_error: 0.1359 - val_loss: 0.0567 - val_mean_absolute_error: 0.2030 - val_mean_absolute_percentage_error: 14693357.0000 - val_root_mean_squared_error: 0.2382
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0188 - mean_absolute_error: 0.1052 - mean_absolute_percentage_error: 28.3577 - root_mean_squared_error: 0.1371 - val_loss: 0.0582 - val_mean_absolute_error: 0.2063 - val_mean_absolute_percentage_error: 14282151.0000 - val_root_mean_squared_error: 0.2412
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0182 - mean_absolute_error: 0.1050 - mean_absolute_percentage_error: 26.6672 - root_mean_squared_error: 0.1349 - val_loss: 0.0578 - val_mean_absolute_error: 0.2057 - val_mean_absolute_percentage_error: 14900706.0000 - val_root_mean_squared_error: 0.2404
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0183 - mean_absolute_error: 0.1052 - mean_absolute_percentage_error: 28.5739 - root_mean_squared_error: 0.1354 - val_loss: 0.0576 - val_mean_absolute_error: 0.2052 - val_mean_absolute_percentage_error: 15082148.0000 - val_root_mean_squared_error: 0.2401
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0178 - mean_absolute_error: 0.1032 - mean_absolute_percentage_error: 25.9044 - root_mean_squared_error: 0.1333 - val_loss: 0.0610 - val_mean_absolute_error: 0.2128 - val_mean_absolute_percentage_error: 13981867.0000 - val_root_mean_squared_error: 0.2471
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0180 - mean_absolute_error: 0.1050 - mean_absolute_percentage_error: 25.7764 - root_mean_squared_error: 0.1342 - val_loss: 0.0600 - val_mean_absolute_error: 0.2109 - val_mean_absolute_percentage_error: 14594281.0000 - val_root_mean_squared_error: 0.2449
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0175 - mean_absolute_error: 0.1016 - mean_absolute_percentage_error: 26.8667 - root_mean_squared_error: 0.1322 - val_loss: 0.0595 - val_mean_absolute_error: 0.2077 - val_mean_absolute_percentage_error: 15639465.0000 - val_root_mean_squared_error: 0.2439
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0184 - mean_absolute_error: 0.1056 - mean_absolute_percentage_error: 27.2528 - root_mean_squared_error: 0.1356 - val_loss: 0.0618 - val_mean_absolute_error: 0.2144 - val_mean_absolute_percentage_error: 14419558.0000 - val_root_mean_squared_error: 0.2486
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0173 - mean_absolute_error: 0.1019 - mean_absolute_percentage_error: 25.7652 - root_mean_squared_error: 0.1316 - val_loss: 0.0625 - val_mean_absolute_error: 0.2155 - val_mean_absolute_percentage_error: 14704121.0000 - val_root_mean_squared_error: 0.2501
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0164 - mean_absolute_error: 0.0991 - mean_absolute_percentage_error: 25.0488 - root_mean_squared_error: 0.1280 - val_loss: 0.0614 - val_mean_absolute_error: 0.2129 - val_mean_absolute_percentage_error: 15157270.0000 - val_root_mean_squared_error: 0.2479
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0171 - mean_absolute_error: 0.1019 - mean_absolute_percentage_error: 24.9686 - root_mean_squared_error: 0.1308 - val_loss: 0.0646 - val_mean_absolute_error: 0.2193 - val_mean_absolute_percentage_error: 14600408.0000 - val_root_mean_squared_error: 0.2541
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0168 - mean_absolute_error: 0.1001 - mean_absolute_percentage_error: 25.3822 - root_mean_squared_error: 0.1297 - val_loss: 0.0648 - val_mean_absolute_error: 0.2192 - val_mean_absolute_percentage_error: 13862922.0000 - val_root_mean_squared_error: 0.2545
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0177 - mean_absolute_error: 0.1036 - mean_absolute_percentage_error: 26.1858 - root_mean_squared_error: 0.1330 - val_loss: 0.0654 - val_mean_absolute_error: 0.2205 - val_mean_absolute_percentage_error: 14606682.0000 - val_root_mean_squared_error: 0.2557

# %%
y_pred = model_cnn_7.predict(x_test)
evaluation_cnn_7 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_7
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# {'Mean Squared Error: ': np.float64(356.9247375561596),
#  'Mean Absolute Error: ': np.float64(14.048584607182718),
#  'Root Mean Absolute Error: ': 18.89245186724475,
#  'Mean Absolute Percentage Error: ': np.float64(26.568739400143286)}

# %%
# y_pred = model_cnn_7.predict(x_test)
loss, mae, mape, rmse = model_cnn_7.evaluate(x_test, y_test)
print("model cnn 7")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0285 - mean_absolute_error: 0.1254 - mean_absolute_percentage_error: 33.8671 - root_mean_squared_error: 0.1687
# model cnn 7
# Mean Square Error: 0.028453821316361427
# Mean Absolute Error: 0.1254337877035141
# Mean Absolute Percentage Error: 33.867061614990234
# Root Mean Squared Error: 0.16868260502815247

# %% [markdown]
# ## model 8 (512 256)

# %%
lr = 0.0003

model_cnn_8 = Sequential()
model_cnn_8.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_8.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_8.add(Flatten())
model_cnn_8.add(Dense(7))
model_cnn_8.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_8.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_13 (Conv1D)              │ (None, 7, 512)         │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_14 (Conv1D)              │ (None, 7, 256)         │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 1792)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 7)              │        12,551 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 147,463 (576.03 KB)
#  Trainable params: 147,463 (576.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_8.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.1481 - mean_absolute_error: 0.3180 - mean_absolute_percentage_error: 61.1290 - root_mean_squared_error: 0.3751 - val_loss: 0.0707 - val_mean_absolute_error: 0.2279 - val_mean_absolute_percentage_error: 12335875.0000 - val_root_mean_squared_error: 0.2660
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0275 - mean_absolute_error: 0.1318 - mean_absolute_percentage_error: 29.6426 - root_mean_squared_error: 0.1655 - val_loss: 0.0571 - val_mean_absolute_error: 0.2011 - val_mean_absolute_percentage_error: 14662526.0000 - val_root_mean_squared_error: 0.2390
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0225 - mean_absolute_error: 0.1191 - mean_absolute_percentage_error: 28.1638 - root_mean_squared_error: 0.1500 - val_loss: 0.0553 - val_mean_absolute_error: 0.1975 - val_mean_absolute_percentage_error: 15691881.0000 - val_root_mean_squared_error: 0.2352
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0197 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 26.8833 - root_mean_squared_error: 0.1404 - val_loss: 0.0562 - val_mean_absolute_error: 0.2006 - val_mean_absolute_percentage_error: 15402643.0000 - val_root_mean_squared_error: 0.2371
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0194 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 28.2606 - root_mean_squared_error: 0.1393 - val_loss: 0.0574 - val_mean_absolute_error: 0.2037 - val_mean_absolute_percentage_error: 14836932.0000 - val_root_mean_squared_error: 0.2396
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0186 - mean_absolute_error: 0.1057 - mean_absolute_percentage_error: 26.4379 - root_mean_squared_error: 0.1363 - val_loss: 0.0568 - val_mean_absolute_error: 0.2027 - val_mean_absolute_percentage_error: 15460746.0000 - val_root_mean_squared_error: 0.2384
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0186 - mean_absolute_error: 0.1055 - mean_absolute_percentage_error: 26.5314 - root_mean_squared_error: 0.1362 - val_loss: 0.0585 - val_mean_absolute_error: 0.2064 - val_mean_absolute_percentage_error: 14795470.0000 - val_root_mean_squared_error: 0.2420
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0187 - mean_absolute_error: 0.1067 - mean_absolute_percentage_error: 25.8012 - root_mean_squared_error: 0.1368 - val_loss: 0.0587 - val_mean_absolute_error: 0.2071 - val_mean_absolute_percentage_error: 14675487.0000 - val_root_mean_squared_error: 0.2424
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0185 - mean_absolute_error: 0.1057 - mean_absolute_percentage_error: 27.0893 - root_mean_squared_error: 0.1361 - val_loss: 0.0612 - val_mean_absolute_error: 0.2117 - val_mean_absolute_percentage_error: 14079409.0000 - val_root_mean_squared_error: 0.2474
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0184 - mean_absolute_error: 0.1051 - mean_absolute_percentage_error: 25.9599 - root_mean_squared_error: 0.1357 - val_loss: 0.0595 - val_mean_absolute_error: 0.2087 - val_mean_absolute_percentage_error: 14860947.0000 - val_root_mean_squared_error: 0.2440
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0178 - mean_absolute_error: 0.1044 - mean_absolute_percentage_error: 26.4513 - root_mean_squared_error: 0.1336 - val_loss: 0.0598 - val_mean_absolute_error: 0.2092 - val_mean_absolute_percentage_error: 15107646.0000 - val_root_mean_squared_error: 0.2445
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0176 - mean_absolute_error: 0.1032 - mean_absolute_percentage_error: 25.9941 - root_mean_squared_error: 0.1325 - val_loss: 0.0622 - val_mean_absolute_error: 0.2145 - val_mean_absolute_percentage_error: 14325607.0000 - val_root_mean_squared_error: 0.2494
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0177 - mean_absolute_error: 0.1036 - mean_absolute_percentage_error: 26.3516 - root_mean_squared_error: 0.1330 - val_loss: 0.0625 - val_mean_absolute_error: 0.2146 - val_mean_absolute_percentage_error: 14117537.0000 - val_root_mean_squared_error: 0.2500
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0176 - mean_absolute_error: 0.1027 - mean_absolute_percentage_error: 26.1828 - root_mean_squared_error: 0.1327 - val_loss: 0.0601 - val_mean_absolute_error: 0.2085 - val_mean_absolute_percentage_error: 16038707.0000 - val_root_mean_squared_error: 0.2451
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0173 - mean_absolute_error: 0.1040 - mean_absolute_percentage_error: 26.0322 - root_mean_squared_error: 0.1315 - val_loss: 0.0636 - val_mean_absolute_error: 0.2175 - val_mean_absolute_percentage_error: 14329578.0000 - val_root_mean_squared_error: 0.2521
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0170 - mean_absolute_error: 0.1008 - mean_absolute_percentage_error: 25.3607 - root_mean_squared_error: 0.1305 - val_loss: 0.0670 - val_mean_absolute_error: 0.2207 - val_mean_absolute_percentage_error: 13621402.0000 - val_root_mean_squared_error: 0.2589
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0175 - mean_absolute_error: 0.1034 - mean_absolute_percentage_error: 25.8537 - root_mean_squared_error: 0.1321 - val_loss: 0.0637 - val_mean_absolute_error: 0.2155 - val_mean_absolute_percentage_error: 14548721.0000 - val_root_mean_squared_error: 0.2524
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0173 - mean_absolute_error: 0.1018 - mean_absolute_percentage_error: 25.8789 - root_mean_squared_error: 0.1314 - val_loss: 0.0652 - val_mean_absolute_error: 0.2203 - val_mean_absolute_percentage_error: 14066893.0000 - val_root_mean_squared_error: 0.2553
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0167 - mean_absolute_error: 0.1004 - mean_absolute_percentage_error: 24.9908 - root_mean_squared_error: 0.1293 - val_loss: 0.0649 - val_mean_absolute_error: 0.2188 - val_mean_absolute_percentage_error: 14376174.0000 - val_root_mean_squared_error: 0.2547
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0158 - mean_absolute_error: 0.0980 - mean_absolute_percentage_error: 23.9290 - root_mean_squared_error: 0.1257 - val_loss: 0.0647 - val_mean_absolute_error: 0.2188 - val_mean_absolute_percentage_error: 15138824.0000 - val_root_mean_squared_error: 0.2544

# %%
y_pred = model_cnn_8.predict(x_test)
evaluation_cnn_8 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_8
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# {'Mean Squared Error: ': np.float64(322.05384081145246),
#  'Mean Absolute Error: ': np.float64(13.293174685264121),
#  'Root Mean Absolute Error: ': 17.945858597778276,
#  'Mean Absolute Percentage Error: ': np.float64(25.151665031733785)}

# %%
# y_pred = model_cnn_8.predict(x_test)
loss, mae, mape, rmse = model_cnn_8.evaluate(x_test, y_test)
print("model cnn 8")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0257 - mean_absolute_error: 0.1187 - mean_absolute_percentage_error: 32.1079 - root_mean_squared_error: 0.1602
# model cnn 8
# Mean Square Error: 0.025673935189843178
# Mean Absolute Error: 0.11868906021118164
# Mean Absolute Percentage Error: 32.10792922973633
# Root Mean Squared Error: 0.1602308750152588

# %% [markdown]
# ## model 9 (512 512)

# %%
lr = 0.0003

model_cnn_9 = Sequential()
model_cnn_9.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_9.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_9.add(Flatten())
model_cnn_9.add(Dense(7))
model_cnn_9.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_9.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_15 (Conv1D)              │ (None, 7, 512)         │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_16 (Conv1D)              │ (None, 7, 512)         │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 3584)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 7)              │        25,095 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 291,335 (1.11 MB)
#  Trainable params: 291,335 (1.11 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_9.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.1377 - mean_absolute_error: 0.3015 - mean_absolute_percentage_error: 58.6110 - root_mean_squared_error: 0.3598 - val_loss: 0.0590 - val_mean_absolute_error: 0.2052 - val_mean_absolute_percentage_error: 13940334.0000 - val_root_mean_squared_error: 0.2429
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0251 - mean_absolute_error: 0.1253 - mean_absolute_percentage_error: 30.7049 - root_mean_squared_error: 0.1585 - val_loss: 0.0557 - val_mean_absolute_error: 0.1992 - val_mean_absolute_percentage_error: 14832501.0000 - val_root_mean_squared_error: 0.2359
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0205 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 27.9148 - root_mean_squared_error: 0.1433 - val_loss: 0.0571 - val_mean_absolute_error: 0.2022 - val_mean_absolute_percentage_error: 14534118.0000 - val_root_mean_squared_error: 0.2390
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0198 - mean_absolute_error: 0.1093 - mean_absolute_percentage_error: 26.9752 - root_mean_squared_error: 0.1407 - val_loss: 0.0562 - val_mean_absolute_error: 0.2024 - val_mean_absolute_percentage_error: 14684262.0000 - val_root_mean_squared_error: 0.2370
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0193 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 27.7025 - root_mean_squared_error: 0.1388 - val_loss: 0.0602 - val_mean_absolute_error: 0.2095 - val_mean_absolute_percentage_error: 13785389.0000 - val_root_mean_squared_error: 0.2454
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0188 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 25.7715 - root_mean_squared_error: 0.1371 - val_loss: 0.0569 - val_mean_absolute_error: 0.2056 - val_mean_absolute_percentage_error: 14820078.0000 - val_root_mean_squared_error: 0.2386
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0181 - mean_absolute_error: 0.1029 - mean_absolute_percentage_error: 26.1810 - root_mean_squared_error: 0.1346 - val_loss: 0.0591 - val_mean_absolute_error: 0.2089 - val_mean_absolute_percentage_error: 14283019.0000 - val_root_mean_squared_error: 0.2430
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0179 - mean_absolute_error: 0.1039 - mean_absolute_percentage_error: 25.3564 - root_mean_squared_error: 0.1337 - val_loss: 0.0591 - val_mean_absolute_error: 0.2091 - val_mean_absolute_percentage_error: 14395692.0000 - val_root_mean_squared_error: 0.2431
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0182 - mean_absolute_error: 0.1052 - mean_absolute_percentage_error: 26.0897 - root_mean_squared_error: 0.1349 - val_loss: 0.0583 - val_mean_absolute_error: 0.2069 - val_mean_absolute_percentage_error: 15120774.0000 - val_root_mean_squared_error: 0.2414
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0175 - mean_absolute_error: 0.1024 - mean_absolute_percentage_error: 25.0747 - root_mean_squared_error: 0.1321 - val_loss: 0.0608 - val_mean_absolute_error: 0.2133 - val_mean_absolute_percentage_error: 14560542.0000 - val_root_mean_squared_error: 0.2465
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0176 - mean_absolute_error: 0.1031 - mean_absolute_percentage_error: 25.5528 - root_mean_squared_error: 0.1328 - val_loss: 0.0620 - val_mean_absolute_error: 0.2135 - val_mean_absolute_percentage_error: 14745902.0000 - val_root_mean_squared_error: 0.2490
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0178 - mean_absolute_error: 0.1033 - mean_absolute_percentage_error: 26.3401 - root_mean_squared_error: 0.1333 - val_loss: 0.0603 - val_mean_absolute_error: 0.2115 - val_mean_absolute_percentage_error: 15268483.0000 - val_root_mean_squared_error: 0.2456
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0175 - mean_absolute_error: 0.1022 - mean_absolute_percentage_error: 26.0969 - root_mean_squared_error: 0.1323 - val_loss: 0.0614 - val_mean_absolute_error: 0.2138 - val_mean_absolute_percentage_error: 14733729.0000 - val_root_mean_squared_error: 0.2478
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0169 - mean_absolute_error: 0.1007 - mean_absolute_percentage_error: 25.7803 - root_mean_squared_error: 0.1299 - val_loss: 0.0616 - val_mean_absolute_error: 0.2124 - val_mean_absolute_percentage_error: 15525476.0000 - val_root_mean_squared_error: 0.2483
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0167 - mean_absolute_error: 0.1008 - mean_absolute_percentage_error: 25.1993 - root_mean_squared_error: 0.1292 - val_loss: 0.0653 - val_mean_absolute_error: 0.2194 - val_mean_absolute_percentage_error: 14389387.0000 - val_root_mean_squared_error: 0.2555
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0174 - mean_absolute_error: 0.1024 - mean_absolute_percentage_error: 25.9465 - root_mean_squared_error: 0.1320 - val_loss: 0.0639 - val_mean_absolute_error: 0.2170 - val_mean_absolute_percentage_error: 15047649.0000 - val_root_mean_squared_error: 0.2527
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0163 - mean_absolute_error: 0.0995 - mean_absolute_percentage_error: 24.4275 - root_mean_squared_error: 0.1276 - val_loss: 0.0639 - val_mean_absolute_error: 0.2181 - val_mean_absolute_percentage_error: 14824024.0000 - val_root_mean_squared_error: 0.2527
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0165 - mean_absolute_error: 0.0990 - mean_absolute_percentage_error: 24.1688 - root_mean_squared_error: 0.1286 - val_loss: 0.0684 - val_mean_absolute_error: 0.2244 - val_mean_absolute_percentage_error: 13741828.0000 - val_root_mean_squared_error: 0.2616
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0154 - mean_absolute_error: 0.0970 - mean_absolute_percentage_error: 23.6490 - root_mean_squared_error: 0.1242 - val_loss: 0.0686 - val_mean_absolute_error: 0.2253 - val_mean_absolute_percentage_error: 13698354.0000 - val_root_mean_squared_error: 0.2619
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0170 - mean_absolute_error: 0.1014 - mean_absolute_percentage_error: 25.4864 - root_mean_squared_error: 0.1305 - val_loss: 0.0695 - val_mean_absolute_error: 0.2264 - val_mean_absolute_percentage_error: 13734660.0000 - val_root_mean_squared_error: 0.2636

# %%
y_pred = model_cnn_9.predict(x_test)
evaluation_cnn_9 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_9
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# {'Mean Squared Error: ': np.float64(248.00585235838474),
#  'Mean Absolute Error: ': np.float64(12.346905435834612),
#  'Root Mean Absolute Error: ': 15.748201559491951,
#  'Mean Absolute Percentage Error: ': np.float64(21.917377992616142)}

# %%
# y_pred = model_cnn_9.predict(x_test)
loss, mae, mape, rmse = model_cnn_9.evaluate(x_test, y_test)
print("model cnn 9")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0198 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 27.7148 - root_mean_squared_error: 0.1406
# model cnn 9
# Mean Square Error: 0.019770875573158264
# Mean Absolute Error: 0.11024022847414017
# Mean Absolute Percentage Error: 27.714767456054688
# Root Mean Squared Error: 0.14060895144939423

# %% [markdown]
# ## model 10 (1024 512)

# %%
lr = 0.0003

model_cnn_10 = Sequential()
model_cnn_10.add(Conv1D(filters=1024, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_10.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_10.add(Flatten())
model_cnn_10.add(Dense(7))
model_cnn_10.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_10.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_17 (Conv1D)              │ (None, 7, 1024)        │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_18 (Conv1D)              │ (None, 7, 512)         │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_9 (Flatten)             │ (None, 3584)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 7)              │        25,095 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 557,063 (2.13 MB)
#  Trainable params: 557,063 (2.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_10.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.1098 - mean_absolute_error: 0.2637 - mean_absolute_percentage_error: 53.8423 - root_mean_squared_error: 0.3210 - val_loss: 0.0534 - val_mean_absolute_error: 0.1897 - val_mean_absolute_percentage_error: 17035918.0000 - val_root_mean_squared_error: 0.2310
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.0226 - mean_absolute_error: 0.1187 - mean_absolute_percentage_error: 29.4617 - root_mean_squared_error: 0.1504 - val_loss: 0.0534 - val_mean_absolute_error: 0.1938 - val_mean_absolute_percentage_error: 15329679.0000 - val_root_mean_squared_error: 0.2311
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0199 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 26.7458 - root_mean_squared_error: 0.1412 - val_loss: 0.0564 - val_mean_absolute_error: 0.2020 - val_mean_absolute_percentage_error: 14785302.0000 - val_root_mean_squared_error: 0.2375
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.0195 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 26.9977 - root_mean_squared_error: 0.1398 - val_loss: 0.0559 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 15470756.0000 - val_root_mean_squared_error: 0.2364
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - loss: 0.0188 - mean_absolute_error: 0.1070 - mean_absolute_percentage_error: 26.8697 - root_mean_squared_error: 0.1371 - val_loss: 0.0586 - val_mean_absolute_error: 0.2071 - val_mean_absolute_percentage_error: 14322952.0000 - val_root_mean_squared_error: 0.2421
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0190 - mean_absolute_error: 0.1084 - mean_absolute_percentage_error: 26.0026 - root_mean_squared_error: 0.1378 - val_loss: 0.0573 - val_mean_absolute_error: 0.2046 - val_mean_absolute_percentage_error: 15620024.0000 - val_root_mean_squared_error: 0.2394
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.0184 - mean_absolute_error: 0.1053 - mean_absolute_percentage_error: 26.2466 - root_mean_squared_error: 0.1358 - val_loss: 0.0601 - val_mean_absolute_error: 0.2095 - val_mean_absolute_percentage_error: 14626369.0000 - val_root_mean_squared_error: 0.2452
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - loss: 0.0184 - mean_absolute_error: 0.1048 - mean_absolute_percentage_error: 26.3907 - root_mean_squared_error: 0.1357 - val_loss: 0.0604 - val_mean_absolute_error: 0.2103 - val_mean_absolute_percentage_error: 14944243.0000 - val_root_mean_squared_error: 0.2457
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0176 - mean_absolute_error: 0.1023 - mean_absolute_percentage_error: 24.7813 - root_mean_squared_error: 0.1327 - val_loss: 0.0630 - val_mean_absolute_error: 0.2143 - val_mean_absolute_percentage_error: 14083922.0000 - val_root_mean_squared_error: 0.2510
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0173 - mean_absolute_error: 0.1024 - mean_absolute_percentage_error: 25.3030 - root_mean_squared_error: 0.1315 - val_loss: 0.0605 - val_mean_absolute_error: 0.2106 - val_mean_absolute_percentage_error: 15263198.0000 - val_root_mean_squared_error: 0.2459
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0185 - mean_absolute_error: 0.1060 - mean_absolute_percentage_error: 26.9240 - root_mean_squared_error: 0.1360 - val_loss: 0.0629 - val_mean_absolute_error: 0.2149 - val_mean_absolute_percentage_error: 15718905.0000 - val_root_mean_squared_error: 0.2507
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0168 - mean_absolute_error: 0.1006 - mean_absolute_percentage_error: 25.1740 - root_mean_squared_error: 0.1295 - val_loss: 0.0641 - val_mean_absolute_error: 0.2163 - val_mean_absolute_percentage_error: 14607199.0000 - val_root_mean_squared_error: 0.2531
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.0177 - mean_absolute_error: 0.1028 - mean_absolute_percentage_error: 26.2611 - root_mean_squared_error: 0.1331 - val_loss: 0.0643 - val_mean_absolute_error: 0.2124 - val_mean_absolute_percentage_error: 14816068.0000 - val_root_mean_squared_error: 0.2535
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.0172 - mean_absolute_error: 0.1019 - mean_absolute_percentage_error: 27.2273 - root_mean_squared_error: 0.1312 - val_loss: 0.0669 - val_mean_absolute_error: 0.2217 - val_mean_absolute_percentage_error: 13955925.0000 - val_root_mean_squared_error: 0.2586
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0174 - mean_absolute_error: 0.1028 - mean_absolute_percentage_error: 24.2419 - root_mean_squared_error: 0.1318 - val_loss: 0.0665 - val_mean_absolute_error: 0.2215 - val_mean_absolute_percentage_error: 14557498.0000 - val_root_mean_squared_error: 0.2578
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0168 - mean_absolute_error: 0.1008 - mean_absolute_percentage_error: 24.9458 - root_mean_squared_error: 0.1298 - val_loss: 0.0696 - val_mean_absolute_error: 0.2237 - val_mean_absolute_percentage_error: 13812479.0000 - val_root_mean_squared_error: 0.2638
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0166 - mean_absolute_error: 0.1004 - mean_absolute_percentage_error: 24.7237 - root_mean_squared_error: 0.1289 - val_loss: 0.0686 - val_mean_absolute_error: 0.2244 - val_mean_absolute_percentage_error: 14056849.0000 - val_root_mean_squared_error: 0.2620
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 0.0166 - mean_absolute_error: 0.0999 - mean_absolute_percentage_error: 24.9210 - root_mean_squared_error: 0.1288 - val_loss: 0.0732 - val_mean_absolute_error: 0.2311 - val_mean_absolute_percentage_error: 13362137.0000 - val_root_mean_squared_error: 0.2706
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.0161 - mean_absolute_error: 0.0993 - mean_absolute_percentage_error: 23.7014 - root_mean_squared_error: 0.1268 - val_loss: 0.0677 - val_mean_absolute_error: 0.2231 - val_mean_absolute_percentage_error: 14874097.0000 - val_root_mean_squared_error: 0.2602
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - loss: 0.0162 - mean_absolute_error: 0.0987 - mean_absolute_percentage_error: 25.1637 - root_mean_squared_error: 0.1273 - val_loss: 0.0697 - val_mean_absolute_error: 0.2271 - val_mean_absolute_percentage_error: 14676957.0000 - val_root_mean_squared_error: 0.2641

# %%
y_pred = model_cnn_10.predict(x_test)
evaluation_cnn_10 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_10
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# {'Mean Squared Error: ': np.float64(309.8490671182868),
#  'Mean Absolute Error: ': np.float64(12.92501332808514),
#  'Root Mean Absolute Error: ': 17.60253013399741,
#  'Mean Absolute Percentage Error: ': np.float64(24.48451157723588)}

# %%
# y_pred = model_cnn_10.predict(x_test)
loss, mae, mape, rmse = model_cnn_10.evaluate(x_test, y_test)
print("model cnn 10")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0247 - mean_absolute_error: 0.1154 - mean_absolute_percentage_error: 31.2801 - root_mean_squared_error: 0.1572
# model cnn 10
# Mean Square Error: 0.02470097504556179
# Mean Absolute Error: 0.11540190130472183
# Mean Absolute Percentage Error: 31.28013801574707
# Root Mean Squared Error: 0.15716543793678284

# %% [markdown]
# ## model 11 (128 256 128)

# %%
lr = 0.0003

model_cnn_11 = Sequential()
model_cnn_11.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_11.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_11.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_11.add(Flatten())
model_cnn_11.add(Dense(7))
model_cnn_11.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_11.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_19 (Conv1D)              │ (None, 7, 128)         │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_20 (Conv1D)              │ (None, 7, 256)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_21 (Conv1D)              │ (None, 7, 128)         │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_10 (Flatten)            │ (None, 896)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 7)              │         6,279 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73,095 (285.53 KB)
#  Trainable params: 73,095 (285.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_11.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.1300 - mean_absolute_error: 0.2989 - mean_absolute_percentage_error: 58.2481 - root_mean_squared_error: 0.3525 - val_loss: 0.0716 - val_mean_absolute_error: 0.2276 - val_mean_absolute_percentage_error: 12242217.0000 - val_root_mean_squared_error: 0.2676
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0341 - mean_absolute_error: 0.1515 - mean_absolute_percentage_error: 31.0968 - root_mean_squared_error: 0.1838 - val_loss: 0.0557 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 15374989.0000 - val_root_mean_squared_error: 0.2359
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0214 - mean_absolute_error: 0.1152 - mean_absolute_percentage_error: 27.1955 - root_mean_squared_error: 0.1464 - val_loss: 0.0544 - val_mean_absolute_error: 0.1935 - val_mean_absolute_percentage_error: 16176538.0000 - val_root_mean_squared_error: 0.2331
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0212 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 27.9314 - root_mean_squared_error: 0.1456 - val_loss: 0.0544 - val_mean_absolute_error: 0.1949 - val_mean_absolute_percentage_error: 15727831.0000 - val_root_mean_squared_error: 0.2333
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0200 - mean_absolute_error: 0.1095 - mean_absolute_percentage_error: 27.3103 - root_mean_squared_error: 0.1415 - val_loss: 0.0557 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 14787979.0000 - val_root_mean_squared_error: 0.2359
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0198 - mean_absolute_error: 0.1098 - mean_absolute_percentage_error: 26.8942 - root_mean_squared_error: 0.1406 - val_loss: 0.0570 - val_mean_absolute_error: 0.2008 - val_mean_absolute_percentage_error: 14594973.0000 - val_root_mean_squared_error: 0.2388
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0193 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 28.1923 - root_mean_squared_error: 0.1388 - val_loss: 0.0554 - val_mean_absolute_error: 0.1990 - val_mean_absolute_percentage_error: 15013914.0000 - val_root_mean_squared_error: 0.2354
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0189 - mean_absolute_error: 0.1063 - mean_absolute_percentage_error: 27.5080 - root_mean_squared_error: 0.1374 - val_loss: 0.0566 - val_mean_absolute_error: 0.2015 - val_mean_absolute_percentage_error: 14533140.0000 - val_root_mean_squared_error: 0.2379
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0180 - mean_absolute_error: 0.1045 - mean_absolute_percentage_error: 26.3523 - root_mean_squared_error: 0.1341 - val_loss: 0.0561 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 14879368.0000 - val_root_mean_squared_error: 0.2369
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0177 - mean_absolute_error: 0.1032 - mean_absolute_percentage_error: 24.8853 - root_mean_squared_error: 0.1329 - val_loss: 0.0565 - val_mean_absolute_error: 0.2009 - val_mean_absolute_percentage_error: 14968360.0000 - val_root_mean_squared_error: 0.2376
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0180 - mean_absolute_error: 0.1035 - mean_absolute_percentage_error: 27.2624 - root_mean_squared_error: 0.1340 - val_loss: 0.0576 - val_mean_absolute_error: 0.2029 - val_mean_absolute_percentage_error: 14466977.0000 - val_root_mean_squared_error: 0.2399
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0178 - mean_absolute_error: 0.1042 - mean_absolute_percentage_error: 25.0016 - root_mean_squared_error: 0.1334 - val_loss: 0.0567 - val_mean_absolute_error: 0.2021 - val_mean_absolute_percentage_error: 15320160.0000 - val_root_mean_squared_error: 0.2382
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0174 - mean_absolute_error: 0.1023 - mean_absolute_percentage_error: 26.8800 - root_mean_squared_error: 0.1319 - val_loss: 0.0585 - val_mean_absolute_error: 0.2051 - val_mean_absolute_percentage_error: 14655731.0000 - val_root_mean_squared_error: 0.2418
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0184 - mean_absolute_error: 0.1051 - mean_absolute_percentage_error: 27.0570 - root_mean_squared_error: 0.1354 - val_loss: 0.0609 - val_mean_absolute_error: 0.2102 - val_mean_absolute_percentage_error: 13875983.0000 - val_root_mean_squared_error: 0.2468
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0179 - mean_absolute_error: 0.1047 - mean_absolute_percentage_error: 25.8273 - root_mean_squared_error: 0.1337 - val_loss: 0.0603 - val_mean_absolute_error: 0.2096 - val_mean_absolute_percentage_error: 14608829.0000 - val_root_mean_squared_error: 0.2455
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0168 - mean_absolute_error: 0.1010 - mean_absolute_percentage_error: 25.0634 - root_mean_squared_error: 0.1295 - val_loss: 0.0595 - val_mean_absolute_error: 0.2084 - val_mean_absolute_percentage_error: 15210879.0000 - val_root_mean_squared_error: 0.2439
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0176 - mean_absolute_error: 0.1024 - mean_absolute_percentage_error: 26.6851 - root_mean_squared_error: 0.1328 - val_loss: 0.0590 - val_mean_absolute_error: 0.2055 - val_mean_absolute_percentage_error: 15835614.0000 - val_root_mean_squared_error: 0.2429
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0170 - mean_absolute_error: 0.1012 - mean_absolute_percentage_error: 26.6629 - root_mean_squared_error: 0.1306 - val_loss: 0.0620 - val_mean_absolute_error: 0.2140 - val_mean_absolute_percentage_error: 14293897.0000 - val_root_mean_squared_error: 0.2491
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0166 - mean_absolute_error: 0.1005 - mean_absolute_percentage_error: 23.9596 - root_mean_squared_error: 0.1288 - val_loss: 0.0623 - val_mean_absolute_error: 0.2144 - val_mean_absolute_percentage_error: 14366964.0000 - val_root_mean_squared_error: 0.2496
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0168 - mean_absolute_error: 0.1014 - mean_absolute_percentage_error: 24.2346 - root_mean_squared_error: 0.1297 - val_loss: 0.0614 - val_mean_absolute_error: 0.2081 - val_mean_absolute_percentage_error: 16408128.0000 - val_root_mean_squared_error: 0.2478

# %%
y_pred = model_cnn_11.predict(x_test)
evaluation_cnn_11 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_11
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# {'Mean Squared Error: ': np.float64(407.9019675863541),
#  'Mean Absolute Error: ': np.float64(15.284369468688965),
#  'Root Mean Absolute Error: ': 20.196583067102072,
#  'Mean Absolute Percentage Error: ': np.float64(29.218351574776964)}

# %%
# y_pred = model_cnn_11.predict(x_test)
loss, mae, mape, rmse = model_cnn_11.evaluate(x_test, y_test)
print("model cnn 11")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0325 - mean_absolute_error: 0.1365 - mean_absolute_percentage_error: 37.2841 - root_mean_squared_error: 0.1803
# model cnn 11
# Mean Square Error: 0.0325176902115345
# Mean Absolute Error: 0.1364675760269165
# Mean Absolute Percentage Error: 37.284122467041016
# Root Mean Squared Error: 0.18032662570476532

# %% [markdown]
# ## model 12 (256 128 64)

# %%
lr = 0.0003

model_cnn_12 = Sequential()
model_cnn_12.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_12.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_12.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_12.add(Flatten())
model_cnn_12.add(Dense(7))
model_cnn_12.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_12.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_22 (Conv1D)              │ (None, 7, 256)         │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_23 (Conv1D)              │ (None, 7, 128)         │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_24 (Conv1D)              │ (None, 7, 64)          │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_11 (Flatten)            │ (None, 448)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 7)              │         3,143 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 46,087 (180.03 KB)
#  Trainable params: 46,087 (180.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_12.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.2551 - mean_absolute_error: 0.4508 - mean_absolute_percentage_error: 81.1069 - root_mean_squared_error: 0.4987 - val_loss: 0.0802 - val_mean_absolute_error: 0.2239 - val_mean_absolute_percentage_error: 20097286.0000 - val_root_mean_squared_error: 0.2831
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0312 - mean_absolute_error: 0.1410 - mean_absolute_percentage_error: 34.4680 - root_mean_squared_error: 0.1762 - val_loss: 0.0535 - val_mean_absolute_error: 0.1909 - val_mean_absolute_percentage_error: 15784778.0000 - val_root_mean_squared_error: 0.2314
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0231 - mean_absolute_error: 0.1181 - mean_absolute_percentage_error: 31.5569 - root_mean_squared_error: 0.1519 - val_loss: 0.0548 - val_mean_absolute_error: 0.1917 - val_mean_absolute_percentage_error: 14917540.0000 - val_root_mean_squared_error: 0.2340
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0206 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 28.2612 - root_mean_squared_error: 0.1436 - val_loss: 0.0542 - val_mean_absolute_error: 0.1911 - val_mean_absolute_percentage_error: 15492511.0000 - val_root_mean_squared_error: 0.2328
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0217 - mean_absolute_error: 0.1153 - mean_absolute_percentage_error: 29.5975 - root_mean_squared_error: 0.1474 - val_loss: 0.0546 - val_mean_absolute_error: 0.1924 - val_mean_absolute_percentage_error: 15398535.0000 - val_root_mean_squared_error: 0.2336
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0198 - mean_absolute_error: 0.1095 - mean_absolute_percentage_error: 26.0970 - root_mean_squared_error: 0.1406 - val_loss: 0.0561 - val_mean_absolute_error: 0.1963 - val_mean_absolute_percentage_error: 14692729.0000 - val_root_mean_squared_error: 0.2368
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0206 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 28.4358 - root_mean_squared_error: 0.1435 - val_loss: 0.0562 - val_mean_absolute_error: 0.1960 - val_mean_absolute_percentage_error: 14973848.0000 - val_root_mean_squared_error: 0.2370
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0199 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 26.9126 - root_mean_squared_error: 0.1411 - val_loss: 0.0564 - val_mean_absolute_error: 0.1964 - val_mean_absolute_percentage_error: 14874472.0000 - val_root_mean_squared_error: 0.2374
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0204 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 29.5443 - root_mean_squared_error: 0.1428 - val_loss: 0.0567 - val_mean_absolute_error: 0.1974 - val_mean_absolute_percentage_error: 14777166.0000 - val_root_mean_squared_error: 0.2382
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0184 - mean_absolute_error: 0.1057 - mean_absolute_percentage_error: 25.5394 - root_mean_squared_error: 0.1357 - val_loss: 0.0567 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 14665876.0000 - val_root_mean_squared_error: 0.2382
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0200 - mean_absolute_error: 0.1104 - mean_absolute_percentage_error: 26.9579 - root_mean_squared_error: 0.1413 - val_loss: 0.0559 - val_mean_absolute_error: 0.1962 - val_mean_absolute_percentage_error: 15250784.0000 - val_root_mean_squared_error: 0.2364
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0185 - mean_absolute_error: 0.1046 - mean_absolute_percentage_error: 26.7172 - root_mean_squared_error: 0.1360 - val_loss: 0.0567 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 14828793.0000 - val_root_mean_squared_error: 0.2381
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0188 - mean_absolute_error: 0.1059 - mean_absolute_percentage_error: 27.0594 - root_mean_squared_error: 0.1372 - val_loss: 0.0583 - val_mean_absolute_error: 0.2015 - val_mean_absolute_percentage_error: 14288602.0000 - val_root_mean_squared_error: 0.2414
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0190 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 26.5838 - root_mean_squared_error: 0.1380 - val_loss: 0.0578 - val_mean_absolute_error: 0.2012 - val_mean_absolute_percentage_error: 14214154.0000 - val_root_mean_squared_error: 0.2404
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0182 - mean_absolute_error: 0.1043 - mean_absolute_percentage_error: 26.9407 - root_mean_squared_error: 0.1347 - val_loss: 0.0568 - val_mean_absolute_error: 0.1998 - val_mean_absolute_percentage_error: 14604182.0000 - val_root_mean_squared_error: 0.2384
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0184 - mean_absolute_error: 0.1057 - mean_absolute_percentage_error: 26.8087 - root_mean_squared_error: 0.1356 - val_loss: 0.0570 - val_mean_absolute_error: 0.1999 - val_mean_absolute_percentage_error: 14919404.0000 - val_root_mean_squared_error: 0.2387
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0190 - mean_absolute_error: 0.1066 - mean_absolute_percentage_error: 27.6511 - root_mean_squared_error: 0.1377 - val_loss: 0.0563 - val_mean_absolute_error: 0.1991 - val_mean_absolute_percentage_error: 15545345.0000 - val_root_mean_squared_error: 0.2372
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0206 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 28.6085 - root_mean_squared_error: 0.1435 - val_loss: 0.0583 - val_mean_absolute_error: 0.2023 - val_mean_absolute_percentage_error: 14250206.0000 - val_root_mean_squared_error: 0.2414
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0187 - mean_absolute_error: 0.1067 - mean_absolute_percentage_error: 26.5294 - root_mean_squared_error: 0.1369 - val_loss: 0.0586 - val_mean_absolute_error: 0.2034 - val_mean_absolute_percentage_error: 14205688.0000 - val_root_mean_squared_error: 0.2422
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0177 - mean_absolute_error: 0.1034 - mean_absolute_percentage_error: 26.4579 - root_mean_squared_error: 0.1330 - val_loss: 0.0574 - val_mean_absolute_error: 0.2016 - val_mean_absolute_percentage_error: 14721932.0000 - val_root_mean_squared_error: 0.2396

# %%
y_pred = model_cnn_12.predict(x_test)
evaluation_cnn_12 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_12
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# {'Mean Squared Error: ': np.float64(320.5368921308092),
#  'Mean Absolute Error: ': np.float64(14.266113845669494),
#  'Root Mean Absolute Error: ': 17.90354412206726,
#  'Mean Absolute Percentage Error: ': np.float64(25.274283338217508)}

# %%
# y_pred = model_cnn_12.predict(x_test)
loss, mae, mape, rmse = model_cnn_12.evaluate(x_test, y_test)
print("model cnn 12")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0256 - mean_absolute_error: 0.1274 - mean_absolute_percentage_error: 31.8379 - root_mean_squared_error: 0.1599
# model cnn 12
# Mean Square Error: 0.025553002953529358
# Mean Absolute Error: 0.1273760050535202
# Mean Absolute Percentage Error: 31.837936401367188
# Root Mean Squared Error: 0.15985307097434998

# %% [markdown]
# ## model 13 (256 128 256)

# %%
lr = 0.0003

model_cnn_13 = Sequential()
model_cnn_13.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_13.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_13.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_13.add(Flatten())
model_cnn_13.add(Dense(7))
model_cnn_13.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_13.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_25 (Conv1D)              │ (None, 7, 256)         │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_26 (Conv1D)              │ (None, 7, 128)         │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_27 (Conv1D)              │ (None, 7, 256)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_12 (Flatten)            │ (None, 1792)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 7)              │        12,551 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,263 (313.53 KB)
#  Trainable params: 80,263 (313.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_13.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=50,
    batch_size=42
)
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.1751 - mean_absolute_error: 0.3575 - mean_absolute_percentage_error: 67.9682 - root_mean_squared_error: 0.4097 - val_loss: 0.0711 - val_mean_absolute_error: 0.2268 - val_mean_absolute_percentage_error: 12554454.0000 - val_root_mean_squared_error: 0.2666
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0321 - mean_absolute_error: 0.1461 - mean_absolute_percentage_error: 31.1026 - root_mean_squared_error: 0.1788 - val_loss: 0.0559 - val_mean_absolute_error: 0.1972 - val_mean_absolute_percentage_error: 14944821.0000 - val_root_mean_squared_error: 0.2365
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0220 - mean_absolute_error: 0.1179 - mean_absolute_percentage_error: 27.2318 - root_mean_squared_error: 0.1482 - val_loss: 0.0552 - val_mean_absolute_error: 0.1964 - val_mean_absolute_percentage_error: 15005233.0000 - val_root_mean_squared_error: 0.2349
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0201 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 28.2883 - root_mean_squared_error: 0.1417 - val_loss: 0.0549 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 15123878.0000 - val_root_mean_squared_error: 0.2344
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0199 - mean_absolute_error: 0.1096 - mean_absolute_percentage_error: 28.6556 - root_mean_squared_error: 0.1410 - val_loss: 0.0544 - val_mean_absolute_error: 0.1961 - val_mean_absolute_percentage_error: 15249018.0000 - val_root_mean_squared_error: 0.2333
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0187 - mean_absolute_error: 0.1054 - mean_absolute_percentage_error: 26.1989 - root_mean_squared_error: 0.1365 - val_loss: 0.0559 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 14633942.0000 - val_root_mean_squared_error: 0.2365
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0191 - mean_absolute_error: 0.1082 - mean_absolute_percentage_error: 26.8994 - root_mean_squared_error: 0.1384 - val_loss: 0.0561 - val_mean_absolute_error: 0.2007 - val_mean_absolute_percentage_error: 14577482.0000 - val_root_mean_squared_error: 0.2369
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0182 - mean_absolute_error: 0.1048 - mean_absolute_percentage_error: 25.6712 - root_mean_squared_error: 0.1348 - val_loss: 0.0548 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 15074344.0000 - val_root_mean_squared_error: 0.2341
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0187 - mean_absolute_error: 0.1063 - mean_absolute_percentage_error: 26.5991 - root_mean_squared_error: 0.1367 - val_loss: 0.0565 - val_mean_absolute_error: 0.2023 - val_mean_absolute_percentage_error: 14480468.0000 - val_root_mean_squared_error: 0.2377
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0180 - mean_absolute_error: 0.1044 - mean_absolute_percentage_error: 25.9933 - root_mean_squared_error: 0.1341 - val_loss: 0.0560 - val_mean_absolute_error: 0.2004 - val_mean_absolute_percentage_error: 15090238.0000 - val_root_mean_squared_error: 0.2367
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0171 - mean_absolute_error: 0.1021 - mean_absolute_percentage_error: 25.7272 - root_mean_squared_error: 0.1307 - val_loss: 0.0555 - val_mean_absolute_error: 0.2001 - val_mean_absolute_percentage_error: 15629284.0000 - val_root_mean_squared_error: 0.2356
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0172 - mean_absolute_error: 0.1020 - mean_absolute_percentage_error: 25.3992 - root_mean_squared_error: 0.1310 - val_loss: 0.0565 - val_mean_absolute_error: 0.2030 - val_mean_absolute_percentage_error: 15168058.0000 - val_root_mean_squared_error: 0.2376
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0177 - mean_absolute_error: 0.1031 - mean_absolute_percentage_error: 25.4412 - root_mean_squared_error: 0.1330 - val_loss: 0.0564 - val_mean_absolute_error: 0.2018 - val_mean_absolute_percentage_error: 15712950.0000 - val_root_mean_squared_error: 0.2375
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0174 - mean_absolute_error: 0.1020 - mean_absolute_percentage_error: 26.1845 - root_mean_squared_error: 0.1319 - val_loss: 0.0579 - val_mean_absolute_error: 0.2046 - val_mean_absolute_percentage_error: 15057419.0000 - val_root_mean_squared_error: 0.2406
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0176 - mean_absolute_error: 0.1027 - mean_absolute_percentage_error: 26.8521 - root_mean_squared_error: 0.1325 - val_loss: 0.0584 - val_mean_absolute_error: 0.2060 - val_mean_absolute_percentage_error: 15192569.0000 - val_root_mean_squared_error: 0.2416
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0173 - mean_absolute_error: 0.1018 - mean_absolute_percentage_error: 26.2044 - root_mean_squared_error: 0.1314 - val_loss: 0.0595 - val_mean_absolute_error: 0.2094 - val_mean_absolute_percentage_error: 15022709.0000 - val_root_mean_squared_error: 0.2439
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0165 - mean_absolute_error: 0.0995 - mean_absolute_percentage_error: 25.0068 - root_mean_squared_error: 0.1284 - val_loss: 0.0598 - val_mean_absolute_error: 0.2089 - val_mean_absolute_percentage_error: 15433079.0000 - val_root_mean_squared_error: 0.2446
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0171 - mean_absolute_error: 0.1017 - mean_absolute_percentage_error: 25.6479 - root_mean_squared_error: 0.1309 - val_loss: 0.0618 - val_mean_absolute_error: 0.2124 - val_mean_absolute_percentage_error: 15925228.0000 - val_root_mean_squared_error: 0.2487
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0170 - mean_absolute_error: 0.1009 - mean_absolute_percentage_error: 25.5528 - root_mean_squared_error: 0.1303 - val_loss: 0.0626 - val_mean_absolute_error: 0.2135 - val_mean_absolute_percentage_error: 15410983.0000 - val_root_mean_squared_error: 0.2503
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0174 - mean_absolute_error: 0.1022 - mean_absolute_percentage_error: 26.3120 - root_mean_squared_error: 0.1319 - val_loss: 0.0631 - val_mean_absolute_error: 0.2142 - val_mean_absolute_percentage_error: 15573490.0000 - val_root_mean_squared_error: 0.2511
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0163 - mean_absolute_error: 0.0989 - mean_absolute_percentage_error: 24.6550 - root_mean_squared_error: 0.1276 - val_loss: 0.0638 - val_mean_absolute_error: 0.2144 - val_mean_absolute_percentage_error: 16217396.0000 - val_root_mean_squared_error: 0.2526
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0160 - mean_absolute_error: 0.0980 - mean_absolute_percentage_error: 24.1909 - root_mean_squared_error: 0.1267 - val_loss: 0.0653 - val_mean_absolute_error: 0.2182 - val_mean_absolute_percentage_error: 15287812.0000 - val_root_mean_squared_error: 0.2555
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0166 - mean_absolute_error: 0.1009 - mean_absolute_percentage_error: 24.8783 - root_mean_squared_error: 0.1289 - val_loss: 0.0668 - val_mean_absolute_error: 0.2203 - val_mean_absolute_percentage_error: 14789047.0000 - val_root_mean_squared_error: 0.2584
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0165 - mean_absolute_error: 0.1003 - mean_absolute_percentage_error: 26.7102 - root_mean_squared_error: 0.1283 - val_loss: 0.0661 - val_mean_absolute_error: 0.2189 - val_mean_absolute_percentage_error: 15545923.0000 - val_root_mean_squared_error: 0.2572
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0168 - mean_absolute_error: 0.1010 - mean_absolute_percentage_error: 24.7223 - root_mean_squared_error: 0.1294 - val_loss: 0.0700 - val_mean_absolute_error: 0.2225 - val_mean_absolute_percentage_error: 15592835.0000 - val_root_mean_squared_error: 0.2646
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0152 - mean_absolute_error: 0.0960 - mean_absolute_percentage_error: 24.7330 - root_mean_squared_error: 0.1234 - val_loss: 0.0653 - val_mean_absolute_error: 0.2198 - val_mean_absolute_percentage_error: 14515063.0000 - val_root_mean_squared_error: 0.2555
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0154 - mean_absolute_error: 0.0965 - mean_absolute_percentage_error: 24.4166 - root_mean_squared_error: 0.1239 - val_loss: 0.0660 - val_mean_absolute_error: 0.2199 - val_mean_absolute_percentage_error: 14801575.0000 - val_root_mean_squared_error: 0.2569
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0155 - mean_absolute_error: 0.0968 - mean_absolute_percentage_error: 23.7755 - root_mean_squared_error: 0.1244 - val_loss: 0.0676 - val_mean_absolute_error: 0.2208 - val_mean_absolute_percentage_error: 16183273.0000 - val_root_mean_squared_error: 0.2601
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0162 - mean_absolute_error: 0.0990 - mean_absolute_percentage_error: 24.9147 - root_mean_squared_error: 0.1271 - val_loss: 0.0711 - val_mean_absolute_error: 0.2278 - val_mean_absolute_percentage_error: 14825985.0000 - val_root_mean_squared_error: 0.2666
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0139 - mean_absolute_error: 0.0916 - mean_absolute_percentage_error: 21.6913 - root_mean_squared_error: 0.1180 - val_loss: 0.0666 - val_mean_absolute_error: 0.2205 - val_mean_absolute_percentage_error: 14954209.0000 - val_root_mean_squared_error: 0.2581
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0146 - mean_absolute_error: 0.0939 - mean_absolute_percentage_error: 22.3428 - root_mean_squared_error: 0.1207 - val_loss: 0.0731 - val_mean_absolute_error: 0.2307 - val_mean_absolute_percentage_error: 14058879.0000 - val_root_mean_squared_error: 0.2704
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0144 - mean_absolute_error: 0.0936 - mean_absolute_percentage_error: 21.7997 - root_mean_squared_error: 0.1201 - val_loss: 0.0701 - val_mean_absolute_error: 0.2269 - val_mean_absolute_percentage_error: 14169692.0000 - val_root_mean_squared_error: 0.2648
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0135 - mean_absolute_error: 0.0907 - mean_absolute_percentage_error: 21.2115 - root_mean_squared_error: 0.1163 - val_loss: 0.0691 - val_mean_absolute_error: 0.2259 - val_mean_absolute_percentage_error: 15025550.0000 - val_root_mean_squared_error: 0.2628
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0132 - mean_absolute_error: 0.0893 - mean_absolute_percentage_error: 21.0509 - root_mean_squared_error: 0.1147 - val_loss: 0.0741 - val_mean_absolute_error: 0.2280 - val_mean_absolute_percentage_error: 15616178.0000 - val_root_mean_squared_error: 0.2722
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0136 - mean_absolute_error: 0.0909 - mean_absolute_percentage_error: 22.0853 - root_mean_squared_error: 0.1166 - val_loss: 0.0753 - val_mean_absolute_error: 0.2307 - val_mean_absolute_percentage_error: 14965817.0000 - val_root_mean_squared_error: 0.2744
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0139 - mean_absolute_error: 0.0908 - mean_absolute_percentage_error: 21.2714 - root_mean_squared_error: 0.1180 - val_loss: 0.0696 - val_mean_absolute_error: 0.2258 - val_mean_absolute_percentage_error: 14890515.0000 - val_root_mean_squared_error: 0.2637
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0126 - mean_absolute_error: 0.0876 - mean_absolute_percentage_error: 20.2654 - root_mean_squared_error: 0.1121 - val_loss: 0.0725 - val_mean_absolute_error: 0.2298 - val_mean_absolute_percentage_error: 14657866.0000 - val_root_mean_squared_error: 0.2692
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0130 - mean_absolute_error: 0.0891 - mean_absolute_percentage_error: 21.2746 - root_mean_squared_error: 0.1140 - val_loss: 0.0713 - val_mean_absolute_error: 0.2264 - val_mean_absolute_percentage_error: 13803854.0000 - val_root_mean_squared_error: 0.2670
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0125 - mean_absolute_error: 0.0873 - mean_absolute_percentage_error: 20.9370 - root_mean_squared_error: 0.1120 - val_loss: 0.0742 - val_mean_absolute_error: 0.2314 - val_mean_absolute_percentage_error: 14176922.0000 - val_root_mean_squared_error: 0.2724
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0120 - mean_absolute_error: 0.0845 - mean_absolute_percentage_error: 19.4873 - root_mean_squared_error: 0.1096 - val_loss: 0.0751 - val_mean_absolute_error: 0.2330 - val_mean_absolute_percentage_error: 14123746.0000 - val_root_mean_squared_error: 0.2741
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0123 - mean_absolute_error: 0.0859 - mean_absolute_percentage_error: 20.2233 - root_mean_squared_error: 0.1109 - val_loss: 0.0717 - val_mean_absolute_error: 0.2297 - val_mean_absolute_percentage_error: 13984199.0000 - val_root_mean_squared_error: 0.2678
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0112 - mean_absolute_error: 0.0820 - mean_absolute_percentage_error: 18.5591 - root_mean_squared_error: 0.1059 - val_loss: 0.0711 - val_mean_absolute_error: 0.2293 - val_mean_absolute_percentage_error: 13848754.0000 - val_root_mean_squared_error: 0.2666
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0124 - mean_absolute_error: 0.0860 - mean_absolute_percentage_error: 19.8934 - root_mean_squared_error: 0.1116 - val_loss: 0.0710 - val_mean_absolute_error: 0.2280 - val_mean_absolute_percentage_error: 14229011.0000 - val_root_mean_squared_error: 0.2664
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0128 - mean_absolute_error: 0.0881 - mean_absolute_percentage_error: 22.4313 - root_mean_squared_error: 0.1129 - val_loss: 0.0767 - val_mean_absolute_error: 0.2340 - val_mean_absolute_percentage_error: 14040551.0000 - val_root_mean_squared_error: 0.2770
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0122 - mean_absolute_error: 0.0856 - mean_absolute_percentage_error: 20.1747 - root_mean_squared_error: 0.1106 - val_loss: 0.0731 - val_mean_absolute_error: 0.2287 - val_mean_absolute_percentage_error: 13919194.0000 - val_root_mean_squared_error: 0.2703
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0120 - mean_absolute_error: 0.0856 - mean_absolute_percentage_error: 20.7932 - root_mean_squared_error: 0.1097 - val_loss: 0.0713 - val_mean_absolute_error: 0.2282 - val_mean_absolute_percentage_error: 13696462.0000 - val_root_mean_squared_error: 0.2670
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0114 - mean_absolute_error: 0.0823 - mean_absolute_percentage_error: 18.9521 - root_mean_squared_error: 0.1070 - val_loss: 0.0771 - val_mean_absolute_error: 0.2324 - val_mean_absolute_percentage_error: 14420576.0000 - val_root_mean_squared_error: 0.2777
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0114 - mean_absolute_error: 0.0826 - mean_absolute_percentage_error: 19.3548 - root_mean_squared_error: 0.1068 - val_loss: 0.0880 - val_mean_absolute_error: 0.2432 - val_mean_absolute_percentage_error: 14779833.0000 - val_root_mean_squared_error: 0.2966
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0127 - mean_absolute_error: 0.0879 - mean_absolute_percentage_error: 19.8456 - root_mean_squared_error: 0.1125 - val_loss: 0.0818 - val_mean_absolute_error: 0.2365 - val_mean_absolute_percentage_error: 14508715.0000 - val_root_mean_squared_error: 0.2860
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0124 - mean_absolute_error: 0.0872 - mean_absolute_percentage_error: 21.7774 - root_mean_squared_error: 0.1114 - val_loss: 0.0731 - val_mean_absolute_error: 0.2285 - val_mean_absolute_percentage_error: 14049565.0000 - val_root_mean_squared_error: 0.2704

# %%
y_pred = model_cnn_13.predict(x_test)
evaluation_cnn_13 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_13
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# {'Mean Squared Error: ': np.float64(623.7250012213093),
#  'Mean Absolute Error: ': np.float64(19.00586840571189),
#  'Root Mean Absolute Error: ': 24.974487006169102,
#  'Mean Absolute Percentage Error: ': np.float64(35.72098593041443)}

# %%
# y_pred = model_cnn_13.predict(x_test)
loss, mae, mape, rmse = model_cnn_13.evaluate(x_test, y_test)
print("model cnn 13")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0497 - mean_absolute_error: 0.1697 - mean_absolute_percentage_error: 45.4759 - root_mean_squared_error: 0.2230
# model cnn 13
# Mean Square Error: 0.04972296953201294
# Mean Absolute Error: 0.16969525814056396
# Mean Absolute Percentage Error: 45.47587203979492
# Root Mean Squared Error: 0.22298647463321686

# %% [markdown]
# ## model 14 (256 128 64, epoch 50)

# %%
lr = 0.0003

model_cnn_14 = Sequential()
model_cnn_14.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_14.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_14.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_14.add(Flatten())
model_cnn_14.add(Dense(7))
model_cnn_14.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_14.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_28 (Conv1D)              │ (None, 7, 256)         │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_29 (Conv1D)              │ (None, 7, 128)         │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_30 (Conv1D)              │ (None, 7, 64)          │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_13 (Flatten)            │ (None, 448)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 7)              │         3,143 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 46,087 (180.03 KB)
#  Trainable params: 46,087 (180.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_14.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=30,
    batch_size=42
)
# Out:
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.2276 - mean_absolute_error: 0.4219 - mean_absolute_percentage_error: 75.0125 - root_mean_squared_error: 0.4708 - val_loss: 0.0557 - val_mean_absolute_error: 0.1963 - val_mean_absolute_percentage_error: 16083540.0000 - val_root_mean_squared_error: 0.2361
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0273 - mean_absolute_error: 0.1316 - mean_absolute_percentage_error: 31.1771 - root_mean_squared_error: 0.1650 - val_loss: 0.0541 - val_mean_absolute_error: 0.1939 - val_mean_absolute_percentage_error: 15635285.0000 - val_root_mean_squared_error: 0.2327
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0215 - mean_absolute_error: 0.1143 - mean_absolute_percentage_error: 29.1047 - root_mean_squared_error: 0.1465 - val_loss: 0.0548 - val_mean_absolute_error: 0.1969 - val_mean_absolute_percentage_error: 14301085.0000 - val_root_mean_squared_error: 0.2341
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0210 - mean_absolute_error: 0.1120 - mean_absolute_percentage_error: 29.1984 - root_mean_squared_error: 0.1449 - val_loss: 0.0548 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 14455601.0000 - val_root_mean_squared_error: 0.2340
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0210 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 29.2891 - root_mean_squared_error: 0.1449 - val_loss: 0.0550 - val_mean_absolute_error: 0.1991 - val_mean_absolute_percentage_error: 14543104.0000 - val_root_mean_squared_error: 0.2345
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0191 - mean_absolute_error: 0.1070 - mean_absolute_percentage_error: 26.0361 - root_mean_squared_error: 0.1382 - val_loss: 0.0565 - val_mean_absolute_error: 0.2018 - val_mean_absolute_percentage_error: 13902513.0000 - val_root_mean_squared_error: 0.2378
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0190 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 26.4499 - root_mean_squared_error: 0.1377 - val_loss: 0.0557 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 14476998.0000 - val_root_mean_squared_error: 0.2361
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0204 - mean_absolute_error: 0.1108 - mean_absolute_percentage_error: 28.9192 - root_mean_squared_error: 0.1427 - val_loss: 0.0554 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 15063842.0000 - val_root_mean_squared_error: 0.2354
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0194 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 27.8247 - root_mean_squared_error: 0.1391 - val_loss: 0.0574 - val_mean_absolute_error: 0.2032 - val_mean_absolute_percentage_error: 14197398.0000 - val_root_mean_squared_error: 0.2395
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0190 - mean_absolute_error: 0.1073 - mean_absolute_percentage_error: 27.4131 - root_mean_squared_error: 0.1378 - val_loss: 0.0572 - val_mean_absolute_error: 0.2025 - val_mean_absolute_percentage_error: 14355996.0000 - val_root_mean_squared_error: 0.2391
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0180 - mean_absolute_error: 0.1035 - mean_absolute_percentage_error: 26.0908 - root_mean_squared_error: 0.1342 - val_loss: 0.0581 - val_mean_absolute_error: 0.2040 - val_mean_absolute_percentage_error: 14507778.0000 - val_root_mean_squared_error: 0.2411
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0177 - mean_absolute_error: 0.1032 - mean_absolute_percentage_error: 25.3007 - root_mean_squared_error: 0.1330 - val_loss: 0.0570 - val_mean_absolute_error: 0.2021 - val_mean_absolute_percentage_error: 15220655.0000 - val_root_mean_squared_error: 0.2388
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0187 - mean_absolute_error: 0.1061 - mean_absolute_percentage_error: 26.7410 - root_mean_squared_error: 0.1369 - val_loss: 0.0587 - val_mean_absolute_error: 0.2053 - val_mean_absolute_percentage_error: 14275017.0000 - val_root_mean_squared_error: 0.2423
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0203 - mean_absolute_error: 0.1117 - mean_absolute_percentage_error: 27.2597 - root_mean_squared_error: 0.1423 - val_loss: 0.0578 - val_mean_absolute_error: 0.2038 - val_mean_absolute_percentage_error: 15172278.0000 - val_root_mean_squared_error: 0.2403
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0182 - mean_absolute_error: 0.1034 - mean_absolute_percentage_error: 27.1013 - root_mean_squared_error: 0.1349 - val_loss: 0.0577 - val_mean_absolute_error: 0.2029 - val_mean_absolute_percentage_error: 15609871.0000 - val_root_mean_squared_error: 0.2403
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0191 - mean_absolute_error: 0.1073 - mean_absolute_percentage_error: 27.7156 - root_mean_squared_error: 0.1380 - val_loss: 0.0598 - val_mean_absolute_error: 0.2074 - val_mean_absolute_percentage_error: 14638409.0000 - val_root_mean_squared_error: 0.2446
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0169 - mean_absolute_error: 0.1006 - mean_absolute_percentage_error: 25.2357 - root_mean_squared_error: 0.1300 - val_loss: 0.0582 - val_mean_absolute_error: 0.2025 - val_mean_absolute_percentage_error: 16303340.0000 - val_root_mean_squared_error: 0.2411
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0177 - mean_absolute_error: 0.1030 - mean_absolute_percentage_error: 26.1565 - root_mean_squared_error: 0.1329 - val_loss: 0.0599 - val_mean_absolute_error: 0.2078 - val_mean_absolute_percentage_error: 14770632.0000 - val_root_mean_squared_error: 0.2447
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0177 - mean_absolute_error: 0.1043 - mean_absolute_percentage_error: 26.7554 - root_mean_squared_error: 0.1332 - val_loss: 0.0610 - val_mean_absolute_error: 0.2097 - val_mean_absolute_percentage_error: 14953059.0000 - val_root_mean_squared_error: 0.2469
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0168 - mean_absolute_error: 0.1011 - mean_absolute_percentage_error: 24.7179 - root_mean_squared_error: 0.1294 - val_loss: 0.0591 - val_mean_absolute_error: 0.2056 - val_mean_absolute_percentage_error: 15772244.0000 - val_root_mean_squared_error: 0.2431
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0181 - mean_absolute_error: 0.1044 - mean_absolute_percentage_error: 27.7473 - root_mean_squared_error: 0.1345 - val_loss: 0.0621 - val_mean_absolute_error: 0.2116 - val_mean_absolute_percentage_error: 14752494.0000 - val_root_mean_squared_error: 0.2491
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0174 - mean_absolute_error: 0.1023 - mean_absolute_percentage_error: 26.0566 - root_mean_squared_error: 0.1320 - val_loss: 0.0645 - val_mean_absolute_error: 0.2162 - val_mean_absolute_percentage_error: 14191033.0000 - val_root_mean_squared_error: 0.2540
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0182 - mean_absolute_error: 0.1061 - mean_absolute_percentage_error: 27.0654 - root_mean_squared_error: 0.1347 - val_loss: 0.0605 - val_mean_absolute_error: 0.2085 - val_mean_absolute_percentage_error: 15278328.0000 - val_root_mean_squared_error: 0.2459
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0173 - mean_absolute_error: 0.1025 - mean_absolute_percentage_error: 25.8374 - root_mean_squared_error: 0.1317 - val_loss: 0.0635 - val_mean_absolute_error: 0.2158 - val_mean_absolute_percentage_error: 13989345.0000 - val_root_mean_squared_error: 0.2519
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0187 - mean_absolute_error: 0.1070 - mean_absolute_percentage_error: 27.0607 - root_mean_squared_error: 0.1368 - val_loss: 0.0605 - val_mean_absolute_error: 0.2083 - val_mean_absolute_percentage_error: 15759255.0000 - val_root_mean_squared_error: 0.2459
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0176 - mean_absolute_error: 0.1026 - mean_absolute_percentage_error: 25.9287 - root_mean_squared_error: 0.1324 - val_loss: 0.0653 - val_mean_absolute_error: 0.2181 - val_mean_absolute_percentage_error: 13994282.0000 - val_root_mean_squared_error: 0.2556
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0172 - mean_absolute_error: 0.1023 - mean_absolute_percentage_error: 25.3661 - root_mean_squared_error: 0.1310 - val_loss: 0.0617 - val_mean_absolute_error: 0.2117 - val_mean_absolute_percentage_error: 15469280.0000 - val_root_mean_squared_error: 0.2484
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0170 - mean_absolute_error: 0.1016 - mean_absolute_percentage_error: 26.7623 - root_mean_squared_error: 0.1303 - val_loss: 0.0626 - val_mean_absolute_error: 0.2143 - val_mean_absolute_percentage_error: 15105524.0000 - val_root_mean_squared_error: 0.2503
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0167 - mean_absolute_error: 0.1012 - mean_absolute_percentage_error: 25.3609 - root_mean_squared_error: 0.1292 - val_loss: 0.0650 - val_mean_absolute_error: 0.2185 - val_mean_absolute_percentage_error: 14688024.0000 - val_root_mean_squared_error: 0.2549
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0172 - mean_absolute_error: 0.1025 - mean_absolute_percentage_error: 24.7347 - root_mean_squared_error: 0.1311 - val_loss: 0.0633 - val_mean_absolute_error: 0.2150 - val_mean_absolute_percentage_error: 15202605.0000 - val_root_mean_squared_error: 0.2515

# %%
y_pred = model_cnn_14.predict(x_test)
evaluation_cnn_14 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_14
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# {'Mean Squared Error: ': np.float64(326.3614521036704),
#  'Mean Absolute Error: ': np.float64(13.501906550660424),
#  'Root Mean Absolute Error: ': 18.065476802555487,
#  'Mean Absolute Percentage Error: ': np.float64(25.21498846913357)}

# %%
# y_pred = model_cnn_14.predict(x_test)
loss, mae, mape, rmse = model_cnn_14.evaluate(x_test, y_test)
print("model cnn 14")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0260 - mean_absolute_error: 0.1206 - mean_absolute_percentage_error: 32.1010 - root_mean_squared_error: 0.1613
# model cnn 14
# Mean Square Error: 0.026017332449555397
# Mean Absolute Error: 0.12055272608995438
# Mean Absolute Percentage Error: 32.100975036621094
# Root Mean Squared Error: 0.16129888594150543

# %% [markdown]
# ## model 15 (1024 1024)

# %%
lr = 0.0003

model_cnn_15 = Sequential()
model_cnn_15.add(Conv1D(filters=1024, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_15.add(Conv1D(filters=1024, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_15.add(Flatten())
model_cnn_15.add(Dense(7))
model_cnn_15.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_15.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_31 (Conv1D)              │ (None, 7, 1024)        │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_32 (Conv1D)              │ (None, 7, 1024)        │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_14 (Flatten)            │ (None, 7168)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 7)              │        50,183 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,106,951 (4.22 MB)
#  Trainable params: 1,106,951 (4.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_15.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - loss: 0.1209 - mean_absolute_error: 0.2743 - mean_absolute_percentage_error: 54.2968 - root_mean_squared_error: 0.3357 - val_loss: 0.0608 - val_mean_absolute_error: 0.1975 - val_mean_absolute_percentage_error: 18729472.0000 - val_root_mean_squared_error: 0.2466
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 240ms/step - loss: 0.0251 - mean_absolute_error: 0.1252 - mean_absolute_percentage_error: 29.1384 - root_mean_squared_error: 0.1582 - val_loss: 0.0556 - val_mean_absolute_error: 0.2000 - val_mean_absolute_percentage_error: 15195482.0000 - val_root_mean_squared_error: 0.2359
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - loss: 0.0216 - mean_absolute_error: 0.1148 - mean_absolute_percentage_error: 28.2844 - root_mean_squared_error: 0.1470 - val_loss: 0.0576 - val_mean_absolute_error: 0.2047 - val_mean_absolute_percentage_error: 14712259.0000 - val_root_mean_squared_error: 0.2400
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 252ms/step - loss: 0.0201 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 27.5526 - root_mean_squared_error: 0.1416 - val_loss: 0.0577 - val_mean_absolute_error: 0.2061 - val_mean_absolute_percentage_error: 14734763.0000 - val_root_mean_squared_error: 0.2403
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 256ms/step - loss: 0.0179 - mean_absolute_error: 0.1040 - mean_absolute_percentage_error: 25.8186 - root_mean_squared_error: 0.1339 - val_loss: 0.0601 - val_mean_absolute_error: 0.2099 - val_mean_absolute_percentage_error: 14148092.0000 - val_root_mean_squared_error: 0.2452
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 251ms/step - loss: 0.0185 - mean_absolute_error: 0.1057 - mean_absolute_percentage_error: 25.9075 - root_mean_squared_error: 0.1360 - val_loss: 0.0609 - val_mean_absolute_error: 0.2110 - val_mean_absolute_percentage_error: 13913081.0000 - val_root_mean_squared_error: 0.2468
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - loss: 0.0180 - mean_absolute_error: 0.1045 - mean_absolute_percentage_error: 25.1910 - root_mean_squared_error: 0.1340 - val_loss: 0.0603 - val_mean_absolute_error: 0.2108 - val_mean_absolute_percentage_error: 14199332.0000 - val_root_mean_squared_error: 0.2455
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - loss: 0.0188 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 26.0381 - root_mean_squared_error: 0.1371 - val_loss: 0.0619 - val_mean_absolute_error: 0.2131 - val_mean_absolute_percentage_error: 14184349.0000 - val_root_mean_squared_error: 0.2488
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 251ms/step - loss: 0.0177 - mean_absolute_error: 0.1031 - mean_absolute_percentage_error: 24.9686 - root_mean_squared_error: 0.1328 - val_loss: 0.0604 - val_mean_absolute_error: 0.2101 - val_mean_absolute_percentage_error: 14932107.0000 - val_root_mean_squared_error: 0.2457
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 267ms/step - loss: 0.0180 - mean_absolute_error: 0.1059 - mean_absolute_percentage_error: 26.0311 - root_mean_squared_error: 0.1343 - val_loss: 0.0599 - val_mean_absolute_error: 0.2086 - val_mean_absolute_percentage_error: 15365389.0000 - val_root_mean_squared_error: 0.2447
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 276ms/step - loss: 0.0162 - mean_absolute_error: 0.0991 - mean_absolute_percentage_error: 24.0237 - root_mean_squared_error: 0.1271 - val_loss: 0.0663 - val_mean_absolute_error: 0.2187 - val_mean_absolute_percentage_error: 13844714.0000 - val_root_mean_squared_error: 0.2575
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 239ms/step - loss: 0.0172 - mean_absolute_error: 0.1029 - mean_absolute_percentage_error: 25.7382 - root_mean_squared_error: 0.1311 - val_loss: 0.0617 - val_mean_absolute_error: 0.2113 - val_mean_absolute_percentage_error: 15624971.0000 - val_root_mean_squared_error: 0.2483
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 251ms/step - loss: 0.0174 - mean_absolute_error: 0.1027 - mean_absolute_percentage_error: 26.2269 - root_mean_squared_error: 0.1318 - val_loss: 0.0649 - val_mean_absolute_error: 0.2172 - val_mean_absolute_percentage_error: 15671591.0000 - val_root_mean_squared_error: 0.2547
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 282ms/step - loss: 0.0181 - mean_absolute_error: 0.1046 - mean_absolute_percentage_error: 26.5962 - root_mean_squared_error: 0.1345 - val_loss: 0.0657 - val_mean_absolute_error: 0.2184 - val_mean_absolute_percentage_error: 15381446.0000 - val_root_mean_squared_error: 0.2563
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 239ms/step - loss: 0.0161 - mean_absolute_error: 0.0991 - mean_absolute_percentage_error: 24.4839 - root_mean_squared_error: 0.1267 - val_loss: 0.0642 - val_mean_absolute_error: 0.2154 - val_mean_absolute_percentage_error: 15505284.0000 - val_root_mean_squared_error: 0.2533
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 281ms/step - loss: 0.0164 - mean_absolute_error: 0.1006 - mean_absolute_percentage_error: 23.9812 - root_mean_squared_error: 0.1281 - val_loss: 0.0673 - val_mean_absolute_error: 0.2215 - val_mean_absolute_percentage_error: 15359958.0000 - val_root_mean_squared_error: 0.2594
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 260ms/step - loss: 0.0159 - mean_absolute_error: 0.0985 - mean_absolute_percentage_error: 24.4942 - root_mean_squared_error: 0.1258 - val_loss: 0.0665 - val_mean_absolute_error: 0.2179 - val_mean_absolute_percentage_error: 16058641.0000 - val_root_mean_squared_error: 0.2578
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 240ms/step - loss: 0.0169 - mean_absolute_error: 0.1011 - mean_absolute_percentage_error: 25.2288 - root_mean_squared_error: 0.1302 - val_loss: 0.0681 - val_mean_absolute_error: 0.2209 - val_mean_absolute_percentage_error: 15465624.0000 - val_root_mean_squared_error: 0.2609
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - loss: 0.0167 - mean_absolute_error: 0.1010 - mean_absolute_percentage_error: 25.0079 - root_mean_squared_error: 0.1291 - val_loss: 0.0711 - val_mean_absolute_error: 0.2244 - val_mean_absolute_percentage_error: 14088120.0000 - val_root_mean_squared_error: 0.2667
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - loss: 0.0177 - mean_absolute_error: 0.1052 - mean_absolute_percentage_error: 26.8171 - root_mean_squared_error: 0.1330 - val_loss: 0.0744 - val_mean_absolute_error: 0.2303 - val_mean_absolute_percentage_error: 13607009.0000 - val_root_mean_squared_error: 0.2727

# %%
y_pred = model_cnn_15.predict(x_test)
evaluation_cnn_15 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_15
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# {'Mean Squared Error: ': np.float64(262.3581179722084),
#  'Mean Absolute Error: ': np.float64(12.571553716854172),
#  'Root Mean Absolute Error: ': 16.197472579764053,
#  'Mean Absolute Percentage Error: ': np.float64(22.314289338570518)}

# %%
# y_pred = model_cnn_15.predict(x_test)
loss, mae, mape, rmse = model_cnn_15.evaluate(x_test, y_test)
print("model cnn 15")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0209 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 28.2311 - root_mean_squared_error: 0.1446
# model cnn 15
# Mean Square Error: 0.02091502957046032
# Mean Absolute Error: 0.11224602162837982
# Mean Absolute Percentage Error: 28.231054306030273
# Root Mean Squared Error: 0.14462029933929443

# %% [markdown]
# ## model 16 (2048 512)

# %%
lr = 0.0003

model_cnn_16 = Sequential()
model_cnn_16.add(Conv1D(filters=2048, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_16.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_16.add(Flatten())
model_cnn_16.add(Dense(7))
model_cnn_16.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_16.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_33 (Conv1D)              │ (None, 7, 2048)        │        14,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_34 (Conv1D)              │ (None, 7, 512)         │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_15 (Flatten)            │ (None, 3584)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 7)              │        25,095 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,088,519 (4.15 MB)
#  Trainable params: 1,088,519 (4.15 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_16.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 275ms/step - loss: 0.1277 - mean_absolute_error: 0.2885 - mean_absolute_percentage_error: 55.8747 - root_mean_squared_error: 0.3451 - val_loss: 0.0609 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 18423906.0000 - val_root_mean_squared_error: 0.2467
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 271ms/step - loss: 0.0277 - mean_absolute_error: 0.1305 - mean_absolute_percentage_error: 35.1175 - root_mean_squared_error: 0.1660 - val_loss: 0.0544 - val_mean_absolute_error: 0.1954 - val_mean_absolute_percentage_error: 16122424.0000 - val_root_mean_squared_error: 0.2333
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 248ms/step - loss: 0.0206 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 28.3482 - root_mean_squared_error: 0.1435 - val_loss: 0.0567 - val_mean_absolute_error: 0.2021 - val_mean_absolute_percentage_error: 14852440.0000 - val_root_mean_squared_error: 0.2382
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - loss: 0.0196 - mean_absolute_error: 0.1085 - mean_absolute_percentage_error: 26.8460 - root_mean_squared_error: 0.1399 - val_loss: 0.0566 - val_mean_absolute_error: 0.2031 - val_mean_absolute_percentage_error: 15327490.0000 - val_root_mean_squared_error: 0.2379
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - loss: 0.0199 - mean_absolute_error: 0.1084 - mean_absolute_percentage_error: 28.6920 - root_mean_squared_error: 0.1409 - val_loss: 0.0599 - val_mean_absolute_error: 0.2093 - val_mean_absolute_percentage_error: 14227861.0000 - val_root_mean_squared_error: 0.2446
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 249ms/step - loss: 0.0194 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 25.8445 - root_mean_squared_error: 0.1394 - val_loss: 0.0584 - val_mean_absolute_error: 0.2080 - val_mean_absolute_percentage_error: 15059793.0000 - val_root_mean_squared_error: 0.2416
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - loss: 0.0190 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 26.0353 - root_mean_squared_error: 0.1378 - val_loss: 0.0585 - val_mean_absolute_error: 0.2080 - val_mean_absolute_percentage_error: 15054754.0000 - val_root_mean_squared_error: 0.2419
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 255ms/step - loss: 0.0186 - mean_absolute_error: 0.1054 - mean_absolute_percentage_error: 28.2163 - root_mean_squared_error: 0.1363 - val_loss: 0.0592 - val_mean_absolute_error: 0.2093 - val_mean_absolute_percentage_error: 15173057.0000 - val_root_mean_squared_error: 0.2434
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 246ms/step - loss: 0.0189 - mean_absolute_error: 0.1055 - mean_absolute_percentage_error: 27.7777 - root_mean_squared_error: 0.1374 - val_loss: 0.0638 - val_mean_absolute_error: 0.2145 - val_mean_absolute_percentage_error: 13823406.0000 - val_root_mean_squared_error: 0.2527
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 257ms/step - loss: 0.0185 - mean_absolute_error: 0.1066 - mean_absolute_percentage_error: 27.0256 - root_mean_squared_error: 0.1358 - val_loss: 0.0617 - val_mean_absolute_error: 0.2132 - val_mean_absolute_percentage_error: 14840488.0000 - val_root_mean_squared_error: 0.2485
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 238ms/step - loss: 0.0176 - mean_absolute_error: 0.1036 - mean_absolute_percentage_error: 25.4838 - root_mean_squared_error: 0.1328 - val_loss: 0.0615 - val_mean_absolute_error: 0.2130 - val_mean_absolute_percentage_error: 15200954.0000 - val_root_mean_squared_error: 0.2479
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 258ms/step - loss: 0.0171 - mean_absolute_error: 0.1015 - mean_absolute_percentage_error: 26.5933 - root_mean_squared_error: 0.1308 - val_loss: 0.0624 - val_mean_absolute_error: 0.2141 - val_mean_absolute_percentage_error: 14470446.0000 - val_root_mean_squared_error: 0.2497
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - loss: 0.0177 - mean_absolute_error: 0.1042 - mean_absolute_percentage_error: 25.9879 - root_mean_squared_error: 0.1331 - val_loss: 0.0624 - val_mean_absolute_error: 0.2150 - val_mean_absolute_percentage_error: 15162654.0000 - val_root_mean_squared_error: 0.2498
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 244ms/step - loss: 0.0172 - mean_absolute_error: 0.1022 - mean_absolute_percentage_error: 25.4848 - root_mean_squared_error: 0.1311 - val_loss: 0.0673 - val_mean_absolute_error: 0.2216 - val_mean_absolute_percentage_error: 13816430.0000 - val_root_mean_squared_error: 0.2595
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 295ms/step - loss: 0.0172 - mean_absolute_error: 0.1033 - mean_absolute_percentage_error: 23.8495 - root_mean_squared_error: 0.1311 - val_loss: 0.0694 - val_mean_absolute_error: 0.2230 - val_mean_absolute_percentage_error: 13805944.0000 - val_root_mean_squared_error: 0.2634
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 261ms/step - loss: 0.0178 - mean_absolute_error: 0.1044 - mean_absolute_percentage_error: 25.6337 - root_mean_squared_error: 0.1332 - val_loss: 0.0663 - val_mean_absolute_error: 0.2207 - val_mean_absolute_percentage_error: 14401503.0000 - val_root_mean_squared_error: 0.2575
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - loss: 0.0171 - mean_absolute_error: 0.1024 - mean_absolute_percentage_error: 25.0096 - root_mean_squared_error: 0.1306 - val_loss: 0.0689 - val_mean_absolute_error: 0.2273 - val_mean_absolute_percentage_error: 14115665.0000 - val_root_mean_squared_error: 0.2625
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 256ms/step - loss: 0.0166 - mean_absolute_error: 0.0997 - mean_absolute_percentage_error: 24.3512 - root_mean_squared_error: 0.1286 - val_loss: 0.0664 - val_mean_absolute_error: 0.2205 - val_mean_absolute_percentage_error: 14906089.0000 - val_root_mean_squared_error: 0.2577
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 249ms/step - loss: 0.0164 - mean_absolute_error: 0.1003 - mean_absolute_percentage_error: 24.2876 - root_mean_squared_error: 0.1282 - val_loss: 0.0675 - val_mean_absolute_error: 0.2225 - val_mean_absolute_percentage_error: 14819530.0000 - val_root_mean_squared_error: 0.2598
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 289ms/step - loss: 0.0155 - mean_absolute_error: 0.0964 - mean_absolute_percentage_error: 23.4520 - root_mean_squared_error: 0.1245 - val_loss: 0.0691 - val_mean_absolute_error: 0.2253 - val_mean_absolute_percentage_error: 15272900.0000 - val_root_mean_squared_error: 0.2630

# %%
y_pred = model_cnn_16.predict(x_test)
evaluation_cnn_16 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_16
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# {'Mean Squared Error: ': np.float64(355.5798910350058),
#  'Mean Absolute Error: ': np.float64(14.188494098429777),
#  'Root Mean Absolute Error: ': 18.856826112445482,
#  'Mean Absolute Percentage Error: ': np.float64(26.8978685202793)}

# %%
# y_pred = model_cnn_15.predict(x_test)
loss, mae, mape, rmse = model_cnn_16.evaluate(x_test, y_test)
print("model cnn 16")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0283 - mean_absolute_error: 0.1267 - mean_absolute_percentage_error: 34.3115 - root_mean_squared_error: 0.1684
# model cnn 16
# Mean Square Error: 0.028346609324216843
# Mean Absolute Error: 0.12668298184871674
# Mean Absolute Percentage Error: 34.31153106689453
# Root Mean Squared Error: 0.1683645099401474

# %% [markdown]
# ## model 17 (1024 512)

# %%
lr = 0.0003

model_cnn_17 = Sequential()
model_cnn_17.add(Conv1D(filters=1024, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_17.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_17.add(Flatten())
model_cnn_17.add(Dense(7))
model_cnn_17.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_17.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_35 (Conv1D)              │ (None, 7, 1024)        │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_36 (Conv1D)              │ (None, 7, 512)         │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_16 (Flatten)            │ (None, 3584)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 7)              │        25,095 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 557,063 (2.13 MB)
#  Trainable params: 557,063 (2.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_17.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=40,
    batch_size=42
)
# Out:
# Epoch 1/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.1279 - mean_absolute_error: 0.2878 - mean_absolute_percentage_error: 57.0378 - root_mean_squared_error: 0.3450 - val_loss: 0.0544 - val_mean_absolute_error: 0.1926 - val_mean_absolute_percentage_error: 17343620.0000 - val_root_mean_squared_error: 0.2333
# Epoch 2/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.0225 - mean_absolute_error: 0.1166 - mean_absolute_percentage_error: 28.2473 - root_mean_squared_error: 0.1499 - val_loss: 0.0549 - val_mean_absolute_error: 0.1977 - val_mean_absolute_percentage_error: 15828556.0000 - val_root_mean_squared_error: 0.2343
# Epoch 3/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0201 - mean_absolute_error: 0.1101 - mean_absolute_percentage_error: 28.3008 - root_mean_squared_error: 0.1419 - val_loss: 0.0566 - val_mean_absolute_error: 0.2026 - val_mean_absolute_percentage_error: 15208618.0000 - val_root_mean_squared_error: 0.2379
# Epoch 4/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0200 - mean_absolute_error: 0.1094 - mean_absolute_percentage_error: 26.1533 - root_mean_squared_error: 0.1413 - val_loss: 0.0579 - val_mean_absolute_error: 0.2060 - val_mean_absolute_percentage_error: 14795609.0000 - val_root_mean_squared_error: 0.2406
# Epoch 5/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.0195 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 26.9698 - root_mean_squared_error: 0.1397 - val_loss: 0.0582 - val_mean_absolute_error: 0.2071 - val_mean_absolute_percentage_error: 14577113.0000 - val_root_mean_squared_error: 0.2413
# Epoch 6/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - loss: 0.0183 - mean_absolute_error: 0.1053 - mean_absolute_percentage_error: 25.7921 - root_mean_squared_error: 0.1353 - val_loss: 0.0582 - val_mean_absolute_error: 0.2062 - val_mean_absolute_percentage_error: 15498055.0000 - val_root_mean_squared_error: 0.2413
# Epoch 7/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0190 - mean_absolute_error: 0.1065 - mean_absolute_percentage_error: 26.4087 - root_mean_squared_error: 0.1377 - val_loss: 0.0618 - val_mean_absolute_error: 0.2147 - val_mean_absolute_percentage_error: 14034554.0000 - val_root_mean_squared_error: 0.2486
# Epoch 8/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.0188 - mean_absolute_error: 0.1066 - mean_absolute_percentage_error: 26.5627 - root_mean_squared_error: 0.1370 - val_loss: 0.0606 - val_mean_absolute_error: 0.2115 - val_mean_absolute_percentage_error: 14663455.0000 - val_root_mean_squared_error: 0.2462
# Epoch 9/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.0186 - mean_absolute_error: 0.1067 - mean_absolute_percentage_error: 27.7582 - root_mean_squared_error: 0.1362 - val_loss: 0.0633 - val_mean_absolute_error: 0.2158 - val_mean_absolute_percentage_error: 14024719.0000 - val_root_mean_squared_error: 0.2516
# Epoch 10/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.0177 - mean_absolute_error: 0.1041 - mean_absolute_percentage_error: 25.2741 - root_mean_squared_error: 0.1331 - val_loss: 0.0605 - val_mean_absolute_error: 0.2115 - val_mean_absolute_percentage_error: 15254847.0000 - val_root_mean_squared_error: 0.2459
# Epoch 11/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0166 - mean_absolute_error: 0.1000 - mean_absolute_percentage_error: 24.4696 - root_mean_squared_error: 0.1287 - val_loss: 0.0690 - val_mean_absolute_error: 0.2231 - val_mean_absolute_percentage_error: 13260428.0000 - val_root_mean_squared_error: 0.2626
# Epoch 12/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - loss: 0.0187 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 25.5224 - root_mean_squared_error: 0.1368 - val_loss: 0.0640 - val_mean_absolute_error: 0.2164 - val_mean_absolute_percentage_error: 14543270.0000 - val_root_mean_squared_error: 0.2531
# Epoch 13/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - loss: 0.0167 - mean_absolute_error: 0.1010 - mean_absolute_percentage_error: 23.5952 - root_mean_squared_error: 0.1294 - val_loss: 0.0658 - val_mean_absolute_error: 0.2205 - val_mean_absolute_percentage_error: 14230559.0000 - val_root_mean_squared_error: 0.2565
# Epoch 14/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0164 - mean_absolute_error: 0.0995 - mean_absolute_percentage_error: 25.1169 - root_mean_squared_error: 0.1279 - val_loss: 0.0666 - val_mean_absolute_error: 0.2211 - val_mean_absolute_percentage_error: 14372681.0000 - val_root_mean_squared_error: 0.2580
# Epoch 15/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0166 - mean_absolute_error: 0.0997 - mean_absolute_percentage_error: 23.9845 - root_mean_squared_error: 0.1286 - val_loss: 0.0634 - val_mean_absolute_error: 0.2168 - val_mean_absolute_percentage_error: 15247317.0000 - val_root_mean_squared_error: 0.2518
# Epoch 16/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.0154 - mean_absolute_error: 0.0969 - mean_absolute_percentage_error: 23.8827 - root_mean_squared_error: 0.1242 - val_loss: 0.0677 - val_mean_absolute_error: 0.2226 - val_mean_absolute_percentage_error: 14152797.0000 - val_root_mean_squared_error: 0.2602
# Epoch 17/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0173 - mean_absolute_error: 0.1028 - mean_absolute_percentage_error: 24.6724 - root_mean_squared_error: 0.1316 - val_loss: 0.0697 - val_mean_absolute_error: 0.2241 - val_mean_absolute_percentage_error: 14013633.0000 - val_root_mean_squared_error: 0.2640
# Epoch 18/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.0172 - mean_absolute_error: 0.1032 - mean_absolute_percentage_error: 24.9665 - root_mean_squared_error: 0.1311 - val_loss: 0.0694 - val_mean_absolute_error: 0.2255 - val_mean_absolute_percentage_error: 13877437.0000 - val_root_mean_squared_error: 0.2635
# Epoch 19/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.0160 - mean_absolute_error: 0.0981 - mean_absolute_percentage_error: 25.7561 - root_mean_squared_error: 0.1263 - val_loss: 0.0671 - val_mean_absolute_error: 0.2222 - val_mean_absolute_percentage_error: 15189496.0000 - val_root_mean_squared_error: 0.2591
# Epoch 20/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0151 - mean_absolute_error: 0.0952 - mean_absolute_percentage_error: 22.7686 - root_mean_squared_error: 0.1229 - val_loss: 0.0692 - val_mean_absolute_error: 0.2266 - val_mean_absolute_percentage_error: 14210892.0000 - val_root_mean_squared_error: 0.2631
# Epoch 21/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 0.0154 - mean_absolute_error: 0.0968 - mean_absolute_percentage_error: 23.6065 - root_mean_squared_error: 0.1241 - val_loss: 0.0740 - val_mean_absolute_error: 0.2311 - val_mean_absolute_percentage_error: 13864498.0000 - val_root_mean_squared_error: 0.2720
# Epoch 22/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.0170 - mean_absolute_error: 0.1029 - mean_absolute_percentage_error: 24.8870 - root_mean_squared_error: 0.1304 - val_loss: 0.0717 - val_mean_absolute_error: 0.2302 - val_mean_absolute_percentage_error: 14738220.0000 - val_root_mean_squared_error: 0.2678
# Epoch 23/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0154 - mean_absolute_error: 0.0971 - mean_absolute_percentage_error: 24.0666 - root_mean_squared_error: 0.1242 - val_loss: 0.0738 - val_mean_absolute_error: 0.2340 - val_mean_absolute_percentage_error: 14302694.0000 - val_root_mean_squared_error: 0.2716
# Epoch 24/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0155 - mean_absolute_error: 0.0971 - mean_absolute_percentage_error: 23.7521 - root_mean_squared_error: 0.1243 - val_loss: 0.0732 - val_mean_absolute_error: 0.2328 - val_mean_absolute_percentage_error: 14647080.0000 - val_root_mean_squared_error: 0.2705
# Epoch 25/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 0.0152 - mean_absolute_error: 0.0962 - mean_absolute_percentage_error: 23.3467 - root_mean_squared_error: 0.1232 - val_loss: 0.0753 - val_mean_absolute_error: 0.2364 - val_mean_absolute_percentage_error: 14136668.0000 - val_root_mean_squared_error: 0.2745
# Epoch 26/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - loss: 0.0153 - mean_absolute_error: 0.0957 - mean_absolute_percentage_error: 23.5553 - root_mean_squared_error: 0.1235 - val_loss: 0.0709 - val_mean_absolute_error: 0.2274 - val_mean_absolute_percentage_error: 15345314.0000 - val_root_mean_squared_error: 0.2662
# Epoch 27/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0165 - mean_absolute_error: 0.1015 - mean_absolute_percentage_error: 25.5943 - root_mean_squared_error: 0.1285 - val_loss: 0.0701 - val_mean_absolute_error: 0.2275 - val_mean_absolute_percentage_error: 14809722.0000 - val_root_mean_squared_error: 0.2647
# Epoch 28/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 0.0151 - mean_absolute_error: 0.0954 - mean_absolute_percentage_error: 23.8780 - root_mean_squared_error: 0.1228 - val_loss: 0.0766 - val_mean_absolute_error: 0.2346 - val_mean_absolute_percentage_error: 14069754.0000 - val_root_mean_squared_error: 0.2767
# Epoch 29/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.0160 - mean_absolute_error: 0.0983 - mean_absolute_percentage_error: 23.8555 - root_mean_squared_error: 0.1263 - val_loss: 0.0708 - val_mean_absolute_error: 0.2280 - val_mean_absolute_percentage_error: 14797521.0000 - val_root_mean_squared_error: 0.2661
# Epoch 30/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.0143 - mean_absolute_error: 0.0932 - mean_absolute_percentage_error: 23.4191 - root_mean_squared_error: 0.1196 - val_loss: 0.0717 - val_mean_absolute_error: 0.2301 - val_mean_absolute_percentage_error: 15096802.0000 - val_root_mean_squared_error: 0.2677
# Epoch 31/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0151 - mean_absolute_error: 0.0961 - mean_absolute_percentage_error: 23.3382 - root_mean_squared_error: 0.1230 - val_loss: 0.0716 - val_mean_absolute_error: 0.2287 - val_mean_absolute_percentage_error: 15430631.0000 - val_root_mean_squared_error: 0.2676
# Epoch 32/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - loss: 0.0138 - mean_absolute_error: 0.0916 - mean_absolute_percentage_error: 22.7892 - root_mean_squared_error: 0.1175 - val_loss: 0.0725 - val_mean_absolute_error: 0.2281 - val_mean_absolute_percentage_error: 15751297.0000 - val_root_mean_squared_error: 0.2693
# Epoch 33/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.0144 - mean_absolute_error: 0.0933 - mean_absolute_percentage_error: 23.2591 - root_mean_squared_error: 0.1199 - val_loss: 0.0731 - val_mean_absolute_error: 0.2277 - val_mean_absolute_percentage_error: 16560352.0000 - val_root_mean_squared_error: 0.2704
# Epoch 34/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.0151 - mean_absolute_error: 0.0957 - mean_absolute_percentage_error: 23.6911 - root_mean_squared_error: 0.1229 - val_loss: 0.0780 - val_mean_absolute_error: 0.2352 - val_mean_absolute_percentage_error: 14161751.0000 - val_root_mean_squared_error: 0.2793
# Epoch 35/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 0.0140 - mean_absolute_error: 0.0927 - mean_absolute_percentage_error: 21.7707 - root_mean_squared_error: 0.1184 - val_loss: 0.0745 - val_mean_absolute_error: 0.2303 - val_mean_absolute_percentage_error: 14958197.0000 - val_root_mean_squared_error: 0.2730
# Epoch 36/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.0135 - mean_absolute_error: 0.0903 - mean_absolute_percentage_error: 22.3497 - root_mean_squared_error: 0.1162 - val_loss: 0.0712 - val_mean_absolute_error: 0.2267 - val_mean_absolute_percentage_error: 15899403.0000 - val_root_mean_squared_error: 0.2668
# Epoch 37/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.0132 - mean_absolute_error: 0.0892 - mean_absolute_percentage_error: 21.6197 - root_mean_squared_error: 0.1150 - val_loss: 0.0750 - val_mean_absolute_error: 0.2312 - val_mean_absolute_percentage_error: 15262968.0000 - val_root_mean_squared_error: 0.2738
# Epoch 38/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - loss: 0.0153 - mean_absolute_error: 0.0964 - mean_absolute_percentage_error: 23.7393 - root_mean_squared_error: 0.1236 - val_loss: 0.0723 - val_mean_absolute_error: 0.2263 - val_mean_absolute_percentage_error: 17243218.0000 - val_root_mean_squared_error: 0.2689
# Epoch 39/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0148 - mean_absolute_error: 0.0946 - mean_absolute_percentage_error: 23.8366 - root_mean_squared_error: 0.1218 - val_loss: 0.0726 - val_mean_absolute_error: 0.2264 - val_mean_absolute_percentage_error: 16947314.0000 - val_root_mean_squared_error: 0.2694
# Epoch 40/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0136 - mean_absolute_error: 0.0913 - mean_absolute_percentage_error: 22.6461 - root_mean_squared_error: 0.1165 - val_loss: 0.0751 - val_mean_absolute_error: 0.2317 - val_mean_absolute_percentage_error: 16208654.0000 - val_root_mean_squared_error: 0.2741

# %%
y_pred = model_cnn_17.predict(x_test)
evaluation_cnn_17 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_17
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# {'Mean Squared Error: ': np.float64(386.56729889748334),
#  'Mean Absolute Error: ': np.float64(14.146349303576411),
#  'Root Mean Absolute Error: ': 19.661314780489207,
#  'Mean Absolute Percentage Error: ': np.float64(27.17288654530953)}

# %%
# y_pred = model_cnn_17.predict(x_test)
loss, mae, mape, rmse = model_cnn_17.evaluate(x_test, y_test)
print("model cnn 17")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0308 - mean_absolute_error: 0.1263 - mean_absolute_percentage_error: 34.8105 - root_mean_squared_error: 0.1755
# model cnn 17
# Mean Square Error: 0.030816907063126564
# Mean Absolute Error: 0.1263066828250885
# Mean Absolute Percentage Error: 34.81047439575195
# Root Mean Squared Error: 0.17554745078086853

# %% [markdown]
# ## model 18 (1024 512)

# %%
lr = 0.0003

model_cnn_18 = Sequential()
model_cnn_18.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_18.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_18.add(Flatten())
model_cnn_18.add(Dense(7))
model_cnn_18.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_18.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_37 (Conv1D)              │ (None, 7, 128)         │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_38 (Conv1D)              │ (None, 7, 256)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_17 (Flatten)            │ (None, 1792)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 7)              │        12,551 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 46,471 (181.53 KB)
#  Trainable params: 46,471 (181.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_18.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=15,
    batch_size=64
)
# Out:
# Epoch 1/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.1938 - mean_absolute_error: 0.3818 - mean_absolute_percentage_error: 67.7230 - root_mean_squared_error: 0.4323 - val_loss: 0.0973 - val_mean_absolute_error: 0.2466 - val_mean_absolute_percentage_error: 20138704.0000 - val_root_mean_squared_error: 0.3119
# Epoch 2/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0386 - mean_absolute_error: 0.1567 - mean_absolute_percentage_error: 39.5126 - root_mean_squared_error: 0.1958 - val_loss: 0.0617 - val_mean_absolute_error: 0.2121 - val_mean_absolute_percentage_error: 12361111.0000 - val_root_mean_squared_error: 0.2484
# Epoch 3/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0271 - mean_absolute_error: 0.1332 - mean_absolute_percentage_error: 29.3987 - root_mean_squared_error: 0.1647 - val_loss: 0.0553 - val_mean_absolute_error: 0.1949 - val_mean_absolute_percentage_error: 16686713.0000 - val_root_mean_squared_error: 0.2352
# Epoch 4/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0223 - mean_absolute_error: 0.1148 - mean_absolute_percentage_error: 30.1736 - root_mean_squared_error: 0.1493 - val_loss: 0.0563 - val_mean_absolute_error: 0.2011 - val_mean_absolute_percentage_error: 13870144.0000 - val_root_mean_squared_error: 0.2373
# Epoch 5/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0217 - mean_absolute_error: 0.1161 - mean_absolute_percentage_error: 26.4440 - root_mean_squared_error: 0.1472 - val_loss: 0.0536 - val_mean_absolute_error: 0.1958 - val_mean_absolute_percentage_error: 15100589.0000 - val_root_mean_squared_error: 0.2315
# Epoch 6/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0202 - mean_absolute_error: 0.1103 - mean_absolute_percentage_error: 27.5376 - root_mean_squared_error: 0.1422 - val_loss: 0.0556 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 14481514.0000 - val_root_mean_squared_error: 0.2358
# Epoch 7/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0195 - mean_absolute_error: 0.1085 - mean_absolute_percentage_error: 27.8495 - root_mean_squared_error: 0.1395 - val_loss: 0.0564 - val_mean_absolute_error: 0.2022 - val_mean_absolute_percentage_error: 14457844.0000 - val_root_mean_squared_error: 0.2375
# Epoch 8/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0193 - mean_absolute_error: 0.1074 - mean_absolute_percentage_error: 26.7344 - root_mean_squared_error: 0.1389 - val_loss: 0.0584 - val_mean_absolute_error: 0.2064 - val_mean_absolute_percentage_error: 13889988.0000 - val_root_mean_squared_error: 0.2416
# Epoch 9/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0194 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 26.6846 - root_mean_squared_error: 0.1393 - val_loss: 0.0572 - val_mean_absolute_error: 0.2051 - val_mean_absolute_percentage_error: 14307807.0000 - val_root_mean_squared_error: 0.2392
# Epoch 10/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0188 - mean_absolute_error: 0.1063 - mean_absolute_percentage_error: 27.3892 - root_mean_squared_error: 0.1372 - val_loss: 0.0577 - val_mean_absolute_error: 0.2060 - val_mean_absolute_percentage_error: 14036234.0000 - val_root_mean_squared_error: 0.2402
# Epoch 11/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0192 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 26.1812 - root_mean_squared_error: 0.1386 - val_loss: 0.0578 - val_mean_absolute_error: 0.2059 - val_mean_absolute_percentage_error: 14244615.0000 - val_root_mean_squared_error: 0.2403
# Epoch 12/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0175 - mean_absolute_error: 0.1031 - mean_absolute_percentage_error: 25.4548 - root_mean_squared_error: 0.1322 - val_loss: 0.0586 - val_mean_absolute_error: 0.2075 - val_mean_absolute_percentage_error: 14348381.0000 - val_root_mean_squared_error: 0.2420
# Epoch 13/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0175 - mean_absolute_error: 0.1024 - mean_absolute_percentage_error: 25.5168 - root_mean_squared_error: 0.1322 - val_loss: 0.0592 - val_mean_absolute_error: 0.2090 - val_mean_absolute_percentage_error: 14350631.0000 - val_root_mean_squared_error: 0.2432
# Epoch 14/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0181 - mean_absolute_error: 0.1043 - mean_absolute_percentage_error: 26.4020 - root_mean_squared_error: 0.1344 - val_loss: 0.0602 - val_mean_absolute_error: 0.2097 - val_mean_absolute_percentage_error: 14098282.0000 - val_root_mean_squared_error: 0.2453
# Epoch 15/15
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0173 - mean_absolute_error: 0.1017 - mean_absolute_percentage_error: 25.1317 - root_mean_squared_error: 0.1314 - val_loss: 0.0621 - val_mean_absolute_error: 0.2139 - val_mean_absolute_percentage_error: 13864195.0000 - val_root_mean_squared_error: 0.2492

# %%
y_pred = model_cnn_18.predict(x_test)
evaluation_cnn_18 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_18
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# {'Mean Squared Error: ': np.float64(313.784171152303),
#  'Mean Absolute Error: ': np.float64(13.686381456803302),
#  'Root Mean Absolute Error: ': 17.713954136564286,
#  'Mean Absolute Percentage Error: ': np.float64(24.85618467718476)}

# %%
# y_pred = model_cnn_18.predict(x_test)
loss, mae, mape, rmse = model_cnn_18.evaluate(x_test, y_test)
print("model cnn 18")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0250 - mean_absolute_error: 0.1222 - mean_absolute_percentage_error: 31.4906 - root_mean_squared_error: 0.1582
# model cnn 18
# Mean Square Error: 0.025014681741595268
# Mean Absolute Error: 0.12219983339309692
# Mean Absolute Percentage Error: 31.490585327148438
# Root Mean Squared Error: 0.15816029906272888

# %% [markdown]
# ## model 19 (256 128 512, epoch 50)

# %%
lr = 0.0003

model_cnn_19 = Sequential()
model_cnn_19.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_19.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_19.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_19.add(Flatten())
model_cnn_19.add(Dense(7))
model_cnn_19.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_19.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_39 (Conv1D)              │ (None, 7, 256)         │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_40 (Conv1D)              │ (None, 7, 128)         │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_41 (Conv1D)              │ (None, 7, 512)         │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_18 (Flatten)            │ (None, 3584)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 7)              │        25,095 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 125,831 (491.53 KB)
#  Trainable params: 125,831 (491.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_19.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=50,
    batch_size=42
)
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.1412 - mean_absolute_error: 0.3094 - mean_absolute_percentage_error: 59.2217 - root_mean_squared_error: 0.3656 - val_loss: 0.0585 - val_mean_absolute_error: 0.2011 - val_mean_absolute_percentage_error: 14237769.0000 - val_root_mean_squared_error: 0.2419
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0245 - mean_absolute_error: 0.1218 - mean_absolute_percentage_error: 30.1596 - root_mean_squared_error: 0.1565 - val_loss: 0.0538 - val_mean_absolute_error: 0.1921 - val_mean_absolute_percentage_error: 15849830.0000 - val_root_mean_squared_error: 0.2321
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0222 - mean_absolute_error: 0.1146 - mean_absolute_percentage_error: 30.9396 - root_mean_squared_error: 0.1489 - val_loss: 0.0533 - val_mean_absolute_error: 0.1919 - val_mean_absolute_percentage_error: 16415479.0000 - val_root_mean_squared_error: 0.2309
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0206 - mean_absolute_error: 0.1108 - mean_absolute_percentage_error: 29.7614 - root_mean_squared_error: 0.1436 - val_loss: 0.0541 - val_mean_absolute_error: 0.1964 - val_mean_absolute_percentage_error: 15868969.0000 - val_root_mean_squared_error: 0.2326
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0195 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 26.8543 - root_mean_squared_error: 0.1395 - val_loss: 0.0559 - val_mean_absolute_error: 0.2000 - val_mean_absolute_percentage_error: 14709471.0000 - val_root_mean_squared_error: 0.2365
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0194 - mean_absolute_error: 0.1085 - mean_absolute_percentage_error: 28.3896 - root_mean_squared_error: 0.1393 - val_loss: 0.0557 - val_mean_absolute_error: 0.2012 - val_mean_absolute_percentage_error: 14695612.0000 - val_root_mean_squared_error: 0.2360
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0182 - mean_absolute_error: 0.1044 - mean_absolute_percentage_error: 26.5381 - root_mean_squared_error: 0.1350 - val_loss: 0.0554 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 15069187.0000 - val_root_mean_squared_error: 0.2353
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0180 - mean_absolute_error: 0.1046 - mean_absolute_percentage_error: 26.1877 - root_mean_squared_error: 0.1342 - val_loss: 0.0556 - val_mean_absolute_error: 0.2021 - val_mean_absolute_percentage_error: 15022871.0000 - val_root_mean_squared_error: 0.2359
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0177 - mean_absolute_error: 0.1032 - mean_absolute_percentage_error: 25.4560 - root_mean_squared_error: 0.1330 - val_loss: 0.0573 - val_mean_absolute_error: 0.2059 - val_mean_absolute_percentage_error: 14819406.0000 - val_root_mean_squared_error: 0.2394
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0178 - mean_absolute_error: 0.1036 - mean_absolute_percentage_error: 26.8851 - root_mean_squared_error: 0.1335 - val_loss: 0.0580 - val_mean_absolute_error: 0.2058 - val_mean_absolute_percentage_error: 15276116.0000 - val_root_mean_squared_error: 0.2408
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0179 - mean_absolute_error: 0.1039 - mean_absolute_percentage_error: 26.7978 - root_mean_squared_error: 0.1337 - val_loss: 0.0573 - val_mean_absolute_error: 0.2034 - val_mean_absolute_percentage_error: 15397653.0000 - val_root_mean_squared_error: 0.2394
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0178 - mean_absolute_error: 0.1032 - mean_absolute_percentage_error: 26.4206 - root_mean_squared_error: 0.1333 - val_loss: 0.0592 - val_mean_absolute_error: 0.2086 - val_mean_absolute_percentage_error: 15483066.0000 - val_root_mean_squared_error: 0.2434
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0166 - mean_absolute_error: 0.0995 - mean_absolute_percentage_error: 24.8809 - root_mean_squared_error: 0.1289 - val_loss: 0.0623 - val_mean_absolute_error: 0.2155 - val_mean_absolute_percentage_error: 13849164.0000 - val_root_mean_squared_error: 0.2495
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0175 - mean_absolute_error: 0.1024 - mean_absolute_percentage_error: 25.3666 - root_mean_squared_error: 0.1323 - val_loss: 0.0605 - val_mean_absolute_error: 0.2113 - val_mean_absolute_percentage_error: 14849453.0000 - val_root_mean_squared_error: 0.2460
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0167 - mean_absolute_error: 0.1006 - mean_absolute_percentage_error: 25.0133 - root_mean_squared_error: 0.1292 - val_loss: 0.0636 - val_mean_absolute_error: 0.2161 - val_mean_absolute_percentage_error: 14765384.0000 - val_root_mean_squared_error: 0.2521
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0174 - mean_absolute_error: 0.1019 - mean_absolute_percentage_error: 26.6482 - root_mean_squared_error: 0.1318 - val_loss: 0.0623 - val_mean_absolute_error: 0.2137 - val_mean_absolute_percentage_error: 15133820.0000 - val_root_mean_squared_error: 0.2496
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0173 - mean_absolute_error: 0.1025 - mean_absolute_percentage_error: 27.1884 - root_mean_squared_error: 0.1314 - val_loss: 0.0650 - val_mean_absolute_error: 0.2172 - val_mean_absolute_percentage_error: 15390302.0000 - val_root_mean_squared_error: 0.2549
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0163 - mean_absolute_error: 0.0990 - mean_absolute_percentage_error: 25.4779 - root_mean_squared_error: 0.1275 - val_loss: 0.0693 - val_mean_absolute_error: 0.2258 - val_mean_absolute_percentage_error: 14240401.0000 - val_root_mean_squared_error: 0.2633
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0160 - mean_absolute_error: 0.0980 - mean_absolute_percentage_error: 24.6957 - root_mean_squared_error: 0.1265 - val_loss: 0.0673 - val_mean_absolute_error: 0.2215 - val_mean_absolute_percentage_error: 15200050.0000 - val_root_mean_squared_error: 0.2594
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0159 - mean_absolute_error: 0.0985 - mean_absolute_percentage_error: 24.6783 - root_mean_squared_error: 0.1261 - val_loss: 0.0705 - val_mean_absolute_error: 0.2283 - val_mean_absolute_percentage_error: 13891497.0000 - val_root_mean_squared_error: 0.2656
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0166 - mean_absolute_error: 0.1006 - mean_absolute_percentage_error: 24.5157 - root_mean_squared_error: 0.1286 - val_loss: 0.0713 - val_mean_absolute_error: 0.2281 - val_mean_absolute_percentage_error: 14581570.0000 - val_root_mean_squared_error: 0.2670
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0155 - mean_absolute_error: 0.0965 - mean_absolute_percentage_error: 24.1546 - root_mean_squared_error: 0.1244 - val_loss: 0.0711 - val_mean_absolute_error: 0.2281 - val_mean_absolute_percentage_error: 14393508.0000 - val_root_mean_squared_error: 0.2667
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0152 - mean_absolute_error: 0.0964 - mean_absolute_percentage_error: 24.0677 - root_mean_squared_error: 0.1234 - val_loss: 0.0721 - val_mean_absolute_error: 0.2303 - val_mean_absolute_percentage_error: 14769592.0000 - val_root_mean_squared_error: 0.2686
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0151 - mean_absolute_error: 0.0955 - mean_absolute_percentage_error: 23.7201 - root_mean_squared_error: 0.1227 - val_loss: 0.0718 - val_mean_absolute_error: 0.2282 - val_mean_absolute_percentage_error: 15780579.0000 - val_root_mean_squared_error: 0.2679
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0156 - mean_absolute_error: 0.0988 - mean_absolute_percentage_error: 23.5438 - root_mean_squared_error: 0.1250 - val_loss: 0.0786 - val_mean_absolute_error: 0.2393 - val_mean_absolute_percentage_error: 12918152.0000 - val_root_mean_squared_error: 0.2804
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0178 - mean_absolute_error: 0.1056 - mean_absolute_percentage_error: 24.8129 - root_mean_squared_error: 0.1333 - val_loss: 0.0736 - val_mean_absolute_error: 0.2322 - val_mean_absolute_percentage_error: 13977512.0000 - val_root_mean_squared_error: 0.2712
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0147 - mean_absolute_error: 0.0946 - mean_absolute_percentage_error: 22.1491 - root_mean_squared_error: 0.1212 - val_loss: 0.0731 - val_mean_absolute_error: 0.2314 - val_mean_absolute_percentage_error: 14621927.0000 - val_root_mean_squared_error: 0.2703
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0137 - mean_absolute_error: 0.0907 - mean_absolute_percentage_error: 21.3099 - root_mean_squared_error: 0.1169 - val_loss: 0.0728 - val_mean_absolute_error: 0.2302 - val_mean_absolute_percentage_error: 14772594.0000 - val_root_mean_squared_error: 0.2697
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0137 - mean_absolute_error: 0.0914 - mean_absolute_percentage_error: 22.6213 - root_mean_squared_error: 0.1169 - val_loss: 0.0805 - val_mean_absolute_error: 0.2402 - val_mean_absolute_percentage_error: 14501095.0000 - val_root_mean_squared_error: 0.2837
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0135 - mean_absolute_error: 0.0911 - mean_absolute_percentage_error: 21.8738 - root_mean_squared_error: 0.1162 - val_loss: 0.0744 - val_mean_absolute_error: 0.2341 - val_mean_absolute_percentage_error: 14948260.0000 - val_root_mean_squared_error: 0.2728
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0125 - mean_absolute_error: 0.0875 - mean_absolute_percentage_error: 21.1084 - root_mean_squared_error: 0.1119 - val_loss: 0.0747 - val_mean_absolute_error: 0.2354 - val_mean_absolute_percentage_error: 14801805.0000 - val_root_mean_squared_error: 0.2732
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0130 - mean_absolute_error: 0.0892 - mean_absolute_percentage_error: 20.4927 - root_mean_squared_error: 0.1140 - val_loss: 0.0770 - val_mean_absolute_error: 0.2381 - val_mean_absolute_percentage_error: 14835487.0000 - val_root_mean_squared_error: 0.2775
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0125 - mean_absolute_error: 0.0870 - mean_absolute_percentage_error: 20.0392 - root_mean_squared_error: 0.1119 - val_loss: 0.0800 - val_mean_absolute_error: 0.2423 - val_mean_absolute_percentage_error: 14331858.0000 - val_root_mean_squared_error: 0.2828
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0141 - mean_absolute_error: 0.0922 - mean_absolute_percentage_error: 21.3732 - root_mean_squared_error: 0.1186 - val_loss: 0.0766 - val_mean_absolute_error: 0.2346 - val_mean_absolute_percentage_error: 15942212.0000 - val_root_mean_squared_error: 0.2768
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0128 - mean_absolute_error: 0.0882 - mean_absolute_percentage_error: 21.0796 - root_mean_squared_error: 0.1131 - val_loss: 0.0820 - val_mean_absolute_error: 0.2441 - val_mean_absolute_percentage_error: 15135303.0000 - val_root_mean_squared_error: 0.2863
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0123 - mean_absolute_error: 0.0866 - mean_absolute_percentage_error: 20.9200 - root_mean_squared_error: 0.1108 - val_loss: 0.0784 - val_mean_absolute_error: 0.2395 - val_mean_absolute_percentage_error: 14999620.0000 - val_root_mean_squared_error: 0.2800
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0136 - mean_absolute_error: 0.0906 - mean_absolute_percentage_error: 21.9443 - root_mean_squared_error: 0.1165 - val_loss: 0.0788 - val_mean_absolute_error: 0.2397 - val_mean_absolute_percentage_error: 14591411.0000 - val_root_mean_squared_error: 0.2807
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0135 - mean_absolute_error: 0.0911 - mean_absolute_percentage_error: 21.4959 - root_mean_squared_error: 0.1163 - val_loss: 0.0759 - val_mean_absolute_error: 0.2342 - val_mean_absolute_percentage_error: 15601153.0000 - val_root_mean_squared_error: 0.2755
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0133 - mean_absolute_error: 0.0895 - mean_absolute_percentage_error: 21.5412 - root_mean_squared_error: 0.1153 - val_loss: 0.0773 - val_mean_absolute_error: 0.2378 - val_mean_absolute_percentage_error: 15351338.0000 - val_root_mean_squared_error: 0.2781
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0120 - mean_absolute_error: 0.0851 - mean_absolute_percentage_error: 21.3130 - root_mean_squared_error: 0.1096 - val_loss: 0.0757 - val_mean_absolute_error: 0.2341 - val_mean_absolute_percentage_error: 16717292.0000 - val_root_mean_squared_error: 0.2752
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0112 - mean_absolute_error: 0.0825 - mean_absolute_percentage_error: 19.3083 - root_mean_squared_error: 0.1060 - val_loss: 0.0784 - val_mean_absolute_error: 0.2384 - val_mean_absolute_percentage_error: 15208713.0000 - val_root_mean_squared_error: 0.2801
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0119 - mean_absolute_error: 0.0843 - mean_absolute_percentage_error: 19.0593 - root_mean_squared_error: 0.1089 - val_loss: 0.0798 - val_mean_absolute_error: 0.2410 - val_mean_absolute_percentage_error: 15344424.0000 - val_root_mean_squared_error: 0.2825
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0117 - mean_absolute_error: 0.0837 - mean_absolute_percentage_error: 19.8818 - root_mean_squared_error: 0.1081 - val_loss: 0.0861 - val_mean_absolute_error: 0.2451 - val_mean_absolute_percentage_error: 15305378.0000 - val_root_mean_squared_error: 0.2934
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0107 - mean_absolute_error: 0.0800 - mean_absolute_percentage_error: 18.6780 - root_mean_squared_error: 0.1034 - val_loss: 0.0837 - val_mean_absolute_error: 0.2448 - val_mean_absolute_percentage_error: 15921530.0000 - val_root_mean_squared_error: 0.2893
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0104 - mean_absolute_error: 0.0789 - mean_absolute_percentage_error: 17.8808 - root_mean_squared_error: 0.1018 - val_loss: 0.0808 - val_mean_absolute_error: 0.2418 - val_mean_absolute_percentage_error: 15680194.0000 - val_root_mean_squared_error: 0.2843
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0104 - mean_absolute_error: 0.0785 - mean_absolute_percentage_error: 18.0720 - root_mean_squared_error: 0.1019 - val_loss: 0.0819 - val_mean_absolute_error: 0.2434 - val_mean_absolute_percentage_error: 15528431.0000 - val_root_mean_squared_error: 0.2861
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0102 - mean_absolute_error: 0.0782 - mean_absolute_percentage_error: 17.5335 - root_mean_squared_error: 0.1011 - val_loss: 0.0808 - val_mean_absolute_error: 0.2414 - val_mean_absolute_percentage_error: 15205734.0000 - val_root_mean_squared_error: 0.2842
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0095 - mean_absolute_error: 0.0752 - mean_absolute_percentage_error: 16.8163 - root_mean_squared_error: 0.0977 - val_loss: 0.0836 - val_mean_absolute_error: 0.2463 - val_mean_absolute_percentage_error: 14972732.0000 - val_root_mean_squared_error: 0.2891
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0101 - mean_absolute_error: 0.0767 - mean_absolute_percentage_error: 17.6432 - root_mean_squared_error: 0.1003 - val_loss: 0.0848 - val_mean_absolute_error: 0.2459 - val_mean_absolute_percentage_error: 14591144.0000 - val_root_mean_squared_error: 0.2912
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0100 - mean_absolute_error: 0.0779 - mean_absolute_percentage_error: 17.4421 - root_mean_squared_error: 0.0997 - val_loss: 0.0838 - val_mean_absolute_error: 0.2432 - val_mean_absolute_percentage_error: 16415934.0000 - val_root_mean_squared_error: 0.2895

# %%
y_pred = model_cnn_19.predict(x_test)
evaluation_cnn_19 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_19
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# {'Mean Squared Error: ': np.float64(600.5764414323583),
#  'Mean Absolute Error: ': np.float64(18.096356450294962),
#  'Root Mean Absolute Error: ': 24.506661164515215,
#  'Mean Absolute Percentage Error: ': np.float64(34.04964176969604)}

# %%
# y_pred = model_cnn_13.predict(x_test)
loss, mae, mape, rmse = model_cnn_19.evaluate(x_test, y_test)
print("model cnn 19")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0479 - mean_absolute_error: 0.1616 - mean_absolute_percentage_error: 43.3706 - root_mean_squared_error: 0.2188
# model cnn 19
# Mean Square Error: 0.04787757992744446
# Mean Absolute Error: 0.1615746021270752
# Mean Absolute Percentage Error: 43.370609283447266
# Root Mean Squared Error: 0.21880945563316345

# %% [markdown]
# ## model 20 (256 128 512, epoch 50)

# %%
lr = 0.0003

model_cnn_20 = Sequential()
model_cnn_20.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_20.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_20.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_cnn_20.add(Flatten())
model_cnn_20.add(Dense(7))
model_cnn_20.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_cnn_20.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_42 (Conv1D)              │ (None, 7, 512)         │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_43 (Conv1D)              │ (None, 7, 128)         │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_44 (Conv1D)              │ (None, 7, 512)         │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_19 (Flatten)            │ (None, 3584)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 7)              │        25,095 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 160,391 (626.53 KB)
#  Trainable params: 160,391 (626.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_cnn_20.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=50,
    batch_size=42
)
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.1574 - mean_absolute_error: 0.3329 - mean_absolute_percentage_error: 63.8871 - root_mean_squared_error: 0.3871 - val_loss: 0.0581 - val_mean_absolute_error: 0.2009 - val_mean_absolute_percentage_error: 14588245.0000 - val_root_mean_squared_error: 0.2411
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0249 - mean_absolute_error: 0.1230 - mean_absolute_percentage_error: 30.4118 - root_mean_squared_error: 0.1577 - val_loss: 0.0526 - val_mean_absolute_error: 0.1871 - val_mean_absolute_percentage_error: 16703263.0000 - val_root_mean_squared_error: 0.2293
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0216 - mean_absolute_error: 0.1130 - mean_absolute_percentage_error: 29.7650 - root_mean_squared_error: 0.1470 - val_loss: 0.0533 - val_mean_absolute_error: 0.1889 - val_mean_absolute_percentage_error: 17448888.0000 - val_root_mean_squared_error: 0.2309
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0208 - mean_absolute_error: 0.1115 - mean_absolute_percentage_error: 28.3059 - root_mean_squared_error: 0.1441 - val_loss: 0.0539 - val_mean_absolute_error: 0.1923 - val_mean_absolute_percentage_error: 16639065.0000 - val_root_mean_squared_error: 0.2322
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0204 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 28.0489 - root_mean_squared_error: 0.1429 - val_loss: 0.0578 - val_mean_absolute_error: 0.1992 - val_mean_absolute_percentage_error: 15041782.0000 - val_root_mean_squared_error: 0.2404
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0203 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 27.1854 - root_mean_squared_error: 0.1425 - val_loss: 0.0549 - val_mean_absolute_error: 0.1953 - val_mean_absolute_percentage_error: 16134689.0000 - val_root_mean_squared_error: 0.2344
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0199 - mean_absolute_error: 0.1087 - mean_absolute_percentage_error: 29.2605 - root_mean_squared_error: 0.1411 - val_loss: 0.0555 - val_mean_absolute_error: 0.1979 - val_mean_absolute_percentage_error: 16004026.0000 - val_root_mean_squared_error: 0.2356
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0184 - mean_absolute_error: 0.1052 - mean_absolute_percentage_error: 26.4394 - root_mean_squared_error: 0.1358 - val_loss: 0.0578 - val_mean_absolute_error: 0.2012 - val_mean_absolute_percentage_error: 14959058.0000 - val_root_mean_squared_error: 0.2405
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0183 - mean_absolute_error: 0.1060 - mean_absolute_percentage_error: 26.1399 - root_mean_squared_error: 0.1354 - val_loss: 0.0562 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 15752034.0000 - val_root_mean_squared_error: 0.2370
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0197 - mean_absolute_error: 0.1087 - mean_absolute_percentage_error: 29.0827 - root_mean_squared_error: 0.1403 - val_loss: 0.0570 - val_mean_absolute_error: 0.2011 - val_mean_absolute_percentage_error: 15427686.0000 - val_root_mean_squared_error: 0.2388
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0181 - mean_absolute_error: 0.1044 - mean_absolute_percentage_error: 26.7215 - root_mean_squared_error: 0.1346 - val_loss: 0.0572 - val_mean_absolute_error: 0.2023 - val_mean_absolute_percentage_error: 15928151.0000 - val_root_mean_squared_error: 0.2393
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0182 - mean_absolute_error: 0.1051 - mean_absolute_percentage_error: 27.2714 - root_mean_squared_error: 0.1348 - val_loss: 0.0572 - val_mean_absolute_error: 0.2017 - val_mean_absolute_percentage_error: 15734196.0000 - val_root_mean_squared_error: 0.2392
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0177 - mean_absolute_error: 0.1026 - mean_absolute_percentage_error: 25.9520 - root_mean_squared_error: 0.1329 - val_loss: 0.0591 - val_mean_absolute_error: 0.2071 - val_mean_absolute_percentage_error: 15406834.0000 - val_root_mean_squared_error: 0.2430
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0170 - mean_absolute_error: 0.1007 - mean_absolute_percentage_error: 24.9102 - root_mean_squared_error: 0.1303 - val_loss: 0.0586 - val_mean_absolute_error: 0.2038 - val_mean_absolute_percentage_error: 15742188.0000 - val_root_mean_squared_error: 0.2421
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0178 - mean_absolute_error: 0.1034 - mean_absolute_percentage_error: 26.6019 - root_mean_squared_error: 0.1333 - val_loss: 0.0587 - val_mean_absolute_error: 0.2053 - val_mean_absolute_percentage_error: 15861953.0000 - val_root_mean_squared_error: 0.2423
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0167 - mean_absolute_error: 0.0999 - mean_absolute_percentage_error: 25.1210 - root_mean_squared_error: 0.1291 - val_loss: 0.0606 - val_mean_absolute_error: 0.2094 - val_mean_absolute_percentage_error: 15971300.0000 - val_root_mean_squared_error: 0.2462
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0165 - mean_absolute_error: 0.0991 - mean_absolute_percentage_error: 25.1925 - root_mean_squared_error: 0.1282 - val_loss: 0.0655 - val_mean_absolute_error: 0.2156 - val_mean_absolute_percentage_error: 14457529.0000 - val_root_mean_squared_error: 0.2559
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0173 - mean_absolute_error: 0.1027 - mean_absolute_percentage_error: 25.6218 - root_mean_squared_error: 0.1314 - val_loss: 0.0650 - val_mean_absolute_error: 0.2158 - val_mean_absolute_percentage_error: 14622153.0000 - val_root_mean_squared_error: 0.2549
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0179 - mean_absolute_error: 0.1051 - mean_absolute_percentage_error: 24.8962 - root_mean_squared_error: 0.1336 - val_loss: 0.0650 - val_mean_absolute_error: 0.2170 - val_mean_absolute_percentage_error: 15416065.0000 - val_root_mean_squared_error: 0.2550
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0165 - mean_absolute_error: 0.0992 - mean_absolute_percentage_error: 25.2458 - root_mean_squared_error: 0.1286 - val_loss: 0.0629 - val_mean_absolute_error: 0.2125 - val_mean_absolute_percentage_error: 15807571.0000 - val_root_mean_squared_error: 0.2507
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0162 - mean_absolute_error: 0.0986 - mean_absolute_percentage_error: 25.6701 - root_mean_squared_error: 0.1273 - val_loss: 0.0643 - val_mean_absolute_error: 0.2153 - val_mean_absolute_percentage_error: 15443753.0000 - val_root_mean_squared_error: 0.2536
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0176 - mean_absolute_error: 0.1026 - mean_absolute_percentage_error: 26.6490 - root_mean_squared_error: 0.1326 - val_loss: 0.0661 - val_mean_absolute_error: 0.2186 - val_mean_absolute_percentage_error: 15097778.0000 - val_root_mean_squared_error: 0.2571
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0169 - mean_absolute_error: 0.1001 - mean_absolute_percentage_error: 25.4461 - root_mean_squared_error: 0.1300 - val_loss: 0.0661 - val_mean_absolute_error: 0.2182 - val_mean_absolute_percentage_error: 14970816.0000 - val_root_mean_squared_error: 0.2570
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0158 - mean_absolute_error: 0.0974 - mean_absolute_percentage_error: 23.7800 - root_mean_squared_error: 0.1259 - val_loss: 0.0689 - val_mean_absolute_error: 0.2224 - val_mean_absolute_percentage_error: 14705719.0000 - val_root_mean_squared_error: 0.2624
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0155 - mean_absolute_error: 0.0971 - mean_absolute_percentage_error: 24.0993 - root_mean_squared_error: 0.1244 - val_loss: 0.0680 - val_mean_absolute_error: 0.2233 - val_mean_absolute_percentage_error: 14748424.0000 - val_root_mean_squared_error: 0.2608
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0154 - mean_absolute_error: 0.0964 - mean_absolute_percentage_error: 24.4512 - root_mean_squared_error: 0.1240 - val_loss: 0.0694 - val_mean_absolute_error: 0.2219 - val_mean_absolute_percentage_error: 15166069.0000 - val_root_mean_squared_error: 0.2634
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0161 - mean_absolute_error: 0.0986 - mean_absolute_percentage_error: 24.3678 - root_mean_squared_error: 0.1268 - val_loss: 0.0710 - val_mean_absolute_error: 0.2253 - val_mean_absolute_percentage_error: 14424594.0000 - val_root_mean_squared_error: 0.2665
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0155 - mean_absolute_error: 0.0962 - mean_absolute_percentage_error: 22.8566 - root_mean_squared_error: 0.1244 - val_loss: 0.0680 - val_mean_absolute_error: 0.2218 - val_mean_absolute_percentage_error: 16065664.0000 - val_root_mean_squared_error: 0.2607
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0155 - mean_absolute_error: 0.0961 - mean_absolute_percentage_error: 23.6865 - root_mean_squared_error: 0.1243 - val_loss: 0.0676 - val_mean_absolute_error: 0.2230 - val_mean_absolute_percentage_error: 14939316.0000 - val_root_mean_squared_error: 0.2599
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0149 - mean_absolute_error: 0.0936 - mean_absolute_percentage_error: 23.2184 - root_mean_squared_error: 0.1219 - val_loss: 0.0705 - val_mean_absolute_error: 0.2244 - val_mean_absolute_percentage_error: 14942357.0000 - val_root_mean_squared_error: 0.2655
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0143 - mean_absolute_error: 0.0932 - mean_absolute_percentage_error: 22.8933 - root_mean_squared_error: 0.1194 - val_loss: 0.0681 - val_mean_absolute_error: 0.2223 - val_mean_absolute_percentage_error: 15328474.0000 - val_root_mean_squared_error: 0.2610
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0151 - mean_absolute_error: 0.0959 - mean_absolute_percentage_error: 23.9876 - root_mean_squared_error: 0.1231 - val_loss: 0.0710 - val_mean_absolute_error: 0.2253 - val_mean_absolute_percentage_error: 16373981.0000 - val_root_mean_squared_error: 0.2664
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0173 - mean_absolute_error: 0.1011 - mean_absolute_percentage_error: 25.9599 - root_mean_squared_error: 0.1315 - val_loss: 0.0705 - val_mean_absolute_error: 0.2254 - val_mean_absolute_percentage_error: 15540408.0000 - val_root_mean_squared_error: 0.2655
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0158 - mean_absolute_error: 0.0979 - mean_absolute_percentage_error: 24.9180 - root_mean_squared_error: 0.1256 - val_loss: 0.0705 - val_mean_absolute_error: 0.2259 - val_mean_absolute_percentage_error: 14988948.0000 - val_root_mean_squared_error: 0.2655
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0140 - mean_absolute_error: 0.0921 - mean_absolute_percentage_error: 22.2029 - root_mean_squared_error: 0.1185 - val_loss: 0.0700 - val_mean_absolute_error: 0.2239 - val_mean_absolute_percentage_error: 15577884.0000 - val_root_mean_squared_error: 0.2645
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0139 - mean_absolute_error: 0.0922 - mean_absolute_percentage_error: 23.3402 - root_mean_squared_error: 0.1178 - val_loss: 0.0697 - val_mean_absolute_error: 0.2226 - val_mean_absolute_percentage_error: 15762972.0000 - val_root_mean_squared_error: 0.2641
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0137 - mean_absolute_error: 0.0912 - mean_absolute_percentage_error: 22.7345 - root_mean_squared_error: 0.1169 - val_loss: 0.0698 - val_mean_absolute_error: 0.2230 - val_mean_absolute_percentage_error: 15610849.0000 - val_root_mean_squared_error: 0.2643
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0136 - mean_absolute_error: 0.0909 - mean_absolute_percentage_error: 21.9026 - root_mean_squared_error: 0.1167 - val_loss: 0.0731 - val_mean_absolute_error: 0.2217 - val_mean_absolute_percentage_error: 14785004.0000 - val_root_mean_squared_error: 0.2704
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0135 - mean_absolute_error: 0.0901 - mean_absolute_percentage_error: 21.4291 - root_mean_squared_error: 0.1163 - val_loss: 0.0716 - val_mean_absolute_error: 0.2246 - val_mean_absolute_percentage_error: 15061135.0000 - val_root_mean_squared_error: 0.2676
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0137 - mean_absolute_error: 0.0903 - mean_absolute_percentage_error: 22.1276 - root_mean_squared_error: 0.1169 - val_loss: 0.0741 - val_mean_absolute_error: 0.2275 - val_mean_absolute_percentage_error: 14571531.0000 - val_root_mean_squared_error: 0.2723
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0130 - mean_absolute_error: 0.0880 - mean_absolute_percentage_error: 21.0804 - root_mean_squared_error: 0.1138 - val_loss: 0.0764 - val_mean_absolute_error: 0.2318 - val_mean_absolute_percentage_error: 14542827.0000 - val_root_mean_squared_error: 0.2764
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0128 - mean_absolute_error: 0.0867 - mean_absolute_percentage_error: 20.6947 - root_mean_squared_error: 0.1132 - val_loss: 0.0770 - val_mean_absolute_error: 0.2285 - val_mean_absolute_percentage_error: 13853480.0000 - val_root_mean_squared_error: 0.2775
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0130 - mean_absolute_error: 0.0884 - mean_absolute_percentage_error: 20.3668 - root_mean_squared_error: 0.1138 - val_loss: 0.0745 - val_mean_absolute_error: 0.2273 - val_mean_absolute_percentage_error: 15295277.0000 - val_root_mean_squared_error: 0.2730
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0119 - mean_absolute_error: 0.0845 - mean_absolute_percentage_error: 19.7366 - root_mean_squared_error: 0.1090 - val_loss: 0.0778 - val_mean_absolute_error: 0.2277 - val_mean_absolute_percentage_error: 13600707.0000 - val_root_mean_squared_error: 0.2789
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0131 - mean_absolute_error: 0.0894 - mean_absolute_percentage_error: 21.5457 - root_mean_squared_error: 0.1146 - val_loss: 0.0713 - val_mean_absolute_error: 0.2224 - val_mean_absolute_percentage_error: 14726062.0000 - val_root_mean_squared_error: 0.2670
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0120 - mean_absolute_error: 0.0849 - mean_absolute_percentage_error: 19.7203 - root_mean_squared_error: 0.1095 - val_loss: 0.0781 - val_mean_absolute_error: 0.2295 - val_mean_absolute_percentage_error: 14549674.0000 - val_root_mean_squared_error: 0.2795
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0123 - mean_absolute_error: 0.0864 - mean_absolute_percentage_error: 20.3231 - root_mean_squared_error: 0.1107 - val_loss: 0.0738 - val_mean_absolute_error: 0.2228 - val_mean_absolute_percentage_error: 14912451.0000 - val_root_mean_squared_error: 0.2716
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0118 - mean_absolute_error: 0.0836 - mean_absolute_percentage_error: 19.8020 - root_mean_squared_error: 0.1086 - val_loss: 0.0770 - val_mean_absolute_error: 0.2313 - val_mean_absolute_percentage_error: 15350396.0000 - val_root_mean_squared_error: 0.2774
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0120 - mean_absolute_error: 0.0848 - mean_absolute_percentage_error: 19.6721 - root_mean_squared_error: 0.1095 - val_loss: 0.0741 - val_mean_absolute_error: 0.2255 - val_mean_absolute_percentage_error: 15959029.0000 - val_root_mean_squared_error: 0.2722
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0124 - mean_absolute_error: 0.0874 - mean_absolute_percentage_error: 21.0489 - root_mean_squared_error: 0.1115 - val_loss: 0.0744 - val_mean_absolute_error: 0.2272 - val_mean_absolute_percentage_error: 16434487.0000 - val_root_mean_squared_error: 0.2728

# %%
y_pred = model_cnn_20.predict(x_test)
evaluation_cnn_20 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_cnn_20
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# {'Mean Squared Error: ': np.float64(307.8782494393687),
#  'Mean Absolute Error: ': np.float64(13.23758481473339),
#  'Root Mean Absolute Error: ': 17.546459740909807,
#  'Mean Absolute Percentage Error: ': np.float64(24.71139895319035)}

# %%
# y_pred = model_cnn_13.predict(x_test)
loss, mae, mape, rmse = model_cnn_20.evaluate(x_test, y_test)
print("model cnn 20")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0245 - mean_absolute_error: 0.1182 - mean_absolute_percentage_error: 31.5259 - root_mean_squared_error: 0.1567
# model cnn 20
# Mean Square Error: 0.024543864652514458
# Mean Absolute Error: 0.11819272488355637
# Mean Absolute Percentage Error: 31.525876998901367
# Root Mean Squared Error: 0.15666481852531433

# %% [markdown]
# # CNN Hyperparameter

# %% [markdown]
# ## gridsearch

# %%
# from keras.callbacks import EarlyStopping
# from sklearn.model_selection import GridSearchCV
# from scikeras.wrappers import KerasRegressor

# # 1. Define your model builder function
# def build_model(filters1=64, filters2=32, kernel_size=1, lr=0.001):
#     model = Sequential()
#     model.add(Input(shape=(7, 11)))
#     model.add(Conv1D(filters=filters1, kernel_size=kernel_size, activation='relu'))
#     model.add(Conv1D(filters=filters2, kernel_size=kernel_size, activation='relu'))
#     model.add(Flatten())
#     model.add(Dense(7))
#     optimizer = Adam(learning_rate=lr)
#     model.compile(loss='mse', optimizer=optimizer,
#                   metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
#     return model

# # 2. Set up KerasRegressor
# model = KerasRegressor(model=build_model, verbose=0)

# # 3. Define early stopping
# early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# # 4. Grid of parameters
# param_grid = {
#     'model__filters1': [256, 512, 1024],
#     'model__filters2': [32, 64, 128],
#     'model__kernel_size': [1],
#     'model__lr': [0.0003],
#     'batch_size': [42],
#     'epochs': [50]  # set high epochs so early stopping can interrupt early
# }

# # 5. GridSearchCV with early stopping passed via fit_params
# grid = GridSearchCV(estimator=model, param_grid=param_grid,
#                     scoring='neg_mean_squared_error',
#                     cv=3,
#                     refit=True)

# # 6. Fit with early stopping
# grid_result_cnn = grid.fit(x_train, y_train, callbacks=[early_stop], validation_data=(x_val, y_val))

# %%
# print("Best parameters found: ", grid_result_cnn.best_params_)
# # print("Best MSE: ", -grid_result.best_score_)

# %%
# best_model = grid_result_cnn.best_estimator_
# loss, mae, mape, rmse = best_model.model_.evaluate(x_test, y_test)
# print("Test MSE:", loss)
# print("Test MAE:", mae)
# print("Test MAPE:", mape)
# print("Test RMSE:", rmse)

# %% [markdown]
# # LSTM Only

# %% [markdown]
# ## model 1 (LSTM=32)

# %%
lr = 0.0003

model_lstm_1 = Sequential()
model_lstm_1.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_1.add(LSTM(32, activation='relu'))
model_lstm_1.add(Flatten())
model_lstm_1.add(Dense(7))
model_lstm_1.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_1.summary()
# Out:
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 32)             │         4,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_20 (Flatten)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,223 (20.40 KB)
#  Trainable params: 5,223 (20.40 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_1.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.2419 - mean_absolute_error: 0.4501 - mean_absolute_percentage_error: 78.2251 - root_mean_squared_error: 0.4914 - val_loss: 0.1751 - val_mean_absolute_error: 0.3577 - val_mean_absolute_percentage_error: 6443156.0000 - val_root_mean_squared_error: 0.4185
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1329 - mean_absolute_error: 0.3050 - mean_absolute_percentage_error: 53.9187 - root_mean_squared_error: 0.3640 - val_loss: 0.1012 - val_mean_absolute_error: 0.2646 - val_mean_absolute_percentage_error: 12391855.0000 - val_root_mean_squared_error: 0.3181
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0554 - mean_absolute_error: 0.1822 - mean_absolute_percentage_error: 37.7273 - root_mean_squared_error: 0.2349 - val_loss: 0.0639 - val_mean_absolute_error: 0.2120 - val_mean_absolute_percentage_error: 15050977.0000 - val_root_mean_squared_error: 0.2528
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0267 - mean_absolute_error: 0.1280 - mean_absolute_percentage_error: 29.8123 - root_mean_squared_error: 0.1634 - val_loss: 0.0565 - val_mean_absolute_error: 0.2015 - val_mean_absolute_percentage_error: 15440950.0000 - val_root_mean_squared_error: 0.2377
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0219 - mean_absolute_error: 0.1140 - mean_absolute_percentage_error: 26.7007 - root_mean_squared_error: 0.1478 - val_loss: 0.0558 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 15155786.0000 - val_root_mean_squared_error: 0.2361
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0220 - mean_absolute_error: 0.1157 - mean_absolute_percentage_error: 28.2084 - root_mean_squared_error: 0.1483 - val_loss: 0.0547 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 15680749.0000 - val_root_mean_squared_error: 0.2338
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0216 - mean_absolute_error: 0.1138 - mean_absolute_percentage_error: 28.5498 - root_mean_squared_error: 0.1470 - val_loss: 0.0550 - val_mean_absolute_error: 0.1961 - val_mean_absolute_percentage_error: 15308021.0000 - val_root_mean_squared_error: 0.2346
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0205 - mean_absolute_error: 0.1111 - mean_absolute_percentage_error: 27.3895 - root_mean_squared_error: 0.1431 - val_loss: 0.0550 - val_mean_absolute_error: 0.1954 - val_mean_absolute_percentage_error: 15338351.0000 - val_root_mean_squared_error: 0.2346
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0205 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 27.6514 - root_mean_squared_error: 0.1433 - val_loss: 0.0546 - val_mean_absolute_error: 0.1943 - val_mean_absolute_percentage_error: 15510280.0000 - val_root_mean_squared_error: 0.2336
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0199 - mean_absolute_error: 0.1100 - mean_absolute_percentage_error: 27.8192 - root_mean_squared_error: 0.1410 - val_loss: 0.0548 - val_mean_absolute_error: 0.1940 - val_mean_absolute_percentage_error: 15402860.0000 - val_root_mean_squared_error: 0.2342
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0211 - mean_absolute_error: 0.1125 - mean_absolute_percentage_error: 28.4388 - root_mean_squared_error: 0.1451 - val_loss: 0.0556 - val_mean_absolute_error: 0.1946 - val_mean_absolute_percentage_error: 15186890.0000 - val_root_mean_squared_error: 0.2357
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0201 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 28.1964 - root_mean_squared_error: 0.1418 - val_loss: 0.0554 - val_mean_absolute_error: 0.1944 - val_mean_absolute_percentage_error: 15220562.0000 - val_root_mean_squared_error: 0.2354
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0209 - mean_absolute_error: 0.1132 - mean_absolute_percentage_error: 28.1395 - root_mean_squared_error: 0.1443 - val_loss: 0.0551 - val_mean_absolute_error: 0.1941 - val_mean_absolute_percentage_error: 15300374.0000 - val_root_mean_squared_error: 0.2348
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0206 - mean_absolute_error: 0.1117 - mean_absolute_percentage_error: 29.3205 - root_mean_squared_error: 0.1434 - val_loss: 0.0554 - val_mean_absolute_error: 0.1944 - val_mean_absolute_percentage_error: 15190295.0000 - val_root_mean_squared_error: 0.2353
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0199 - mean_absolute_error: 0.1094 - mean_absolute_percentage_error: 26.9981 - root_mean_squared_error: 0.1410 - val_loss: 0.0554 - val_mean_absolute_error: 0.1947 - val_mean_absolute_percentage_error: 15138026.0000 - val_root_mean_squared_error: 0.2353
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0194 - mean_absolute_error: 0.1080 - mean_absolute_percentage_error: 27.6632 - root_mean_squared_error: 0.1394 - val_loss: 0.0567 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 14727939.0000 - val_root_mean_squared_error: 0.2382
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0208 - mean_absolute_error: 0.1126 - mean_absolute_percentage_error: 27.9881 - root_mean_squared_error: 0.1441 - val_loss: 0.0547 - val_mean_absolute_error: 0.1941 - val_mean_absolute_percentage_error: 15373252.0000 - val_root_mean_squared_error: 0.2338
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0205 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 27.1693 - root_mean_squared_error: 0.1430 - val_loss: 0.0566 - val_mean_absolute_error: 0.1972 - val_mean_absolute_percentage_error: 14616381.0000 - val_root_mean_squared_error: 0.2378
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0180 - mean_absolute_error: 0.1044 - mean_absolute_percentage_error: 24.7064 - root_mean_squared_error: 0.1341 - val_loss: 0.0575 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 14362894.0000 - val_root_mean_squared_error: 0.2398
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0199 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 27.2595 - root_mean_squared_error: 0.1409 - val_loss: 0.0574 - val_mean_absolute_error: 0.1978 - val_mean_absolute_percentage_error: 14504028.0000 - val_root_mean_squared_error: 0.2396

# %%
y_pred = model_lstm_1.predict(x_test)

evaluation_lstm_1 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_1
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# {'Mean Squared Error: ': np.float64(340.11774836036926),
#  'Mean Absolute Error: ': np.float64(14.84447903535804),
#  'Root Mean Absolute Error: ': 18.44228153890861,
#  'Mean Absolute Percentage Error: ': np.float64(23.803440264229536)}

# %%
loss, mae, mape, rmse = model_lstm_1.evaluate(x_test, y_test)
print("model lstm 1")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0271 - mean_absolute_error: 0.1325 - mean_absolute_percentage_error: 29.3235 - root_mean_squared_error: 0.1647
# model lstm 1
# Mean Square Error: 0.027113977819681168
# Mean Absolute Error: 0.13253998756408691
# Mean Absolute Percentage Error: 29.32354736328125
# Root Mean Squared Error: 0.16466322541236877

# %% [markdown]
# ## model 2 (LSTM=32. 32)

# %%
lr = 0.0003

model_lstm_2 = Sequential()
model_lstm_2.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_2.add(LSTM(32, activation='relu', return_sequences=True))
model_lstm_2.add(LSTM(32, activation='relu'))
model_lstm_2.add(Flatten())
model_lstm_2.add(Dense(7))
model_lstm_2.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_2.summary()
# Out:
# Model: "sequential_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 7, 32)          │         4,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_21 (Flatten)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,543 (52.90 KB)
#  Trainable params: 13,543 (52.90 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_2.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 0.3571 - mean_absolute_error: 0.5685 - mean_absolute_percentage_error: 101.3269 - root_mean_squared_error: 0.5974 - val_loss: 0.2886 - val_mean_absolute_error: 0.4923 - val_mean_absolute_percentage_error: 1922210.6250 - val_root_mean_squared_error: 0.5372
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2435 - mean_absolute_error: 0.4577 - mean_absolute_percentage_error: 79.4178 - root_mean_squared_error: 0.4931 - val_loss: 0.1382 - val_mean_absolute_error: 0.3142 - val_mean_absolute_percentage_error: 8029880.5000 - val_root_mean_squared_error: 0.3717
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0891 - mean_absolute_error: 0.2350 - mean_absolute_percentage_error: 48.0718 - root_mean_squared_error: 0.2981 - val_loss: 0.0783 - val_mean_absolute_error: 0.2329 - val_mean_absolute_percentage_error: 11527804.0000 - val_root_mean_squared_error: 0.2798
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0383 - mean_absolute_error: 0.1552 - mean_absolute_percentage_error: 33.7739 - root_mean_squared_error: 0.1956 - val_loss: 0.0552 - val_mean_absolute_error: 0.1983 - val_mean_absolute_percentage_error: 13668172.0000 - val_root_mean_squared_error: 0.2349
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0260 - mean_absolute_error: 0.1265 - mean_absolute_percentage_error: 32.4216 - root_mean_squared_error: 0.1611 - val_loss: 0.0543 - val_mean_absolute_error: 0.1977 - val_mean_absolute_percentage_error: 13514005.0000 - val_root_mean_squared_error: 0.2329
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0227 - mean_absolute_error: 0.1179 - mean_absolute_percentage_error: 30.7374 - root_mean_squared_error: 0.1506 - val_loss: 0.0549 - val_mean_absolute_error: 0.1990 - val_mean_absolute_percentage_error: 13434991.0000 - val_root_mean_squared_error: 0.2343
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0206 - mean_absolute_error: 0.1124 - mean_absolute_percentage_error: 27.1442 - root_mean_squared_error: 0.1433 - val_loss: 0.0545 - val_mean_absolute_error: 0.1980 - val_mean_absolute_percentage_error: 13545299.0000 - val_root_mean_squared_error: 0.2335
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0218 - mean_absolute_error: 0.1148 - mean_absolute_percentage_error: 28.8064 - root_mean_squared_error: 0.1476 - val_loss: 0.0544 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 13629273.0000 - val_root_mean_squared_error: 0.2332
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0217 - mean_absolute_error: 0.1145 - mean_absolute_percentage_error: 29.9081 - root_mean_squared_error: 0.1471 - val_loss: 0.0544 - val_mean_absolute_error: 0.1961 - val_mean_absolute_percentage_error: 13748344.0000 - val_root_mean_squared_error: 0.2332
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0215 - mean_absolute_error: 0.1139 - mean_absolute_percentage_error: 29.2899 - root_mean_squared_error: 0.1465 - val_loss: 0.0547 - val_mean_absolute_error: 0.1963 - val_mean_absolute_percentage_error: 13759542.0000 - val_root_mean_squared_error: 0.2339
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0204 - mean_absolute_error: 0.1115 - mean_absolute_percentage_error: 27.6830 - root_mean_squared_error: 0.1426 - val_loss: 0.0531 - val_mean_absolute_error: 0.1939 - val_mean_absolute_percentage_error: 14170700.0000 - val_root_mean_squared_error: 0.2304
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0209 - mean_absolute_error: 0.1120 - mean_absolute_percentage_error: 28.6691 - root_mean_squared_error: 0.1444 - val_loss: 0.0548 - val_mean_absolute_error: 0.1957 - val_mean_absolute_percentage_error: 13866824.0000 - val_root_mean_squared_error: 0.2341
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0204 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 27.5089 - root_mean_squared_error: 0.1428 - val_loss: 0.0539 - val_mean_absolute_error: 0.1944 - val_mean_absolute_percentage_error: 14145087.0000 - val_root_mean_squared_error: 0.2321
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0216 - mean_absolute_error: 0.1143 - mean_absolute_percentage_error: 30.5266 - root_mean_squared_error: 0.1469 - val_loss: 0.0556 - val_mean_absolute_error: 0.1965 - val_mean_absolute_percentage_error: 13853014.0000 - val_root_mean_squared_error: 0.2358
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0208 - mean_absolute_error: 0.1124 - mean_absolute_percentage_error: 29.7008 - root_mean_squared_error: 0.1442 - val_loss: 0.0527 - val_mean_absolute_error: 0.1916 - val_mean_absolute_percentage_error: 14638498.0000 - val_root_mean_squared_error: 0.2295
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0214 - mean_absolute_error: 0.1132 - mean_absolute_percentage_error: 29.0499 - root_mean_squared_error: 0.1464 - val_loss: 0.0537 - val_mean_absolute_error: 0.1927 - val_mean_absolute_percentage_error: 14418400.0000 - val_root_mean_squared_error: 0.2317
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0217 - mean_absolute_error: 0.1151 - mean_absolute_percentage_error: 29.1257 - root_mean_squared_error: 0.1473 - val_loss: 0.0535 - val_mean_absolute_error: 0.1922 - val_mean_absolute_percentage_error: 14531616.0000 - val_root_mean_squared_error: 0.2314
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0214 - mean_absolute_error: 0.1140 - mean_absolute_percentage_error: 30.1134 - root_mean_squared_error: 0.1462 - val_loss: 0.0537 - val_mean_absolute_error: 0.1928 - val_mean_absolute_percentage_error: 14552932.0000 - val_root_mean_squared_error: 0.2317
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0199 - mean_absolute_error: 0.1103 - mean_absolute_percentage_error: 28.0245 - root_mean_squared_error: 0.1410 - val_loss: 0.0549 - val_mean_absolute_error: 0.1944 - val_mean_absolute_percentage_error: 14326631.0000 - val_root_mean_squared_error: 0.2343
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0202 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 28.0609 - root_mean_squared_error: 0.1421 - val_loss: 0.0542 - val_mean_absolute_error: 0.1929 - val_mean_absolute_percentage_error: 14557889.0000 - val_root_mean_squared_error: 0.2328

# %%
y_pred = model_lstm_2.predict(x_test)

evaluation_lstm_2 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_2
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# {'Mean Squared Error: ': np.float64(392.0863969822591),
#  'Mean Absolute Error: ': np.float64(16.510735317152374),
#  'Root Mean Absolute Error: ': 19.801171606302972,
#  'Mean Absolute Percentage Error: ': np.float64(27.492623217690426)}

# %%
loss, mae, mape, rmse = model_lstm_2.evaluate(x_test, y_test)
print("model lstm 2")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0313 - mean_absolute_error: 0.1474 - mean_absolute_percentage_error: 34.1190 - root_mean_squared_error: 0.1768
# model lstm 2
# Mean Square Error: 0.031256888061761856
# Mean Absolute Error: 0.14741727709770203
# Mean Absolute Percentage Error: 34.11897659301758
# Root Mean Squared Error: 0.17679618299007416

# %% [markdown]
# ## model 3 (LSTM=256. 32)

# %%
lr = 0.0003

model_lstm_3 = Sequential()
model_lstm_3.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_3.add(LSTM(256, activation='relu', return_sequences=True))
model_lstm_3.add(LSTM(32, activation='relu'))
model_lstm_3.add(Flatten())
model_lstm_3.add(Dense(7))
model_lstm_3.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_3.summary()
# Out:
# Model: "sequential_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 7, 256)         │       269,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 32)             │        36,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_22 (Flatten)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 306,535 (1.17 MB)
#  Trainable params: 306,535 (1.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_3.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - loss: 0.2753 - mean_absolute_error: 0.4878 - mean_absolute_percentage_error: 86.6109 - root_mean_squared_error: 0.5232 - val_loss: 0.1044 - val_mean_absolute_error: 0.2619 - val_mean_absolute_percentage_error: 15200788.0000 - val_root_mean_squared_error: 0.3230
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0629 - mean_absolute_error: 0.1990 - mean_absolute_percentage_error: 41.3669 - root_mean_squared_error: 0.2492 - val_loss: 0.0519 - val_mean_absolute_error: 0.1917 - val_mean_absolute_percentage_error: 15372832.0000 - val_root_mean_squared_error: 0.2278
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0251 - mean_absolute_error: 0.1239 - mean_absolute_percentage_error: 29.9047 - root_mean_squared_error: 0.1584 - val_loss: 0.0533 - val_mean_absolute_error: 0.1926 - val_mean_absolute_percentage_error: 14787811.0000 - val_root_mean_squared_error: 0.2308
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0233 - mean_absolute_error: 0.1193 - mean_absolute_percentage_error: 30.6936 - root_mean_squared_error: 0.1526 - val_loss: 0.0542 - val_mean_absolute_error: 0.1929 - val_mean_absolute_percentage_error: 14577553.0000 - val_root_mean_squared_error: 0.2327
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0210 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 28.9190 - root_mean_squared_error: 0.1449 - val_loss: 0.0534 - val_mean_absolute_error: 0.1924 - val_mean_absolute_percentage_error: 14559089.0000 - val_root_mean_squared_error: 0.2311
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0207 - mean_absolute_error: 0.1124 - mean_absolute_percentage_error: 28.6549 - root_mean_squared_error: 0.1439 - val_loss: 0.0529 - val_mean_absolute_error: 0.1916 - val_mean_absolute_percentage_error: 14725602.0000 - val_root_mean_squared_error: 0.2301
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0212 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 27.4333 - root_mean_squared_error: 0.1458 - val_loss: 0.0521 - val_mean_absolute_error: 0.1909 - val_mean_absolute_percentage_error: 14864818.0000 - val_root_mean_squared_error: 0.2282
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0207 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 28.4185 - root_mean_squared_error: 0.1438 - val_loss: 0.0533 - val_mean_absolute_error: 0.1930 - val_mean_absolute_percentage_error: 14448710.0000 - val_root_mean_squared_error: 0.2309
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0200 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 27.8479 - root_mean_squared_error: 0.1415 - val_loss: 0.0521 - val_mean_absolute_error: 0.1928 - val_mean_absolute_percentage_error: 14633192.0000 - val_root_mean_squared_error: 0.2282
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0207 - mean_absolute_error: 0.1120 - mean_absolute_percentage_error: 28.7911 - root_mean_squared_error: 0.1437 - val_loss: 0.0532 - val_mean_absolute_error: 0.1938 - val_mean_absolute_percentage_error: 14436740.0000 - val_root_mean_squared_error: 0.2306
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0204 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 28.9982 - root_mean_squared_error: 0.1428 - val_loss: 0.0565 - val_mean_absolute_error: 0.1976 - val_mean_absolute_percentage_error: 13942209.0000 - val_root_mean_squared_error: 0.2377
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0198 - mean_absolute_error: 0.1106 - mean_absolute_percentage_error: 27.5375 - root_mean_squared_error: 0.1408 - val_loss: 0.0526 - val_mean_absolute_error: 0.1937 - val_mean_absolute_percentage_error: 14934367.0000 - val_root_mean_squared_error: 0.2293
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0209 - mean_absolute_error: 0.1128 - mean_absolute_percentage_error: 29.5850 - root_mean_squared_error: 0.1445 - val_loss: 0.0562 - val_mean_absolute_error: 0.1997 - val_mean_absolute_percentage_error: 13797306.0000 - val_root_mean_squared_error: 0.2370
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0205 - mean_absolute_error: 0.1124 - mean_absolute_percentage_error: 28.8385 - root_mean_squared_error: 0.1431 - val_loss: 0.0543 - val_mean_absolute_error: 0.1992 - val_mean_absolute_percentage_error: 14446778.0000 - val_root_mean_squared_error: 0.2330
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0187 - mean_absolute_error: 0.1064 - mean_absolute_percentage_error: 26.6280 - root_mean_squared_error: 0.1366 - val_loss: 0.0549 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 14238304.0000 - val_root_mean_squared_error: 0.2343
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0199 - mean_absolute_error: 0.1092 - mean_absolute_percentage_error: 28.4360 - root_mean_squared_error: 0.1411 - val_loss: 0.0604 - val_mean_absolute_error: 0.2054 - val_mean_absolute_percentage_error: 13615630.0000 - val_root_mean_squared_error: 0.2457
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0196 - mean_absolute_error: 0.1103 - mean_absolute_percentage_error: 26.6781 - root_mean_squared_error: 0.1400 - val_loss: 0.0555 - val_mean_absolute_error: 0.2011 - val_mean_absolute_percentage_error: 14618666.0000 - val_root_mean_squared_error: 0.2356
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0190 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 27.6414 - root_mean_squared_error: 0.1377 - val_loss: 0.0563 - val_mean_absolute_error: 0.2014 - val_mean_absolute_percentage_error: 14120651.0000 - val_root_mean_squared_error: 0.2372
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0189 - mean_absolute_error: 0.1070 - mean_absolute_percentage_error: 26.8594 - root_mean_squared_error: 0.1374 - val_loss: 0.0551 - val_mean_absolute_error: 0.1985 - val_mean_absolute_percentage_error: 15052740.0000 - val_root_mean_squared_error: 0.2348
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0188 - mean_absolute_error: 0.1058 - mean_absolute_percentage_error: 26.3196 - root_mean_squared_error: 0.1370 - val_loss: 0.0552 - val_mean_absolute_error: 0.1993 - val_mean_absolute_percentage_error: 14997736.0000 - val_root_mean_squared_error: 0.2350

# %%
y_pred = model_lstm_3.predict(x_test)

evaluation_lstm_3 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_3
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# {'Mean Squared Error: ': np.float64(395.8629015229882),
#  'Mean Absolute Error: ': np.float64(15.105303316700216),
#  'Root Mean Absolute Error: ': 19.896303715087086,
#  'Mean Absolute Percentage Error: ': np.float64(28.91552608709616)}

# %%
loss, mae, mape, rmse = model_lstm_3.evaluate(x_test, y_test)
print("model lstm 3")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0316 - mean_absolute_error: 0.1349 - mean_absolute_percentage_error: 36.8759 - root_mean_squared_error: 0.1776
# model lstm 3
# Mean Square Error: 0.031557947397232056
# Mean Absolute Error: 0.1348687708377838
# Mean Absolute Percentage Error: 36.87588119506836
# Root Mean Squared Error: 0.17764556407928467

# %% [markdown]
# ## model 4 (LSTM=256. 64)

# %%
lr = 0.0003

model_lstm_4 = Sequential()
model_lstm_4.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_4.add(LSTM(256, activation='relu', return_sequences=True))
model_lstm_4.add(LSTM(64, activation='relu'))
model_lstm_4.add(Flatten())
model_lstm_4.add(Dense(7))
model_lstm_4.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_4.summary()
# Out:
# Model: "sequential_23"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_5 (LSTM)                   │ (None, 7, 256)         │       269,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 64)             │        82,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_23 (Flatten)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 351,943 (1.34 MB)
#  Trainable params: 351,943 (1.34 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_4.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 0.2793 - mean_absolute_error: 0.4904 - mean_absolute_percentage_error: 87.0582 - root_mean_squared_error: 0.5268 - val_loss: 0.0757 - val_mean_absolute_error: 0.2259 - val_mean_absolute_percentage_error: 15547745.0000 - val_root_mean_squared_error: 0.2751
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0366 - mean_absolute_error: 0.1491 - mean_absolute_percentage_error: 32.7817 - root_mean_squared_error: 0.1909 - val_loss: 0.0564 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 14603779.0000 - val_root_mean_squared_error: 0.2374
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0248 - mean_absolute_error: 0.1239 - mean_absolute_percentage_error: 30.8335 - root_mean_squared_error: 0.1575 - val_loss: 0.0534 - val_mean_absolute_error: 0.1915 - val_mean_absolute_percentage_error: 14955815.0000 - val_root_mean_squared_error: 0.2311
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0222 - mean_absolute_error: 0.1164 - mean_absolute_percentage_error: 30.2062 - root_mean_squared_error: 0.1489 - val_loss: 0.0547 - val_mean_absolute_error: 0.1934 - val_mean_absolute_percentage_error: 14408052.0000 - val_root_mean_squared_error: 0.2339
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0224 - mean_absolute_error: 0.1170 - mean_absolute_percentage_error: 29.6379 - root_mean_squared_error: 0.1496 - val_loss: 0.0533 - val_mean_absolute_error: 0.1912 - val_mean_absolute_percentage_error: 14746810.0000 - val_root_mean_squared_error: 0.2309
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0204 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 27.8437 - root_mean_squared_error: 0.1427 - val_loss: 0.0540 - val_mean_absolute_error: 0.1933 - val_mean_absolute_percentage_error: 14451064.0000 - val_root_mean_squared_error: 0.2325
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0198 - mean_absolute_error: 0.1096 - mean_absolute_percentage_error: 27.1103 - root_mean_squared_error: 0.1407 - val_loss: 0.0531 - val_mean_absolute_error: 0.1904 - val_mean_absolute_percentage_error: 14837930.0000 - val_root_mean_squared_error: 0.2303
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0196 - mean_absolute_error: 0.1094 - mean_absolute_percentage_error: 27.8490 - root_mean_squared_error: 0.1398 - val_loss: 0.0545 - val_mean_absolute_error: 0.1955 - val_mean_absolute_percentage_error: 14260020.0000 - val_root_mean_squared_error: 0.2335
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0209 - mean_absolute_error: 0.1132 - mean_absolute_percentage_error: 30.6496 - root_mean_squared_error: 0.1447 - val_loss: 0.0525 - val_mean_absolute_error: 0.1926 - val_mean_absolute_percentage_error: 14812561.0000 - val_root_mean_squared_error: 0.2291
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0199 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 27.6952 - root_mean_squared_error: 0.1412 - val_loss: 0.0535 - val_mean_absolute_error: 0.1959 - val_mean_absolute_percentage_error: 14389877.0000 - val_root_mean_squared_error: 0.2314
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0194 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 27.6388 - root_mean_squared_error: 0.1394 - val_loss: 0.0552 - val_mean_absolute_error: 0.1992 - val_mean_absolute_percentage_error: 13980668.0000 - val_root_mean_squared_error: 0.2349
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0195 - mean_absolute_error: 0.1086 - mean_absolute_percentage_error: 27.9676 - root_mean_squared_error: 0.1398 - val_loss: 0.0563 - val_mean_absolute_error: 0.2003 - val_mean_absolute_percentage_error: 13926780.0000 - val_root_mean_squared_error: 0.2373
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0195 - mean_absolute_error: 0.1095 - mean_absolute_percentage_error: 27.1678 - root_mean_squared_error: 0.1398 - val_loss: 0.0564 - val_mean_absolute_error: 0.2036 - val_mean_absolute_percentage_error: 13978603.0000 - val_root_mean_squared_error: 0.2376
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0200 - mean_absolute_error: 0.1099 - mean_absolute_percentage_error: 28.4974 - root_mean_squared_error: 0.1413 - val_loss: 0.0599 - val_mean_absolute_error: 0.2083 - val_mean_absolute_percentage_error: 13285204.0000 - val_root_mean_squared_error: 0.2447
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0200 - mean_absolute_error: 0.1118 - mean_absolute_percentage_error: 27.7677 - root_mean_squared_error: 0.1415 - val_loss: 0.0563 - val_mean_absolute_error: 0.2033 - val_mean_absolute_percentage_error: 14167532.0000 - val_root_mean_squared_error: 0.2372
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0185 - mean_absolute_error: 0.1065 - mean_absolute_percentage_error: 26.7876 - root_mean_squared_error: 0.1358 - val_loss: 0.0568 - val_mean_absolute_error: 0.2053 - val_mean_absolute_percentage_error: 14052318.0000 - val_root_mean_squared_error: 0.2382
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0191 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 28.7810 - root_mean_squared_error: 0.1382 - val_loss: 0.0584 - val_mean_absolute_error: 0.2073 - val_mean_absolute_percentage_error: 13714385.0000 - val_root_mean_squared_error: 0.2416
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0189 - mean_absolute_error: 0.1066 - mean_absolute_percentage_error: 26.7679 - root_mean_squared_error: 0.1376 - val_loss: 0.0573 - val_mean_absolute_error: 0.2049 - val_mean_absolute_percentage_error: 14202963.0000 - val_root_mean_squared_error: 0.2395
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0182 - mean_absolute_error: 0.1042 - mean_absolute_percentage_error: 26.5796 - root_mean_squared_error: 0.1349 - val_loss: 0.0573 - val_mean_absolute_error: 0.2035 - val_mean_absolute_percentage_error: 14275912.0000 - val_root_mean_squared_error: 0.2393
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0185 - mean_absolute_error: 0.1063 - mean_absolute_percentage_error: 27.7849 - root_mean_squared_error: 0.1361 - val_loss: 0.0581 - val_mean_absolute_error: 0.2066 - val_mean_absolute_percentage_error: 14382388.0000 - val_root_mean_squared_error: 0.2410

# %%
y_pred = model_lstm_4.predict(x_test)

evaluation_lstm_4 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_4
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# {'Mean Squared Error: ': np.float64(385.0995006265619),
#  'Mean Absolute Error: ': np.float64(14.782673660589724),
#  'Root Mean Absolute Error: ': 19.623952217292057,
#  'Mean Absolute Percentage Error: ': np.float64(28.017642150445106)}

# %%
loss, mae, mape, rmse = model_lstm_4.evaluate(x_test, y_test)
print("model lstm 4")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0307 - mean_absolute_error: 0.1320 - mean_absolute_percentage_error: 35.6844 - root_mean_squared_error: 0.1752
# model lstm 4
# Mean Square Error: 0.030699891969561577
# Mean Absolute Error: 0.13198815286159515
# Mean Absolute Percentage Error: 35.6844482421875
# Root Mean Squared Error: 0.17521384358406067

# %% [markdown]
# ## model 5 (LSTM=512. 128)

# %%
lr = 0.0003

model_lstm_5 = Sequential()
model_lstm_5.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_5.add(LSTM(512, activation='relu', return_sequences=True))
model_lstm_5.add(LSTM(128, activation='relu'))
model_lstm_5.add(Flatten())
model_lstm_5.add(Dense(7))
model_lstm_5.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_5.summary()
# Out:
# Model: "sequential_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_7 (LSTM)                   │ (None, 7, 512)         │     1,062,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_8 (LSTM)                   │ (None, 128)            │       328,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_24 (Flatten)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,392,007 (5.31 MB)
#  Trainable params: 1,392,007 (5.31 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_5.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 155ms/step - loss: 0.2501 - mean_absolute_error: 0.4508 - mean_absolute_percentage_error: 81.3857 - root_mean_squared_error: 0.4958 - val_loss: 0.0778 - val_mean_absolute_error: 0.2382 - val_mean_absolute_percentage_error: 10982953.0000 - val_root_mean_squared_error: 0.2789
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0367 - mean_absolute_error: 0.1577 - mean_absolute_percentage_error: 33.2824 - root_mean_squared_error: 0.1914 - val_loss: 0.0570 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 13899095.0000 - val_root_mean_squared_error: 0.2388
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0228 - mean_absolute_error: 0.1191 - mean_absolute_percentage_error: 29.5821 - root_mean_squared_error: 0.1511 - val_loss: 0.0532 - val_mean_absolute_error: 0.1901 - val_mean_absolute_percentage_error: 14698691.0000 - val_root_mean_squared_error: 0.2306
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - loss: 0.0220 - mean_absolute_error: 0.1167 - mean_absolute_percentage_error: 28.6779 - root_mean_squared_error: 0.1482 - val_loss: 0.0532 - val_mean_absolute_error: 0.1900 - val_mean_absolute_percentage_error: 14720981.0000 - val_root_mean_squared_error: 0.2306
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 0.0213 - mean_absolute_error: 0.1132 - mean_absolute_percentage_error: 29.6971 - root_mean_squared_error: 0.1458 - val_loss: 0.0515 - val_mean_absolute_error: 0.1874 - val_mean_absolute_percentage_error: 15218990.0000 - val_root_mean_squared_error: 0.2270
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0228 - mean_absolute_error: 0.1169 - mean_absolute_percentage_error: 29.9476 - root_mean_squared_error: 0.1507 - val_loss: 0.0521 - val_mean_absolute_error: 0.1890 - val_mean_absolute_percentage_error: 15040436.0000 - val_root_mean_squared_error: 0.2283
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0208 - mean_absolute_error: 0.1127 - mean_absolute_percentage_error: 28.4622 - root_mean_squared_error: 0.1440 - val_loss: 0.0547 - val_mean_absolute_error: 0.1931 - val_mean_absolute_percentage_error: 14402451.0000 - val_root_mean_squared_error: 0.2338
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0198 - mean_absolute_error: 0.1103 - mean_absolute_percentage_error: 28.9796 - root_mean_squared_error: 0.1405 - val_loss: 0.0534 - val_mean_absolute_error: 0.1918 - val_mean_absolute_percentage_error: 14627598.0000 - val_root_mean_squared_error: 0.2310
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0205 - mean_absolute_error: 0.1120 - mean_absolute_percentage_error: 26.7984 - root_mean_squared_error: 0.1433 - val_loss: 0.0528 - val_mean_absolute_error: 0.1903 - val_mean_absolute_percentage_error: 14899549.0000 - val_root_mean_squared_error: 0.2297
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 0.0202 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 28.6483 - root_mean_squared_error: 0.1421 - val_loss: 0.0529 - val_mean_absolute_error: 0.1909 - val_mean_absolute_percentage_error: 14904629.0000 - val_root_mean_squared_error: 0.2299
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 0.0203 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 29.5809 - root_mean_squared_error: 0.1424 - val_loss: 0.0557 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 14065685.0000 - val_root_mean_squared_error: 0.2359
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0197 - mean_absolute_error: 0.1095 - mean_absolute_percentage_error: 28.6441 - root_mean_squared_error: 0.1405 - val_loss: 0.0546 - val_mean_absolute_error: 0.1942 - val_mean_absolute_percentage_error: 14516545.0000 - val_root_mean_squared_error: 0.2336
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0188 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 26.5569 - root_mean_squared_error: 0.1371 - val_loss: 0.0543 - val_mean_absolute_error: 0.1976 - val_mean_absolute_percentage_error: 14212306.0000 - val_root_mean_squared_error: 0.2330
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0204 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 28.1140 - root_mean_squared_error: 0.1427 - val_loss: 0.0539 - val_mean_absolute_error: 0.1975 - val_mean_absolute_percentage_error: 14401145.0000 - val_root_mean_squared_error: 0.2323
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 0.0192 - mean_absolute_error: 0.1079 - mean_absolute_percentage_error: 27.4085 - root_mean_squared_error: 0.1385 - val_loss: 0.0532 - val_mean_absolute_error: 0.1924 - val_mean_absolute_percentage_error: 15214729.0000 - val_root_mean_squared_error: 0.2306
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0202 - mean_absolute_error: 0.1103 - mean_absolute_percentage_error: 27.9541 - root_mean_squared_error: 0.1419 - val_loss: 0.0562 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 14244989.0000 - val_root_mean_squared_error: 0.2371
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0192 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 28.0302 - root_mean_squared_error: 0.1385 - val_loss: 0.0544 - val_mean_absolute_error: 0.1990 - val_mean_absolute_percentage_error: 14424776.0000 - val_root_mean_squared_error: 0.2333
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0189 - mean_absolute_error: 0.1074 - mean_absolute_percentage_error: 27.8385 - root_mean_squared_error: 0.1374 - val_loss: 0.0571 - val_mean_absolute_error: 0.2038 - val_mean_absolute_percentage_error: 13700983.0000 - val_root_mean_squared_error: 0.2390
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0189 - mean_absolute_error: 0.1069 - mean_absolute_percentage_error: 27.0628 - root_mean_squared_error: 0.1376 - val_loss: 0.0549 - val_mean_absolute_error: 0.1980 - val_mean_absolute_percentage_error: 14793158.0000 - val_root_mean_squared_error: 0.2344
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0191 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 28.4942 - root_mean_squared_error: 0.1383 - val_loss: 0.0548 - val_mean_absolute_error: 0.1973 - val_mean_absolute_percentage_error: 14883316.0000 - val_root_mean_squared_error: 0.2340

# %%
y_pred = model_lstm_5.predict(x_test)

evaluation_lstm_5 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_5
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# {'Mean Squared Error: ': np.float64(324.7721261971295),
#  'Mean Absolute Error: ': np.float64(13.977943595574827),
#  'Root Mean Absolute Error: ': 18.021435186941396,
#  'Mean Absolute Percentage Error: ': np.float64(25.840499978600956)}

# %%
loss, mae, mape, rmse = model_lstm_5.evaluate(x_test, y_test)
print("model lstm 5")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0259 - mean_absolute_error: 0.1248 - mean_absolute_percentage_error: 32.8091 - root_mean_squared_error: 0.1609
# model lstm 5
# Mean Square Error: 0.025890633463859558
# Mean Absolute Error: 0.12480305880308151
# Mean Absolute Percentage Error: 32.80914306640625
# Root Mean Squared Error: 0.160905659198761

# %% [markdown]
# ## model 6 (LSTM=16)

# %%
lr = 0.0003

model_lstm_6 = Sequential()
model_lstm_6.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_6.add(LSTM(16, activation='relu'))
model_lstm_6.add(Flatten())
model_lstm_6.add(Dense(7))
model_lstm_6.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_6.summary()
# Out:
# Model: "sequential_25"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_9 (LSTM)                   │ (None, 16)             │         1,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_25 (Flatten)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 7)              │           119 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,591 (6.21 KB)
#  Trainable params: 1,591 (6.21 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_6.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.2960 - mean_absolute_error: 0.4932 - mean_absolute_percentage_error: 86.8988 - root_mean_squared_error: 0.5439 - val_loss: 0.2619 - val_mean_absolute_error: 0.4610 - val_mean_absolute_percentage_error: 3951509.7500 - val_root_mean_squared_error: 0.5117
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2179 - mean_absolute_error: 0.4181 - mean_absolute_percentage_error: 72.7865 - root_mean_squared_error: 0.4667 - val_loss: 0.1955 - val_mean_absolute_error: 0.3908 - val_mean_absolute_percentage_error: 6515204.0000 - val_root_mean_squared_error: 0.4421
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1440 - mean_absolute_error: 0.3179 - mean_absolute_percentage_error: 55.7881 - root_mean_squared_error: 0.3792 - val_loss: 0.1221 - val_mean_absolute_error: 0.2972 - val_mean_absolute_percentage_error: 10175105.0000 - val_root_mean_squared_error: 0.3495
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0739 - mean_absolute_error: 0.2158 - mean_absolute_percentage_error: 41.5020 - root_mean_squared_error: 0.2714 - val_loss: 0.0725 - val_mean_absolute_error: 0.2246 - val_mean_absolute_percentage_error: 13775359.0000 - val_root_mean_squared_error: 0.2693
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0314 - mean_absolute_error: 0.1415 - mean_absolute_percentage_error: 34.0370 - root_mean_squared_error: 0.1771 - val_loss: 0.0574 - val_mean_absolute_error: 0.1987 - val_mean_absolute_percentage_error: 14872785.0000 - val_root_mean_squared_error: 0.2395
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0235 - mean_absolute_error: 0.1207 - mean_absolute_percentage_error: 30.1928 - root_mean_squared_error: 0.1532 - val_loss: 0.0581 - val_mean_absolute_error: 0.2004 - val_mean_absolute_percentage_error: 14548704.0000 - val_root_mean_squared_error: 0.2411
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0226 - mean_absolute_error: 0.1188 - mean_absolute_percentage_error: 28.1624 - root_mean_squared_error: 0.1503 - val_loss: 0.0578 - val_mean_absolute_error: 0.2006 - val_mean_absolute_percentage_error: 14617795.0000 - val_root_mean_squared_error: 0.2405
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0225 - mean_absolute_error: 0.1177 - mean_absolute_percentage_error: 29.6467 - root_mean_squared_error: 0.1498 - val_loss: 0.0580 - val_mean_absolute_error: 0.2012 - val_mean_absolute_percentage_error: 14670790.0000 - val_root_mean_squared_error: 0.2409
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0221 - mean_absolute_error: 0.1162 - mean_absolute_percentage_error: 29.4386 - root_mean_squared_error: 0.1487 - val_loss: 0.0579 - val_mean_absolute_error: 0.2014 - val_mean_absolute_percentage_error: 14834296.0000 - val_root_mean_squared_error: 0.2407
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0219 - mean_absolute_error: 0.1152 - mean_absolute_percentage_error: 29.4977 - root_mean_squared_error: 0.1479 - val_loss: 0.0574 - val_mean_absolute_error: 0.2007 - val_mean_absolute_percentage_error: 14997667.0000 - val_root_mean_squared_error: 0.2396
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0217 - mean_absolute_error: 0.1152 - mean_absolute_percentage_error: 28.0803 - root_mean_squared_error: 0.1472 - val_loss: 0.0589 - val_mean_absolute_error: 0.2034 - val_mean_absolute_percentage_error: 14855706.0000 - val_root_mean_squared_error: 0.2427
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0202 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 26.4752 - root_mean_squared_error: 0.1420 - val_loss: 0.0585 - val_mean_absolute_error: 0.2032 - val_mean_absolute_percentage_error: 15097132.0000 - val_root_mean_squared_error: 0.2419
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0212 - mean_absolute_error: 0.1137 - mean_absolute_percentage_error: 28.9818 - root_mean_squared_error: 0.1455 - val_loss: 0.0578 - val_mean_absolute_error: 0.2015 - val_mean_absolute_percentage_error: 15397773.0000 - val_root_mean_squared_error: 0.2405
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0213 - mean_absolute_error: 0.1137 - mean_absolute_percentage_error: 28.4095 - root_mean_squared_error: 0.1459 - val_loss: 0.0596 - val_mean_absolute_error: 0.2048 - val_mean_absolute_percentage_error: 15095967.0000 - val_root_mean_squared_error: 0.2442
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0205 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 27.4690 - root_mean_squared_error: 0.1432 - val_loss: 0.0587 - val_mean_absolute_error: 0.2034 - val_mean_absolute_percentage_error: 15423166.0000 - val_root_mean_squared_error: 0.2423
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0200 - mean_absolute_error: 0.1108 - mean_absolute_percentage_error: 26.9094 - root_mean_squared_error: 0.1413 - val_loss: 0.0595 - val_mean_absolute_error: 0.2042 - val_mean_absolute_percentage_error: 15369320.0000 - val_root_mean_squared_error: 0.2438
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0199 - mean_absolute_error: 0.1100 - mean_absolute_percentage_error: 28.1727 - root_mean_squared_error: 0.1412 - val_loss: 0.0591 - val_mean_absolute_error: 0.2034 - val_mean_absolute_percentage_error: 15575526.0000 - val_root_mean_squared_error: 0.2431
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0202 - mean_absolute_error: 0.1106 - mean_absolute_percentage_error: 26.9503 - root_mean_squared_error: 0.1422 - val_loss: 0.0611 - val_mean_absolute_error: 0.2067 - val_mean_absolute_percentage_error: 15207135.0000 - val_root_mean_squared_error: 0.2472
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0200 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 26.4485 - root_mean_squared_error: 0.1415 - val_loss: 0.0604 - val_mean_absolute_error: 0.2052 - val_mean_absolute_percentage_error: 15363116.0000 - val_root_mean_squared_error: 0.2458
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0200 - mean_absolute_error: 0.1106 - mean_absolute_percentage_error: 26.6675 - root_mean_squared_error: 0.1412 - val_loss: 0.0602 - val_mean_absolute_error: 0.2048 - val_mean_absolute_percentage_error: 15483831.0000 - val_root_mean_squared_error: 0.2454

# %%
y_pred = model_lstm_6.predict(x_test)

evaluation_lstm_6 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_6
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# {'Mean Squared Error: ': np.float64(340.19115233959553),
#  'Mean Absolute Error: ': np.float64(14.633661114439672),
#  'Root Mean Absolute Error: ': 18.444271531822437,
#  'Mean Absolute Percentage Error: ': np.float64(22.943267627097597)}

# %%
loss, mae, mape, rmse = model_lstm_6.evaluate(x_test, y_test)
print("model lstm 6")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0271 - mean_absolute_error: 0.1307 - mean_absolute_percentage_error: 28.1392 - root_mean_squared_error: 0.1647
# model lstm 6
# Mean Square Error: 0.027119828388094902
# Mean Absolute Error: 0.13065767288208008
# Mean Absolute Percentage Error: 28.139184951782227
# Root Mean Squared Error: 0.16468098759651184

# %% [markdown]
# ## model 7 (LSTM=16 16)

# %%
lr = 0.0003

model_lstm_7 = Sequential()
model_lstm_7.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_7.add(LSTM(16, activation='relu', return_sequences=True))
model_lstm_7.add(LSTM(16, activation='relu'))
model_lstm_7.add(Flatten())
model_lstm_7.add(Dense(7))
model_lstm_7.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_7.summary()
# Out:
# Model: "sequential_26"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_10 (LSTM)                  │ (None, 7, 16)          │         1,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 16)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_26 (Flatten)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 7)              │           119 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,703 (14.46 KB)
#  Trainable params: 3,703 (14.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_7.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.3237 - mean_absolute_error: 0.5402 - mean_absolute_percentage_error: 95.6427 - root_mean_squared_error: 0.5688 - val_loss: 0.2711 - val_mean_absolute_error: 0.4761 - val_mean_absolute_percentage_error: 2272626.0000 - val_root_mean_squared_error: 0.5207
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2421 - mean_absolute_error: 0.4573 - mean_absolute_percentage_error: 79.4868 - root_mean_squared_error: 0.4919 - val_loss: 0.1790 - val_mean_absolute_error: 0.3733 - val_mean_absolute_percentage_error: 5443273.0000 - val_root_mean_squared_error: 0.4231
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1422 - mean_absolute_error: 0.3257 - mean_absolute_percentage_error: 56.6110 - root_mean_squared_error: 0.3763 - val_loss: 0.1017 - val_mean_absolute_error: 0.2681 - val_mean_absolute_percentage_error: 11802382.0000 - val_root_mean_squared_error: 0.3190
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0692 - mean_absolute_error: 0.2102 - mean_absolute_percentage_error: 43.1520 - root_mean_squared_error: 0.2628 - val_loss: 0.0678 - val_mean_absolute_error: 0.2234 - val_mean_absolute_percentage_error: 12361319.0000 - val_root_mean_squared_error: 0.2603
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0358 - mean_absolute_error: 0.1500 - mean_absolute_percentage_error: 32.8632 - root_mean_squared_error: 0.1890 - val_loss: 0.0556 - val_mean_absolute_error: 0.2039 - val_mean_absolute_percentage_error: 13589783.0000 - val_root_mean_squared_error: 0.2358
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0266 - mean_absolute_error: 0.1277 - mean_absolute_percentage_error: 31.7334 - root_mean_squared_error: 0.1629 - val_loss: 0.0534 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 13521432.0000 - val_root_mean_squared_error: 0.2311
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0229 - mean_absolute_error: 0.1181 - mean_absolute_percentage_error: 30.2470 - root_mean_squared_error: 0.1514 - val_loss: 0.0527 - val_mean_absolute_error: 0.1956 - val_mean_absolute_percentage_error: 13767660.0000 - val_root_mean_squared_error: 0.2295
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0228 - mean_absolute_error: 0.1187 - mean_absolute_percentage_error: 30.3406 - root_mean_squared_error: 0.1508 - val_loss: 0.0538 - val_mean_absolute_error: 0.1953 - val_mean_absolute_percentage_error: 13655885.0000 - val_root_mean_squared_error: 0.2320
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0218 - mean_absolute_error: 0.1161 - mean_absolute_percentage_error: 28.8126 - root_mean_squared_error: 0.1476 - val_loss: 0.0541 - val_mean_absolute_error: 0.1956 - val_mean_absolute_percentage_error: 13650126.0000 - val_root_mean_squared_error: 0.2326
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0221 - mean_absolute_error: 0.1171 - mean_absolute_percentage_error: 29.4706 - root_mean_squared_error: 0.1488 - val_loss: 0.0551 - val_mean_absolute_error: 0.1964 - val_mean_absolute_percentage_error: 13536641.0000 - val_root_mean_squared_error: 0.2346
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0227 - mean_absolute_error: 0.1192 - mean_absolute_percentage_error: 30.0547 - root_mean_squared_error: 0.1505 - val_loss: 0.0538 - val_mean_absolute_error: 0.1942 - val_mean_absolute_percentage_error: 13861000.0000 - val_root_mean_squared_error: 0.2319
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0216 - mean_absolute_error: 0.1155 - mean_absolute_percentage_error: 28.1110 - root_mean_squared_error: 0.1470 - val_loss: 0.0540 - val_mean_absolute_error: 0.1943 - val_mean_absolute_percentage_error: 13868636.0000 - val_root_mean_squared_error: 0.2323
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0213 - mean_absolute_error: 0.1141 - mean_absolute_percentage_error: 29.0596 - root_mean_squared_error: 0.1459 - val_loss: 0.0534 - val_mean_absolute_error: 0.1936 - val_mean_absolute_percentage_error: 14006014.0000 - val_root_mean_squared_error: 0.2312
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0219 - mean_absolute_error: 0.1155 - mean_absolute_percentage_error: 29.6769 - root_mean_squared_error: 0.1479 - val_loss: 0.0520 - val_mean_absolute_error: 0.1914 - val_mean_absolute_percentage_error: 14429869.0000 - val_root_mean_squared_error: 0.2280
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0219 - mean_absolute_error: 0.1154 - mean_absolute_percentage_error: 29.1878 - root_mean_squared_error: 0.1480 - val_loss: 0.0552 - val_mean_absolute_error: 0.1958 - val_mean_absolute_percentage_error: 13734702.0000 - val_root_mean_squared_error: 0.2348
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0218 - mean_absolute_error: 0.1154 - mean_absolute_percentage_error: 29.9925 - root_mean_squared_error: 0.1477 - val_loss: 0.0550 - val_mean_absolute_error: 0.1953 - val_mean_absolute_percentage_error: 13812391.0000 - val_root_mean_squared_error: 0.2345
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0216 - mean_absolute_error: 0.1159 - mean_absolute_percentage_error: 28.6679 - root_mean_squared_error: 0.1471 - val_loss: 0.0564 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 13686966.0000 - val_root_mean_squared_error: 0.2375
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0213 - mean_absolute_error: 0.1154 - mean_absolute_percentage_error: 28.8101 - root_mean_squared_error: 0.1458 - val_loss: 0.0549 - val_mean_absolute_error: 0.1945 - val_mean_absolute_percentage_error: 13949518.0000 - val_root_mean_squared_error: 0.2343
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0206 - mean_absolute_error: 0.1131 - mean_absolute_percentage_error: 27.1681 - root_mean_squared_error: 0.1436 - val_loss: 0.0541 - val_mean_absolute_error: 0.1936 - val_mean_absolute_percentage_error: 14175151.0000 - val_root_mean_squared_error: 0.2326
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0216 - mean_absolute_error: 0.1149 - mean_absolute_percentage_error: 29.8827 - root_mean_squared_error: 0.1470 - val_loss: 0.0539 - val_mean_absolute_error: 0.1934 - val_mean_absolute_percentage_error: 14286037.0000 - val_root_mean_squared_error: 0.2321

# %%
y_pred = model_lstm_7.predict(x_test)

evaluation_lstm_7 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_7
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# {'Mean Squared Error: ': np.float64(388.7641676932649),
#  'Mean Absolute Error: ': np.float64(16.76678328611413),
#  'Root Mean Absolute Error: ': 19.717103430607267,
#  'Mean Absolute Percentage Error: ': np.float64(27.62630369072231)}

# %%
loss, mae, mape, rmse = model_lstm_7.evaluate(x_test, y_test)
print("model lstm 7")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0310 - mean_absolute_error: 0.1497 - mean_absolute_percentage_error: 34.2039 - root_mean_squared_error: 0.1760
# model lstm 7
# Mean Square Error: 0.030992036685347557
# Mean Absolute Error: 0.14970341324806213
# Mean Absolute Percentage Error: 34.20393753051758
# Root Mean Squared Error: 0.17604555189609528

# %% [markdown]
# ## model 8 (LSTM=16 16 16)

# %%
lr = 0.0003

model_lstm_8 = Sequential()
model_lstm_8.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_8.add(LSTM(16, activation='relu', return_sequences=True))
model_lstm_8.add(LSTM(16, activation='relu', return_sequences=True))
model_lstm_8.add(LSTM(16, activation='relu'))
model_lstm_8.add(Flatten())
model_lstm_8.add(Dense(7))
model_lstm_8.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_8.summary()
# Out:
# Model: "sequential_27"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_12 (LSTM)                  │ (None, 7, 16)          │         1,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_13 (LSTM)                  │ (None, 7, 16)          │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_14 (LSTM)                  │ (None, 16)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_27 (Flatten)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 7)              │           119 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,815 (22.71 KB)
#  Trainable params: 5,815 (22.71 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_8.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 93ms/step - loss: 0.3344 - mean_absolute_error: 0.5502 - mean_absolute_percentage_error: 98.1905 - root_mean_squared_error: 0.5782 - val_loss: 0.3083 - val_mean_absolute_error: 0.5100 - val_mean_absolute_percentage_error: 1319317.1250 - val_root_mean_squared_error: 0.5552
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2847 - mean_absolute_error: 0.5032 - mean_absolute_percentage_error: 88.4289 - root_mean_squared_error: 0.5335 - val_loss: 0.2358 - val_mean_absolute_error: 0.4423 - val_mean_absolute_percentage_error: 3849289.5000 - val_root_mean_squared_error: 0.4856
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1860 - mean_absolute_error: 0.3894 - mean_absolute_percentage_error: 67.2974 - root_mean_squared_error: 0.4304 - val_loss: 0.1011 - val_mean_absolute_error: 0.2710 - val_mean_absolute_percentage_error: 13073612.0000 - val_root_mean_squared_error: 0.3180
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0721 - mean_absolute_error: 0.2195 - mean_absolute_percentage_error: 45.2952 - root_mean_squared_error: 0.2679 - val_loss: 0.0628 - val_mean_absolute_error: 0.2102 - val_mean_absolute_percentage_error: 13445631.0000 - val_root_mean_squared_error: 0.2505
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0301 - mean_absolute_error: 0.1377 - mean_absolute_percentage_error: 30.6998 - root_mean_squared_error: 0.1732 - val_loss: 0.0523 - val_mean_absolute_error: 0.1903 - val_mean_absolute_percentage_error: 14958333.0000 - val_root_mean_squared_error: 0.2286
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0227 - mean_absolute_error: 0.1177 - mean_absolute_percentage_error: 28.6672 - root_mean_squared_error: 0.1506 - val_loss: 0.0511 - val_mean_absolute_error: 0.1872 - val_mean_absolute_percentage_error: 15156823.0000 - val_root_mean_squared_error: 0.2260
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0221 - mean_absolute_error: 0.1181 - mean_absolute_percentage_error: 27.7297 - root_mean_squared_error: 0.1488 - val_loss: 0.0525 - val_mean_absolute_error: 0.1901 - val_mean_absolute_percentage_error: 14554677.0000 - val_root_mean_squared_error: 0.2291
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0227 - mean_absolute_error: 0.1186 - mean_absolute_percentage_error: 31.4322 - root_mean_squared_error: 0.1506 - val_loss: 0.0516 - val_mean_absolute_error: 0.1892 - val_mean_absolute_percentage_error: 14664981.0000 - val_root_mean_squared_error: 0.2271
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0223 - mean_absolute_error: 0.1177 - mean_absolute_percentage_error: 30.0546 - root_mean_squared_error: 0.1494 - val_loss: 0.0516 - val_mean_absolute_error: 0.1892 - val_mean_absolute_percentage_error: 14705558.0000 - val_root_mean_squared_error: 0.2272
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0222 - mean_absolute_error: 0.1155 - mean_absolute_percentage_error: 30.8141 - root_mean_squared_error: 0.1489 - val_loss: 0.0521 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 14446345.0000 - val_root_mean_squared_error: 0.2282
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0219 - mean_absolute_error: 0.1155 - mean_absolute_percentage_error: 29.6379 - root_mean_squared_error: 0.1481 - val_loss: 0.0524 - val_mean_absolute_error: 0.1922 - val_mean_absolute_percentage_error: 14274877.0000 - val_root_mean_squared_error: 0.2288
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0208 - mean_absolute_error: 0.1123 - mean_absolute_percentage_error: 28.4675 - root_mean_squared_error: 0.1441 - val_loss: 0.0531 - val_mean_absolute_error: 0.1941 - val_mean_absolute_percentage_error: 13996582.0000 - val_root_mean_squared_error: 0.2305
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0204 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 28.6998 - root_mean_squared_error: 0.1427 - val_loss: 0.0526 - val_mean_absolute_error: 0.1932 - val_mean_absolute_percentage_error: 14176198.0000 - val_root_mean_squared_error: 0.2293
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0198 - mean_absolute_error: 0.1098 - mean_absolute_percentage_error: 28.7143 - root_mean_squared_error: 0.1407 - val_loss: 0.0526 - val_mean_absolute_error: 0.1947 - val_mean_absolute_percentage_error: 14005149.0000 - val_root_mean_squared_error: 0.2294
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0190 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 27.2766 - root_mean_squared_error: 0.1379 - val_loss: 0.0553 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 13401369.0000 - val_root_mean_squared_error: 0.2351
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0200 - mean_absolute_error: 0.1098 - mean_absolute_percentage_error: 28.0075 - root_mean_squared_error: 0.1414 - val_loss: 0.0557 - val_mean_absolute_error: 0.1989 - val_mean_absolute_percentage_error: 13285471.0000 - val_root_mean_squared_error: 0.2361
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0198 - mean_absolute_error: 0.1095 - mean_absolute_percentage_error: 28.4588 - root_mean_squared_error: 0.1407 - val_loss: 0.0566 - val_mean_absolute_error: 0.2004 - val_mean_absolute_percentage_error: 13129138.0000 - val_root_mean_squared_error: 0.2378
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0197 - mean_absolute_error: 0.1100 - mean_absolute_percentage_error: 27.8472 - root_mean_squared_error: 0.1404 - val_loss: 0.0562 - val_mean_absolute_error: 0.1997 - val_mean_absolute_percentage_error: 13192994.0000 - val_root_mean_squared_error: 0.2370
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0193 - mean_absolute_error: 0.1079 - mean_absolute_percentage_error: 28.2306 - root_mean_squared_error: 0.1389 - val_loss: 0.0563 - val_mean_absolute_error: 0.2004 - val_mean_absolute_percentage_error: 13220281.0000 - val_root_mean_squared_error: 0.2373
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0200 - mean_absolute_error: 0.1104 - mean_absolute_percentage_error: 28.8545 - root_mean_squared_error: 0.1415 - val_loss: 0.0562 - val_mean_absolute_error: 0.2004 - val_mean_absolute_percentage_error: 13163347.0000 - val_root_mean_squared_error: 0.2370

# %%
y_pred = model_lstm_8.predict(x_test)

evaluation_lstm_8 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_8
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# {'Mean Squared Error: ': np.float64(316.5355930347165),
#  'Mean Absolute Error: ': np.float64(14.23902614749208),
#  'Root Mean Absolute Error: ': 17.79144718775616,
#  'Mean Absolute Percentage Error: ': np.float64(25.42743128179052)}

# %%
loss, mae, mape, rmse = model_lstm_8.evaluate(x_test, y_test)
print("model lstm 8")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0252 - mean_absolute_error: 0.1271 - mean_absolute_percentage_error: 32.1044 - root_mean_squared_error: 0.1589
# model lstm 8
# Mean Square Error: 0.025234024971723557
# Mean Absolute Error: 0.12713415920734406
# Mean Absolute Percentage Error: 32.10444641113281
# Root Mean Squared Error: 0.1588522046804428

# %% [markdown]
# ## model 9 (LSTM=32 16)

# %%
lr = 0.0003

model_lstm_9 = Sequential()
model_lstm_9.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_9.add(LSTM(32, activation='relu', return_sequences=True))
model_lstm_9.add(LSTM(16, activation='relu'))
model_lstm_9.add(Flatten())
model_lstm_9.add(Dense(7))
model_lstm_9.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_9.summary()
# Out:
# Model: "sequential_28"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_15 (LSTM)                  │ (None, 7, 32)          │         4,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_16 (LSTM)                  │ (None, 16)             │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_28 (Flatten)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 7)              │           119 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,247 (32.21 KB)
#  Trainable params: 8,247 (32.21 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_9.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 0.3442 - mean_absolute_error: 0.5602 - mean_absolute_percentage_error: 98.8299 - root_mean_squared_error: 0.5866 - val_loss: 0.2991 - val_mean_absolute_error: 0.5023 - val_mean_absolute_percentage_error: 1605935.6250 - val_root_mean_squared_error: 0.5469
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2632 - mean_absolute_error: 0.4825 - mean_absolute_percentage_error: 85.1442 - root_mean_squared_error: 0.5129 - val_loss: 0.2004 - val_mean_absolute_error: 0.4037 - val_mean_absolute_percentage_error: 5404966.5000 - val_root_mean_squared_error: 0.4476
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1353 - mean_absolute_error: 0.3098 - mean_absolute_percentage_error: 54.8920 - root_mean_squared_error: 0.3656 - val_loss: 0.0656 - val_mean_absolute_error: 0.2193 - val_mean_absolute_percentage_error: 14624310.0000 - val_root_mean_squared_error: 0.2562
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0336 - mean_absolute_error: 0.1431 - mean_absolute_percentage_error: 32.8725 - root_mean_squared_error: 0.1831 - val_loss: 0.0604 - val_mean_absolute_error: 0.2078 - val_mean_absolute_percentage_error: 13733321.0000 - val_root_mean_squared_error: 0.2458
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0256 - mean_absolute_error: 0.1256 - mean_absolute_percentage_error: 29.8671 - root_mean_squared_error: 0.1601 - val_loss: 0.0551 - val_mean_absolute_error: 0.1993 - val_mean_absolute_percentage_error: 14552629.0000 - val_root_mean_squared_error: 0.2348
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0237 - mean_absolute_error: 0.1203 - mean_absolute_percentage_error: 29.5738 - root_mean_squared_error: 0.1541 - val_loss: 0.0548 - val_mean_absolute_error: 0.1979 - val_mean_absolute_percentage_error: 14602842.0000 - val_root_mean_squared_error: 0.2341
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0238 - mean_absolute_error: 0.1197 - mean_absolute_percentage_error: 29.8330 - root_mean_squared_error: 0.1543 - val_loss: 0.0569 - val_mean_absolute_error: 0.2012 - val_mean_absolute_percentage_error: 14149192.0000 - val_root_mean_squared_error: 0.2386
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0227 - mean_absolute_error: 0.1167 - mean_absolute_percentage_error: 27.8026 - root_mean_squared_error: 0.1505 - val_loss: 0.0565 - val_mean_absolute_error: 0.2011 - val_mean_absolute_percentage_error: 14255313.0000 - val_root_mean_squared_error: 0.2377
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0223 - mean_absolute_error: 0.1168 - mean_absolute_percentage_error: 28.0590 - root_mean_squared_error: 0.1493 - val_loss: 0.0549 - val_mean_absolute_error: 0.1975 - val_mean_absolute_percentage_error: 14540716.0000 - val_root_mean_squared_error: 0.2342
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0224 - mean_absolute_error: 0.1170 - mean_absolute_percentage_error: 30.5864 - root_mean_squared_error: 0.1496 - val_loss: 0.0531 - val_mean_absolute_error: 0.1942 - val_mean_absolute_percentage_error: 15082315.0000 - val_root_mean_squared_error: 0.2304
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0219 - mean_absolute_error: 0.1153 - mean_absolute_percentage_error: 29.6536 - root_mean_squared_error: 0.1479 - val_loss: 0.0533 - val_mean_absolute_error: 0.1950 - val_mean_absolute_percentage_error: 14954518.0000 - val_root_mean_squared_error: 0.2309
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0227 - mean_absolute_error: 0.1170 - mean_absolute_percentage_error: 31.6272 - root_mean_squared_error: 0.1507 - val_loss: 0.0534 - val_mean_absolute_error: 0.1954 - val_mean_absolute_percentage_error: 14902316.0000 - val_root_mean_squared_error: 0.2311
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0228 - mean_absolute_error: 0.1180 - mean_absolute_percentage_error: 31.9749 - root_mean_squared_error: 0.1510 - val_loss: 0.0534 - val_mean_absolute_error: 0.1955 - val_mean_absolute_percentage_error: 14900122.0000 - val_root_mean_squared_error: 0.2312
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0212 - mean_absolute_error: 0.1128 - mean_absolute_percentage_error: 29.5194 - root_mean_squared_error: 0.1454 - val_loss: 0.0553 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 14304834.0000 - val_root_mean_squared_error: 0.2352
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0208 - mean_absolute_error: 0.1137 - mean_absolute_percentage_error: 28.8948 - root_mean_squared_error: 0.1442 - val_loss: 0.0541 - val_mean_absolute_error: 0.1978 - val_mean_absolute_percentage_error: 14711079.0000 - val_root_mean_squared_error: 0.2325
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0204 - mean_absolute_error: 0.1111 - mean_absolute_percentage_error: 28.3116 - root_mean_squared_error: 0.1427 - val_loss: 0.0541 - val_mean_absolute_error: 0.1985 - val_mean_absolute_percentage_error: 14822989.0000 - val_root_mean_squared_error: 0.2326
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0203 - mean_absolute_error: 0.1108 - mean_absolute_percentage_error: 29.0079 - root_mean_squared_error: 0.1426 - val_loss: 0.0545 - val_mean_absolute_error: 0.1992 - val_mean_absolute_percentage_error: 14850945.0000 - val_root_mean_squared_error: 0.2334
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0210 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 28.4504 - root_mean_squared_error: 0.1451 - val_loss: 0.0548 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 14899043.0000 - val_root_mean_squared_error: 0.2340
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0211 - mean_absolute_error: 0.1133 - mean_absolute_percentage_error: 29.7740 - root_mean_squared_error: 0.1454 - val_loss: 0.0552 - val_mean_absolute_error: 0.2013 - val_mean_absolute_percentage_error: 14693684.0000 - val_root_mean_squared_error: 0.2349
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0200 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 26.9906 - root_mean_squared_error: 0.1414 - val_loss: 0.0563 - val_mean_absolute_error: 0.2038 - val_mean_absolute_percentage_error: 14169347.0000 - val_root_mean_squared_error: 0.2372

# %%
y_pred = model_lstm_9.predict(x_test)

evaluation_lstm_9 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_9
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# {'Mean Squared Error: ': np.float64(379.76451502489266),
#  'Mean Absolute Error: ': np.float64(15.208665283358826),
#  'Root Mean Absolute Error: ': 19.48754769140778,
#  'Mean Absolute Percentage Error: ': np.float64(27.620088164244827)}

# %%
loss, mae, mape, rmse = model_lstm_9.evaluate(x_test, y_test)
print("model lstm 9")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0303 - mean_absolute_error: 0.1358 - mean_absolute_percentage_error: 34.9018 - root_mean_squared_error: 0.1740
# model lstm 9
# Mean Square Error: 0.030274594202637672
# Mean Absolute Error: 0.13579164445400238
# Mean Absolute Percentage Error: 34.901817321777344
# Root Mean Squared Error: 0.1739959567785263

# %% [markdown]
# ## model 10 (LSTM=128. 64)

# %%
lr = 0.0003

model_lstm_10 = Sequential()
model_lstm_10.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_10.add(LSTM(128, activation='relu', return_sequences=True))
model_lstm_10.add(LSTM(64, activation='relu'))
model_lstm_10.add(Flatten())
model_lstm_10.add(Dense(7))
model_lstm_10.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_10.summary()
# Out:
# Model: "sequential_29"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_17 (LSTM)                  │ (None, 7, 128)         │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_18 (LSTM)                  │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_29 (Flatten)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 118,983 (464.78 KB)
#  Trainable params: 118,983 (464.78 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_10.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.2739 - mean_absolute_error: 0.4865 - mean_absolute_percentage_error: 86.6694 - root_mean_squared_error: 0.5217 - val_loss: 0.0883 - val_mean_absolute_error: 0.2406 - val_mean_absolute_percentage_error: 15276545.0000 - val_root_mean_squared_error: 0.2971
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0486 - mean_absolute_error: 0.1748 - mean_absolute_percentage_error: 41.9468 - root_mean_squared_error: 0.2189 - val_loss: 0.0564 - val_mean_absolute_error: 0.2023 - val_mean_absolute_percentage_error: 13640981.0000 - val_root_mean_squared_error: 0.2375
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0255 - mean_absolute_error: 0.1249 - mean_absolute_percentage_error: 29.4566 - root_mean_squared_error: 0.1596 - val_loss: 0.0597 - val_mean_absolute_error: 0.2087 - val_mean_absolute_percentage_error: 12851906.0000 - val_root_mean_squared_error: 0.2444
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0245 - mean_absolute_error: 0.1234 - mean_absolute_percentage_error: 29.7908 - root_mean_squared_error: 0.1565 - val_loss: 0.0551 - val_mean_absolute_error: 0.1987 - val_mean_absolute_percentage_error: 13743463.0000 - val_root_mean_squared_error: 0.2348
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0215 - mean_absolute_error: 0.1139 - mean_absolute_percentage_error: 29.3495 - root_mean_squared_error: 0.1465 - val_loss: 0.0528 - val_mean_absolute_error: 0.1939 - val_mean_absolute_percentage_error: 14275561.0000 - val_root_mean_squared_error: 0.2298
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0217 - mean_absolute_error: 0.1140 - mean_absolute_percentage_error: 30.0709 - root_mean_squared_error: 0.1473 - val_loss: 0.0534 - val_mean_absolute_error: 0.1950 - val_mean_absolute_percentage_error: 14150241.0000 - val_root_mean_squared_error: 0.2311
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0212 - mean_absolute_error: 0.1139 - mean_absolute_percentage_error: 28.6330 - root_mean_squared_error: 0.1457 - val_loss: 0.0549 - val_mean_absolute_error: 0.1980 - val_mean_absolute_percentage_error: 13842495.0000 - val_root_mean_squared_error: 0.2343
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0205 - mean_absolute_error: 0.1106 - mean_absolute_percentage_error: 28.7837 - root_mean_squared_error: 0.1432 - val_loss: 0.0546 - val_mean_absolute_error: 0.1978 - val_mean_absolute_percentage_error: 13802913.0000 - val_root_mean_squared_error: 0.2336
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0210 - mean_absolute_error: 0.1135 - mean_absolute_percentage_error: 28.7899 - root_mean_squared_error: 0.1449 - val_loss: 0.0544 - val_mean_absolute_error: 0.1988 - val_mean_absolute_percentage_error: 13714219.0000 - val_root_mean_squared_error: 0.2333
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0205 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 27.5244 - root_mean_squared_error: 0.1432 - val_loss: 0.0555 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 13797000.0000 - val_root_mean_squared_error: 0.2355
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0203 - mean_absolute_error: 0.1103 - mean_absolute_percentage_error: 28.6441 - root_mean_squared_error: 0.1424 - val_loss: 0.0547 - val_mean_absolute_error: 0.1997 - val_mean_absolute_percentage_error: 13754366.0000 - val_root_mean_squared_error: 0.2339
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0203 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 28.7624 - root_mean_squared_error: 0.1425 - val_loss: 0.0555 - val_mean_absolute_error: 0.2003 - val_mean_absolute_percentage_error: 13597321.0000 - val_root_mean_squared_error: 0.2357
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0199 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 29.3715 - root_mean_squared_error: 0.1411 - val_loss: 0.0554 - val_mean_absolute_error: 0.2029 - val_mean_absolute_percentage_error: 13456979.0000 - val_root_mean_squared_error: 0.2353
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0212 - mean_absolute_error: 0.1137 - mean_absolute_percentage_error: 30.3023 - root_mean_squared_error: 0.1456 - val_loss: 0.0554 - val_mean_absolute_error: 0.2019 - val_mean_absolute_percentage_error: 13522511.0000 - val_root_mean_squared_error: 0.2354
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0201 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 28.3460 - root_mean_squared_error: 0.1418 - val_loss: 0.0566 - val_mean_absolute_error: 0.2027 - val_mean_absolute_percentage_error: 13417618.0000 - val_root_mean_squared_error: 0.2379
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0200 - mean_absolute_error: 0.1096 - mean_absolute_percentage_error: 28.4357 - root_mean_squared_error: 0.1414 - val_loss: 0.0560 - val_mean_absolute_error: 0.2041 - val_mean_absolute_percentage_error: 13567524.0000 - val_root_mean_squared_error: 0.2367
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0189 - mean_absolute_error: 0.1073 - mean_absolute_percentage_error: 26.5183 - root_mean_squared_error: 0.1376 - val_loss: 0.0569 - val_mean_absolute_error: 0.2052 - val_mean_absolute_percentage_error: 13374452.0000 - val_root_mean_squared_error: 0.2386
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0190 - mean_absolute_error: 0.1070 - mean_absolute_percentage_error: 27.2792 - root_mean_squared_error: 0.1377 - val_loss: 0.0569 - val_mean_absolute_error: 0.2025 - val_mean_absolute_percentage_error: 13729274.0000 - val_root_mean_squared_error: 0.2386
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0182 - mean_absolute_error: 0.1057 - mean_absolute_percentage_error: 25.8481 - root_mean_squared_error: 0.1350 - val_loss: 0.0593 - val_mean_absolute_error: 0.2102 - val_mean_absolute_percentage_error: 13673656.0000 - val_root_mean_squared_error: 0.2436
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0183 - mean_absolute_error: 0.1054 - mean_absolute_percentage_error: 25.4960 - root_mean_squared_error: 0.1352 - val_loss: 0.0576 - val_mean_absolute_error: 0.2067 - val_mean_absolute_percentage_error: 13748756.0000 - val_root_mean_squared_error: 0.2400

# %%
y_pred = model_lstm_10.predict(x_test)

evaluation_lstm_10 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_10
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# {'Mean Squared Error: ': np.float64(407.9362081373832),
#  'Mean Absolute Error: ': np.float64(15.009092642336475),
#  'Root Mean Absolute Error: ': 20.19743073109506,
#  'Mean Absolute Percentage Error: ': np.float64(28.816592599477563)}

# %%
loss, mae, mape, rmse = model_lstm_10.evaluate(x_test, y_test)
print("model lstm 10")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0325 - mean_absolute_error: 0.1340 - mean_absolute_percentage_error: 36.7682 - root_mean_squared_error: 0.1803
# model lstm 10
# Mean Square Error: 0.03252042084932327
# Mean Absolute Error: 0.13400974869728088
# Mean Absolute Percentage Error: 36.76820755004883
# Root Mean Squared Error: 0.1803341954946518

# %% [markdown]
# ## model 11 (LSTM=128 128)

# %%
lr = 0.0003

model_lstm_11 = Sequential()
model_lstm_11.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_11.add(LSTM(128, activation='relu', return_sequences=True))
model_lstm_11.add(LSTM(128, activation='relu'))
model_lstm_11.add(Flatten())
model_lstm_11.add(Dense(7))
model_lstm_11.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_11.summary()
# Out:
# Model: "sequential_30"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_19 (LSTM)                  │ (None, 7, 128)         │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_20 (LSTM)                  │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_30 (Flatten)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 201,607 (787.53 KB)
#  Trainable params: 201,607 (787.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_11.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.2977 - mean_absolute_error: 0.5131 - mean_absolute_percentage_error: 90.9418 - root_mean_squared_error: 0.5447 - val_loss: 0.1005 - val_mean_absolute_error: 0.2653 - val_mean_absolute_percentage_error: 12748996.0000 - val_root_mean_squared_error: 0.3170
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0606 - mean_absolute_error: 0.1933 - mean_absolute_percentage_error: 40.6529 - root_mean_squared_error: 0.2444 - val_loss: 0.0550 - val_mean_absolute_error: 0.1961 - val_mean_absolute_percentage_error: 14540527.0000 - val_root_mean_squared_error: 0.2344
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0268 - mean_absolute_error: 0.1291 - mean_absolute_percentage_error: 32.4556 - root_mean_squared_error: 0.1636 - val_loss: 0.0511 - val_mean_absolute_error: 0.1870 - val_mean_absolute_percentage_error: 15157250.0000 - val_root_mean_squared_error: 0.2260
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0223 - mean_absolute_error: 0.1170 - mean_absolute_percentage_error: 31.1404 - root_mean_squared_error: 0.1494 - val_loss: 0.0510 - val_mean_absolute_error: 0.1866 - val_mean_absolute_percentage_error: 15323779.0000 - val_root_mean_squared_error: 0.2258
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0216 - mean_absolute_error: 0.1148 - mean_absolute_percentage_error: 29.5941 - root_mean_squared_error: 0.1470 - val_loss: 0.0512 - val_mean_absolute_error: 0.1876 - val_mean_absolute_percentage_error: 15112838.0000 - val_root_mean_squared_error: 0.2263
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0212 - mean_absolute_error: 0.1149 - mean_absolute_percentage_error: 30.1427 - root_mean_squared_error: 0.1458 - val_loss: 0.0540 - val_mean_absolute_error: 0.1924 - val_mean_absolute_percentage_error: 14378815.0000 - val_root_mean_squared_error: 0.2323
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0206 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 27.9122 - root_mean_squared_error: 0.1435 - val_loss: 0.0534 - val_mean_absolute_error: 0.1923 - val_mean_absolute_percentage_error: 14452339.0000 - val_root_mean_squared_error: 0.2310
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0199 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 27.4739 - root_mean_squared_error: 0.1409 - val_loss: 0.0519 - val_mean_absolute_error: 0.1903 - val_mean_absolute_percentage_error: 14870919.0000 - val_root_mean_squared_error: 0.2277
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0199 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 27.2729 - root_mean_squared_error: 0.1411 - val_loss: 0.0557 - val_mean_absolute_error: 0.1977 - val_mean_absolute_percentage_error: 13820355.0000 - val_root_mean_squared_error: 0.2360
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0207 - mean_absolute_error: 0.1130 - mean_absolute_percentage_error: 28.4110 - root_mean_squared_error: 0.1440 - val_loss: 0.0536 - val_mean_absolute_error: 0.1943 - val_mean_absolute_percentage_error: 14468450.0000 - val_root_mean_squared_error: 0.2315
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0214 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 31.5693 - root_mean_squared_error: 0.1464 - val_loss: 0.0526 - val_mean_absolute_error: 0.1927 - val_mean_absolute_percentage_error: 14765319.0000 - val_root_mean_squared_error: 0.2293
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0202 - mean_absolute_error: 0.1111 - mean_absolute_percentage_error: 27.7590 - root_mean_squared_error: 0.1422 - val_loss: 0.0563 - val_mean_absolute_error: 0.2004 - val_mean_absolute_percentage_error: 13627155.0000 - val_root_mean_squared_error: 0.2374
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0200 - mean_absolute_error: 0.1098 - mean_absolute_percentage_error: 28.7535 - root_mean_squared_error: 0.1412 - val_loss: 0.0529 - val_mean_absolute_error: 0.1939 - val_mean_absolute_percentage_error: 14760436.0000 - val_root_mean_squared_error: 0.2300
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0197 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 28.4528 - root_mean_squared_error: 0.1405 - val_loss: 0.0562 - val_mean_absolute_error: 0.1992 - val_mean_absolute_percentage_error: 13920381.0000 - val_root_mean_squared_error: 0.2370
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0194 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 28.0269 - root_mean_squared_error: 0.1393 - val_loss: 0.0548 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 14339190.0000 - val_root_mean_squared_error: 0.2340
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0190 - mean_absolute_error: 0.1080 - mean_absolute_percentage_error: 27.4410 - root_mean_squared_error: 0.1377 - val_loss: 0.0560 - val_mean_absolute_error: 0.1997 - val_mean_absolute_percentage_error: 14009550.0000 - val_root_mean_squared_error: 0.2366
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0191 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 27.2090 - root_mean_squared_error: 0.1382 - val_loss: 0.0554 - val_mean_absolute_error: 0.1988 - val_mean_absolute_percentage_error: 14285316.0000 - val_root_mean_squared_error: 0.2353
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0186 - mean_absolute_error: 0.1066 - mean_absolute_percentage_error: 26.4694 - root_mean_squared_error: 0.1365 - val_loss: 0.0562 - val_mean_absolute_error: 0.2030 - val_mean_absolute_percentage_error: 14152420.0000 - val_root_mean_squared_error: 0.2371
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0195 - mean_absolute_error: 0.1093 - mean_absolute_percentage_error: 27.9754 - root_mean_squared_error: 0.1396 - val_loss: 0.0540 - val_mean_absolute_error: 0.1966 - val_mean_absolute_percentage_error: 14816871.0000 - val_root_mean_squared_error: 0.2323
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0186 - mean_absolute_error: 0.1064 - mean_absolute_percentage_error: 28.1664 - root_mean_squared_error: 0.1363 - val_loss: 0.0562 - val_mean_absolute_error: 0.1992 - val_mean_absolute_percentage_error: 14545321.0000 - val_root_mean_squared_error: 0.2371

# %%
y_pred = model_lstm_11.predict(x_test)

evaluation_lstm_11 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_11
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# {'Mean Squared Error: ': np.float64(301.9662657849719),
#  'Mean Absolute Error: ': np.float64(13.733981658001335),
#  'Root Mean Absolute Error: ': 17.377176576906038,
#  'Mean Absolute Percentage Error: ': np.float64(24.452698227640965)}

# %%
loss, mae, mape, rmse = model_lstm_11.evaluate(x_test, y_test)
print("model lstm 11")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0241 - mean_absolute_error: 0.1226 - mean_absolute_percentage_error: 30.8456 - root_mean_squared_error: 0.1552
# model lstm 11
# Mean Square Error: 0.024072567000985146
# Mean Absolute Error: 0.12262482941150665
# Mean Absolute Percentage Error: 30.8455810546875
# Root Mean Squared Error: 0.15515336394309998

# %% [markdown]
# ## model 12 (LSTM=64 128)

# %%
lr = 0.0003

model_lstm_12 = Sequential()
model_lstm_12.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_12.add(LSTM(64, activation='relu', return_sequences=True))
model_lstm_12.add(LSTM(128, activation='relu'))
model_lstm_12.add(Flatten())
model_lstm_12.add(Dense(7))
model_lstm_12.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_12.summary()
# Out:
# Model: "sequential_31"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_21 (LSTM)                  │ (None, 7, 64)          │        18,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_22 (LSTM)                  │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_31 (Flatten)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 117,895 (460.53 KB)
#  Trainable params: 117,895 (460.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_12.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 0.2989 - mean_absolute_error: 0.5147 - mean_absolute_percentage_error: 90.1031 - root_mean_squared_error: 0.5455 - val_loss: 0.0687 - val_mean_absolute_error: 0.2223 - val_mean_absolute_percentage_error: 12746359.0000 - val_root_mean_squared_error: 0.2620
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0413 - mean_absolute_error: 0.1613 - mean_absolute_percentage_error: 38.1608 - root_mean_squared_error: 0.2030 - val_loss: 0.0637 - val_mean_absolute_error: 0.2106 - val_mean_absolute_percentage_error: 12914355.0000 - val_root_mean_squared_error: 0.2524
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0257 - mean_absolute_error: 0.1275 - mean_absolute_percentage_error: 30.5147 - root_mean_squared_error: 0.1603 - val_loss: 0.0521 - val_mean_absolute_error: 0.1883 - val_mean_absolute_percentage_error: 15141922.0000 - val_root_mean_squared_error: 0.2282
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0221 - mean_absolute_error: 0.1163 - mean_absolute_percentage_error: 29.3976 - root_mean_squared_error: 0.1487 - val_loss: 0.0509 - val_mean_absolute_error: 0.1859 - val_mean_absolute_percentage_error: 15580327.0000 - val_root_mean_squared_error: 0.2255
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0221 - mean_absolute_error: 0.1162 - mean_absolute_percentage_error: 29.0847 - root_mean_squared_error: 0.1487 - val_loss: 0.0524 - val_mean_absolute_error: 0.1882 - val_mean_absolute_percentage_error: 14951476.0000 - val_root_mean_squared_error: 0.2290
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0210 - mean_absolute_error: 0.1132 - mean_absolute_percentage_error: 28.4123 - root_mean_squared_error: 0.1450 - val_loss: 0.0521 - val_mean_absolute_error: 0.1875 - val_mean_absolute_percentage_error: 15106396.0000 - val_root_mean_squared_error: 0.2283
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0215 - mean_absolute_error: 0.1141 - mean_absolute_percentage_error: 29.0935 - root_mean_squared_error: 0.1465 - val_loss: 0.0518 - val_mean_absolute_error: 0.1873 - val_mean_absolute_percentage_error: 15216558.0000 - val_root_mean_squared_error: 0.2277
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0203 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 28.3187 - root_mean_squared_error: 0.1425 - val_loss: 0.0534 - val_mean_absolute_error: 0.1904 - val_mean_absolute_percentage_error: 14703637.0000 - val_root_mean_squared_error: 0.2310
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0223 - mean_absolute_error: 0.1170 - mean_absolute_percentage_error: 30.2975 - root_mean_squared_error: 0.1494 - val_loss: 0.0526 - val_mean_absolute_error: 0.1892 - val_mean_absolute_percentage_error: 14990315.0000 - val_root_mean_squared_error: 0.2294
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0216 - mean_absolute_error: 0.1141 - mean_absolute_percentage_error: 29.4352 - root_mean_squared_error: 0.1469 - val_loss: 0.0535 - val_mean_absolute_error: 0.1918 - val_mean_absolute_percentage_error: 14761862.0000 - val_root_mean_squared_error: 0.2313
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0213 - mean_absolute_error: 0.1142 - mean_absolute_percentage_error: 28.5950 - root_mean_squared_error: 0.1458 - val_loss: 0.0531 - val_mean_absolute_error: 0.1918 - val_mean_absolute_percentage_error: 14851532.0000 - val_root_mean_squared_error: 0.2304
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0207 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 28.3639 - root_mean_squared_error: 0.1437 - val_loss: 0.0524 - val_mean_absolute_error: 0.1915 - val_mean_absolute_percentage_error: 15302861.0000 - val_root_mean_squared_error: 0.2289
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0206 - mean_absolute_error: 0.1113 - mean_absolute_percentage_error: 28.7704 - root_mean_squared_error: 0.1434 - val_loss: 0.0528 - val_mean_absolute_error: 0.1925 - val_mean_absolute_percentage_error: 15085127.0000 - val_root_mean_squared_error: 0.2299
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0199 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 27.6272 - root_mean_squared_error: 0.1409 - val_loss: 0.0550 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 14540471.0000 - val_root_mean_squared_error: 0.2345
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0199 - mean_absolute_error: 0.1103 - mean_absolute_percentage_error: 28.3469 - root_mean_squared_error: 0.1411 - val_loss: 0.0539 - val_mean_absolute_error: 0.1960 - val_mean_absolute_percentage_error: 14821756.0000 - val_root_mean_squared_error: 0.2322
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0199 - mean_absolute_error: 0.1100 - mean_absolute_percentage_error: 26.9588 - root_mean_squared_error: 0.1410 - val_loss: 0.0560 - val_mean_absolute_error: 0.2014 - val_mean_absolute_percentage_error: 14197728.0000 - val_root_mean_squared_error: 0.2365
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0190 - mean_absolute_error: 0.1070 - mean_absolute_percentage_error: 25.8438 - root_mean_squared_error: 0.1380 - val_loss: 0.0555 - val_mean_absolute_error: 0.1992 - val_mean_absolute_percentage_error: 14617664.0000 - val_root_mean_squared_error: 0.2355
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0192 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 27.1826 - root_mean_squared_error: 0.1384 - val_loss: 0.0554 - val_mean_absolute_error: 0.2011 - val_mean_absolute_percentage_error: 14468096.0000 - val_root_mean_squared_error: 0.2354
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0195 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 26.9684 - root_mean_squared_error: 0.1396 - val_loss: 0.0551 - val_mean_absolute_error: 0.2010 - val_mean_absolute_percentage_error: 14595829.0000 - val_root_mean_squared_error: 0.2348
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0182 - mean_absolute_error: 0.1040 - mean_absolute_percentage_error: 26.2529 - root_mean_squared_error: 0.1348 - val_loss: 0.0576 - val_mean_absolute_error: 0.2051 - val_mean_absolute_percentage_error: 13984566.0000 - val_root_mean_squared_error: 0.2400

# %%
y_pred = model_lstm_12.predict(x_test)

evaluation_lstm_12 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_12
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# {'Mean Squared Error: ': np.float64(271.98071853461926),
#  'Mean Absolute Error: ': np.float64(13.213419174661443),
#  'Root Mean Absolute Error: ': 16.491837936828606,
#  'Mean Absolute Percentage Error: ': np.float64(23.168551997855385)}

# %%
loss, mae, mape, rmse = model_lstm_12.evaluate(x_test, y_test)
print("model lstm 12")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0217 - mean_absolute_error: 0.1180 - mean_absolute_percentage_error: 29.2195 - root_mean_squared_error: 0.1472
# model lstm 12
# Mean Square Error: 0.0216821376234293
# Mean Absolute Error: 0.11797695606946945
# Mean Absolute Percentage Error: 29.219472885131836
# Root Mean Squared Error: 0.1472485512495041

# %% [markdown]
# ## model 13 (LSTM=128)

# %%
lr = 0.0003

model_lstm_13 = Sequential()
model_lstm_13.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_13.add(LSTM(128, activation='relu', return_sequences=True))
model_lstm_13.add(Flatten())
model_lstm_13.add(Dense(7))
model_lstm_13.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_13.summary()
# Out:
# Model: "sequential_32"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_23 (LSTM)                  │ (None, 7, 128)         │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_32 (Flatten)            │ (None, 896)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 7)              │         6,279 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 75,399 (294.53 KB)
#  Trainable params: 75,399 (294.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_13.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.2459 - mean_absolute_error: 0.4510 - mean_absolute_percentage_error: 78.1502 - root_mean_squared_error: 0.4912 - val_loss: 0.0643 - val_mean_absolute_error: 0.1997 - val_mean_absolute_percentage_error: 19353830.0000 - val_root_mean_squared_error: 0.2535
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0392 - mean_absolute_error: 0.1564 - mean_absolute_percentage_error: 39.2980 - root_mean_squared_error: 0.1968 - val_loss: 0.0604 - val_mean_absolute_error: 0.2026 - val_mean_absolute_percentage_error: 13659873.0000 - val_root_mean_squared_error: 0.2457
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0243 - mean_absolute_error: 0.1214 - mean_absolute_percentage_error: 30.0521 - root_mean_squared_error: 0.1559 - val_loss: 0.0520 - val_mean_absolute_error: 0.1885 - val_mean_absolute_percentage_error: 15341995.0000 - val_root_mean_squared_error: 0.2280
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0229 - mean_absolute_error: 0.1185 - mean_absolute_percentage_error: 30.3464 - root_mean_squared_error: 0.1511 - val_loss: 0.0510 - val_mean_absolute_error: 0.1869 - val_mean_absolute_percentage_error: 15562858.0000 - val_root_mean_squared_error: 0.2257
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0214 - mean_absolute_error: 0.1129 - mean_absolute_percentage_error: 29.1179 - root_mean_squared_error: 0.1462 - val_loss: 0.0526 - val_mean_absolute_error: 0.1891 - val_mean_absolute_percentage_error: 14980282.0000 - val_root_mean_squared_error: 0.2293
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0208 - mean_absolute_error: 0.1124 - mean_absolute_percentage_error: 29.2973 - root_mean_squared_error: 0.1441 - val_loss: 0.0534 - val_mean_absolute_error: 0.1901 - val_mean_absolute_percentage_error: 14928577.0000 - val_root_mean_squared_error: 0.2310
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0218 - mean_absolute_error: 0.1149 - mean_absolute_percentage_error: 28.6344 - root_mean_squared_error: 0.1475 - val_loss: 0.0536 - val_mean_absolute_error: 0.1918 - val_mean_absolute_percentage_error: 14756971.0000 - val_root_mean_squared_error: 0.2315
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0211 - mean_absolute_error: 0.1145 - mean_absolute_percentage_error: 28.2649 - root_mean_squared_error: 0.1454 - val_loss: 0.0529 - val_mean_absolute_error: 0.1912 - val_mean_absolute_percentage_error: 14947834.0000 - val_root_mean_squared_error: 0.2301
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0199 - mean_absolute_error: 0.1103 - mean_absolute_percentage_error: 28.0407 - root_mean_squared_error: 0.1411 - val_loss: 0.0542 - val_mean_absolute_error: 0.1926 - val_mean_absolute_percentage_error: 14836166.0000 - val_root_mean_squared_error: 0.2327
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0191 - mean_absolute_error: 0.1074 - mean_absolute_percentage_error: 26.1135 - root_mean_squared_error: 0.1381 - val_loss: 0.0556 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 14425511.0000 - val_root_mean_squared_error: 0.2359
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0194 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 26.6937 - root_mean_squared_error: 0.1394 - val_loss: 0.0563 - val_mean_absolute_error: 0.1982 - val_mean_absolute_percentage_error: 14465107.0000 - val_root_mean_squared_error: 0.2372
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0198 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 28.6927 - root_mean_squared_error: 0.1407 - val_loss: 0.0551 - val_mean_absolute_error: 0.1979 - val_mean_absolute_percentage_error: 14872271.0000 - val_root_mean_squared_error: 0.2347
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0198 - mean_absolute_error: 0.1099 - mean_absolute_percentage_error: 29.8390 - root_mean_squared_error: 0.1408 - val_loss: 0.0548 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 15114618.0000 - val_root_mean_squared_error: 0.2342
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0190 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 27.0616 - root_mean_squared_error: 0.1379 - val_loss: 0.0567 - val_mean_absolute_error: 0.2017 - val_mean_absolute_percentage_error: 14503864.0000 - val_root_mean_squared_error: 0.2380
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0190 - mean_absolute_error: 0.1074 - mean_absolute_percentage_error: 27.5948 - root_mean_squared_error: 0.1378 - val_loss: 0.0590 - val_mean_absolute_error: 0.2058 - val_mean_absolute_percentage_error: 14209511.0000 - val_root_mean_squared_error: 0.2428
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0177 - mean_absolute_error: 0.1042 - mean_absolute_percentage_error: 26.2018 - root_mean_squared_error: 0.1330 - val_loss: 0.0579 - val_mean_absolute_error: 0.2056 - val_mean_absolute_percentage_error: 14351302.0000 - val_root_mean_squared_error: 0.2407
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0175 - mean_absolute_error: 0.1026 - mean_absolute_percentage_error: 26.2096 - root_mean_squared_error: 0.1323 - val_loss: 0.0593 - val_mean_absolute_error: 0.2055 - val_mean_absolute_percentage_error: 14366614.0000 - val_root_mean_squared_error: 0.2435
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0189 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 27.0941 - root_mean_squared_error: 0.1374 - val_loss: 0.0563 - val_mean_absolute_error: 0.2015 - val_mean_absolute_percentage_error: 15245519.0000 - val_root_mean_squared_error: 0.2374
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0184 - mean_absolute_error: 0.1063 - mean_absolute_percentage_error: 26.3117 - root_mean_squared_error: 0.1357 - val_loss: 0.0585 - val_mean_absolute_error: 0.2078 - val_mean_absolute_percentage_error: 14435403.0000 - val_root_mean_squared_error: 0.2418
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0183 - mean_absolute_error: 0.1054 - mean_absolute_percentage_error: 26.4935 - root_mean_squared_error: 0.1350 - val_loss: 0.0573 - val_mean_absolute_error: 0.2014 - val_mean_absolute_percentage_error: 15177017.0000 - val_root_mean_squared_error: 0.2394

# %%
y_pred = model_lstm_13.predict(x_test)

evaluation_lstm_13 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_13
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# {'Mean Squared Error: ': np.float64(321.657629135667),
#  'Mean Absolute Error: ': np.float64(13.947566986083984),
#  'Root Mean Absolute Error: ': 17.934816116583605,
#  'Mean Absolute Percentage Error: ': np.float64(25.885039068633287)}

# %%
loss, mae, mape, rmse = model_lstm_13.evaluate(x_test, y_test)
print("model lstm 13")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0256 - mean_absolute_error: 0.1245 - mean_absolute_percentage_error: 32.9022 - root_mean_squared_error: 0.1601
# model lstm 13
# Mean Square Error: 0.02564234845340252
# Mean Absolute Error: 0.12453185021877289
# Mean Absolute Percentage Error: 32.902217864990234
# Root Mean Squared Error: 0.1601322889328003

# %% [markdown]
# ## model 14 (LSTM=64)

# %%
lr = 0.0003

model_lstm_14 = Sequential()
model_lstm_14.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_14.add(LSTM(64, activation='relu', return_sequences=True))
model_lstm_14.add(Flatten())
model_lstm_14.add(Dense(7))
model_lstm_14.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_14.summary()
# Out:
# Model: "sequential_33"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_24 (LSTM)                  │ (None, 7, 64)          │        18,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_33 (Flatten)            │ (None, 448)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 7)              │         3,143 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,319 (83.28 KB)
#  Trainable params: 21,319 (83.28 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_14.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.2969 - mean_absolute_error: 0.5119 - mean_absolute_percentage_error: 90.8411 - root_mean_squared_error: 0.5441 - val_loss: 0.1269 - val_mean_absolute_error: 0.3155 - val_mean_absolute_percentage_error: 7749652.5000 - val_root_mean_squared_error: 0.3563
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0634 - mean_absolute_error: 0.2059 - mean_absolute_percentage_error: 40.7759 - root_mean_squared_error: 0.2494 - val_loss: 0.0541 - val_mean_absolute_error: 0.1903 - val_mean_absolute_percentage_error: 17057244.0000 - val_root_mean_squared_error: 0.2326
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0251 - mean_absolute_error: 0.1243 - mean_absolute_percentage_error: 31.6883 - root_mean_squared_error: 0.1583 - val_loss: 0.0541 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 13986243.0000 - val_root_mean_squared_error: 0.2327
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0240 - mean_absolute_error: 0.1234 - mean_absolute_percentage_error: 31.3442 - root_mean_squared_error: 0.1549 - val_loss: 0.0508 - val_mean_absolute_error: 0.1900 - val_mean_absolute_percentage_error: 15345801.0000 - val_root_mean_squared_error: 0.2253
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0234 - mean_absolute_error: 0.1197 - mean_absolute_percentage_error: 31.8428 - root_mean_squared_error: 0.1529 - val_loss: 0.0514 - val_mean_absolute_error: 0.1901 - val_mean_absolute_percentage_error: 15235699.0000 - val_root_mean_squared_error: 0.2267
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0220 - mean_absolute_error: 0.1156 - mean_absolute_percentage_error: 29.8740 - root_mean_squared_error: 0.1484 - val_loss: 0.0545 - val_mean_absolute_error: 0.1961 - val_mean_absolute_percentage_error: 14269728.0000 - val_root_mean_squared_error: 0.2334
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0215 - mean_absolute_error: 0.1156 - mean_absolute_percentage_error: 29.3561 - root_mean_squared_error: 0.1465 - val_loss: 0.0540 - val_mean_absolute_error: 0.1946 - val_mean_absolute_percentage_error: 14545623.0000 - val_root_mean_squared_error: 0.2324
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0210 - mean_absolute_error: 0.1135 - mean_absolute_percentage_error: 28.3425 - root_mean_squared_error: 0.1449 - val_loss: 0.0535 - val_mean_absolute_error: 0.1939 - val_mean_absolute_percentage_error: 14952289.0000 - val_root_mean_squared_error: 0.2313
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0212 - mean_absolute_error: 0.1134 - mean_absolute_percentage_error: 29.0642 - root_mean_squared_error: 0.1454 - val_loss: 0.0553 - val_mean_absolute_error: 0.1985 - val_mean_absolute_percentage_error: 14334476.0000 - val_root_mean_squared_error: 0.2352
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0198 - mean_absolute_error: 0.1089 - mean_absolute_percentage_error: 27.1562 - root_mean_squared_error: 0.1408 - val_loss: 0.0576 - val_mean_absolute_error: 0.2025 - val_mean_absolute_percentage_error: 13747582.0000 - val_root_mean_squared_error: 0.2399
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0198 - mean_absolute_error: 0.1096 - mean_absolute_percentage_error: 27.3773 - root_mean_squared_error: 0.1407 - val_loss: 0.0588 - val_mean_absolute_error: 0.2046 - val_mean_absolute_percentage_error: 13476899.0000 - val_root_mean_squared_error: 0.2426
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0196 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 26.5109 - root_mean_squared_error: 0.1399 - val_loss: 0.0603 - val_mean_absolute_error: 0.2074 - val_mean_absolute_percentage_error: 13157803.0000 - val_root_mean_squared_error: 0.2455
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0190 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 26.8897 - root_mean_squared_error: 0.1378 - val_loss: 0.0580 - val_mean_absolute_error: 0.2035 - val_mean_absolute_percentage_error: 13746851.0000 - val_root_mean_squared_error: 0.2408
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0199 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 27.6554 - root_mean_squared_error: 0.1410 - val_loss: 0.0588 - val_mean_absolute_error: 0.2038 - val_mean_absolute_percentage_error: 13636501.0000 - val_root_mean_squared_error: 0.2424
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0190 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 27.5214 - root_mean_squared_error: 0.1378 - val_loss: 0.0570 - val_mean_absolute_error: 0.2015 - val_mean_absolute_percentage_error: 14122174.0000 - val_root_mean_squared_error: 0.2388
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0194 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 27.1019 - root_mean_squared_error: 0.1392 - val_loss: 0.0581 - val_mean_absolute_error: 0.2027 - val_mean_absolute_percentage_error: 13849325.0000 - val_root_mean_squared_error: 0.2410
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0195 - mean_absolute_error: 0.1085 - mean_absolute_percentage_error: 28.0429 - root_mean_squared_error: 0.1396 - val_loss: 0.0600 - val_mean_absolute_error: 0.2070 - val_mean_absolute_percentage_error: 13273144.0000 - val_root_mean_squared_error: 0.2450
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0194 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 26.8705 - root_mean_squared_error: 0.1392 - val_loss: 0.0589 - val_mean_absolute_error: 0.2037 - val_mean_absolute_percentage_error: 13722817.0000 - val_root_mean_squared_error: 0.2428
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0187 - mean_absolute_error: 0.1058 - mean_absolute_percentage_error: 27.4184 - root_mean_squared_error: 0.1368 - val_loss: 0.0572 - val_mean_absolute_error: 0.2011 - val_mean_absolute_percentage_error: 14220648.0000 - val_root_mean_squared_error: 0.2391
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0184 - mean_absolute_error: 0.1048 - mean_absolute_percentage_error: 26.7610 - root_mean_squared_error: 0.1355 - val_loss: 0.0605 - val_mean_absolute_error: 0.2059 - val_mean_absolute_percentage_error: 13490539.0000 - val_root_mean_squared_error: 0.2459

# %%
y_pred = model_lstm_14.predict(x_test)

evaluation_lstm_14 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_14
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# {'Mean Squared Error: ': np.float64(336.93133774970903),
#  'Mean Absolute Error: ': np.float64(15.04144080804319),
#  'Root Mean Absolute Error: ': 18.35568951986574,
#  'Mean Absolute Percentage Error: ': np.float64(25.902786676580003)}

# %%
loss, mae, mape, rmse = model_lstm_14.evaluate(x_test, y_test)
print("model lstm 14")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0269 - mean_absolute_error: 0.1343 - mean_absolute_percentage_error: 32.4453 - root_mean_squared_error: 0.1639
# model lstm 14
# Mean Square Error: 0.026859959587454796
# Mean Absolute Error: 0.13429856300354004
# Mean Absolute Percentage Error: 32.44533157348633
# Root Mean Squared Error: 0.163890078663826

# %% [markdown]
# ## model 15 (LSTM=256)

# %%
lr = 0.0003

model_lstm_15 = Sequential()
model_lstm_15.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_15.add(LSTM(256, activation='relu', return_sequences=True))
model_lstm_15.add(Flatten())
model_lstm_15.add(Dense(7))
model_lstm_15.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_15.summary()
# Out:
# Model: "sequential_34"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_25 (LSTM)                  │ (None, 7, 256)         │       269,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_34 (Flatten)            │ (None, 1792)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 7)              │        12,551 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 281,863 (1.08 MB)
#  Trainable params: 281,863 (1.08 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_15.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.1996 - mean_absolute_error: 0.3972 - mean_absolute_percentage_error: 73.8006 - root_mean_squared_error: 0.4420 - val_loss: 0.0507 - val_mean_absolute_error: 0.1862 - val_mean_absolute_percentage_error: 16600281.0000 - val_root_mean_squared_error: 0.2251
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0278 - mean_absolute_error: 0.1341 - mean_absolute_percentage_error: 31.2032 - root_mean_squared_error: 0.1668 - val_loss: 0.0509 - val_mean_absolute_error: 0.1864 - val_mean_absolute_percentage_error: 16342879.0000 - val_root_mean_squared_error: 0.2256
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0220 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 30.5618 - root_mean_squared_error: 0.1483 - val_loss: 0.0552 - val_mean_absolute_error: 0.1944 - val_mean_absolute_percentage_error: 14703558.0000 - val_root_mean_squared_error: 0.2350
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0227 - mean_absolute_error: 0.1180 - mean_absolute_percentage_error: 29.3515 - root_mean_squared_error: 0.1506 - val_loss: 0.0527 - val_mean_absolute_error: 0.1893 - val_mean_absolute_percentage_error: 15424650.0000 - val_root_mean_squared_error: 0.2295
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0226 - mean_absolute_error: 0.1167 - mean_absolute_percentage_error: 29.2245 - root_mean_squared_error: 0.1502 - val_loss: 0.0527 - val_mean_absolute_error: 0.1897 - val_mean_absolute_percentage_error: 15406536.0000 - val_root_mean_squared_error: 0.2295
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0206 - mean_absolute_error: 0.1117 - mean_absolute_percentage_error: 28.9518 - root_mean_squared_error: 0.1436 - val_loss: 0.0531 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 15352672.0000 - val_root_mean_squared_error: 0.2303
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0208 - mean_absolute_error: 0.1124 - mean_absolute_percentage_error: 28.5822 - root_mean_squared_error: 0.1441 - val_loss: 0.0528 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 15440601.0000 - val_root_mean_squared_error: 0.2297
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0218 - mean_absolute_error: 0.1142 - mean_absolute_percentage_error: 30.6759 - root_mean_squared_error: 0.1476 - val_loss: 0.0538 - val_mean_absolute_error: 0.1926 - val_mean_absolute_percentage_error: 15141675.0000 - val_root_mean_squared_error: 0.2320
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0199 - mean_absolute_error: 0.1099 - mean_absolute_percentage_error: 26.8513 - root_mean_squared_error: 0.1411 - val_loss: 0.0538 - val_mean_absolute_error: 0.1948 - val_mean_absolute_percentage_error: 15162770.0000 - val_root_mean_squared_error: 0.2320
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0200 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 27.6283 - root_mean_squared_error: 0.1414 - val_loss: 0.0532 - val_mean_absolute_error: 0.1921 - val_mean_absolute_percentage_error: 15559038.0000 - val_root_mean_squared_error: 0.2306
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0192 - mean_absolute_error: 0.1077 - mean_absolute_percentage_error: 27.3375 - root_mean_squared_error: 0.1386 - val_loss: 0.0547 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 15015690.0000 - val_root_mean_squared_error: 0.2339
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0192 - mean_absolute_error: 0.1073 - mean_absolute_percentage_error: 27.2451 - root_mean_squared_error: 0.1386 - val_loss: 0.0544 - val_mean_absolute_error: 0.1961 - val_mean_absolute_percentage_error: 15307117.0000 - val_root_mean_squared_error: 0.2333
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0186 - mean_absolute_error: 0.1064 - mean_absolute_percentage_error: 26.2088 - root_mean_squared_error: 0.1362 - val_loss: 0.0585 - val_mean_absolute_error: 0.2031 - val_mean_absolute_percentage_error: 14328809.0000 - val_root_mean_squared_error: 0.2419
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0197 - mean_absolute_error: 0.1096 - mean_absolute_percentage_error: 26.9901 - root_mean_squared_error: 0.1404 - val_loss: 0.0552 - val_mean_absolute_error: 0.1987 - val_mean_absolute_percentage_error: 15311241.0000 - val_root_mean_squared_error: 0.2350
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0186 - mean_absolute_error: 0.1051 - mean_absolute_percentage_error: 28.0677 - root_mean_squared_error: 0.1363 - val_loss: 0.0552 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 15418969.0000 - val_root_mean_squared_error: 0.2349
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0193 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 28.9065 - root_mean_squared_error: 0.1387 - val_loss: 0.0581 - val_mean_absolute_error: 0.2049 - val_mean_absolute_percentage_error: 14468498.0000 - val_root_mean_squared_error: 0.2411
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0191 - mean_absolute_error: 0.1082 - mean_absolute_percentage_error: 26.4041 - root_mean_squared_error: 0.1381 - val_loss: 0.0566 - val_mean_absolute_error: 0.2016 - val_mean_absolute_percentage_error: 14772086.0000 - val_root_mean_squared_error: 0.2380
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0180 - mean_absolute_error: 0.1037 - mean_absolute_percentage_error: 25.8675 - root_mean_squared_error: 0.1341 - val_loss: 0.0574 - val_mean_absolute_error: 0.2044 - val_mean_absolute_percentage_error: 15011265.0000 - val_root_mean_squared_error: 0.2397
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0170 - mean_absolute_error: 0.1015 - mean_absolute_percentage_error: 25.4073 - root_mean_squared_error: 0.1303 - val_loss: 0.0557 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 15952639.0000 - val_root_mean_squared_error: 0.2360
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0184 - mean_absolute_error: 0.1048 - mean_absolute_percentage_error: 27.4357 - root_mean_squared_error: 0.1356 - val_loss: 0.0575 - val_mean_absolute_error: 0.2047 - val_mean_absolute_percentage_error: 14822167.0000 - val_root_mean_squared_error: 0.2398

# %%
y_pred = model_lstm_15.predict(x_test)

evaluation_lstm_15 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_15
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# {'Mean Squared Error: ': np.float64(321.99200746362897),
#  'Mean Absolute Error: ': np.float64(13.920665118159082),
#  'Root Mean Absolute Error: ': 17.944135740225246,
#  'Mean Absolute Percentage Error: ': np.float64(25.754616371782816)}

# %%
loss, mae, mape, rmse = model_lstm_15.evaluate(x_test, y_test)
print("model lstm 15")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0257 - mean_absolute_error: 0.1243 - mean_absolute_percentage_error: 32.7161 - root_mean_squared_error: 0.1602
# model lstm 15
# Mean Square Error: 0.025669004768133163
# Mean Absolute Error: 0.12429165095090866
# Mean Absolute Percentage Error: 32.716068267822266
# Root Mean Squared Error: 0.16021549701690674

# %% [markdown]
# ## model 16 (LSTM=512)

# %%
lr = 0.0003

model_lstm_16 = Sequential()
model_lstm_16.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_16.add(LSTM(512, activation='relu', return_sequences=True))
model_lstm_16.add(Flatten())
model_lstm_16.add(Dense(7))
model_lstm_16.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_16.summary()
# Out:
# Model: "sequential_35"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_26 (LSTM)                  │ (None, 7, 512)         │     1,062,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_35 (Flatten)            │ (None, 3584)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 7)              │        25,095 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,088,007 (4.15 MB)
#  Trainable params: 1,088,007 (4.15 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_16.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.1844 - mean_absolute_error: 0.3656 - mean_absolute_percentage_error: 66.6131 - root_mean_squared_error: 0.4196 - val_loss: 0.0723 - val_mean_absolute_error: 0.2292 - val_mean_absolute_percentage_error: 11407193.0000 - val_root_mean_squared_error: 0.2690
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.0320 - mean_absolute_error: 0.1440 - mean_absolute_percentage_error: 31.0393 - root_mean_squared_error: 0.1786 - val_loss: 0.0573 - val_mean_absolute_error: 0.1999 - val_mean_absolute_percentage_error: 13480289.0000 - val_root_mean_squared_error: 0.2394
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.0255 - mean_absolute_error: 0.1282 - mean_absolute_percentage_error: 29.7092 - root_mean_squared_error: 0.1596 - val_loss: 0.0523 - val_mean_absolute_error: 0.1897 - val_mean_absolute_percentage_error: 14647306.0000 - val_root_mean_squared_error: 0.2287
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0220 - mean_absolute_error: 0.1161 - mean_absolute_percentage_error: 28.3999 - root_mean_squared_error: 0.1482 - val_loss: 0.0509 - val_mean_absolute_error: 0.1877 - val_mean_absolute_percentage_error: 15214007.0000 - val_root_mean_squared_error: 0.2256
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.0210 - mean_absolute_error: 0.1120 - mean_absolute_percentage_error: 28.0287 - root_mean_squared_error: 0.1448 - val_loss: 0.0515 - val_mean_absolute_error: 0.1893 - val_mean_absolute_percentage_error: 14995819.0000 - val_root_mean_squared_error: 0.2270
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.0215 - mean_absolute_error: 0.1147 - mean_absolute_percentage_error: 30.7488 - root_mean_squared_error: 0.1468 - val_loss: 0.0509 - val_mean_absolute_error: 0.1888 - val_mean_absolute_percentage_error: 15581510.0000 - val_root_mean_squared_error: 0.2257
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0237 - mean_absolute_error: 0.1190 - mean_absolute_percentage_error: 32.8095 - root_mean_squared_error: 0.1540 - val_loss: 0.0516 - val_mean_absolute_error: 0.1903 - val_mean_absolute_percentage_error: 15127433.0000 - val_root_mean_squared_error: 0.2272
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.0212 - mean_absolute_error: 0.1142 - mean_absolute_percentage_error: 28.9931 - root_mean_squared_error: 0.1454 - val_loss: 0.0549 - val_mean_absolute_error: 0.1953 - val_mean_absolute_percentage_error: 14359366.0000 - val_root_mean_squared_error: 0.2343
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0217 - mean_absolute_error: 0.1149 - mean_absolute_percentage_error: 29.1073 - root_mean_squared_error: 0.1471 - val_loss: 0.0557 - val_mean_absolute_error: 0.1991 - val_mean_absolute_percentage_error: 14047544.0000 - val_root_mean_squared_error: 0.2359
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0208 - mean_absolute_error: 0.1128 - mean_absolute_percentage_error: 29.2058 - root_mean_squared_error: 0.1441 - val_loss: 0.0561 - val_mean_absolute_error: 0.1980 - val_mean_absolute_percentage_error: 14120139.0000 - val_root_mean_squared_error: 0.2369
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0205 - mean_absolute_error: 0.1118 - mean_absolute_percentage_error: 29.3281 - root_mean_squared_error: 0.1432 - val_loss: 0.0532 - val_mean_absolute_error: 0.1938 - val_mean_absolute_percentage_error: 15045342.0000 - val_root_mean_squared_error: 0.2308
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.0205 - mean_absolute_error: 0.1130 - mean_absolute_percentage_error: 29.2129 - root_mean_squared_error: 0.1431 - val_loss: 0.0568 - val_mean_absolute_error: 0.2009 - val_mean_absolute_percentage_error: 13994616.0000 - val_root_mean_squared_error: 0.2384
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0195 - mean_absolute_error: 0.1089 - mean_absolute_percentage_error: 27.7297 - root_mean_squared_error: 0.1397 - val_loss: 0.0550 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 14526987.0000 - val_root_mean_squared_error: 0.2346
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0190 - mean_absolute_error: 0.1080 - mean_absolute_percentage_error: 26.7728 - root_mean_squared_error: 0.1378 - val_loss: 0.0569 - val_mean_absolute_error: 0.2027 - val_mean_absolute_percentage_error: 13878036.0000 - val_root_mean_squared_error: 0.2386
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.0187 - mean_absolute_error: 0.1065 - mean_absolute_percentage_error: 26.5097 - root_mean_squared_error: 0.1369 - val_loss: 0.0541 - val_mean_absolute_error: 0.1965 - val_mean_absolute_percentage_error: 15029463.0000 - val_root_mean_squared_error: 0.2326
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0195 - mean_absolute_error: 0.1086 - mean_absolute_percentage_error: 28.2853 - root_mean_squared_error: 0.1395 - val_loss: 0.0565 - val_mean_absolute_error: 0.2026 - val_mean_absolute_percentage_error: 14239552.0000 - val_root_mean_squared_error: 0.2377
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - loss: 0.0187 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 26.0906 - root_mean_squared_error: 0.1366 - val_loss: 0.0568 - val_mean_absolute_error: 0.2005 - val_mean_absolute_percentage_error: 14437560.0000 - val_root_mean_squared_error: 0.2383
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0190 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 26.7501 - root_mean_squared_error: 0.1378 - val_loss: 0.0567 - val_mean_absolute_error: 0.2031 - val_mean_absolute_percentage_error: 14111209.0000 - val_root_mean_squared_error: 0.2382
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.0185 - mean_absolute_error: 0.1066 - mean_absolute_percentage_error: 27.3328 - root_mean_squared_error: 0.1361 - val_loss: 0.0610 - val_mean_absolute_error: 0.2125 - val_mean_absolute_percentage_error: 13122551.0000 - val_root_mean_squared_error: 0.2470
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.0197 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 26.9788 - root_mean_squared_error: 0.1403 - val_loss: 0.0573 - val_mean_absolute_error: 0.2018 - val_mean_absolute_percentage_error: 15446044.0000 - val_root_mean_squared_error: 0.2394

# %%
y_pred = model_lstm_16.predict(x_test)

evaluation_lstm_16 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_16
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# {'Mean Squared Error: ': np.float64(466.82663771646855),
#  'Mean Absolute Error: ': np.float64(16.250607957645336),
#  'Root Mean Absolute Error: ': 21.606171287770273,
#  'Mean Absolute Percentage Error: ': np.float64(31.161397248350614)}

# %%
loss, mae, mape, rmse = model_lstm_16.evaluate(x_test, y_test)
print("model lstm 16")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0372 - mean_absolute_error: 0.1451 - mean_absolute_percentage_error: 39.7344 - root_mean_squared_error: 0.1929
# model lstm 16
# Mean Square Error: 0.037215132266283035
# Mean Absolute Error: 0.14509472250938416
# Mean Absolute Percentage Error: 39.734397888183594
# Root Mean Squared Error: 0.1929122358560562

# %% [markdown]
# ## model 17 (LSTM=512 128)

# %%
lr = 0.0003

model_lstm_17 = Sequential()
model_lstm_17.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_17.add(LSTM(512, activation='relu', return_sequences=True))
model_lstm_17.add(LSTM(128, activation='relu'))
model_lstm_17.add(Flatten())
model_lstm_17.add(Dense(7))
model_lstm_17.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_17.summary()
# Out:
# Model: "sequential_36"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_27 (LSTM)                  │ (None, 7, 512)         │     1,062,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_28 (LSTM)                  │ (None, 128)            │       328,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_36 (Flatten)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,392,007 (5.31 MB)
#  Trainable params: 1,392,007 (5.31 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_17.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - loss: 0.2168 - mean_absolute_error: 0.4135 - mean_absolute_percentage_error: 75.9879 - root_mean_squared_error: 0.4603 - val_loss: 0.0759 - val_mean_absolute_error: 0.2351 - val_mean_absolute_percentage_error: 11297524.0000 - val_root_mean_squared_error: 0.2756
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0337 - mean_absolute_error: 0.1503 - mean_absolute_percentage_error: 31.8493 - root_mean_squared_error: 0.1832 - val_loss: 0.0557 - val_mean_absolute_error: 0.1959 - val_mean_absolute_percentage_error: 14064612.0000 - val_root_mean_squared_error: 0.2361
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0225 - mean_absolute_error: 0.1184 - mean_absolute_percentage_error: 29.3283 - root_mean_squared_error: 0.1499 - val_loss: 0.0513 - val_mean_absolute_error: 0.1861 - val_mean_absolute_percentage_error: 15290746.0000 - val_root_mean_squared_error: 0.2264
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0213 - mean_absolute_error: 0.1139 - mean_absolute_percentage_error: 29.0019 - root_mean_squared_error: 0.1459 - val_loss: 0.0523 - val_mean_absolute_error: 0.1880 - val_mean_absolute_percentage_error: 14996478.0000 - val_root_mean_squared_error: 0.2287
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0218 - mean_absolute_error: 0.1154 - mean_absolute_percentage_error: 28.9467 - root_mean_squared_error: 0.1476 - val_loss: 0.0530 - val_mean_absolute_error: 0.1886 - val_mean_absolute_percentage_error: 14819997.0000 - val_root_mean_squared_error: 0.2302
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0211 - mean_absolute_error: 0.1135 - mean_absolute_percentage_error: 28.9242 - root_mean_squared_error: 0.1451 - val_loss: 0.0516 - val_mean_absolute_error: 0.1876 - val_mean_absolute_percentage_error: 15210137.0000 - val_root_mean_squared_error: 0.2271
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0226 - mean_absolute_error: 0.1169 - mean_absolute_percentage_error: 30.2800 - root_mean_squared_error: 0.1503 - val_loss: 0.0533 - val_mean_absolute_error: 0.1907 - val_mean_absolute_percentage_error: 14554643.0000 - val_root_mean_squared_error: 0.2309
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0207 - mean_absolute_error: 0.1127 - mean_absolute_percentage_error: 28.6098 - root_mean_squared_error: 0.1440 - val_loss: 0.0523 - val_mean_absolute_error: 0.1894 - val_mean_absolute_percentage_error: 14960162.0000 - val_root_mean_squared_error: 0.2287
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0216 - mean_absolute_error: 0.1146 - mean_absolute_percentage_error: 30.9353 - root_mean_squared_error: 0.1471 - val_loss: 0.0547 - val_mean_absolute_error: 0.1931 - val_mean_absolute_percentage_error: 14269721.0000 - val_root_mean_squared_error: 0.2338
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0201 - mean_absolute_error: 0.1108 - mean_absolute_percentage_error: 27.6791 - root_mean_squared_error: 0.1418 - val_loss: 0.0546 - val_mean_absolute_error: 0.1937 - val_mean_absolute_percentage_error: 14259322.0000 - val_root_mean_squared_error: 0.2337
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.0204 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 29.2517 - root_mean_squared_error: 0.1428 - val_loss: 0.0567 - val_mean_absolute_error: 0.1982 - val_mean_absolute_percentage_error: 13654233.0000 - val_root_mean_squared_error: 0.2382
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0207 - mean_absolute_error: 0.1135 - mean_absolute_percentage_error: 28.9528 - root_mean_squared_error: 0.1440 - val_loss: 0.0528 - val_mean_absolute_error: 0.1910 - val_mean_absolute_percentage_error: 14915230.0000 - val_root_mean_squared_error: 0.2298
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0199 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 28.3187 - root_mean_squared_error: 0.1411 - val_loss: 0.0545 - val_mean_absolute_error: 0.1973 - val_mean_absolute_percentage_error: 13931683.0000 - val_root_mean_squared_error: 0.2334
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0199 - mean_absolute_error: 0.1099 - mean_absolute_percentage_error: 27.3941 - root_mean_squared_error: 0.1410 - val_loss: 0.0538 - val_mean_absolute_error: 0.1953 - val_mean_absolute_percentage_error: 14349508.0000 - val_root_mean_squared_error: 0.2320
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0203 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 27.5902 - root_mean_squared_error: 0.1425 - val_loss: 0.0521 - val_mean_absolute_error: 0.1927 - val_mean_absolute_percentage_error: 15035915.0000 - val_root_mean_squared_error: 0.2282
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - loss: 0.0196 - mean_absolute_error: 0.1079 - mean_absolute_percentage_error: 29.5640 - root_mean_squared_error: 0.1400 - val_loss: 0.0536 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 14710476.0000 - val_root_mean_squared_error: 0.2315
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - loss: 0.0191 - mean_absolute_error: 0.1084 - mean_absolute_percentage_error: 28.4364 - root_mean_squared_error: 0.1382 - val_loss: 0.0549 - val_mean_absolute_error: 0.2005 - val_mean_absolute_percentage_error: 13918115.0000 - val_root_mean_squared_error: 0.2344
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0183 - mean_absolute_error: 0.1050 - mean_absolute_percentage_error: 26.4908 - root_mean_squared_error: 0.1354 - val_loss: 0.0554 - val_mean_absolute_error: 0.2013 - val_mean_absolute_percentage_error: 13964610.0000 - val_root_mean_squared_error: 0.2353
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0190 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 27.3069 - root_mean_squared_error: 0.1378 - val_loss: 0.0561 - val_mean_absolute_error: 0.1993 - val_mean_absolute_percentage_error: 14043300.0000 - val_root_mean_squared_error: 0.2368
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0197 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 26.7097 - root_mean_squared_error: 0.1403 - val_loss: 0.0530 - val_mean_absolute_error: 0.1939 - val_mean_absolute_percentage_error: 15439626.0000 - val_root_mean_squared_error: 0.2303

# %%
y_pred = model_lstm_17.predict(x_test)

evaluation_lstm_17 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_17
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# {'Mean Squared Error: ': np.float64(353.5499715529387),
#  'Mean Absolute Error: ': np.float64(14.611112711380937),
#  'Root Mean Absolute Error: ': 18.802924547871235,
#  'Mean Absolute Percentage Error: ': np.float64(27.375874587516353)}

# %%
loss, mae, mape, rmse = model_lstm_17.evaluate(x_test, y_test)
print("model lstm 17")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0282 - mean_absolute_error: 0.1305 - mean_absolute_percentage_error: 34.8169 - root_mean_squared_error: 0.1679
# model lstm 17
# Mean Square Error: 0.028184786438941956
# Mean Absolute Error: 0.13045634329319
# Mean Absolute Percentage Error: 34.816864013671875
# Root Mean Squared Error: 0.1678832471370697

# %% [markdown]
# ## model 18 (LSTM=16 16 16)

# %%
from keras.layers import LeakyReLU, ELU
lr = 0.0003

model_lstm_18 = Sequential()
model_lstm_18.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_18.add(LSTM(16, return_sequences=True))
model_lstm_18.add(LeakyReLU(alpha=0.1))  # or ELU(alpha=1.0)

model_lstm_18.add(LSTM(16, return_sequences=True))
model_lstm_18.add(LeakyReLU(alpha=0.1))  # or ELU(alpha=1.0)

model_lstm_18.add(LSTM(16))
model_lstm_18.add(Flatten())
model_lstm_18.add(Dense(7))
model_lstm_18.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_18.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "sequential_37"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_29 (LSTM)                  │ (None, 7, 16)          │         1,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 7, 16)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_30 (LSTM)                  │ (None, 7, 16)          │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 7, 16)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_31 (LSTM)                  │ (None, 16)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_37 (Flatten)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 7)              │           119 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,815 (22.71 KB)
#  Trainable params: 5,815 (22.71 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_18.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - loss: 0.3134 - mean_absolute_error: 0.5290 - mean_absolute_percentage_error: 95.5103 - root_mean_squared_error: 0.5598 - val_loss: 0.2692 - val_mean_absolute_error: 0.4734 - val_mean_absolute_percentage_error: 3280095.2500 - val_root_mean_squared_error: 0.5188
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2264 - mean_absolute_error: 0.4313 - mean_absolute_percentage_error: 74.8317 - root_mean_squared_error: 0.4754 - val_loss: 0.1452 - val_mean_absolute_error: 0.3049 - val_mean_absolute_percentage_error: 10870090.0000 - val_root_mean_squared_error: 0.3810
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1037 - mean_absolute_error: 0.2383 - mean_absolute_percentage_error: 49.7401 - root_mean_squared_error: 0.3217 - val_loss: 0.0770 - val_mean_absolute_error: 0.2183 - val_mean_absolute_percentage_error: 15128644.0000 - val_root_mean_squared_error: 0.2774
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0439 - mean_absolute_error: 0.1601 - mean_absolute_percentage_error: 36.4617 - root_mean_squared_error: 0.2093 - val_loss: 0.0522 - val_mean_absolute_error: 0.1824 - val_mean_absolute_percentage_error: 16942830.0000 - val_root_mean_squared_error: 0.2285
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0254 - mean_absolute_error: 0.1276 - mean_absolute_percentage_error: 33.8606 - root_mean_squared_error: 0.1595 - val_loss: 0.0503 - val_mean_absolute_error: 0.1787 - val_mean_absolute_percentage_error: 16640460.0000 - val_root_mean_squared_error: 0.2242
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0241 - mean_absolute_error: 0.1238 - mean_absolute_percentage_error: 32.2427 - root_mean_squared_error: 0.1552 - val_loss: 0.0516 - val_mean_absolute_error: 0.1825 - val_mean_absolute_percentage_error: 15883548.0000 - val_root_mean_squared_error: 0.2272
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0238 - mean_absolute_error: 0.1243 - mean_absolute_percentage_error: 31.8158 - root_mean_squared_error: 0.1543 - val_loss: 0.0501 - val_mean_absolute_error: 0.1810 - val_mean_absolute_percentage_error: 16302790.0000 - val_root_mean_squared_error: 0.2238
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0235 - mean_absolute_error: 0.1205 - mean_absolute_percentage_error: 31.8694 - root_mean_squared_error: 0.1532 - val_loss: 0.0507 - val_mean_absolute_error: 0.1835 - val_mean_absolute_percentage_error: 15631780.0000 - val_root_mean_squared_error: 0.2251
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0229 - mean_absolute_error: 0.1188 - mean_absolute_percentage_error: 32.2519 - root_mean_squared_error: 0.1512 - val_loss: 0.0518 - val_mean_absolute_error: 0.1866 - val_mean_absolute_percentage_error: 14889771.0000 - val_root_mean_squared_error: 0.2276
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0216 - mean_absolute_error: 0.1153 - mean_absolute_percentage_error: 29.1667 - root_mean_squared_error: 0.1471 - val_loss: 0.0534 - val_mean_absolute_error: 0.1893 - val_mean_absolute_percentage_error: 14355860.0000 - val_root_mean_squared_error: 0.2311
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0217 - mean_absolute_error: 0.1156 - mean_absolute_percentage_error: 29.1167 - root_mean_squared_error: 0.1472 - val_loss: 0.0532 - val_mean_absolute_error: 0.1896 - val_mean_absolute_percentage_error: 14338422.0000 - val_root_mean_squared_error: 0.2307
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0221 - mean_absolute_error: 0.1158 - mean_absolute_percentage_error: 30.9143 - root_mean_squared_error: 0.1487 - val_loss: 0.0540 - val_mean_absolute_error: 0.1913 - val_mean_absolute_percentage_error: 14010354.0000 - val_root_mean_squared_error: 0.2324
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0223 - mean_absolute_error: 0.1162 - mean_absolute_percentage_error: 30.5534 - root_mean_squared_error: 0.1494 - val_loss: 0.0536 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 14143407.0000 - val_root_mean_squared_error: 0.2315
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0209 - mean_absolute_error: 0.1111 - mean_absolute_percentage_error: 28.6960 - root_mean_squared_error: 0.1445 - val_loss: 0.0550 - val_mean_absolute_error: 0.1925 - val_mean_absolute_percentage_error: 13685718.0000 - val_root_mean_squared_error: 0.2346
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0217 - mean_absolute_error: 0.1148 - mean_absolute_percentage_error: 30.2421 - root_mean_squared_error: 0.1472 - val_loss: 0.0526 - val_mean_absolute_error: 0.1904 - val_mean_absolute_percentage_error: 14481210.0000 - val_root_mean_squared_error: 0.2293
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0213 - mean_absolute_error: 0.1129 - mean_absolute_percentage_error: 29.1639 - root_mean_squared_error: 0.1459 - val_loss: 0.0543 - val_mean_absolute_error: 0.1916 - val_mean_absolute_percentage_error: 13851395.0000 - val_root_mean_squared_error: 0.2330
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0215 - mean_absolute_error: 0.1140 - mean_absolute_percentage_error: 29.6057 - root_mean_squared_error: 0.1465 - val_loss: 0.0533 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 14106155.0000 - val_root_mean_squared_error: 0.2310
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0211 - mean_absolute_error: 0.1119 - mean_absolute_percentage_error: 29.4014 - root_mean_squared_error: 0.1451 - val_loss: 0.0556 - val_mean_absolute_error: 0.1932 - val_mean_absolute_percentage_error: 13492888.0000 - val_root_mean_squared_error: 0.2358
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0212 - mean_absolute_error: 0.1126 - mean_absolute_percentage_error: 29.7833 - root_mean_squared_error: 0.1456 - val_loss: 0.0547 - val_mean_absolute_error: 0.1921 - val_mean_absolute_percentage_error: 13637046.0000 - val_root_mean_squared_error: 0.2339
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0212 - mean_absolute_error: 0.1129 - mean_absolute_percentage_error: 29.5276 - root_mean_squared_error: 0.1457 - val_loss: 0.0528 - val_mean_absolute_error: 0.1907 - val_mean_absolute_percentage_error: 14222337.0000 - val_root_mean_squared_error: 0.2297

# %%
y_pred = model_lstm_18.predict(x_test)

evaluation_lstm_18 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_18
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# {'Mean Squared Error: ': np.float64(430.8832270191488),
#  'Mean Absolute Error: ': np.float64(17.273792111143774),
#  'Root Mean Absolute Error: ': 20.757726923224247,
#  'Mean Absolute Percentage Error: ': np.float64(29.58385066397657)}

# %%
loss, mae, mape, rmse = model_lstm_18.evaluate(x_test, y_test)
print("model lstm 18")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0343 - mean_absolute_error: 0.1542 - mean_absolute_percentage_error: 36.9139 - root_mean_squared_error: 0.1853
# model lstm 18
# Mean Square Error: 0.034349747002124786
# Mean Absolute Error: 0.1542302817106247
# Mean Absolute Percentage Error: 36.913917541503906
# Root Mean Squared Error: 0.18533684313297272

# %% [markdown]
# ## model 19 (LSTM=16 16 16)

# %%
lr = 0.0003

model_lstm_19 = Sequential()
model_lstm_19.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_19.add(LSTM(16, return_sequences=True))
model_lstm_19.add(ELU(alpha=1.0))  # or ELU(alpha=1.0)

model_lstm_19.add(LSTM(16, return_sequences=True))
model_lstm_19.add(ELU(alpha=1.0))  # or ELU(alpha=1.0)

model_lstm_19.add(LSTM(16))
model_lstm_19.add(Flatten())
model_lstm_19.add(Dense(7))
model_lstm_19.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_19.summary()
# Out:
# Model: "sequential_38"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_32 (LSTM)                  │ (None, 7, 16)          │         1,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu (ELU)                       │ (None, 7, 16)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_33 (LSTM)                  │ (None, 7, 16)          │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_1 (ELU)                     │ (None, 7, 16)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_34 (LSTM)                  │ (None, 16)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_38 (Flatten)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 7)              │           119 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,815 (22.71 KB)
#  Trainable params: 5,815 (22.71 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_19.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - loss: 0.3249 - mean_absolute_error: 0.5426 - mean_absolute_percentage_error: 95.1254 - root_mean_squared_error: 0.5697 - val_loss: 0.2460 - val_mean_absolute_error: 0.4515 - val_mean_absolute_percentage_error: 3413283.7500 - val_root_mean_squared_error: 0.4960
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1961 - mean_absolute_error: 0.4003 - mean_absolute_percentage_error: 68.6410 - root_mean_squared_error: 0.4418 - val_loss: 0.1078 - val_mean_absolute_error: 0.2758 - val_mean_absolute_percentage_error: 12105600.0000 - val_root_mean_squared_error: 0.3284
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0724 - mean_absolute_error: 0.2167 - mean_absolute_percentage_error: 45.9522 - root_mean_squared_error: 0.2686 - val_loss: 0.0594 - val_mean_absolute_error: 0.1964 - val_mean_absolute_percentage_error: 15927159.0000 - val_root_mean_squared_error: 0.2438
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0307 - mean_absolute_error: 0.1423 - mean_absolute_percentage_error: 33.6619 - root_mean_squared_error: 0.1750 - val_loss: 0.0501 - val_mean_absolute_error: 0.1797 - val_mean_absolute_percentage_error: 17323302.0000 - val_root_mean_squared_error: 0.2238
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0253 - mean_absolute_error: 0.1261 - mean_absolute_percentage_error: 35.5469 - root_mean_squared_error: 0.1591 - val_loss: 0.0502 - val_mean_absolute_error: 0.1796 - val_mean_absolute_percentage_error: 16716327.0000 - val_root_mean_squared_error: 0.2241
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0242 - mean_absolute_error: 0.1235 - mean_absolute_percentage_error: 33.2009 - root_mean_squared_error: 0.1554 - val_loss: 0.0506 - val_mean_absolute_error: 0.1810 - val_mean_absolute_percentage_error: 16357592.0000 - val_root_mean_squared_error: 0.2248
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0236 - mean_absolute_error: 0.1220 - mean_absolute_percentage_error: 32.6911 - root_mean_squared_error: 0.1535 - val_loss: 0.0507 - val_mean_absolute_error: 0.1824 - val_mean_absolute_percentage_error: 16290084.0000 - val_root_mean_squared_error: 0.2252
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0226 - mean_absolute_error: 0.1184 - mean_absolute_percentage_error: 30.9632 - root_mean_squared_error: 0.1504 - val_loss: 0.0518 - val_mean_absolute_error: 0.1854 - val_mean_absolute_percentage_error: 15822614.0000 - val_root_mean_squared_error: 0.2275
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0230 - mean_absolute_error: 0.1193 - mean_absolute_percentage_error: 32.3459 - root_mean_squared_error: 0.1516 - val_loss: 0.0525 - val_mean_absolute_error: 0.1874 - val_mean_absolute_percentage_error: 15613766.0000 - val_root_mean_squared_error: 0.2292
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0228 - mean_absolute_error: 0.1191 - mean_absolute_percentage_error: 32.3447 - root_mean_squared_error: 0.1510 - val_loss: 0.0528 - val_mean_absolute_error: 0.1884 - val_mean_absolute_percentage_error: 15686465.0000 - val_root_mean_squared_error: 0.2299
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0208 - mean_absolute_error: 0.1130 - mean_absolute_percentage_error: 28.3630 - root_mean_squared_error: 0.1442 - val_loss: 0.0563 - val_mean_absolute_error: 0.1935 - val_mean_absolute_percentage_error: 14617568.0000 - val_root_mean_squared_error: 0.2374
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0214 - mean_absolute_error: 0.1151 - mean_absolute_percentage_error: 28.4834 - root_mean_squared_error: 0.1463 - val_loss: 0.0549 - val_mean_absolute_error: 0.1910 - val_mean_absolute_percentage_error: 15138711.0000 - val_root_mean_squared_error: 0.2342
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0207 - mean_absolute_error: 0.1135 - mean_absolute_percentage_error: 29.2320 - root_mean_squared_error: 0.1440 - val_loss: 0.0541 - val_mean_absolute_error: 0.1905 - val_mean_absolute_percentage_error: 15603170.0000 - val_root_mean_squared_error: 0.2326
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0206 - mean_absolute_error: 0.1118 - mean_absolute_percentage_error: 29.4191 - root_mean_squared_error: 0.1435 - val_loss: 0.0563 - val_mean_absolute_error: 0.1932 - val_mean_absolute_percentage_error: 14911732.0000 - val_root_mean_squared_error: 0.2372
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0205 - mean_absolute_error: 0.1113 - mean_absolute_percentage_error: 29.4631 - root_mean_squared_error: 0.1432 - val_loss: 0.0555 - val_mean_absolute_error: 0.1920 - val_mean_absolute_percentage_error: 15185598.0000 - val_root_mean_squared_error: 0.2355
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0213 - mean_absolute_error: 0.1130 - mean_absolute_percentage_error: 27.9293 - root_mean_squared_error: 0.1458 - val_loss: 0.0560 - val_mean_absolute_error: 0.1929 - val_mean_absolute_percentage_error: 15092267.0000 - val_root_mean_squared_error: 0.2366
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0209 - mean_absolute_error: 0.1131 - mean_absolute_percentage_error: 29.0364 - root_mean_squared_error: 0.1446 - val_loss: 0.0551 - val_mean_absolute_error: 0.1917 - val_mean_absolute_percentage_error: 15448232.0000 - val_root_mean_squared_error: 0.2347
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0223 - mean_absolute_error: 0.1161 - mean_absolute_percentage_error: 30.6897 - root_mean_squared_error: 0.1490 - val_loss: 0.0563 - val_mean_absolute_error: 0.1926 - val_mean_absolute_percentage_error: 15092579.0000 - val_root_mean_squared_error: 0.2373
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0214 - mean_absolute_error: 0.1137 - mean_absolute_percentage_error: 29.7420 - root_mean_squared_error: 0.1462 - val_loss: 0.0568 - val_mean_absolute_error: 0.1943 - val_mean_absolute_percentage_error: 14985322.0000 - val_root_mean_squared_error: 0.2384
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0219 - mean_absolute_error: 0.1163 - mean_absolute_percentage_error: 29.0225 - root_mean_squared_error: 0.1480 - val_loss: 0.0568 - val_mean_absolute_error: 0.1937 - val_mean_absolute_percentage_error: 14954910.0000 - val_root_mean_squared_error: 0.2383

# %%
y_pred = model_lstm_19.predict(x_test)

evaluation_lstm_19 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_19
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# {'Mean Squared Error: ': np.float64(401.08763956785367),
#  'Mean Absolute Error: ': np.float64(16.457443937963372),
#  'Root Mean Absolute Error: ': 20.02717253053595,
#  'Mean Absolute Percentage Error: ': np.float64(27.461652576503997)}

# %%
loss, mae, mape, rmse = model_lstm_19.evaluate(x_test, y_test)
print("model lstm 19")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0320 - mean_absolute_error: 0.1469 - mean_absolute_percentage_error: 34.1232 - root_mean_squared_error: 0.1788
# model lstm 19
# Mean Square Error: 0.03197445720434189
# Mean Absolute Error: 0.14694145321846008
# Mean Absolute Percentage Error: 34.12320327758789
# Root Mean Squared Error: 0.17881402373313904

# %% [markdown]
# ## model 20 (LSTM=128 200)

# %%
lr = 0.0003

model_lstm_20 = Sequential()
model_lstm_20.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_20.add(LSTM(128, activation='relu', return_sequences=True))
model_lstm_20.add(LSTM(200, activation='relu'))
model_lstm_20.add(Flatten())
model_lstm_20.add(Dense(7))
model_lstm_20.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_20.summary()
# Out:
# Model: "sequential_39"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_35 (LSTM)                  │ (None, 7, 128)         │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_36 (LSTM)                  │ (None, 200)            │       263,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_39 (Flatten)            │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 7)              │         1,407 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 333,727 (1.27 MB)
#  Trainable params: 333,727 (1.27 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_20.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - loss: 0.2799 - mean_absolute_error: 0.4912 - mean_absolute_percentage_error: 87.8308 - root_mean_squared_error: 0.5274 - val_loss: 0.0776 - val_mean_absolute_error: 0.2209 - val_mean_absolute_percentage_error: 18553908.0000 - val_root_mean_squared_error: 0.2785
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0435 - mean_absolute_error: 0.1633 - mean_absolute_percentage_error: 39.3433 - root_mean_squared_error: 0.2074 - val_loss: 0.0541 - val_mean_absolute_error: 0.1923 - val_mean_absolute_percentage_error: 15039214.0000 - val_root_mean_squared_error: 0.2325
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0252 - mean_absolute_error: 0.1239 - mean_absolute_percentage_error: 31.6077 - root_mean_squared_error: 0.1587 - val_loss: 0.0537 - val_mean_absolute_error: 0.1917 - val_mean_absolute_percentage_error: 14362261.0000 - val_root_mean_squared_error: 0.2318
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0225 - mean_absolute_error: 0.1180 - mean_absolute_percentage_error: 31.2283 - root_mean_squared_error: 0.1499 - val_loss: 0.0507 - val_mean_absolute_error: 0.1866 - val_mean_absolute_percentage_error: 15026839.0000 - val_root_mean_squared_error: 0.2251
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0207 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 29.3593 - root_mean_squared_error: 0.1439 - val_loss: 0.0515 - val_mean_absolute_error: 0.1893 - val_mean_absolute_percentage_error: 14669746.0000 - val_root_mean_squared_error: 0.2270
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0218 - mean_absolute_error: 0.1160 - mean_absolute_percentage_error: 30.2747 - root_mean_squared_error: 0.1478 - val_loss: 0.0502 - val_mean_absolute_error: 0.1879 - val_mean_absolute_percentage_error: 15202767.0000 - val_root_mean_squared_error: 0.2241
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0210 - mean_absolute_error: 0.1128 - mean_absolute_percentage_error: 30.3809 - root_mean_squared_error: 0.1447 - val_loss: 0.0516 - val_mean_absolute_error: 0.1919 - val_mean_absolute_percentage_error: 14678740.0000 - val_root_mean_squared_error: 0.2270
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0218 - mean_absolute_error: 0.1144 - mean_absolute_percentage_error: 30.8645 - root_mean_squared_error: 0.1474 - val_loss: 0.0511 - val_mean_absolute_error: 0.1900 - val_mean_absolute_percentage_error: 15054950.0000 - val_root_mean_squared_error: 0.2261
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0206 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 28.9689 - root_mean_squared_error: 0.1435 - val_loss: 0.0529 - val_mean_absolute_error: 0.1953 - val_mean_absolute_percentage_error: 14200459.0000 - val_root_mean_squared_error: 0.2299
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0202 - mean_absolute_error: 0.1106 - mean_absolute_percentage_error: 30.3740 - root_mean_squared_error: 0.1423 - val_loss: 0.0529 - val_mean_absolute_error: 0.1965 - val_mean_absolute_percentage_error: 14386284.0000 - val_root_mean_squared_error: 0.2300
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0206 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 28.1937 - root_mean_squared_error: 0.1434 - val_loss: 0.0551 - val_mean_absolute_error: 0.2026 - val_mean_absolute_percentage_error: 13541094.0000 - val_root_mean_squared_error: 0.2348
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0200 - mean_absolute_error: 0.1108 - mean_absolute_percentage_error: 26.6081 - root_mean_squared_error: 0.1414 - val_loss: 0.0542 - val_mean_absolute_error: 0.1998 - val_mean_absolute_percentage_error: 14046260.0000 - val_root_mean_squared_error: 0.2328
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0201 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 29.3075 - root_mean_squared_error: 0.1417 - val_loss: 0.0545 - val_mean_absolute_error: 0.1993 - val_mean_absolute_percentage_error: 13974700.0000 - val_root_mean_squared_error: 0.2335
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0194 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 28.5379 - root_mean_squared_error: 0.1393 - val_loss: 0.0548 - val_mean_absolute_error: 0.2010 - val_mean_absolute_percentage_error: 14196759.0000 - val_root_mean_squared_error: 0.2341
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0206 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 29.4323 - root_mean_squared_error: 0.1436 - val_loss: 0.0580 - val_mean_absolute_error: 0.2075 - val_mean_absolute_percentage_error: 12999998.0000 - val_root_mean_squared_error: 0.2409
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0204 - mean_absolute_error: 0.1117 - mean_absolute_percentage_error: 28.2504 - root_mean_squared_error: 0.1427 - val_loss: 0.0541 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 14341568.0000 - val_root_mean_squared_error: 0.2327
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0200 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 29.1191 - root_mean_squared_error: 0.1413 - val_loss: 0.0565 - val_mean_absolute_error: 0.2058 - val_mean_absolute_percentage_error: 13223324.0000 - val_root_mean_squared_error: 0.2377
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0199 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 28.3429 - root_mean_squared_error: 0.1412 - val_loss: 0.0574 - val_mean_absolute_error: 0.2053 - val_mean_absolute_percentage_error: 13921834.0000 - val_root_mean_squared_error: 0.2396
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0182 - mean_absolute_error: 0.1044 - mean_absolute_percentage_error: 26.3339 - root_mean_squared_error: 0.1349 - val_loss: 0.0555 - val_mean_absolute_error: 0.2025 - val_mean_absolute_percentage_error: 13715966.0000 - val_root_mean_squared_error: 0.2356
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0180 - mean_absolute_error: 0.1050 - mean_absolute_percentage_error: 25.6529 - root_mean_squared_error: 0.1341 - val_loss: 0.0583 - val_mean_absolute_error: 0.2065 - val_mean_absolute_percentage_error: 13957458.0000 - val_root_mean_squared_error: 0.2416

# %%
y_pred = model_lstm_20.predict(x_test)

evaluation_lstm_20 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_20
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# {'Mean Squared Error: ': np.float64(505.48421103464335),
#  'Mean Absolute Error: ': np.float64(16.546811006507095),
#  'Root Mean Absolute Error: ': 22.48297602708866,
#  'Mean Absolute Percentage Error: ': np.float64(32.24402781983183)}

# %%
loss, mae, mape, rmse = model_lstm_20.evaluate(x_test, y_test)
print("model lstm 20")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0403 - mean_absolute_error: 0.1477 - mean_absolute_percentage_error: 41.2078 - root_mean_squared_error: 0.2007
# model lstm 20
# Mean Square Error: 0.04029688611626625
# Mean Absolute Error: 0.14773938059806824
# Mean Absolute Percentage Error: 41.207828521728516
# Root Mean Squared Error: 0.20074084401130676

# %% [markdown]
# ## model 21 (LSTM=128 256)

# %%
lr = 0.0003

model_lstm_21 = Sequential()
model_lstm_21.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_21.add(LSTM(128, activation='relu', return_sequences=True))
model_lstm_21.add(LSTM(256, activation='relu'))
model_lstm_21.add(Flatten())
model_lstm_21.add(Dense(7))
model_lstm_21.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_21.summary()
# Out:
# Model: "sequential_40"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_37 (LSTM)                  │ (None, 7, 128)         │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_38 (LSTM)                  │ (None, 256)            │       394,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_40 (Flatten)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_40 (Dense)                │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 465,159 (1.77 MB)
#  Trainable params: 465,159 (1.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_21.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 0.2673 - mean_absolute_error: 0.4780 - mean_absolute_percentage_error: 85.4492 - root_mean_squared_error: 0.5147 - val_loss: 0.0749 - val_mean_absolute_error: 0.2147 - val_mean_absolute_percentage_error: 19452040.0000 - val_root_mean_squared_error: 0.2736
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0386 - mean_absolute_error: 0.1569 - mean_absolute_percentage_error: 35.2619 - root_mean_squared_error: 0.1958 - val_loss: 0.0529 - val_mean_absolute_error: 0.1891 - val_mean_absolute_percentage_error: 16721612.0000 - val_root_mean_squared_error: 0.2299
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0236 - mean_absolute_error: 0.1205 - mean_absolute_percentage_error: 31.6352 - root_mean_squared_error: 0.1538 - val_loss: 0.0521 - val_mean_absolute_error: 0.1889 - val_mean_absolute_percentage_error: 15193671.0000 - val_root_mean_squared_error: 0.2283
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0225 - mean_absolute_error: 0.1172 - mean_absolute_percentage_error: 29.3523 - root_mean_squared_error: 0.1499 - val_loss: 0.0526 - val_mean_absolute_error: 0.1879 - val_mean_absolute_percentage_error: 15084858.0000 - val_root_mean_squared_error: 0.2293
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0205 - mean_absolute_error: 0.1120 - mean_absolute_percentage_error: 28.9719 - root_mean_squared_error: 0.1431 - val_loss: 0.0524 - val_mean_absolute_error: 0.1883 - val_mean_absolute_percentage_error: 15153777.0000 - val_root_mean_squared_error: 0.2288
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0215 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 28.7241 - root_mean_squared_error: 0.1465 - val_loss: 0.0513 - val_mean_absolute_error: 0.1873 - val_mean_absolute_percentage_error: 15448284.0000 - val_root_mean_squared_error: 0.2266
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0208 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 29.2873 - root_mean_squared_error: 0.1441 - val_loss: 0.0509 - val_mean_absolute_error: 0.1874 - val_mean_absolute_percentage_error: 15666311.0000 - val_root_mean_squared_error: 0.2257
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0205 - mean_absolute_error: 0.1113 - mean_absolute_percentage_error: 27.9319 - root_mean_squared_error: 0.1432 - val_loss: 0.0513 - val_mean_absolute_error: 0.1889 - val_mean_absolute_percentage_error: 15516122.0000 - val_root_mean_squared_error: 0.2265
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0217 - mean_absolute_error: 0.1141 - mean_absolute_percentage_error: 30.2389 - root_mean_squared_error: 0.1471 - val_loss: 0.0526 - val_mean_absolute_error: 0.1930 - val_mean_absolute_percentage_error: 14570508.0000 - val_root_mean_squared_error: 0.2294
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0218 - mean_absolute_error: 0.1158 - mean_absolute_percentage_error: 29.4180 - root_mean_squared_error: 0.1475 - val_loss: 0.0533 - val_mean_absolute_error: 0.1951 - val_mean_absolute_percentage_error: 14387983.0000 - val_root_mean_squared_error: 0.2309
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0202 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 27.6295 - root_mean_squared_error: 0.1422 - val_loss: 0.0543 - val_mean_absolute_error: 0.1978 - val_mean_absolute_percentage_error: 14171242.0000 - val_root_mean_squared_error: 0.2330
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0195 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 27.9032 - root_mean_squared_error: 0.1398 - val_loss: 0.0556 - val_mean_absolute_error: 0.1976 - val_mean_absolute_percentage_error: 14123462.0000 - val_root_mean_squared_error: 0.2358
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 0.0206 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 28.9135 - root_mean_squared_error: 0.1437 - val_loss: 0.0565 - val_mean_absolute_error: 0.2030 - val_mean_absolute_percentage_error: 13631158.0000 - val_root_mean_squared_error: 0.2377
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0205 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 28.4027 - root_mean_squared_error: 0.1430 - val_loss: 0.0543 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 14333606.0000 - val_root_mean_squared_error: 0.2330
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0197 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 28.0829 - root_mean_squared_error: 0.1403 - val_loss: 0.0555 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 14237522.0000 - val_root_mean_squared_error: 0.2355
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0183 - mean_absolute_error: 0.1046 - mean_absolute_percentage_error: 26.0142 - root_mean_squared_error: 0.1352 - val_loss: 0.0549 - val_mean_absolute_error: 0.2006 - val_mean_absolute_percentage_error: 14393689.0000 - val_root_mean_squared_error: 0.2343
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0175 - mean_absolute_error: 0.1028 - mean_absolute_percentage_error: 25.4961 - root_mean_squared_error: 0.1322 - val_loss: 0.0560 - val_mean_absolute_error: 0.2029 - val_mean_absolute_percentage_error: 13851765.0000 - val_root_mean_squared_error: 0.2367
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0191 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 28.1469 - root_mean_squared_error: 0.1382 - val_loss: 0.0556 - val_mean_absolute_error: 0.2037 - val_mean_absolute_percentage_error: 13900431.0000 - val_root_mean_squared_error: 0.2359
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0183 - mean_absolute_error: 0.1045 - mean_absolute_percentage_error: 25.7294 - root_mean_squared_error: 0.1351 - val_loss: 0.0556 - val_mean_absolute_error: 0.2007 - val_mean_absolute_percentage_error: 14753355.0000 - val_root_mean_squared_error: 0.2357
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0188 - mean_absolute_error: 0.1064 - mean_absolute_percentage_error: 26.6268 - root_mean_squared_error: 0.1372 - val_loss: 0.0597 - val_mean_absolute_error: 0.2111 - val_mean_absolute_percentage_error: 12913415.0000 - val_root_mean_squared_error: 0.2443

# %%
y_pred = model_lstm_21.predict(x_test)

evaluation_lstm_21 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_21
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# {'Mean Squared Error: ': np.float64(295.41889165762313),
#  'Mean Absolute Error: ': np.float64(13.529825093794841),
#  'Root Mean Absolute Error: ': 17.187754119070448,
#  'Mean Absolute Percentage Error: ': np.float64(24.716833615875313)}

# %%
loss, mae, mape, rmse = model_lstm_21.evaluate(x_test, y_test)
print("model lstm 21")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0236 - mean_absolute_error: 0.1208 - mean_absolute_percentage_error: 31.3613 - root_mean_squared_error: 0.1535
# model lstm 21
# Mean Square Error: 0.02355061285197735
# Mean Absolute Error: 0.12080200761556625
# Mean Absolute Percentage Error: 31.361284255981445
# Root Mean Squared Error: 0.15346208214759827

# %% [markdown]
# ## model 22 (LSTM=128 512)

# %%
lr = 0.0003

model_lstm_22 = Sequential()
model_lstm_22.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_22.add(LSTM(128, activation='relu', return_sequences=True))
model_lstm_22.add(LSTM(512, activation='relu'))
model_lstm_22.add(Flatten())
model_lstm_22.add(Dense(7))
model_lstm_22.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_22.summary()
# Out:
# Model: "sequential_41"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_39 (LSTM)                  │ (None, 7, 128)         │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_40 (LSTM)                  │ (None, 512)            │     1,312,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_41 (Flatten)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,385,479 (5.29 MB)
#  Trainable params: 1,385,479 (5.29 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_22.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - loss: 0.2326 - mean_absolute_error: 0.4304 - mean_absolute_percentage_error: 78.4560 - root_mean_squared_error: 0.4770 - val_loss: 0.0736 - val_mean_absolute_error: 0.2304 - val_mean_absolute_percentage_error: 12236343.0000 - val_root_mean_squared_error: 0.2713
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0361 - mean_absolute_error: 0.1569 - mean_absolute_percentage_error: 33.5979 - root_mean_squared_error: 0.1897 - val_loss: 0.0516 - val_mean_absolute_error: 0.1836 - val_mean_absolute_percentage_error: 15497199.0000 - val_root_mean_squared_error: 0.2272
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0233 - mean_absolute_error: 0.1218 - mean_absolute_percentage_error: 32.5490 - root_mean_squared_error: 0.1526 - val_loss: 0.0506 - val_mean_absolute_error: 0.1835 - val_mean_absolute_percentage_error: 15956980.0000 - val_root_mean_squared_error: 0.2250
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0212 - mean_absolute_error: 0.1150 - mean_absolute_percentage_error: 29.7272 - root_mean_squared_error: 0.1457 - val_loss: 0.0508 - val_mean_absolute_error: 0.1847 - val_mean_absolute_percentage_error: 15817441.0000 - val_root_mean_squared_error: 0.2255
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0212 - mean_absolute_error: 0.1145 - mean_absolute_percentage_error: 29.0597 - root_mean_squared_error: 0.1456 - val_loss: 0.0512 - val_mean_absolute_error: 0.1878 - val_mean_absolute_percentage_error: 15731158.0000 - val_root_mean_squared_error: 0.2264
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.0204 - mean_absolute_error: 0.1106 - mean_absolute_percentage_error: 28.4519 - root_mean_squared_error: 0.1427 - val_loss: 0.0528 - val_mean_absolute_error: 0.1897 - val_mean_absolute_percentage_error: 15380756.0000 - val_root_mean_squared_error: 0.2299
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0205 - mean_absolute_error: 0.1118 - mean_absolute_percentage_error: 30.2736 - root_mean_squared_error: 0.1431 - val_loss: 0.0553 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 14567021.0000 - val_root_mean_squared_error: 0.2352
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0210 - mean_absolute_error: 0.1131 - mean_absolute_percentage_error: 28.4190 - root_mean_squared_error: 0.1447 - val_loss: 0.0574 - val_mean_absolute_error: 0.2022 - val_mean_absolute_percentage_error: 13947176.0000 - val_root_mean_squared_error: 0.2396
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0204 - mean_absolute_error: 0.1120 - mean_absolute_percentage_error: 28.4478 - root_mean_squared_error: 0.1429 - val_loss: 0.0554 - val_mean_absolute_error: 0.1962 - val_mean_absolute_percentage_error: 14812066.0000 - val_root_mean_squared_error: 0.2353
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0194 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 27.4930 - root_mean_squared_error: 0.1393 - val_loss: 0.0595 - val_mean_absolute_error: 0.2060 - val_mean_absolute_percentage_error: 13740967.0000 - val_root_mean_squared_error: 0.2439
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 0.0202 - mean_absolute_error: 0.1113 - mean_absolute_percentage_error: 27.8840 - root_mean_squared_error: 0.1421 - val_loss: 0.0545 - val_mean_absolute_error: 0.1975 - val_mean_absolute_percentage_error: 15422765.0000 - val_root_mean_squared_error: 0.2334
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - loss: 0.0195 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 27.6749 - root_mean_squared_error: 0.1398 - val_loss: 0.0566 - val_mean_absolute_error: 0.2035 - val_mean_absolute_percentage_error: 14398839.0000 - val_root_mean_squared_error: 0.2379
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0194 - mean_absolute_error: 0.1086 - mean_absolute_percentage_error: 27.6248 - root_mean_squared_error: 0.1391 - val_loss: 0.0564 - val_mean_absolute_error: 0.2023 - val_mean_absolute_percentage_error: 14443636.0000 - val_root_mean_squared_error: 0.2376
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0177 - mean_absolute_error: 0.1037 - mean_absolute_percentage_error: 24.7980 - root_mean_squared_error: 0.1330 - val_loss: 0.0580 - val_mean_absolute_error: 0.2084 - val_mean_absolute_percentage_error: 14083585.0000 - val_root_mean_squared_error: 0.2407
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0190 - mean_absolute_error: 0.1073 - mean_absolute_percentage_error: 28.2173 - root_mean_squared_error: 0.1378 - val_loss: 0.0567 - val_mean_absolute_error: 0.2035 - val_mean_absolute_percentage_error: 14577606.0000 - val_root_mean_squared_error: 0.2382
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0180 - mean_absolute_error: 0.1044 - mean_absolute_percentage_error: 26.4494 - root_mean_squared_error: 0.1342 - val_loss: 0.0588 - val_mean_absolute_error: 0.2098 - val_mean_absolute_percentage_error: 13945132.0000 - val_root_mean_squared_error: 0.2424
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0182 - mean_absolute_error: 0.1050 - mean_absolute_percentage_error: 26.6562 - root_mean_squared_error: 0.1349 - val_loss: 0.0613 - val_mean_absolute_error: 0.2159 - val_mean_absolute_percentage_error: 13405713.0000 - val_root_mean_squared_error: 0.2475
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - loss: 0.0186 - mean_absolute_error: 0.1060 - mean_absolute_percentage_error: 27.6029 - root_mean_squared_error: 0.1362 - val_loss: 0.0597 - val_mean_absolute_error: 0.2123 - val_mean_absolute_percentage_error: 13973395.0000 - val_root_mean_squared_error: 0.2444
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 0.0183 - mean_absolute_error: 0.1053 - mean_absolute_percentage_error: 26.2358 - root_mean_squared_error: 0.1352 - val_loss: 0.0616 - val_mean_absolute_error: 0.2153 - val_mean_absolute_percentage_error: 14226858.0000 - val_root_mean_squared_error: 0.2481
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0172 - mean_absolute_error: 0.1020 - mean_absolute_percentage_error: 24.9447 - root_mean_squared_error: 0.1311 - val_loss: 0.0577 - val_mean_absolute_error: 0.2054 - val_mean_absolute_percentage_error: 15070389.0000 - val_root_mean_squared_error: 0.2401

# %%
y_pred = model_lstm_22.predict(x_test)

evaluation_lstm_22 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_22
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# {'Mean Squared Error: ': np.float64(371.5288416056039),
#  'Mean Absolute Error: ': np.float64(14.506794637563276),
#  'Root Mean Absolute Error: ': 19.275083439653482,
#  'Mean Absolute Percentage Error: ': np.float64(27.581209227944818)}

# %%
loss, mae, mape, rmse = model_lstm_22.evaluate(x_test, y_test)
print("model lstm 22")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0296 - mean_absolute_error: 0.1295 - mean_absolute_percentage_error: 35.1706 - root_mean_squared_error: 0.1721
# model lstm 22
# Mean Square Error: 0.029618050903081894
# Mean Absolute Error: 0.12952494621276855
# Mean Absolute Percentage Error: 35.17060089111328
# Root Mean Squared Error: 0.17209894955158234

# %% [markdown]
# ## model 23 (LSTM=500 250)

# %%
lr = 0.0003

model_lstm_23 = Sequential()
model_lstm_23.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_23.add(LSTM(500, activation='relu', return_sequences=True))
model_lstm_23.add(LSTM(250, activation='relu'))
model_lstm_23.add(Flatten())
model_lstm_23.add(Dense(7))
model_lstm_23.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_23.summary()
# Out:
# Model: "sequential_42"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_41 (LSTM)                  │ (None, 7, 500)         │     1,014,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_42 (LSTM)                  │ (None, 250)            │       751,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_42 (Flatten)            │ (None, 250)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 7)              │         1,757 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,766,757 (6.74 MB)
#  Trainable params: 1,766,757 (6.74 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_23.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - loss: 0.2081 - mean_absolute_error: 0.3981 - mean_absolute_percentage_error: 72.8778 - root_mean_squared_error: 0.4491 - val_loss: 0.0800 - val_mean_absolute_error: 0.2425 - val_mean_absolute_percentage_error: 11103959.0000 - val_root_mean_squared_error: 0.2829
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - loss: 0.0351 - mean_absolute_error: 0.1524 - mean_absolute_percentage_error: 33.5648 - root_mean_squared_error: 0.1868 - val_loss: 0.0589 - val_mean_absolute_error: 0.2013 - val_mean_absolute_percentage_error: 13586617.0000 - val_root_mean_squared_error: 0.2427
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0236 - mean_absolute_error: 0.1222 - mean_absolute_percentage_error: 29.8501 - root_mean_squared_error: 0.1536 - val_loss: 0.0535 - val_mean_absolute_error: 0.1909 - val_mean_absolute_percentage_error: 14704398.0000 - val_root_mean_squared_error: 0.2312
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0213 - mean_absolute_error: 0.1143 - mean_absolute_percentage_error: 30.6081 - root_mean_squared_error: 0.1459 - val_loss: 0.0523 - val_mean_absolute_error: 0.1883 - val_mean_absolute_percentage_error: 15134703.0000 - val_root_mean_squared_error: 0.2288
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0201 - mean_absolute_error: 0.1106 - mean_absolute_percentage_error: 27.0920 - root_mean_squared_error: 0.1417 - val_loss: 0.0532 - val_mean_absolute_error: 0.1897 - val_mean_absolute_percentage_error: 14988746.0000 - val_root_mean_squared_error: 0.2306
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0218 - mean_absolute_error: 0.1155 - mean_absolute_percentage_error: 30.6013 - root_mean_squared_error: 0.1478 - val_loss: 0.0532 - val_mean_absolute_error: 0.1917 - val_mean_absolute_percentage_error: 15003234.0000 - val_root_mean_squared_error: 0.2307
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0212 - mean_absolute_error: 0.1144 - mean_absolute_percentage_error: 29.3264 - root_mean_squared_error: 0.1457 - val_loss: 0.0536 - val_mean_absolute_error: 0.1924 - val_mean_absolute_percentage_error: 15119869.0000 - val_root_mean_squared_error: 0.2315
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - loss: 0.0199 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 27.0882 - root_mean_squared_error: 0.1411 - val_loss: 0.0550 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 14392489.0000 - val_root_mean_squared_error: 0.2344
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 0.0204 - mean_absolute_error: 0.1115 - mean_absolute_percentage_error: 29.4328 - root_mean_squared_error: 0.1429 - val_loss: 0.0542 - val_mean_absolute_error: 0.1950 - val_mean_absolute_percentage_error: 14940313.0000 - val_root_mean_squared_error: 0.2329
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0198 - mean_absolute_error: 0.1092 - mean_absolute_percentage_error: 28.5736 - root_mean_squared_error: 0.1407 - val_loss: 0.0593 - val_mean_absolute_error: 0.1998 - val_mean_absolute_percentage_error: 14341804.0000 - val_root_mean_squared_error: 0.2436
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0206 - mean_absolute_error: 0.1119 - mean_absolute_percentage_error: 28.4700 - root_mean_squared_error: 0.1434 - val_loss: 0.0549 - val_mean_absolute_error: 0.1966 - val_mean_absolute_percentage_error: 14842726.0000 - val_root_mean_squared_error: 0.2343
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0194 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 27.0822 - root_mean_squared_error: 0.1392 - val_loss: 0.0555 - val_mean_absolute_error: 0.2013 - val_mean_absolute_percentage_error: 14364026.0000 - val_root_mean_squared_error: 0.2356
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0188 - mean_absolute_error: 0.1069 - mean_absolute_percentage_error: 25.9841 - root_mean_squared_error: 0.1372 - val_loss: 0.0544 - val_mean_absolute_error: 0.1972 - val_mean_absolute_percentage_error: 15137434.0000 - val_root_mean_squared_error: 0.2333
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - loss: 0.0194 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 27.5302 - root_mean_squared_error: 0.1392 - val_loss: 0.0570 - val_mean_absolute_error: 0.1989 - val_mean_absolute_percentage_error: 14721732.0000 - val_root_mean_squared_error: 0.2388
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0195 - mean_absolute_error: 0.1085 - mean_absolute_percentage_error: 27.4976 - root_mean_squared_error: 0.1395 - val_loss: 0.0531 - val_mean_absolute_error: 0.1923 - val_mean_absolute_percentage_error: 15879983.0000 - val_root_mean_squared_error: 0.2305
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0193 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 28.7917 - root_mean_squared_error: 0.1389 - val_loss: 0.0557 - val_mean_absolute_error: 0.2005 - val_mean_absolute_percentage_error: 14567270.0000 - val_root_mean_squared_error: 0.2360
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0180 - mean_absolute_error: 0.1043 - mean_absolute_percentage_error: 26.2601 - root_mean_squared_error: 0.1342 - val_loss: 0.0625 - val_mean_absolute_error: 0.2145 - val_mean_absolute_percentage_error: 13323528.0000 - val_root_mean_squared_error: 0.2500
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0192 - mean_absolute_error: 0.1079 - mean_absolute_percentage_error: 26.4081 - root_mean_squared_error: 0.1384 - val_loss: 0.0588 - val_mean_absolute_error: 0.2079 - val_mean_absolute_percentage_error: 14113823.0000 - val_root_mean_squared_error: 0.2425
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 0.0184 - mean_absolute_error: 0.1056 - mean_absolute_percentage_error: 26.6032 - root_mean_squared_error: 0.1355 - val_loss: 0.0565 - val_mean_absolute_error: 0.2021 - val_mean_absolute_percentage_error: 15248675.0000 - val_root_mean_squared_error: 0.2377
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - loss: 0.0179 - mean_absolute_error: 0.1042 - mean_absolute_percentage_error: 27.8336 - root_mean_squared_error: 0.1340 - val_loss: 0.0583 - val_mean_absolute_error: 0.2054 - val_mean_absolute_percentage_error: 15155612.0000 - val_root_mean_squared_error: 0.2415

# %%
y_pred = model_lstm_23.predict(x_test)

evaluation_lstm_23 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_23
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# {'Mean Squared Error: ': np.float64(419.47515755431897),
#  'Mean Absolute Error: ': np.float64(15.502510946624133),
#  'Root Mean Absolute Error: ': 20.481092684579085,
#  'Mean Absolute Percentage Error: ': np.float64(29.37209014553771)}

# %%
loss, mae, mape, rmse = model_lstm_23.evaluate(x_test, y_test)
print("model lstm 23")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0334 - mean_absolute_error: 0.1384 - mean_absolute_percentage_error: 37.4073 - root_mean_squared_error: 0.1829
# model lstm 23
# Mean Square Error: 0.033440299332141876
# Mean Absolute Error: 0.13841526210308075
# Mean Absolute Percentage Error: 37.40731430053711
# Root Mean Squared Error: 0.1828668862581253

# %% [markdown]
# ## model 24 (LSTM=512 256)

# %%
lr = 0.0003

model_lstm_24 = Sequential()
model_lstm_24.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_24.add(LSTM(512, activation='relu', return_sequences=True))
model_lstm_24.add(LSTM(256, activation='relu'))
model_lstm_24.add(Flatten())
model_lstm_24.add(Dense(7))
model_lstm_24.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_24.summary()
# Out:
# Model: "sequential_43"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_43 (LSTM)                  │ (None, 7, 512)         │     1,062,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_44 (LSTM)                  │ (None, 256)            │       787,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_43 (Flatten)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,852,167 (7.07 MB)
#  Trainable params: 1,852,167 (7.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_24.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 181ms/step - loss: 0.1976 - mean_absolute_error: 0.3872 - mean_absolute_percentage_error: 70.4908 - root_mean_squared_error: 0.4377 - val_loss: 0.0745 - val_mean_absolute_error: 0.2303 - val_mean_absolute_percentage_error: 11899053.0000 - val_root_mean_squared_error: 0.2729
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 0.0326 - mean_absolute_error: 0.1451 - mean_absolute_percentage_error: 31.6840 - root_mean_squared_error: 0.1803 - val_loss: 0.0576 - val_mean_absolute_error: 0.2007 - val_mean_absolute_percentage_error: 14319693.0000 - val_root_mean_squared_error: 0.2401
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0240 - mean_absolute_error: 0.1226 - mean_absolute_percentage_error: 29.8976 - root_mean_squared_error: 0.1548 - val_loss: 0.0534 - val_mean_absolute_error: 0.1884 - val_mean_absolute_percentage_error: 14981454.0000 - val_root_mean_squared_error: 0.2310
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - loss: 0.0225 - mean_absolute_error: 0.1177 - mean_absolute_percentage_error: 30.3558 - root_mean_squared_error: 0.1498 - val_loss: 0.0512 - val_mean_absolute_error: 0.1861 - val_mean_absolute_percentage_error: 15758991.0000 - val_root_mean_squared_error: 0.2263
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.0212 - mean_absolute_error: 0.1130 - mean_absolute_percentage_error: 29.8263 - root_mean_squared_error: 0.1455 - val_loss: 0.0526 - val_mean_absolute_error: 0.1888 - val_mean_absolute_percentage_error: 15182750.0000 - val_root_mean_squared_error: 0.2293
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.0203 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 28.3396 - root_mean_squared_error: 0.1423 - val_loss: 0.0526 - val_mean_absolute_error: 0.1907 - val_mean_absolute_percentage_error: 15139645.0000 - val_root_mean_squared_error: 0.2293
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - loss: 0.0211 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 28.5345 - root_mean_squared_error: 0.1452 - val_loss: 0.0548 - val_mean_absolute_error: 0.1936 - val_mean_absolute_percentage_error: 14532905.0000 - val_root_mean_squared_error: 0.2341
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - loss: 0.0206 - mean_absolute_error: 0.1117 - mean_absolute_percentage_error: 28.2282 - root_mean_squared_error: 0.1437 - val_loss: 0.0525 - val_mean_absolute_error: 0.1902 - val_mean_absolute_percentage_error: 15379058.0000 - val_root_mean_squared_error: 0.2291
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - loss: 0.0198 - mean_absolute_error: 0.1094 - mean_absolute_percentage_error: 27.8329 - root_mean_squared_error: 0.1407 - val_loss: 0.0555 - val_mean_absolute_error: 0.1956 - val_mean_absolute_percentage_error: 14273248.0000 - val_root_mean_squared_error: 0.2356
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - loss: 0.0196 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 27.2023 - root_mean_squared_error: 0.1400 - val_loss: 0.0534 - val_mean_absolute_error: 0.1930 - val_mean_absolute_percentage_error: 15018703.0000 - val_root_mean_squared_error: 0.2311
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - loss: 0.0192 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 27.0286 - root_mean_squared_error: 0.1384 - val_loss: 0.0588 - val_mean_absolute_error: 0.2012 - val_mean_absolute_percentage_error: 13502814.0000 - val_root_mean_squared_error: 0.2425
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - loss: 0.0207 - mean_absolute_error: 0.1124 - mean_absolute_percentage_error: 28.1363 - root_mean_squared_error: 0.1437 - val_loss: 0.0537 - val_mean_absolute_error: 0.1951 - val_mean_absolute_percentage_error: 14828860.0000 - val_root_mean_squared_error: 0.2318
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - loss: 0.0194 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 28.2147 - root_mean_squared_error: 0.1394 - val_loss: 0.0534 - val_mean_absolute_error: 0.1950 - val_mean_absolute_percentage_error: 14866398.0000 - val_root_mean_squared_error: 0.2311
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - loss: 0.0204 - mean_absolute_error: 0.1106 - mean_absolute_percentage_error: 29.0205 - root_mean_squared_error: 0.1428 - val_loss: 0.0561 - val_mean_absolute_error: 0.1965 - val_mean_absolute_percentage_error: 14144014.0000 - val_root_mean_squared_error: 0.2368
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 0.0193 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 27.3716 - root_mean_squared_error: 0.1388 - val_loss: 0.0568 - val_mean_absolute_error: 0.1969 - val_mean_absolute_percentage_error: 14230167.0000 - val_root_mean_squared_error: 0.2382
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - loss: 0.0205 - mean_absolute_error: 0.1126 - mean_absolute_percentage_error: 30.4661 - root_mean_squared_error: 0.1431 - val_loss: 0.0541 - val_mean_absolute_error: 0.1957 - val_mean_absolute_percentage_error: 14505110.0000 - val_root_mean_squared_error: 0.2326
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - loss: 0.0178 - mean_absolute_error: 0.1031 - mean_absolute_percentage_error: 25.7987 - root_mean_squared_error: 0.1332 - val_loss: 0.0564 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 14124062.0000 - val_root_mean_squared_error: 0.2375
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - loss: 0.0177 - mean_absolute_error: 0.1048 - mean_absolute_percentage_error: 25.6468 - root_mean_squared_error: 0.1332 - val_loss: 0.0561 - val_mean_absolute_error: 0.1957 - val_mean_absolute_percentage_error: 14450570.0000 - val_root_mean_squared_error: 0.2370
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - loss: 0.0179 - mean_absolute_error: 0.1054 - mean_absolute_percentage_error: 25.8966 - root_mean_squared_error: 0.1336 - val_loss: 0.0583 - val_mean_absolute_error: 0.2032 - val_mean_absolute_percentage_error: 13512235.0000 - val_root_mean_squared_error: 0.2416
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0182 - mean_absolute_error: 0.1059 - mean_absolute_percentage_error: 26.6772 - root_mean_squared_error: 0.1351 - val_loss: 0.0561 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 14178243.0000 - val_root_mean_squared_error: 0.2369

# %%
y_pred = model_lstm_24.predict(x_test)

evaluation_lstm_24 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_24
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# {'Mean Squared Error: ': np.float64(298.2663526506554),
#  'Mean Absolute Error: ': np.float64(13.852951497447734),
#  'Root Mean Absolute Error: ': 17.270389475939893,
#  'Mean Absolute Percentage Error: ': np.float64(24.072552732877288)}

# %%
loss, mae, mape, rmse = model_lstm_24.evaluate(x_test, y_test)
print("model lstm 24")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0238 - mean_absolute_error: 0.1237 - mean_absolute_percentage_error: 30.2591 - root_mean_squared_error: 0.1542
# model lstm 24
# Mean Square Error: 0.023777609691023827
# Mean Absolute Error: 0.12368706613779068
# Mean Absolute Percentage Error: 30.259063720703125
# Root Mean Squared Error: 0.15419989824295044

# %% [markdown]
# ## model 25 (LSTM=1024 512)

# %%
lr = 0.0003

model_lstm_25 = Sequential()
model_lstm_25.add(Input(shape=(x_train.shape[1], x_train.shape[2])))
model_lstm_25.add(LSTM(1024, activation='relu', return_sequences=True))
model_lstm_25.add(LSTM(512, activation='relu'))
model_lstm_25.add(Flatten())
model_lstm_25.add(Dense(7))
model_lstm_25.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_lstm_25.summary()
# Out:
# Model: "sequential_44"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_45 (LSTM)                  │ (None, 7, 1024)        │     4,222,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_46 (LSTM)                  │ (None, 512)            │     3,147,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_44 (Flatten)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,374,343 (28.13 MB)
#  Trainable params: 7,374,343 (28.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_lstm_25.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 720ms/step - loss: 0.1864 - mean_absolute_error: 0.3681 - mean_absolute_percentage_error: 67.2716 - root_mean_squared_error: 0.4229 - val_loss: 0.0592 - val_mean_absolute_error: 0.1969 - val_mean_absolute_percentage_error: 15989226.0000 - val_root_mean_squared_error: 0.2432
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 673ms/step - loss: 0.0281 - mean_absolute_error: 0.1306 - mean_absolute_percentage_error: 34.0955 - root_mean_squared_error: 0.1672 - val_loss: 0.0520 - val_mean_absolute_error: 0.1883 - val_mean_absolute_percentage_error: 15597169.0000 - val_root_mean_squared_error: 0.2280
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 20s 666ms/step - loss: 0.0227 - mean_absolute_error: 0.1180 - mean_absolute_percentage_error: 30.4885 - root_mean_squared_error: 0.1506 - val_loss: 0.0523 - val_mean_absolute_error: 0.1878 - val_mean_absolute_percentage_error: 15163625.0000 - val_root_mean_squared_error: 0.2286
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 21s 668ms/step - loss: 0.0218 - mean_absolute_error: 0.1153 - mean_absolute_percentage_error: 29.1877 - root_mean_squared_error: 0.1477 - val_loss: 0.0516 - val_mean_absolute_error: 0.1872 - val_mean_absolute_percentage_error: 15482191.0000 - val_root_mean_squared_error: 0.2271
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 21s 679ms/step - loss: 0.0210 - mean_absolute_error: 0.1126 - mean_absolute_percentage_error: 30.3051 - root_mean_squared_error: 0.1449 - val_loss: 0.0527 - val_mean_absolute_error: 0.1884 - val_mean_absolute_percentage_error: 15225943.0000 - val_root_mean_squared_error: 0.2295
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 20s 644ms/step - loss: 0.0203 - mean_absolute_error: 0.1108 - mean_absolute_percentage_error: 27.0359 - root_mean_squared_error: 0.1425 - val_loss: 0.0526 - val_mean_absolute_error: 0.1899 - val_mean_absolute_percentage_error: 15212083.0000 - val_root_mean_squared_error: 0.2292
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 21s 674ms/step - loss: 0.0208 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 27.5482 - root_mean_squared_error: 0.1443 - val_loss: 0.0523 - val_mean_absolute_error: 0.1904 - val_mean_absolute_percentage_error: 15167603.0000 - val_root_mean_squared_error: 0.2287
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 20s 680ms/step - loss: 0.0203 - mean_absolute_error: 0.1113 - mean_absolute_percentage_error: 28.5558 - root_mean_squared_error: 0.1423 - val_loss: 0.0537 - val_mean_absolute_error: 0.1919 - val_mean_absolute_percentage_error: 14804893.0000 - val_root_mean_squared_error: 0.2318
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 685ms/step - loss: 0.0209 - mean_absolute_error: 0.1124 - mean_absolute_percentage_error: 29.3211 - root_mean_squared_error: 0.1445 - val_loss: 0.0527 - val_mean_absolute_error: 0.1928 - val_mean_absolute_percentage_error: 14731551.0000 - val_root_mean_squared_error: 0.2296
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 20s 629ms/step - loss: 0.0206 - mean_absolute_error: 0.1119 - mean_absolute_percentage_error: 29.2040 - root_mean_squared_error: 0.1435 - val_loss: 0.0542 - val_mean_absolute_error: 0.1917 - val_mean_absolute_percentage_error: 14653386.0000 - val_root_mean_squared_error: 0.2327
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 21s 671ms/step - loss: 0.0202 - mean_absolute_error: 0.1113 - mean_absolute_percentage_error: 27.5801 - root_mean_squared_error: 0.1420 - val_loss: 0.0524 - val_mean_absolute_error: 0.1912 - val_mean_absolute_percentage_error: 14898668.0000 - val_root_mean_squared_error: 0.2289
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 20s 672ms/step - loss: 0.0200 - mean_absolute_error: 0.1104 - mean_absolute_percentage_error: 28.8809 - root_mean_squared_error: 0.1413 - val_loss: 0.0529 - val_mean_absolute_error: 0.1941 - val_mean_absolute_percentage_error: 14655002.0000 - val_root_mean_squared_error: 0.2300
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 616ms/step - loss: 0.0183 - mean_absolute_error: 0.1048 - mean_absolute_percentage_error: 26.4482 - root_mean_squared_error: 0.1354 - val_loss: 0.0549 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 13976681.0000 - val_root_mean_squared_error: 0.2344
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 629ms/step - loss: 0.0191 - mean_absolute_error: 0.1074 - mean_absolute_percentage_error: 27.8268 - root_mean_squared_error: 0.1382 - val_loss: 0.0530 - val_mean_absolute_error: 0.1944 - val_mean_absolute_percentage_error: 14782119.0000 - val_root_mean_squared_error: 0.2303
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 21s 667ms/step - loss: 0.0185 - mean_absolute_error: 0.1059 - mean_absolute_percentage_error: 26.0469 - root_mean_squared_error: 0.1361 - val_loss: 0.0550 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 14655487.0000 - val_root_mean_squared_error: 0.2346
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 21s 671ms/step - loss: 0.0192 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 28.5114 - root_mean_squared_error: 0.1387 - val_loss: 0.0535 - val_mean_absolute_error: 0.1963 - val_mean_absolute_percentage_error: 14662771.0000 - val_root_mean_squared_error: 0.2313
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 628ms/step - loss: 0.0193 - mean_absolute_error: 0.1089 - mean_absolute_percentage_error: 27.3944 - root_mean_squared_error: 0.1389 - val_loss: 0.0599 - val_mean_absolute_error: 0.2064 - val_mean_absolute_percentage_error: 13387816.0000 - val_root_mean_squared_error: 0.2448
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 632ms/step - loss: 0.0185 - mean_absolute_error: 0.1063 - mean_absolute_percentage_error: 26.2779 - root_mean_squared_error: 0.1361 - val_loss: 0.0583 - val_mean_absolute_error: 0.2065 - val_mean_absolute_percentage_error: 13614674.0000 - val_root_mean_squared_error: 0.2415
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 675ms/step - loss: 0.0183 - mean_absolute_error: 0.1059 - mean_absolute_percentage_error: 26.6635 - root_mean_squared_error: 0.1353 - val_loss: 0.0603 - val_mean_absolute_error: 0.2080 - val_mean_absolute_percentage_error: 13394377.0000 - val_root_mean_squared_error: 0.2455
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 20s 656ms/step - loss: 0.0204 - mean_absolute_error: 0.1134 - mean_absolute_percentage_error: 28.8858 - root_mean_squared_error: 0.1428 - val_loss: 0.0597 - val_mean_absolute_error: 0.2082 - val_mean_absolute_percentage_error: 13132966.0000 - val_root_mean_squared_error: 0.2444

# %%
y_pred = model_lstm_25.predict(x_test)

evaluation_lstm_25 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_lstm_25
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# {'Mean Squared Error: ': np.float64(316.91277572113967),
#  'Mean Absolute Error: ': np.float64(14.169352570358587),
#  'Root Mean Absolute Error: ': 17.802044144455426,
#  'Mean Absolute Percentage Error: ': np.float64(25.577514425098176)}

# %%
loss, mae, mape, rmse = model_lstm_25.evaluate(x_test, y_test)
print("model lstm 25")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0253 - mean_absolute_error: 0.1265 - mean_absolute_percentage_error: 32.3677 - root_mean_squared_error: 0.1589
# model lstm 25
# Mean Square Error: 0.025264089927077293
# Mean Absolute Error: 0.1265120655298233
# Mean Absolute Percentage Error: 32.3676872253418
# Root Mean Squared Error: 0.15894681215286255

# %% [markdown]
# # LSTM Hyperparameter

# %% [markdown]
# ## Gridsearch

# %%
# from keras.callbacks import EarlyStopping
# from sklearn.model_selection import GridSearchCV
# from scikeras.wrappers import KerasRegressor
# from keras.optimizers import Adam

# # 1. Define your model builder function
# def build_model(units1=64, units2=32, lr=0.001):
#     model = Sequential()
#     model.add(Input(shape=(7, 11)))
#     model.add(LSTM(units=units1, activation='relu', return_sequences=True))
#     model.add(LSTM(units=units2, activation='relu'))
#     model.add(Flatten())
#     model.add(Dense(7))
#     optimizer = Adam(learning_rate=lr)
#     model.compile(loss='mse', optimizer=optimizer,
#                   metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
#     return model

# # 2. Set up KerasRegressor
# model = KerasRegressor(model=build_model, verbose=0)

# # 3. Define early stopping
# early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# # 4. Grid of parameters
# param_grid = {
#     'model__units1': [16, 32, 64],
#     'model__units2': [32, 64, 128],
#     'model__lr': [0.0003, 0.0002],
#     'batch_size': [42],
#     'epochs': [50]  # set high epochs so early stopping can interrupt early
# }

# # 5. GridSearchCV with early stopping passed via fit_params
# grid = GridSearchCV(estimator=model, param_grid=param_grid,
#                     scoring='neg_mean_squared_error',
#                     cv=3,
#                     refit=True)

# # 6. Fit with early stopping
# grid_result_cnn = grid.fit(x_train, y_train, callbacks=[early_stop], validation_data=(x_val, y_val))

# %%
# print("Best parameters found: ", grid_result_cnn.best_params_)
# print("Best MSE: ", -grid_result.best_score_)

# %%
# best_model = grid_result_cnn.best_estimator_
# loss, mae, mape, rmse = best_model.model_.evaluate(x_test, y_test)
# print("Test MSE:", loss)
# print("Test MAE:", mae)
# print("Test MAPE:", mape)
# print("Test RMSE:", rmse)

# %% [markdown]
# # Hybrid

# %% [markdown]
# # Model 2 layer CNN > LSTM

# %% [markdown]
# ## model 1 (CNN=64 LSTM=64)

# %%
lr = 0.0003

model_hybrid_1 = Sequential()
model_hybrid_1.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_1.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_1.add(Flatten())
model_hybrid_1.add(Dense(7))
model_hybrid_1.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_1.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_45"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_45 (Conv1D)              │ (None, 7, 64)          │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_47 (LSTM)                  │ (None, 7, 64)          │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_45 (Flatten)            │ (None, 448)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 7)              │         3,143 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 36,615 (143.03 KB)
#  Trainable params: 36,615 (143.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_1.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.2420 - mean_absolute_error: 0.4445 - mean_absolute_percentage_error: 78.2582 - root_mean_squared_error: 0.4882 - val_loss: 0.0590 - val_mean_absolute_error: 0.1942 - val_mean_absolute_percentage_error: 18847812.0000 - val_root_mean_squared_error: 0.2429
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0415 - mean_absolute_error: 0.1640 - mean_absolute_percentage_error: 43.1687 - root_mean_squared_error: 0.2034 - val_loss: 0.0652 - val_mean_absolute_error: 0.2141 - val_mean_absolute_percentage_error: 13230013.0000 - val_root_mean_squared_error: 0.2553
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0259 - mean_absolute_error: 0.1291 - mean_absolute_percentage_error: 30.4045 - root_mean_squared_error: 0.1610 - val_loss: 0.0508 - val_mean_absolute_error: 0.1857 - val_mean_absolute_percentage_error: 16036192.0000 - val_root_mean_squared_error: 0.2255
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0223 - mean_absolute_error: 0.1160 - mean_absolute_percentage_error: 28.2197 - root_mean_squared_error: 0.1495 - val_loss: 0.0518 - val_mean_absolute_error: 0.1872 - val_mean_absolute_percentage_error: 15493049.0000 - val_root_mean_squared_error: 0.2277
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0214 - mean_absolute_error: 0.1139 - mean_absolute_percentage_error: 28.5996 - root_mean_squared_error: 0.1461 - val_loss: 0.0530 - val_mean_absolute_error: 0.1897 - val_mean_absolute_percentage_error: 15085622.0000 - val_root_mean_squared_error: 0.2302
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0214 - mean_absolute_error: 0.1141 - mean_absolute_percentage_error: 27.8542 - root_mean_squared_error: 0.1462 - val_loss: 0.0534 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 14843473.0000 - val_root_mean_squared_error: 0.2311
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0224 - mean_absolute_error: 0.1176 - mean_absolute_percentage_error: 29.5454 - root_mean_squared_error: 0.1497 - val_loss: 0.0504 - val_mean_absolute_error: 0.1871 - val_mean_absolute_percentage_error: 15915379.0000 - val_root_mean_squared_error: 0.2246
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0225 - mean_absolute_error: 0.1159 - mean_absolute_percentage_error: 30.5273 - root_mean_squared_error: 0.1498 - val_loss: 0.0506 - val_mean_absolute_error: 0.1878 - val_mean_absolute_percentage_error: 15625602.0000 - val_root_mean_squared_error: 0.2250
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0221 - mean_absolute_error: 0.1156 - mean_absolute_percentage_error: 30.1727 - root_mean_squared_error: 0.1488 - val_loss: 0.0515 - val_mean_absolute_error: 0.1911 - val_mean_absolute_percentage_error: 15140929.0000 - val_root_mean_squared_error: 0.2269
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0205 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 27.8613 - root_mean_squared_error: 0.1431 - val_loss: 0.0535 - val_mean_absolute_error: 0.1947 - val_mean_absolute_percentage_error: 14471162.0000 - val_root_mean_squared_error: 0.2312
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0208 - mean_absolute_error: 0.1127 - mean_absolute_percentage_error: 28.2417 - root_mean_squared_error: 0.1442 - val_loss: 0.0538 - val_mean_absolute_error: 0.1951 - val_mean_absolute_percentage_error: 14416602.0000 - val_root_mean_squared_error: 0.2319
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0207 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 28.6426 - root_mean_squared_error: 0.1438 - val_loss: 0.0527 - val_mean_absolute_error: 0.1944 - val_mean_absolute_percentage_error: 14868385.0000 - val_root_mean_squared_error: 0.2295
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0198 - mean_absolute_error: 0.1095 - mean_absolute_percentage_error: 27.7700 - root_mean_squared_error: 0.1409 - val_loss: 0.0551 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 14110236.0000 - val_root_mean_squared_error: 0.2346
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0210 - mean_absolute_error: 0.1130 - mean_absolute_percentage_error: 29.6547 - root_mean_squared_error: 0.1449 - val_loss: 0.0533 - val_mean_absolute_error: 0.1964 - val_mean_absolute_percentage_error: 14810388.0000 - val_root_mean_squared_error: 0.2309
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0205 - mean_absolute_error: 0.1117 - mean_absolute_percentage_error: 29.4348 - root_mean_squared_error: 0.1433 - val_loss: 0.0536 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 14673311.0000 - val_root_mean_squared_error: 0.2316
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0195 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 28.2191 - root_mean_squared_error: 0.1397 - val_loss: 0.0535 - val_mean_absolute_error: 0.1962 - val_mean_absolute_percentage_error: 14908092.0000 - val_root_mean_squared_error: 0.2314
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0197 - mean_absolute_error: 0.1092 - mean_absolute_percentage_error: 27.4095 - root_mean_squared_error: 0.1402 - val_loss: 0.0548 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 14505622.0000 - val_root_mean_squared_error: 0.2341
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0191 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 28.3843 - root_mean_squared_error: 0.1382 - val_loss: 0.0582 - val_mean_absolute_error: 0.2042 - val_mean_absolute_percentage_error: 13593300.0000 - val_root_mean_squared_error: 0.2413
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0187 - mean_absolute_error: 0.1063 - mean_absolute_percentage_error: 26.8694 - root_mean_squared_error: 0.1368 - val_loss: 0.0561 - val_mean_absolute_error: 0.2015 - val_mean_absolute_percentage_error: 14240462.0000 - val_root_mean_squared_error: 0.2368
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0183 - mean_absolute_error: 0.1051 - mean_absolute_percentage_error: 26.2560 - root_mean_squared_error: 0.1353 - val_loss: 0.0545 - val_mean_absolute_error: 0.1994 - val_mean_absolute_percentage_error: 14631699.0000 - val_root_mean_squared_error: 0.2334

# %%
y_pred = model_hybrid_1.predict(x_test)

evaluation_hybrid_1 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_1
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# {'Mean Squared Error: ': np.float64(368.07719860158966),
#  'Mean Absolute Error: ': np.float64(14.585360215634719),
#  'Root Mean Absolute Error: ': 19.185338115383573,
#  'Mean Absolute Percentage Error: ': np.float64(27.464497393851005)}

# %%
loss, mae, mape, rmse = model_hybrid_1.evaluate(x_test, y_test)
print("model hybrid 1")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0293 - mean_absolute_error: 0.1302 - mean_absolute_percentage_error: 34.9834 - root_mean_squared_error: 0.1713
# model hybrid 1
# Mean Square Error: 0.029342887923121452
# Mean Absolute Error: 0.13022644817829132
# Mean Absolute Percentage Error: 34.98341751098633
# Root Mean Squared Error: 0.17129765450954437

# %% [markdown]
# ## model 2 (CNN=64 LSTM=32)

# %%
lr = 0.0003

model_hybrid_2 = Sequential()
model_hybrid_2.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_2.add(LSTM(32, activation='tanh', return_sequences=True))
model_hybrid_2.add(Flatten())
model_hybrid_2.add(Dense(7))
model_hybrid_2.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_2.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_46"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_46 (Conv1D)              │ (None, 7, 64)          │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_48 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_46 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,439 (56.40 KB)
#  Trainable params: 14,439 (56.40 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_2.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.2069 - mean_absolute_error: 0.4031 - mean_absolute_percentage_error: 71.7821 - root_mean_squared_error: 0.4523 - val_loss: 0.0682 - val_mean_absolute_error: 0.2112 - val_mean_absolute_percentage_error: 16631683.0000 - val_root_mean_squared_error: 0.2611
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0334 - mean_absolute_error: 0.1439 - mean_absolute_percentage_error: 35.8161 - root_mean_squared_error: 0.1828 - val_loss: 0.0590 - val_mean_absolute_error: 0.2052 - val_mean_absolute_percentage_error: 15237593.0000 - val_root_mean_squared_error: 0.2430
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0263 - mean_absolute_error: 0.1276 - mean_absolute_percentage_error: 30.2861 - root_mean_squared_error: 0.1619 - val_loss: 0.0532 - val_mean_absolute_error: 0.1901 - val_mean_absolute_percentage_error: 16756487.0000 - val_root_mean_squared_error: 0.2307
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0213 - mean_absolute_error: 0.1128 - mean_absolute_percentage_error: 28.7824 - root_mean_squared_error: 0.1459 - val_loss: 0.0542 - val_mean_absolute_error: 0.1910 - val_mean_absolute_percentage_error: 16061770.0000 - val_root_mean_squared_error: 0.2328
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0211 - mean_absolute_error: 0.1129 - mean_absolute_percentage_error: 28.5170 - root_mean_squared_error: 0.1451 - val_loss: 0.0549 - val_mean_absolute_error: 0.1912 - val_mean_absolute_percentage_error: 15968394.0000 - val_root_mean_squared_error: 0.2343
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0204 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 27.9971 - root_mean_squared_error: 0.1428 - val_loss: 0.0542 - val_mean_absolute_error: 0.1900 - val_mean_absolute_percentage_error: 16368358.0000 - val_root_mean_squared_error: 0.2328
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0197 - mean_absolute_error: 0.1086 - mean_absolute_percentage_error: 27.2468 - root_mean_squared_error: 0.1402 - val_loss: 0.0558 - val_mean_absolute_error: 0.1938 - val_mean_absolute_percentage_error: 15819708.0000 - val_root_mean_squared_error: 0.2362
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0201 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 27.3617 - root_mean_squared_error: 0.1418 - val_loss: 0.0549 - val_mean_absolute_error: 0.1926 - val_mean_absolute_percentage_error: 16197378.0000 - val_root_mean_squared_error: 0.2343
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0198 - mean_absolute_error: 0.1089 - mean_absolute_percentage_error: 28.3941 - root_mean_squared_error: 0.1408 - val_loss: 0.0554 - val_mean_absolute_error: 0.1943 - val_mean_absolute_percentage_error: 16049295.0000 - val_root_mean_squared_error: 0.2353
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0191 - mean_absolute_error: 0.1069 - mean_absolute_percentage_error: 27.8302 - root_mean_squared_error: 0.1382 - val_loss: 0.0551 - val_mean_absolute_error: 0.1944 - val_mean_absolute_percentage_error: 16230061.0000 - val_root_mean_squared_error: 0.2348
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0193 - mean_absolute_error: 0.1084 - mean_absolute_percentage_error: 27.4038 - root_mean_squared_error: 0.1389 - val_loss: 0.0553 - val_mean_absolute_error: 0.1947 - val_mean_absolute_percentage_error: 16371625.0000 - val_root_mean_squared_error: 0.2352
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0188 - mean_absolute_error: 0.1058 - mean_absolute_percentage_error: 27.8234 - root_mean_squared_error: 0.1372 - val_loss: 0.0560 - val_mean_absolute_error: 0.1961 - val_mean_absolute_percentage_error: 16234655.0000 - val_root_mean_squared_error: 0.2365
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0192 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 28.2081 - root_mean_squared_error: 0.1386 - val_loss: 0.0567 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 15889439.0000 - val_root_mean_squared_error: 0.2381
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0190 - mean_absolute_error: 0.1064 - mean_absolute_percentage_error: 26.4311 - root_mean_squared_error: 0.1379 - val_loss: 0.0575 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 15771081.0000 - val_root_mean_squared_error: 0.2397
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0188 - mean_absolute_error: 0.1060 - mean_absolute_percentage_error: 27.5767 - root_mean_squared_error: 0.1373 - val_loss: 0.0569 - val_mean_absolute_error: 0.1987 - val_mean_absolute_percentage_error: 16202498.0000 - val_root_mean_squared_error: 0.2386
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0196 - mean_absolute_error: 0.1089 - mean_absolute_percentage_error: 27.3235 - root_mean_squared_error: 0.1400 - val_loss: 0.0563 - val_mean_absolute_error: 0.1971 - val_mean_absolute_percentage_error: 16634519.0000 - val_root_mean_squared_error: 0.2373
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0192 - mean_absolute_error: 0.1070 - mean_absolute_percentage_error: 27.4192 - root_mean_squared_error: 0.1384 - val_loss: 0.0592 - val_mean_absolute_error: 0.2031 - val_mean_absolute_percentage_error: 15568121.0000 - val_root_mean_squared_error: 0.2433
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0183 - mean_absolute_error: 0.1055 - mean_absolute_percentage_error: 26.4892 - root_mean_squared_error: 0.1354 - val_loss: 0.0598 - val_mean_absolute_error: 0.2040 - val_mean_absolute_percentage_error: 15544748.0000 - val_root_mean_squared_error: 0.2444
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0186 - mean_absolute_error: 0.1056 - mean_absolute_percentage_error: 26.7174 - root_mean_squared_error: 0.1362 - val_loss: 0.0587 - val_mean_absolute_error: 0.2028 - val_mean_absolute_percentage_error: 15760668.0000 - val_root_mean_squared_error: 0.2423
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0184 - mean_absolute_error: 0.1054 - mean_absolute_percentage_error: 27.4917 - root_mean_squared_error: 0.1355 - val_loss: 0.0578 - val_mean_absolute_error: 0.2001 - val_mean_absolute_percentage_error: 16348960.0000 - val_root_mean_squared_error: 0.2405

# %%
y_pred = model_hybrid_2.predict(x_test)

evaluation_hybrid_2 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_2
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# {'Mean Squared Error: ': np.float64(327.6028594153596),
#  'Mean Absolute Error: ': np.float64(14.298462225466361),
#  'Root Mean Absolute Error: ': 18.099802745205807,
#  'Mean Absolute Percentage Error: ': np.float64(25.68796351144772)}

# %%
loss, mae, mape, rmse = model_hybrid_2.evaluate(x_test, y_test)
print("model hybrid 2")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0261 - mean_absolute_error: 0.1277 - mean_absolute_percentage_error: 32.4508 - root_mean_squared_error: 0.1616
# model hybrid 2
# Mean Square Error: 0.026116298511624336
# Mean Absolute Error: 0.12766484916210175
# Mean Absolute Percentage Error: 32.45075607299805
# Root Mean Squared Error: 0.1616053730249405

# %% [markdown]
# ## model 3 (CNN=32 LSTM=32)

# %%
lr = 0.0003

model_hybrid_3 = Sequential()
model_hybrid_3.add(Conv1D(filters=32, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_3.add(LSTM(32, activation='tanh', return_sequences=True))
model_hybrid_3.add(Flatten())
model_hybrid_3.add(Dense(7))
model_hybrid_3.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_3.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_47"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_47 (Conv1D)              │ (None, 7, 32)          │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_49 (LSTM)                  │ (None, 7, 32)          │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_47 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,119 (39.53 KB)
#  Trainable params: 10,119 (39.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_3.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.2757 - mean_absolute_error: 0.4819 - mean_absolute_percentage_error: 85.9436 - root_mean_squared_error: 0.5233 - val_loss: 0.1069 - val_mean_absolute_error: 0.2818 - val_mean_absolute_percentage_error: 10622810.0000 - val_root_mean_squared_error: 0.3269
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0519 - mean_absolute_error: 0.1859 - mean_absolute_percentage_error: 37.2742 - root_mean_squared_error: 0.2268 - val_loss: 0.0561 - val_mean_absolute_error: 0.1925 - val_mean_absolute_percentage_error: 17608444.0000 - val_root_mean_squared_error: 0.2368
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0267 - mean_absolute_error: 0.1267 - mean_absolute_percentage_error: 31.1805 - root_mean_squared_error: 0.1635 - val_loss: 0.0540 - val_mean_absolute_error: 0.1900 - val_mean_absolute_percentage_error: 15986420.0000 - val_root_mean_squared_error: 0.2324
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0233 - mean_absolute_error: 0.1186 - mean_absolute_percentage_error: 29.3938 - root_mean_squared_error: 0.1527 - val_loss: 0.0525 - val_mean_absolute_error: 0.1862 - val_mean_absolute_percentage_error: 16637785.0000 - val_root_mean_squared_error: 0.2291
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0224 - mean_absolute_error: 0.1161 - mean_absolute_percentage_error: 30.2498 - root_mean_squared_error: 0.1495 - val_loss: 0.0517 - val_mean_absolute_error: 0.1848 - val_mean_absolute_percentage_error: 16573120.0000 - val_root_mean_squared_error: 0.2275
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0210 - mean_absolute_error: 0.1129 - mean_absolute_percentage_error: 29.3217 - root_mean_squared_error: 0.1450 - val_loss: 0.0517 - val_mean_absolute_error: 0.1842 - val_mean_absolute_percentage_error: 16489145.0000 - val_root_mean_squared_error: 0.2273
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0208 - mean_absolute_error: 0.1120 - mean_absolute_percentage_error: 28.9937 - root_mean_squared_error: 0.1443 - val_loss: 0.0516 - val_mean_absolute_error: 0.1836 - val_mean_absolute_percentage_error: 16498458.0000 - val_root_mean_squared_error: 0.2273
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0210 - mean_absolute_error: 0.1131 - mean_absolute_percentage_error: 27.8417 - root_mean_squared_error: 0.1448 - val_loss: 0.0514 - val_mean_absolute_error: 0.1833 - val_mean_absolute_percentage_error: 16569708.0000 - val_root_mean_squared_error: 0.2266
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0213 - mean_absolute_error: 0.1134 - mean_absolute_percentage_error: 28.1266 - root_mean_squared_error: 0.1461 - val_loss: 0.0522 - val_mean_absolute_error: 0.1846 - val_mean_absolute_percentage_error: 16127206.0000 - val_root_mean_squared_error: 0.2285
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0197 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 26.8534 - root_mean_squared_error: 0.1403 - val_loss: 0.0511 - val_mean_absolute_error: 0.1836 - val_mean_absolute_percentage_error: 16590103.0000 - val_root_mean_squared_error: 0.2261
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0206 - mean_absolute_error: 0.1118 - mean_absolute_percentage_error: 29.8521 - root_mean_squared_error: 0.1435 - val_loss: 0.0512 - val_mean_absolute_error: 0.1839 - val_mean_absolute_percentage_error: 16466118.0000 - val_root_mean_squared_error: 0.2263
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0204 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 28.7861 - root_mean_squared_error: 0.1429 - val_loss: 0.0516 - val_mean_absolute_error: 0.1848 - val_mean_absolute_percentage_error: 16208138.0000 - val_root_mean_squared_error: 0.2272
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0204 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 29.4371 - root_mean_squared_error: 0.1427 - val_loss: 0.0525 - val_mean_absolute_error: 0.1866 - val_mean_absolute_percentage_error: 15761455.0000 - val_root_mean_squared_error: 0.2292
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0209 - mean_absolute_error: 0.1133 - mean_absolute_percentage_error: 29.8825 - root_mean_squared_error: 0.1444 - val_loss: 0.0523 - val_mean_absolute_error: 0.1875 - val_mean_absolute_percentage_error: 15723287.0000 - val_root_mean_squared_error: 0.2287
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0190 - mean_absolute_error: 0.1074 - mean_absolute_percentage_error: 27.2522 - root_mean_squared_error: 0.1378 - val_loss: 0.0523 - val_mean_absolute_error: 0.1888 - val_mean_absolute_percentage_error: 15442905.0000 - val_root_mean_squared_error: 0.2286
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0191 - mean_absolute_error: 0.1080 - mean_absolute_percentage_error: 28.6712 - root_mean_squared_error: 0.1383 - val_loss: 0.0525 - val_mean_absolute_error: 0.1896 - val_mean_absolute_percentage_error: 15361074.0000 - val_root_mean_squared_error: 0.2291
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0197 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 28.8773 - root_mean_squared_error: 0.1403 - val_loss: 0.0540 - val_mean_absolute_error: 0.1929 - val_mean_absolute_percentage_error: 14688445.0000 - val_root_mean_squared_error: 0.2325
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0191 - mean_absolute_error: 0.1079 - mean_absolute_percentage_error: 28.0028 - root_mean_squared_error: 0.1382 - val_loss: 0.0524 - val_mean_absolute_error: 0.1914 - val_mean_absolute_percentage_error: 15270479.0000 - val_root_mean_squared_error: 0.2290
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0187 - mean_absolute_error: 0.1066 - mean_absolute_percentage_error: 27.8238 - root_mean_squared_error: 0.1368 - val_loss: 0.0536 - val_mean_absolute_error: 0.1937 - val_mean_absolute_percentage_error: 14786434.0000 - val_root_mean_squared_error: 0.2316
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0189 - mean_absolute_error: 0.1070 - mean_absolute_percentage_error: 27.3523 - root_mean_squared_error: 0.1373 - val_loss: 0.0534 - val_mean_absolute_error: 0.1935 - val_mean_absolute_percentage_error: 14943265.0000 - val_root_mean_squared_error: 0.2311

# %%
y_pred = model_hybrid_3.predict(x_test)

evaluation_hybrid_3 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_3
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# {'Mean Squared Error: ': np.float64(315.60906852084565),
#  'Mean Absolute Error: ': np.float64(14.145307190564212),
#  'Root Mean Absolute Error: ': 17.76538962479702,
#  'Mean Absolute Percentage Error: ': np.float64(25.504562203188776)}

# %%
loss, mae, mape, rmse = model_hybrid_3.evaluate(x_test, y_test)
print("model hybrid 3")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0252 - mean_absolute_error: 0.1263 - mean_absolute_percentage_error: 32.2317 - root_mean_squared_error: 0.1586
# model hybrid 3
# Mean Square Error: 0.025160159915685654
# Mean Absolute Error: 0.12629738450050354
# Mean Absolute Percentage Error: 32.23171615600586
# Root Mean Squared Error: 0.15861953794956207

# %% [markdown]
# ## model 4 (CNN=24 LSTM=12)

# %%
lr = 0.0003

model_hybrid_4 = Sequential()
model_hybrid_4.add(Conv1D(filters=24, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_4.add(LSTM(12, activation='tanh', return_sequences=True))
model_hybrid_4.add(Flatten())
model_hybrid_4.add(Dense(7))
model_hybrid_4.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_4.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_48"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_48 (Conv1D)              │ (None, 7, 24)          │           168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_50 (LSTM)                  │ (None, 7, 12)          │         1,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_48 (Flatten)            │ (None, 84)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ (None, 7)              │           595 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,539 (9.92 KB)
#  Trainable params: 2,539 (9.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_4.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.2007 - mean_absolute_error: 0.4088 - mean_absolute_percentage_error: 72.0425 - root_mean_squared_error: 0.4470 - val_loss: 0.1011 - val_mean_absolute_error: 0.2713 - val_mean_absolute_percentage_error: 10624344.0000 - val_root_mean_squared_error: 0.3180
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0477 - mean_absolute_error: 0.1753 - mean_absolute_percentage_error: 36.1722 - root_mean_squared_error: 0.2179 - val_loss: 0.0523 - val_mean_absolute_error: 0.1850 - val_mean_absolute_percentage_error: 17255814.0000 - val_root_mean_squared_error: 0.2288
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0256 - mean_absolute_error: 0.1253 - mean_absolute_percentage_error: 33.2101 - root_mean_squared_error: 0.1600 - val_loss: 0.0569 - val_mean_absolute_error: 0.1934 - val_mean_absolute_percentage_error: 14686146.0000 - val_root_mean_squared_error: 0.2386
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0236 - mean_absolute_error: 0.1214 - mean_absolute_percentage_error: 29.9718 - root_mean_squared_error: 0.1537 - val_loss: 0.0527 - val_mean_absolute_error: 0.1855 - val_mean_absolute_percentage_error: 15660020.0000 - val_root_mean_squared_error: 0.2296
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0230 - mean_absolute_error: 0.1177 - mean_absolute_percentage_error: 30.3165 - root_mean_squared_error: 0.1516 - val_loss: 0.0537 - val_mean_absolute_error: 0.1870 - val_mean_absolute_percentage_error: 15203482.0000 - val_root_mean_squared_error: 0.2317
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0209 - mean_absolute_error: 0.1140 - mean_absolute_percentage_error: 28.2240 - root_mean_squared_error: 0.1444 - val_loss: 0.0530 - val_mean_absolute_error: 0.1867 - val_mean_absolute_percentage_error: 15407716.0000 - val_root_mean_squared_error: 0.2302
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0229 - mean_absolute_error: 0.1171 - mean_absolute_percentage_error: 30.6050 - root_mean_squared_error: 0.1512 - val_loss: 0.0538 - val_mean_absolute_error: 0.1881 - val_mean_absolute_percentage_error: 15176284.0000 - val_root_mean_squared_error: 0.2320
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0212 - mean_absolute_error: 0.1139 - mean_absolute_percentage_error: 28.3529 - root_mean_squared_error: 0.1456 - val_loss: 0.0535 - val_mean_absolute_error: 0.1885 - val_mean_absolute_percentage_error: 15333198.0000 - val_root_mean_squared_error: 0.2313
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0218 - mean_absolute_error: 0.1151 - mean_absolute_percentage_error: 29.9234 - root_mean_squared_error: 0.1476 - val_loss: 0.0537 - val_mean_absolute_error: 0.1891 - val_mean_absolute_percentage_error: 15325946.0000 - val_root_mean_squared_error: 0.2318
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0213 - mean_absolute_error: 0.1143 - mean_absolute_percentage_error: 29.3477 - root_mean_squared_error: 0.1459 - val_loss: 0.0542 - val_mean_absolute_error: 0.1906 - val_mean_absolute_percentage_error: 15296787.0000 - val_root_mean_squared_error: 0.2327
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0214 - mean_absolute_error: 0.1135 - mean_absolute_percentage_error: 30.0742 - root_mean_squared_error: 0.1463 - val_loss: 0.0545 - val_mean_absolute_error: 0.1917 - val_mean_absolute_percentage_error: 15239641.0000 - val_root_mean_squared_error: 0.2335
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0209 - mean_absolute_error: 0.1127 - mean_absolute_percentage_error: 28.5198 - root_mean_squared_error: 0.1445 - val_loss: 0.0551 - val_mean_absolute_error: 0.1927 - val_mean_absolute_percentage_error: 15052675.0000 - val_root_mean_squared_error: 0.2347
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0217 - mean_absolute_error: 0.1150 - mean_absolute_percentage_error: 30.2939 - root_mean_squared_error: 0.1473 - val_loss: 0.0540 - val_mean_absolute_error: 0.1914 - val_mean_absolute_percentage_error: 15381348.0000 - val_root_mean_squared_error: 0.2324
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0208 - mean_absolute_error: 0.1126 - mean_absolute_percentage_error: 28.0576 - root_mean_squared_error: 0.1442 - val_loss: 0.0554 - val_mean_absolute_error: 0.1933 - val_mean_absolute_percentage_error: 14995955.0000 - val_root_mean_squared_error: 0.2353
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0203 - mean_absolute_error: 0.1111 - mean_absolute_percentage_error: 27.7210 - root_mean_squared_error: 0.1425 - val_loss: 0.0543 - val_mean_absolute_error: 0.1921 - val_mean_absolute_percentage_error: 15285379.0000 - val_root_mean_squared_error: 0.2331
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0199 - mean_absolute_error: 0.1099 - mean_absolute_percentage_error: 26.7664 - root_mean_squared_error: 0.1409 - val_loss: 0.0550 - val_mean_absolute_error: 0.1934 - val_mean_absolute_percentage_error: 15092572.0000 - val_root_mean_squared_error: 0.2346
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0200 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 28.3036 - root_mean_squared_error: 0.1413 - val_loss: 0.0545 - val_mean_absolute_error: 0.1928 - val_mean_absolute_percentage_error: 15263692.0000 - val_root_mean_squared_error: 0.2334
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0208 - mean_absolute_error: 0.1125 - mean_absolute_percentage_error: 28.9744 - root_mean_squared_error: 0.1441 - val_loss: 0.0541 - val_mean_absolute_error: 0.1918 - val_mean_absolute_percentage_error: 15337674.0000 - val_root_mean_squared_error: 0.2326
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0204 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 28.5513 - root_mean_squared_error: 0.1428 - val_loss: 0.0545 - val_mean_absolute_error: 0.1928 - val_mean_absolute_percentage_error: 15282150.0000 - val_root_mean_squared_error: 0.2335
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0199 - mean_absolute_error: 0.1101 - mean_absolute_percentage_error: 28.2204 - root_mean_squared_error: 0.1409 - val_loss: 0.0549 - val_mean_absolute_error: 0.1933 - val_mean_absolute_percentage_error: 15149059.0000 - val_root_mean_squared_error: 0.2344

# %%
y_pred = model_hybrid_4.predict(x_test)

evaluation_hybrid_4 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_4
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# {'Mean Squared Error: ': np.float64(409.30828164831024),
#  'Mean Absolute Error: ': np.float64(16.674587288681344),
#  'Root Mean Absolute Error: ': 20.231368753703006,
#  'Mean Absolute Percentage Error: ': np.float64(27.921256943160245)}

# %%
loss, mae, mape, rmse = model_hybrid_4.evaluate(x_test, y_test)
print("model hybrid 4")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0326 - mean_absolute_error: 0.1489 - mean_absolute_percentage_error: 34.7342 - root_mean_squared_error: 0.1806
# model hybrid 4
# Mean Square Error: 0.03262980282306671
# Mean Absolute Error: 0.1488802433013916
# Mean Absolute Percentage Error: 34.734153747558594
# Root Mean Squared Error: 0.1806372106075287

# %% [markdown]
# ## model 5 (CNN=256 LSTM=128)

# %%
lr = 0.0003

model_hybrid_5 = Sequential()
model_hybrid_5.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_5.add(LSTM(128, activation='tanh', return_sequences=True))
model_hybrid_5.add(Flatten())
model_hybrid_5.add(Dense(7))
model_hybrid_5.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_5.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_49"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_49 (Conv1D)              │ (None, 7, 256)         │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_51 (LSTM)                  │ (None, 7, 128)         │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_49 (Flatten)            │ (None, 896)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 7)              │         6,279 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 205,191 (801.53 KB)
#  Trainable params: 205,191 (801.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_5.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - loss: 0.1691 - mean_absolute_error: 0.3461 - mean_absolute_percentage_error: 65.4936 - root_mean_squared_error: 0.4016 - val_loss: 0.0768 - val_mean_absolute_error: 0.2369 - val_mean_absolute_percentage_error: 11611185.0000 - val_root_mean_squared_error: 0.2770
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0328 - mean_absolute_error: 0.1476 - mean_absolute_percentage_error: 31.1895 - root_mean_squared_error: 0.1807 - val_loss: 0.0545 - val_mean_absolute_error: 0.1927 - val_mean_absolute_percentage_error: 14813805.0000 - val_root_mean_squared_error: 0.2334
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0230 - mean_absolute_error: 0.1190 - mean_absolute_percentage_error: 28.5486 - root_mean_squared_error: 0.1517 - val_loss: 0.0517 - val_mean_absolute_error: 0.1880 - val_mean_absolute_percentage_error: 15612118.0000 - val_root_mean_squared_error: 0.2273
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0215 - mean_absolute_error: 0.1146 - mean_absolute_percentage_error: 29.4906 - root_mean_squared_error: 0.1467 - val_loss: 0.0510 - val_mean_absolute_error: 0.1874 - val_mean_absolute_percentage_error: 15864558.0000 - val_root_mean_squared_error: 0.2257
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0208 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 28.0468 - root_mean_squared_error: 0.1443 - val_loss: 0.0519 - val_mean_absolute_error: 0.1909 - val_mean_absolute_percentage_error: 15341962.0000 - val_root_mean_squared_error: 0.2279
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0210 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 28.3920 - root_mean_squared_error: 0.1449 - val_loss: 0.0540 - val_mean_absolute_error: 0.1950 - val_mean_absolute_percentage_error: 14547968.0000 - val_root_mean_squared_error: 0.2324
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0194 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 26.8317 - root_mean_squared_error: 0.1392 - val_loss: 0.0537 - val_mean_absolute_error: 0.1958 - val_mean_absolute_percentage_error: 14585550.0000 - val_root_mean_squared_error: 0.2318
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0206 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 28.4807 - root_mean_squared_error: 0.1435 - val_loss: 0.0550 - val_mean_absolute_error: 0.1985 - val_mean_absolute_percentage_error: 14138696.0000 - val_root_mean_squared_error: 0.2346
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0199 - mean_absolute_error: 0.1100 - mean_absolute_percentage_error: 28.4615 - root_mean_squared_error: 0.1411 - val_loss: 0.0546 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 14397548.0000 - val_root_mean_squared_error: 0.2337
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0190 - mean_absolute_error: 0.1061 - mean_absolute_percentage_error: 27.1480 - root_mean_squared_error: 0.1376 - val_loss: 0.0580 - val_mean_absolute_error: 0.2046 - val_mean_absolute_percentage_error: 13457752.0000 - val_root_mean_squared_error: 0.2408
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0190 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 27.0701 - root_mean_squared_error: 0.1378 - val_loss: 0.0540 - val_mean_absolute_error: 0.1965 - val_mean_absolute_percentage_error: 15372456.0000 - val_root_mean_squared_error: 0.2325
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0201 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 27.9441 - root_mean_squared_error: 0.1415 - val_loss: 0.0565 - val_mean_absolute_error: 0.2016 - val_mean_absolute_percentage_error: 14066377.0000 - val_root_mean_squared_error: 0.2377
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0190 - mean_absolute_error: 0.1077 - mean_absolute_percentage_error: 26.4091 - root_mean_squared_error: 0.1379 - val_loss: 0.0547 - val_mean_absolute_error: 0.1985 - val_mean_absolute_percentage_error: 15018407.0000 - val_root_mean_squared_error: 0.2338
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0181 - mean_absolute_error: 0.1044 - mean_absolute_percentage_error: 26.6855 - root_mean_squared_error: 0.1345 - val_loss: 0.0571 - val_mean_absolute_error: 0.2043 - val_mean_absolute_percentage_error: 14167649.0000 - val_root_mean_squared_error: 0.2390
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0180 - mean_absolute_error: 0.1044 - mean_absolute_percentage_error: 26.1636 - root_mean_squared_error: 0.1343 - val_loss: 0.0578 - val_mean_absolute_error: 0.2058 - val_mean_absolute_percentage_error: 14040883.0000 - val_root_mean_squared_error: 0.2405
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0174 - mean_absolute_error: 0.1020 - mean_absolute_percentage_error: 25.7280 - root_mean_squared_error: 0.1318 - val_loss: 0.0594 - val_mean_absolute_error: 0.2090 - val_mean_absolute_percentage_error: 13847241.0000 - val_root_mean_squared_error: 0.2438
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0176 - mean_absolute_error: 0.1038 - mean_absolute_percentage_error: 24.6131 - root_mean_squared_error: 0.1328 - val_loss: 0.0580 - val_mean_absolute_error: 0.2075 - val_mean_absolute_percentage_error: 14158826.0000 - val_root_mean_squared_error: 0.2408
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0180 - mean_absolute_error: 0.1038 - mean_absolute_percentage_error: 26.4484 - root_mean_squared_error: 0.1341 - val_loss: 0.0579 - val_mean_absolute_error: 0.2060 - val_mean_absolute_percentage_error: 14494559.0000 - val_root_mean_squared_error: 0.2406
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0173 - mean_absolute_error: 0.1020 - mean_absolute_percentage_error: 26.2690 - root_mean_squared_error: 0.1315 - val_loss: 0.0600 - val_mean_absolute_error: 0.2083 - val_mean_absolute_percentage_error: 15276930.0000 - val_root_mean_squared_error: 0.2449
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0175 - mean_absolute_error: 0.1028 - mean_absolute_percentage_error: 25.6580 - root_mean_squared_error: 0.1324 - val_loss: 0.0606 - val_mean_absolute_error: 0.2107 - val_mean_absolute_percentage_error: 14154705.0000 - val_root_mean_squared_error: 0.2461

# %%
y_pred = model_hybrid_5.predict(x_test)

evaluation_hybrid_5 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_5
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# {'Mean Squared Error: ': np.float64(278.67293421442804),
#  'Mean Absolute Error: ': np.float64(12.875939797381966),
#  'Root Mean Absolute Error: ': 16.693499759320332,
#  'Mean Absolute Percentage Error: ': np.float64(23.449496326932877)}

# %%
loss, mae, mape, rmse = model_hybrid_5.evaluate(x_test, y_test)
print("model hybrid 5")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0222 - mean_absolute_error: 0.1150 - mean_absolute_percentage_error: 29.7374 - root_mean_squared_error: 0.1490
# model hybrid 5
# Mean Square Error: 0.02221563458442688
# Mean Absolute Error: 0.11496375501155853
# Mean Absolute Percentage Error: 29.737369537353516
# Root Mean Squared Error: 0.14904910326004028

# %% [markdown]
# ## model 6 (CNN=256 LSTM=64)

# %%
lr = 0.0003

model_hybrid_6 = Sequential()
model_hybrid_6.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_6.add(LSTM(64, activation='tanh', return_sequences=True))
model_hybrid_6.add(Flatten())
model_hybrid_6.add(Dense(7))
model_hybrid_6.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_6.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_50"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_50 (Conv1D)              │ (None, 7, 256)         │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_52 (LSTM)                  │ (None, 7, 64)          │        82,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_50 (Flatten)            │ (None, 448)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_50 (Dense)                │ (None, 7)              │         3,143 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 87,111 (340.28 KB)
#  Trainable params: 87,111 (340.28 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_6.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.1653 - mean_absolute_error: 0.3476 - mean_absolute_percentage_error: 64.8745 - root_mean_squared_error: 0.3987 - val_loss: 0.0558 - val_mean_absolute_error: 0.1951 - val_mean_absolute_percentage_error: 15014584.0000 - val_root_mean_squared_error: 0.2361
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0280 - mean_absolute_error: 0.1354 - mean_absolute_percentage_error: 28.9500 - root_mean_squared_error: 0.1673 - val_loss: 0.0511 - val_mean_absolute_error: 0.1837 - val_mean_absolute_percentage_error: 17232232.0000 - val_root_mean_squared_error: 0.2260
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0229 - mean_absolute_error: 0.1178 - mean_absolute_percentage_error: 32.4966 - root_mean_squared_error: 0.1512 - val_loss: 0.0513 - val_mean_absolute_error: 0.1847 - val_mean_absolute_percentage_error: 16590054.0000 - val_root_mean_squared_error: 0.2266
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0204 - mean_absolute_error: 0.1111 - mean_absolute_percentage_error: 27.5237 - root_mean_squared_error: 0.1426 - val_loss: 0.0545 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 15370206.0000 - val_root_mean_squared_error: 0.2334
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0216 - mean_absolute_error: 0.1140 - mean_absolute_percentage_error: 30.7949 - root_mean_squared_error: 0.1470 - val_loss: 0.0554 - val_mean_absolute_error: 0.1938 - val_mean_absolute_percentage_error: 15108807.0000 - val_root_mean_squared_error: 0.2353
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0204 - mean_absolute_error: 0.1118 - mean_absolute_percentage_error: 27.6115 - root_mean_squared_error: 0.1426 - val_loss: 0.0541 - val_mean_absolute_error: 0.1932 - val_mean_absolute_percentage_error: 15503748.0000 - val_root_mean_squared_error: 0.2326
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0208 - mean_absolute_error: 0.1126 - mean_absolute_percentage_error: 28.7327 - root_mean_squared_error: 0.1441 - val_loss: 0.0540 - val_mean_absolute_error: 0.1933 - val_mean_absolute_percentage_error: 15590528.0000 - val_root_mean_squared_error: 0.2323
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0199 - mean_absolute_error: 0.1095 - mean_absolute_percentage_error: 28.5785 - root_mean_squared_error: 0.1411 - val_loss: 0.0548 - val_mean_absolute_error: 0.1949 - val_mean_absolute_percentage_error: 15428147.0000 - val_root_mean_squared_error: 0.2341
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0192 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 27.3212 - root_mean_squared_error: 0.1387 - val_loss: 0.0546 - val_mean_absolute_error: 0.1956 - val_mean_absolute_percentage_error: 15512402.0000 - val_root_mean_squared_error: 0.2337
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0193 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 28.2283 - root_mean_squared_error: 0.1391 - val_loss: 0.0550 - val_mean_absolute_error: 0.1963 - val_mean_absolute_percentage_error: 15426838.0000 - val_root_mean_squared_error: 0.2345
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0200 - mean_absolute_error: 0.1098 - mean_absolute_percentage_error: 30.2286 - root_mean_squared_error: 0.1413 - val_loss: 0.0556 - val_mean_absolute_error: 0.1976 - val_mean_absolute_percentage_error: 15314602.0000 - val_root_mean_squared_error: 0.2357
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0191 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 27.3469 - root_mean_squared_error: 0.1383 - val_loss: 0.0564 - val_mean_absolute_error: 0.1990 - val_mean_absolute_percentage_error: 15154776.0000 - val_root_mean_squared_error: 0.2376
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0190 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 27.1991 - root_mean_squared_error: 0.1378 - val_loss: 0.0551 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 16071533.0000 - val_root_mean_squared_error: 0.2348
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0200 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 29.1112 - root_mean_squared_error: 0.1414 - val_loss: 0.0579 - val_mean_absolute_error: 0.2016 - val_mean_absolute_percentage_error: 14854870.0000 - val_root_mean_squared_error: 0.2406
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0183 - mean_absolute_error: 0.1055 - mean_absolute_percentage_error: 26.8075 - root_mean_squared_error: 0.1351 - val_loss: 0.0567 - val_mean_absolute_error: 0.2000 - val_mean_absolute_percentage_error: 15286603.0000 - val_root_mean_squared_error: 0.2381
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0177 - mean_absolute_error: 0.1039 - mean_absolute_percentage_error: 25.8596 - root_mean_squared_error: 0.1328 - val_loss: 0.0563 - val_mean_absolute_error: 0.1998 - val_mean_absolute_percentage_error: 15528280.0000 - val_root_mean_squared_error: 0.2374
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0190 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 28.2331 - root_mean_squared_error: 0.1378 - val_loss: 0.0583 - val_mean_absolute_error: 0.2027 - val_mean_absolute_percentage_error: 15086484.0000 - val_root_mean_squared_error: 0.2414
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0180 - mean_absolute_error: 0.1048 - mean_absolute_percentage_error: 25.6888 - root_mean_squared_error: 0.1342 - val_loss: 0.0568 - val_mean_absolute_error: 0.2006 - val_mean_absolute_percentage_error: 15967160.0000 - val_root_mean_squared_error: 0.2383
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0169 - mean_absolute_error: 0.1010 - mean_absolute_percentage_error: 24.6820 - root_mean_squared_error: 0.1301 - val_loss: 0.0568 - val_mean_absolute_error: 0.1999 - val_mean_absolute_percentage_error: 16256791.0000 - val_root_mean_squared_error: 0.2382
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0169 - mean_absolute_error: 0.1006 - mean_absolute_percentage_error: 25.0483 - root_mean_squared_error: 0.1299 - val_loss: 0.0593 - val_mean_absolute_error: 0.2047 - val_mean_absolute_percentage_error: 15112117.0000 - val_root_mean_squared_error: 0.2436

# %%
y_pred = model_hybrid_6.predict(x_test)

evaluation_hybrid_6 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_6
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# {'Mean Squared Error: ': np.float64(281.63863413084306),
#  'Mean Absolute Error: ': np.float64(13.404991266678792),
#  'Root Mean Absolute Error: ': 16.782092662443592,
#  'Mean Absolute Percentage Error: ': np.float64(23.61762003946376)}

# %%
loss, mae, mape, rmse = model_hybrid_6.evaluate(x_test, y_test)
print("model hybrid 6")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0225 - mean_absolute_error: 0.1197 - mean_absolute_percentage_error: 29.7793 - root_mean_squared_error: 0.1498
# model hybrid 6
# Mean Square Error: 0.022452058270573616
# Mean Absolute Error: 0.11968743056058884
# Mean Absolute Percentage Error: 29.779266357421875
# Root Mean Squared Error: 0.1498401015996933

# %% [markdown]
# ## model 7 (CNN=32 LSTM=64)

# %%
lr = 0.0003

model_hybrid_7 = Sequential()
model_hybrid_7.add(Conv1D(filters=32, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_7.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_7.add(Flatten())
model_hybrid_7.add(Dense(7))
model_hybrid_7.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_7.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_51"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_51 (Conv1D)              │ (None, 7, 32)          │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_53 (LSTM)                  │ (None, 7, 64)          │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_51 (Flatten)            │ (None, 448)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 7)              │         3,143 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,199 (110.15 KB)
#  Trainable params: 28,199 (110.15 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_7.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.3026 - mean_absolute_error: 0.5155 - mean_absolute_percentage_error: 88.6593 - root_mean_squared_error: 0.5482 - val_loss: 0.0773 - val_mean_absolute_error: 0.2383 - val_mean_absolute_percentage_error: 10932278.0000 - val_root_mean_squared_error: 0.2780
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0424 - mean_absolute_error: 0.1643 - mean_absolute_percentage_error: 39.4755 - root_mean_squared_error: 0.2056 - val_loss: 0.0551 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 13492381.0000 - val_root_mean_squared_error: 0.2346
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0273 - mean_absolute_error: 0.1347 - mean_absolute_percentage_error: 30.2617 - root_mean_squared_error: 0.1653 - val_loss: 0.0514 - val_mean_absolute_error: 0.1890 - val_mean_absolute_percentage_error: 15750573.0000 - val_root_mean_squared_error: 0.2268
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0240 - mean_absolute_error: 0.1186 - mean_absolute_percentage_error: 33.8826 - root_mean_squared_error: 0.1549 - val_loss: 0.0526 - val_mean_absolute_error: 0.1927 - val_mean_absolute_percentage_error: 14374572.0000 - val_root_mean_squared_error: 0.2293
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0240 - mean_absolute_error: 0.1203 - mean_absolute_percentage_error: 31.1315 - root_mean_squared_error: 0.1547 - val_loss: 0.0517 - val_mean_absolute_error: 0.1910 - val_mean_absolute_percentage_error: 14853793.0000 - val_root_mean_squared_error: 0.2273
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0228 - mean_absolute_error: 0.1178 - mean_absolute_percentage_error: 33.0157 - root_mean_squared_error: 0.1510 - val_loss: 0.0519 - val_mean_absolute_error: 0.1926 - val_mean_absolute_percentage_error: 14869506.0000 - val_root_mean_squared_error: 0.2278
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0212 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 30.5270 - root_mean_squared_error: 0.1456 - val_loss: 0.0534 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 14426617.0000 - val_root_mean_squared_error: 0.2310
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0204 - mean_absolute_error: 0.1100 - mean_absolute_percentage_error: 28.4455 - root_mean_squared_error: 0.1429 - val_loss: 0.0546 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 14212523.0000 - val_root_mean_squared_error: 0.2336
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0208 - mean_absolute_error: 0.1119 - mean_absolute_percentage_error: 29.0950 - root_mean_squared_error: 0.1443 - val_loss: 0.0541 - val_mean_absolute_error: 0.1992 - val_mean_absolute_percentage_error: 14288057.0000 - val_root_mean_squared_error: 0.2325
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0195 - mean_absolute_error: 0.1084 - mean_absolute_percentage_error: 27.7545 - root_mean_squared_error: 0.1396 - val_loss: 0.0541 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 14401785.0000 - val_root_mean_squared_error: 0.2326
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0207 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 29.6164 - root_mean_squared_error: 0.1438 - val_loss: 0.0548 - val_mean_absolute_error: 0.2008 - val_mean_absolute_percentage_error: 13984821.0000 - val_root_mean_squared_error: 0.2342
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0197 - mean_absolute_error: 0.1092 - mean_absolute_percentage_error: 27.6931 - root_mean_squared_error: 0.1404 - val_loss: 0.0552 - val_mean_absolute_error: 0.2009 - val_mean_absolute_percentage_error: 13894746.0000 - val_root_mean_squared_error: 0.2349
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0192 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 26.7941 - root_mean_squared_error: 0.1384 - val_loss: 0.0569 - val_mean_absolute_error: 0.2037 - val_mean_absolute_percentage_error: 13684774.0000 - val_root_mean_squared_error: 0.2385
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0202 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 29.3493 - root_mean_squared_error: 0.1421 - val_loss: 0.0544 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 14192316.0000 - val_root_mean_squared_error: 0.2331
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0195 - mean_absolute_error: 0.1085 - mean_absolute_percentage_error: 29.1544 - root_mean_squared_error: 0.1398 - val_loss: 0.0543 - val_mean_absolute_error: 0.1993 - val_mean_absolute_percentage_error: 14269571.0000 - val_root_mean_squared_error: 0.2331
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0186 - mean_absolute_error: 0.1053 - mean_absolute_percentage_error: 27.6215 - root_mean_squared_error: 0.1365 - val_loss: 0.0552 - val_mean_absolute_error: 0.2013 - val_mean_absolute_percentage_error: 14086912.0000 - val_root_mean_squared_error: 0.2349
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0181 - mean_absolute_error: 0.1045 - mean_absolute_percentage_error: 27.1246 - root_mean_squared_error: 0.1347 - val_loss: 0.0543 - val_mean_absolute_error: 0.1994 - val_mean_absolute_percentage_error: 14625626.0000 - val_root_mean_squared_error: 0.2331
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0180 - mean_absolute_error: 0.1033 - mean_absolute_percentage_error: 25.7632 - root_mean_squared_error: 0.1341 - val_loss: 0.0546 - val_mean_absolute_error: 0.2000 - val_mean_absolute_percentage_error: 14316822.0000 - val_root_mean_squared_error: 0.2336
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0189 - mean_absolute_error: 0.1070 - mean_absolute_percentage_error: 27.2481 - root_mean_squared_error: 0.1376 - val_loss: 0.0556 - val_mean_absolute_error: 0.2024 - val_mean_absolute_percentage_error: 14123118.0000 - val_root_mean_squared_error: 0.2358
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0186 - mean_absolute_error: 0.1057 - mean_absolute_percentage_error: 28.0133 - root_mean_squared_error: 0.1364 - val_loss: 0.0539 - val_mean_absolute_error: 0.1985 - val_mean_absolute_percentage_error: 14913848.0000 - val_root_mean_squared_error: 0.2321

# %%
y_pred = model_hybrid_7.predict(x_test)

evaluation_hybrid_7 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_7
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# {'Mean Squared Error: ': np.float64(298.72962497714514),
#  'Mean Absolute Error: ': np.float64(13.601172836459414),
#  'Root Mean Absolute Error: ': 17.283796601937468,
#  'Mean Absolute Percentage Error: ': np.float64(24.964750144738453)}

# %%
loss, mae, mape, rmse = model_hybrid_7.evaluate(x_test, y_test)
print("model hybrid 7")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0238 - mean_absolute_error: 0.1214 - mean_absolute_percentage_error: 31.6904 - root_mean_squared_error: 0.1543
# model hybrid 7
# Mean Square Error: 0.02381454035639763
# Mean Absolute Error: 0.12143903970718384
# Mean Absolute Percentage Error: 31.69041633605957
# Root Mean Squared Error: 0.15431959927082062

# %% [markdown]
# ## model 8 (CNN=1024 LSTM=128)

# %%
lr = 0.0003

model_hybrid_8 = Sequential()
model_hybrid_8.add(Conv1D(filters=1024, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_8.add(LSTM(128, activation='relu', return_sequences=True))
model_hybrid_8.add(Flatten())
model_hybrid_8.add(Dense(7))
model_hybrid_8.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_8.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_52"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_52 (Conv1D)              │ (None, 7, 1024)        │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_54 (LSTM)                  │ (None, 7, 128)         │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_52 (Flatten)            │ (None, 896)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (None, 7)              │         6,279 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 603,783 (2.30 MB)
#  Trainable params: 603,783 (2.30 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_8.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 0.1960 - mean_absolute_error: 0.3779 - mean_absolute_percentage_error: 68.6088 - root_mean_squared_error: 0.4322 - val_loss: 0.0704 - val_mean_absolute_error: 0.2248 - val_mean_absolute_percentage_error: 12416438.0000 - val_root_mean_squared_error: 0.2654
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0292 - mean_absolute_error: 0.1367 - mean_absolute_percentage_error: 31.1849 - root_mean_squared_error: 0.1706 - val_loss: 0.0554 - val_mean_absolute_error: 0.1961 - val_mean_absolute_percentage_error: 14632225.0000 - val_root_mean_squared_error: 0.2353
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0224 - mean_absolute_error: 0.1171 - mean_absolute_percentage_error: 28.6269 - root_mean_squared_error: 0.1497 - val_loss: 0.0531 - val_mean_absolute_error: 0.1920 - val_mean_absolute_percentage_error: 15110131.0000 - val_root_mean_squared_error: 0.2304
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0201 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 28.6483 - root_mean_squared_error: 0.1416 - val_loss: 0.0529 - val_mean_absolute_error: 0.1931 - val_mean_absolute_percentage_error: 15213572.0000 - val_root_mean_squared_error: 0.2301
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0205 - mean_absolute_error: 0.1106 - mean_absolute_percentage_error: 29.1243 - root_mean_squared_error: 0.1430 - val_loss: 0.0541 - val_mean_absolute_error: 0.1960 - val_mean_absolute_percentage_error: 14885570.0000 - val_root_mean_squared_error: 0.2326
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0198 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 27.9932 - root_mean_squared_error: 0.1407 - val_loss: 0.0554 - val_mean_absolute_error: 0.1989 - val_mean_absolute_percentage_error: 14457473.0000 - val_root_mean_squared_error: 0.2354
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0198 - mean_absolute_error: 0.1093 - mean_absolute_percentage_error: 27.1712 - root_mean_squared_error: 0.1409 - val_loss: 0.0544 - val_mean_absolute_error: 0.1977 - val_mean_absolute_percentage_error: 14819272.0000 - val_root_mean_squared_error: 0.2333
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0195 - mean_absolute_error: 0.1087 - mean_absolute_percentage_error: 27.5067 - root_mean_squared_error: 0.1398 - val_loss: 0.0584 - val_mean_absolute_error: 0.2043 - val_mean_absolute_percentage_error: 13870833.0000 - val_root_mean_squared_error: 0.2417
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0184 - mean_absolute_error: 0.1056 - mean_absolute_percentage_error: 25.9083 - root_mean_squared_error: 0.1357 - val_loss: 0.0550 - val_mean_absolute_error: 0.1990 - val_mean_absolute_percentage_error: 14909921.0000 - val_root_mean_squared_error: 0.2346
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0200 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 29.7135 - root_mean_squared_error: 0.1413 - val_loss: 0.0557 - val_mean_absolute_error: 0.2011 - val_mean_absolute_percentage_error: 14963185.0000 - val_root_mean_squared_error: 0.2360
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0195 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 29.3737 - root_mean_squared_error: 0.1396 - val_loss: 0.0560 - val_mean_absolute_error: 0.2011 - val_mean_absolute_percentage_error: 14960863.0000 - val_root_mean_squared_error: 0.2366
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0183 - mean_absolute_error: 0.1058 - mean_absolute_percentage_error: 27.6975 - root_mean_squared_error: 0.1353 - val_loss: 0.0575 - val_mean_absolute_error: 0.2039 - val_mean_absolute_percentage_error: 14825679.0000 - val_root_mean_squared_error: 0.2399
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0186 - mean_absolute_error: 0.1052 - mean_absolute_percentage_error: 27.4116 - root_mean_squared_error: 0.1363 - val_loss: 0.0600 - val_mean_absolute_error: 0.2074 - val_mean_absolute_percentage_error: 14316550.0000 - val_root_mean_squared_error: 0.2449
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0184 - mean_absolute_error: 0.1057 - mean_absolute_percentage_error: 25.9719 - root_mean_squared_error: 0.1355 - val_loss: 0.0570 - val_mean_absolute_error: 0.2033 - val_mean_absolute_percentage_error: 15469405.0000 - val_root_mean_squared_error: 0.2388
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0181 - mean_absolute_error: 0.1041 - mean_absolute_percentage_error: 26.8605 - root_mean_squared_error: 0.1346 - val_loss: 0.0582 - val_mean_absolute_error: 0.2059 - val_mean_absolute_percentage_error: 15390335.0000 - val_root_mean_squared_error: 0.2413
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0177 - mean_absolute_error: 0.1033 - mean_absolute_percentage_error: 25.4676 - root_mean_squared_error: 0.1330 - val_loss: 0.0625 - val_mean_absolute_error: 0.2122 - val_mean_absolute_percentage_error: 14252055.0000 - val_root_mean_squared_error: 0.2500
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0181 - mean_absolute_error: 0.1049 - mean_absolute_percentage_error: 26.1435 - root_mean_squared_error: 0.1345 - val_loss: 0.0587 - val_mean_absolute_error: 0.2062 - val_mean_absolute_percentage_error: 16077891.0000 - val_root_mean_squared_error: 0.2423
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0174 - mean_absolute_error: 0.1013 - mean_absolute_percentage_error: 26.2889 - root_mean_squared_error: 0.1318 - val_loss: 0.0597 - val_mean_absolute_error: 0.2096 - val_mean_absolute_percentage_error: 15287070.0000 - val_root_mean_squared_error: 0.2443
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0175 - mean_absolute_error: 0.1026 - mean_absolute_percentage_error: 26.0002 - root_mean_squared_error: 0.1322 - val_loss: 0.0618 - val_mean_absolute_error: 0.2131 - val_mean_absolute_percentage_error: 14910388.0000 - val_root_mean_squared_error: 0.2486
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0183 - mean_absolute_error: 0.1056 - mean_absolute_percentage_error: 27.4846 - root_mean_squared_error: 0.1351 - val_loss: 0.0596 - val_mean_absolute_error: 0.2083 - val_mean_absolute_percentage_error: 15661170.0000 - val_root_mean_squared_error: 0.2440

# %%
y_pred = model_hybrid_8.predict(x_test)

evaluation_hybrid_8 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_8
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# {'Mean Squared Error: ': np.float64(297.3300744137226),
#  'Mean Absolute Error: ': np.float64(13.170095774592186),
#  'Root Mean Absolute Error: ': 17.2432617104109,
#  'Mean Absolute Percentage Error: ': np.float64(24.34830239326961)}

# %%
loss, mae, mape, rmse = model_hybrid_8.evaluate(x_test, y_test)
print("model hybrid 8")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0237 - mean_absolute_error: 0.1176 - mean_absolute_percentage_error: 30.9664 - root_mean_squared_error: 0.1540
# model hybrid 8
# Mean Square Error: 0.023702967911958694
# Mean Absolute Error: 0.11759013682603836
# Mean Absolute Percentage Error: 30.96636962890625
# Root Mean Squared Error: 0.15395767986774445

# %% [markdown]
# # model 4 layer CNN > LSTM

# %% [markdown]
# ## model 9 (CNN=1024, 512 LSTM=128, 64)

# %%
lr = 0.0003

model_hybrid_9 = Sequential()
model_hybrid_9.add(Conv1D(filters=1024, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_9.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_9.add(LSTM(128, activation='relu', return_sequences=True))
model_hybrid_9.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_9.add(Flatten())
model_hybrid_9.add(Dense(7))
model_hybrid_9.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_9.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_53"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_53 (Conv1D)              │ (None, 7, 1024)        │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_54 (Conv1D)              │ (None, 7, 512)         │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_55 (LSTM)                  │ (None, 7, 128)         │       328,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_56 (LSTM)                  │ (None, 7, 64)          │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_53 (Flatten)            │ (None, 448)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (None, 7)              │         3,143 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 912,711 (3.48 MB)
#  Trainable params: 912,711 (3.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_9.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - loss: 0.2148 - mean_absolute_error: 0.4025 - mean_absolute_percentage_error: 72.4607 - root_mean_squared_error: 0.4553 - val_loss: 0.0625 - val_mean_absolute_error: 0.2081 - val_mean_absolute_percentage_error: 14610588.0000 - val_root_mean_squared_error: 0.2500
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - loss: 0.0287 - mean_absolute_error: 0.1337 - mean_absolute_percentage_error: 33.0033 - root_mean_squared_error: 0.1692 - val_loss: 0.0532 - val_mean_absolute_error: 0.1919 - val_mean_absolute_percentage_error: 14867209.0000 - val_root_mean_squared_error: 0.2306
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.0223 - mean_absolute_error: 0.1165 - mean_absolute_percentage_error: 29.4935 - root_mean_squared_error: 0.1494 - val_loss: 0.0544 - val_mean_absolute_error: 0.1953 - val_mean_absolute_percentage_error: 13861393.0000 - val_root_mean_squared_error: 0.2332
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - loss: 0.0211 - mean_absolute_error: 0.1134 - mean_absolute_percentage_error: 28.6847 - root_mean_squared_error: 0.1453 - val_loss: 0.0524 - val_mean_absolute_error: 0.1939 - val_mean_absolute_percentage_error: 14645473.0000 - val_root_mean_squared_error: 0.2289
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.0210 - mean_absolute_error: 0.1117 - mean_absolute_percentage_error: 28.2255 - root_mean_squared_error: 0.1447 - val_loss: 0.0556 - val_mean_absolute_error: 0.1983 - val_mean_absolute_percentage_error: 13392907.0000 - val_root_mean_squared_error: 0.2359
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.0197 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 27.8296 - root_mean_squared_error: 0.1403 - val_loss: 0.0534 - val_mean_absolute_error: 0.1958 - val_mean_absolute_percentage_error: 14095614.0000 - val_root_mean_squared_error: 0.2311
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - loss: 0.0203 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 27.4183 - root_mean_squared_error: 0.1423 - val_loss: 0.0559 - val_mean_absolute_error: 0.2021 - val_mean_absolute_percentage_error: 13099672.0000 - val_root_mean_squared_error: 0.2365
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - loss: 0.0203 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 28.5853 - root_mean_squared_error: 0.1423 - val_loss: 0.0534 - val_mean_absolute_error: 0.1976 - val_mean_absolute_percentage_error: 14253898.0000 - val_root_mean_squared_error: 0.2310
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0208 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 28.0747 - root_mean_squared_error: 0.1442 - val_loss: 0.0548 - val_mean_absolute_error: 0.1992 - val_mean_absolute_percentage_error: 13858770.0000 - val_root_mean_squared_error: 0.2342
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 0.0193 - mean_absolute_error: 0.1079 - mean_absolute_percentage_error: 28.6684 - root_mean_squared_error: 0.1391 - val_loss: 0.0540 - val_mean_absolute_error: 0.1982 - val_mean_absolute_percentage_error: 14470244.0000 - val_root_mean_squared_error: 0.2323
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0194 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 27.9724 - root_mean_squared_error: 0.1391 - val_loss: 0.0544 - val_mean_absolute_error: 0.1985 - val_mean_absolute_percentage_error: 14608793.0000 - val_root_mean_squared_error: 0.2333
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: 0.0201 - mean_absolute_error: 0.1101 - mean_absolute_percentage_error: 28.4003 - root_mean_squared_error: 0.1418 - val_loss: 0.0538 - val_mean_absolute_error: 0.1972 - val_mean_absolute_percentage_error: 14881047.0000 - val_root_mean_squared_error: 0.2319
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - loss: 0.0208 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 29.5476 - root_mean_squared_error: 0.1441 - val_loss: 0.0582 - val_mean_absolute_error: 0.2042 - val_mean_absolute_percentage_error: 13075369.0000 - val_root_mean_squared_error: 0.2412
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - loss: 0.0196 - mean_absolute_error: 0.1094 - mean_absolute_percentage_error: 28.0189 - root_mean_squared_error: 0.1401 - val_loss: 0.0562 - val_mean_absolute_error: 0.2020 - val_mean_absolute_percentage_error: 13807951.0000 - val_root_mean_squared_error: 0.2370
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - loss: 0.0188 - mean_absolute_error: 0.1062 - mean_absolute_percentage_error: 27.5231 - root_mean_squared_error: 0.1372 - val_loss: 0.0594 - val_mean_absolute_error: 0.2050 - val_mean_absolute_percentage_error: 13163489.0000 - val_root_mean_squared_error: 0.2437
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - loss: 0.0204 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 26.7692 - root_mean_squared_error: 0.1427 - val_loss: 0.0577 - val_mean_absolute_error: 0.2060 - val_mean_absolute_percentage_error: 13868742.0000 - val_root_mean_squared_error: 0.2402
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0209 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 27.7283 - root_mean_squared_error: 0.1446 - val_loss: 0.0555 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 14534577.0000 - val_root_mean_squared_error: 0.2355
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 0.0199 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 28.9681 - root_mean_squared_error: 0.1411 - val_loss: 0.0558 - val_mean_absolute_error: 0.2008 - val_mean_absolute_percentage_error: 14392226.0000 - val_root_mean_squared_error: 0.2362
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 0.0189 - mean_absolute_error: 0.1069 - mean_absolute_percentage_error: 27.4821 - root_mean_squared_error: 0.1375 - val_loss: 0.0584 - val_mean_absolute_error: 0.2056 - val_mean_absolute_percentage_error: 13493918.0000 - val_root_mean_squared_error: 0.2417
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 0.0197 - mean_absolute_error: 0.1089 - mean_absolute_percentage_error: 27.6097 - root_mean_squared_error: 0.1403 - val_loss: 0.0558 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 14459512.0000 - val_root_mean_squared_error: 0.2361

# %%
y_pred = model_hybrid_9.predict(x_test)

evaluation_hybrid_9 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_9
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# {'Mean Squared Error: ': np.float64(351.1029415015795),
#  'Mean Absolute Error: ': np.float64(14.309362645051916),
#  'Root Mean Absolute Error: ': 18.737741099224834,
#  'Mean Absolute Percentage Error: ': np.float64(26.9330533094466)}

# %%
loss, mae, mape, rmse = model_hybrid_9.evaluate(x_test, y_test)
print("model hybrid 9")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0280 - mean_absolute_error: 0.1278 - mean_absolute_percentage_error: 34.3203 - root_mean_squared_error: 0.1673
# model hybrid 9
# Mean Square Error: 0.027989709749817848
# Mean Absolute Error: 0.12776215374469757
# Mean Absolute Percentage Error: 34.320281982421875
# Root Mean Squared Error: 0.1673012524843216

# %% [markdown]
# ## model 10 (CNN=1024, 512 LSTM=128, 128)

# %%
lr = 0.0003

model_hybrid_10 = Sequential()
model_hybrid_10.add(Conv1D(filters=1024, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_10.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_10.add(LSTM(128, activation='relu', return_sequences=True))
model_hybrid_10.add(LSTM(128, activation='relu', return_sequences=True))
model_hybrid_10.add(Flatten())
model_hybrid_10.add(Dense(7))
model_hybrid_10.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_10.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_54"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_55 (Conv1D)              │ (None, 7, 1024)        │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_56 (Conv1D)              │ (None, 7, 512)         │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_57 (LSTM)                  │ (None, 7, 128)         │       328,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_58 (LSTM)                  │ (None, 7, 128)         │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_54 (Flatten)            │ (None, 896)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_54 (Dense)                │ (None, 7)              │         6,279 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 998,023 (3.81 MB)
#  Trainable params: 998,023 (3.81 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_10.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 193ms/step - loss: 0.2380 - mean_absolute_error: 0.4346 - mean_absolute_percentage_error: 78.4062 - root_mean_squared_error: 0.4824 - val_loss: 0.1041 - val_mean_absolute_error: 0.2829 - val_mean_absolute_percentage_error: 9113855.0000 - val_root_mean_squared_error: 0.3227
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 0.0499 - mean_absolute_error: 0.1858 - mean_absolute_percentage_error: 37.8719 - root_mean_squared_error: 0.2218 - val_loss: 0.0604 - val_mean_absolute_error: 0.2045 - val_mean_absolute_percentage_error: 13269165.0000 - val_root_mean_squared_error: 0.2458
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 0.0262 - mean_absolute_error: 0.1288 - mean_absolute_percentage_error: 31.4432 - root_mean_squared_error: 0.1618 - val_loss: 0.0522 - val_mean_absolute_error: 0.1888 - val_mean_absolute_percentage_error: 15054039.0000 - val_root_mean_squared_error: 0.2284
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0225 - mean_absolute_error: 0.1173 - mean_absolute_percentage_error: 30.6002 - root_mean_squared_error: 0.1500 - val_loss: 0.0513 - val_mean_absolute_error: 0.1877 - val_mean_absolute_percentage_error: 15459575.0000 - val_root_mean_squared_error: 0.2265
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - loss: 0.0227 - mean_absolute_error: 0.1177 - mean_absolute_percentage_error: 31.4941 - root_mean_squared_error: 0.1505 - val_loss: 0.0529 - val_mean_absolute_error: 0.1918 - val_mean_absolute_percentage_error: 14777849.0000 - val_root_mean_squared_error: 0.2300
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - loss: 0.0209 - mean_absolute_error: 0.1123 - mean_absolute_percentage_error: 27.9456 - root_mean_squared_error: 0.1446 - val_loss: 0.0543 - val_mean_absolute_error: 0.1950 - val_mean_absolute_percentage_error: 14277964.0000 - val_root_mean_squared_error: 0.2331
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 0.0209 - mean_absolute_error: 0.1133 - mean_absolute_percentage_error: 29.1172 - root_mean_squared_error: 0.1446 - val_loss: 0.0543 - val_mean_absolute_error: 0.1955 - val_mean_absolute_percentage_error: 14328604.0000 - val_root_mean_squared_error: 0.2330
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 0.0204 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 28.8202 - root_mean_squared_error: 0.1428 - val_loss: 0.0542 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 14266165.0000 - val_root_mean_squared_error: 0.2327
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 0.0200 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 28.1080 - root_mean_squared_error: 0.1415 - val_loss: 0.0578 - val_mean_absolute_error: 0.2001 - val_mean_absolute_percentage_error: 13434574.0000 - val_root_mean_squared_error: 0.2405
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0199 - mean_absolute_error: 0.1099 - mean_absolute_percentage_error: 28.3558 - root_mean_squared_error: 0.1412 - val_loss: 0.0554 - val_mean_absolute_error: 0.1983 - val_mean_absolute_percentage_error: 13847405.0000 - val_root_mean_squared_error: 0.2354
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - loss: 0.0193 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 27.4590 - root_mean_squared_error: 0.1388 - val_loss: 0.0551 - val_mean_absolute_error: 0.1987 - val_mean_absolute_percentage_error: 13899926.0000 - val_root_mean_squared_error: 0.2347
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0203 - mean_absolute_error: 0.1115 - mean_absolute_percentage_error: 30.3465 - root_mean_squared_error: 0.1426 - val_loss: 0.0550 - val_mean_absolute_error: 0.1980 - val_mean_absolute_percentage_error: 13958606.0000 - val_root_mean_squared_error: 0.2345
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0195 - mean_absolute_error: 0.1087 - mean_absolute_percentage_error: 27.7772 - root_mean_squared_error: 0.1396 - val_loss: 0.0576 - val_mean_absolute_error: 0.2021 - val_mean_absolute_percentage_error: 13236393.0000 - val_root_mean_squared_error: 0.2400
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0187 - mean_absolute_error: 0.1063 - mean_absolute_percentage_error: 26.7125 - root_mean_squared_error: 0.1369 - val_loss: 0.0545 - val_mean_absolute_error: 0.1951 - val_mean_absolute_percentage_error: 14428320.0000 - val_root_mean_squared_error: 0.2335
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 0.0192 - mean_absolute_error: 0.1080 - mean_absolute_percentage_error: 28.0271 - root_mean_squared_error: 0.1387 - val_loss: 0.0602 - val_mean_absolute_error: 0.2075 - val_mean_absolute_percentage_error: 12748841.0000 - val_root_mean_squared_error: 0.2454
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.0205 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 28.5742 - root_mean_squared_error: 0.1431 - val_loss: 0.0527 - val_mean_absolute_error: 0.1930 - val_mean_absolute_percentage_error: 15207334.0000 - val_root_mean_squared_error: 0.2295
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0195 - mean_absolute_error: 0.1077 - mean_absolute_percentage_error: 28.5660 - root_mean_squared_error: 0.1395 - val_loss: 0.0535 - val_mean_absolute_error: 0.1966 - val_mean_absolute_percentage_error: 14774441.0000 - val_root_mean_squared_error: 0.2314
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0190 - mean_absolute_error: 0.1071 - mean_absolute_percentage_error: 27.8101 - root_mean_squared_error: 0.1377 - val_loss: 0.0544 - val_mean_absolute_error: 0.1948 - val_mean_absolute_percentage_error: 14655998.0000 - val_root_mean_squared_error: 0.2333
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - loss: 0.0189 - mean_absolute_error: 0.1069 - mean_absolute_percentage_error: 27.8235 - root_mean_squared_error: 0.1374 - val_loss: 0.0584 - val_mean_absolute_error: 0.2044 - val_mean_absolute_percentage_error: 13432529.0000 - val_root_mean_squared_error: 0.2416
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 0.0194 - mean_absolute_error: 0.1087 - mean_absolute_percentage_error: 27.8265 - root_mean_squared_error: 0.1394 - val_loss: 0.0583 - val_mean_absolute_error: 0.2048 - val_mean_absolute_percentage_error: 13429910.0000 - val_root_mean_squared_error: 0.2414

# %%
y_pred = model_hybrid_10.predict(x_test)

evaluation_hybrid_10 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_10
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# {'Mean Squared Error: ': np.float64(336.56983218861296),
#  'Mean Absolute Error: ': np.float64(14.560619198546119),
#  'Root Mean Absolute Error: ': 18.345839642507862,
#  'Mean Absolute Percentage Error: ': np.float64(26.094718172552483)}

# %%
loss, mae, mape, rmse = model_hybrid_10.evaluate(x_test, y_test)
print("model hybrid 10")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0268 - mean_absolute_error: 0.1300 - mean_absolute_percentage_error: 32.9690 - root_mean_squared_error: 0.1638
# model hybrid 10
# Mean Square Error: 0.026831140741705894
# Mean Absolute Error: 0.13000552356243134
# Mean Absolute Percentage Error: 32.96895980834961
# Root Mean Squared Error: 0.1638021320104599

# %% [markdown]
# ## model 11 (CNN=1024, 512 LSTM=256, 128)

# %%
lr = 0.0003

model_hybrid_11 = Sequential()
model_hybrid_11.add(Conv1D(filters=1024, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_11.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_11.add(LSTM(256, activation='relu', return_sequences=True))
model_hybrid_11.add(LSTM(128, activation='relu', return_sequences=True))
model_hybrid_11.add(Flatten())
model_hybrid_11.add(Dense(7))
model_hybrid_11.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_11.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_55"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_57 (Conv1D)              │ (None, 7, 1024)        │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_58 (Conv1D)              │ (None, 7, 512)         │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_59 (LSTM)                  │ (None, 7, 256)         │       787,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_60 (LSTM)                  │ (None, 7, 128)         │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_55 (Flatten)            │ (None, 896)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 7)              │         6,279 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,522,823 (5.81 MB)
#  Trainable params: 1,522,823 (5.81 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_11.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - loss: 0.2259 - mean_absolute_error: 0.4162 - mean_absolute_percentage_error: 74.8952 - root_mean_squared_error: 0.4687 - val_loss: 0.0600 - val_mean_absolute_error: 0.2047 - val_mean_absolute_percentage_error: 14503196.0000 - val_root_mean_squared_error: 0.2449
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - loss: 0.0292 - mean_absolute_error: 0.1356 - mean_absolute_percentage_error: 33.5384 - root_mean_squared_error: 0.1708 - val_loss: 0.0507 - val_mean_absolute_error: 0.1869 - val_mean_absolute_percentage_error: 15600011.0000 - val_root_mean_squared_error: 0.2252
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - loss: 0.0219 - mean_absolute_error: 0.1160 - mean_absolute_percentage_error: 29.3830 - root_mean_squared_error: 0.1480 - val_loss: 0.0535 - val_mean_absolute_error: 0.1932 - val_mean_absolute_percentage_error: 14234332.0000 - val_root_mean_squared_error: 0.2313
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 0.0220 - mean_absolute_error: 0.1169 - mean_absolute_percentage_error: 29.6270 - root_mean_squared_error: 0.1483 - val_loss: 0.0520 - val_mean_absolute_error: 0.1923 - val_mean_absolute_percentage_error: 14722933.0000 - val_root_mean_squared_error: 0.2280
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 0.0202 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 29.3201 - root_mean_squared_error: 0.1420 - val_loss: 0.0554 - val_mean_absolute_error: 0.1980 - val_mean_absolute_percentage_error: 13515426.0000 - val_root_mean_squared_error: 0.2353
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 185ms/step - loss: 0.0204 - mean_absolute_error: 0.1119 - mean_absolute_percentage_error: 28.0094 - root_mean_squared_error: 0.1427 - val_loss: 0.0570 - val_mean_absolute_error: 0.2013 - val_mean_absolute_percentage_error: 13035106.0000 - val_root_mean_squared_error: 0.2388
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0197 - mean_absolute_error: 0.1101 - mean_absolute_percentage_error: 27.4362 - root_mean_squared_error: 0.1404 - val_loss: 0.0544 - val_mean_absolute_error: 0.1979 - val_mean_absolute_percentage_error: 13627564.0000 - val_root_mean_squared_error: 0.2332
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 0.0202 - mean_absolute_error: 0.1111 - mean_absolute_percentage_error: 29.3788 - root_mean_squared_error: 0.1420 - val_loss: 0.0531 - val_mean_absolute_error: 0.1954 - val_mean_absolute_percentage_error: 14991127.0000 - val_root_mean_squared_error: 0.2303
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0217 - mean_absolute_error: 0.1157 - mean_absolute_percentage_error: 29.8102 - root_mean_squared_error: 0.1473 - val_loss: 0.0629 - val_mean_absolute_error: 0.2098 - val_mean_absolute_percentage_error: 12145919.0000 - val_root_mean_squared_error: 0.2508
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - loss: 0.0212 - mean_absolute_error: 0.1143 - mean_absolute_percentage_error: 29.2129 - root_mean_squared_error: 0.1457 - val_loss: 0.0539 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 13876793.0000 - val_root_mean_squared_error: 0.2321
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0199 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 27.4041 - root_mean_squared_error: 0.1410 - val_loss: 0.0551 - val_mean_absolute_error: 0.1976 - val_mean_absolute_percentage_error: 13536878.0000 - val_root_mean_squared_error: 0.2347
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - loss: 0.0190 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 27.4729 - root_mean_squared_error: 0.1379 - val_loss: 0.0539 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 13951444.0000 - val_root_mean_squared_error: 0.2321
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0191 - mean_absolute_error: 0.1069 - mean_absolute_percentage_error: 27.4465 - root_mean_squared_error: 0.1382 - val_loss: 0.0578 - val_mean_absolute_error: 0.2030 - val_mean_absolute_percentage_error: 13073318.0000 - val_root_mean_squared_error: 0.2404
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0201 - mean_absolute_error: 0.1099 - mean_absolute_percentage_error: 27.4066 - root_mean_squared_error: 0.1419 - val_loss: 0.0597 - val_mean_absolute_error: 0.2040 - val_mean_absolute_percentage_error: 12895106.0000 - val_root_mean_squared_error: 0.2444
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - loss: 0.0199 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 27.6030 - root_mean_squared_error: 0.1410 - val_loss: 0.0560 - val_mean_absolute_error: 0.2012 - val_mean_absolute_percentage_error: 13972414.0000 - val_root_mean_squared_error: 0.2366
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 0.0182 - mean_absolute_error: 0.1049 - mean_absolute_percentage_error: 25.8210 - root_mean_squared_error: 0.1347 - val_loss: 0.0590 - val_mean_absolute_error: 0.2041 - val_mean_absolute_percentage_error: 13069247.0000 - val_root_mean_squared_error: 0.2428
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - loss: 0.0203 - mean_absolute_error: 0.1118 - mean_absolute_percentage_error: 27.9606 - root_mean_squared_error: 0.1424 - val_loss: 0.0596 - val_mean_absolute_error: 0.2052 - val_mean_absolute_percentage_error: 13288326.0000 - val_root_mean_squared_error: 0.2442
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0202 - mean_absolute_error: 0.1119 - mean_absolute_percentage_error: 28.4784 - root_mean_squared_error: 0.1421 - val_loss: 0.0600 - val_mean_absolute_error: 0.2066 - val_mean_absolute_percentage_error: 13109006.0000 - val_root_mean_squared_error: 0.2449
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - loss: 0.0198 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 27.4971 - root_mean_squared_error: 0.1408 - val_loss: 0.0662 - val_mean_absolute_error: 0.2155 - val_mean_absolute_percentage_error: 12663439.0000 - val_root_mean_squared_error: 0.2573
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - loss: 0.0223 - mean_absolute_error: 0.1186 - mean_absolute_percentage_error: 27.2975 - root_mean_squared_error: 0.1494 - val_loss: 0.0563 - val_mean_absolute_error: 0.2017 - val_mean_absolute_percentage_error: 14811635.0000 - val_root_mean_squared_error: 0.2373

# %%
y_pred = model_hybrid_11.predict(x_test)

evaluation_hybrid_11 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_11
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# {'Mean Squared Error: ': np.float64(357.2811472876997),
#  'Mean Absolute Error: ': np.float64(14.423620379700955),
#  'Root Mean Absolute Error: ': 18.901882109665685,
#  'Mean Absolute Percentage Error: ': np.float64(27.190408651718467)}

# %%
loss, mae, mape, rmse = model_hybrid_11.evaluate(x_test, y_test)
print("model hybrid 11")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0285 - mean_absolute_error: 0.1288 - mean_absolute_percentage_error: 34.6417 - root_mean_squared_error: 0.1688
# model hybrid 11
# Mean Square Error: 0.028482230380177498
# Mean Absolute Error: 0.12878231704235077
# Mean Absolute Percentage Error: 34.641685485839844
# Root Mean Squared Error: 0.1687667965888977

# %% [markdown]
# ## model 12 (CNN=1024, 512 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_12 = Sequential()
model_hybrid_12.add(Conv1D(filters=1024, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_12.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_12.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_12.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_12.add(Flatten())
model_hybrid_12.add(Dense(7))
model_hybrid_12.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_12.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_56"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_59 (Conv1D)              │ (None, 7, 1024)        │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_60 (Conv1D)              │ (None, 7, 512)         │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_61 (LSTM)                  │ (None, 7, 64)          │       147,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_62 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_56 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_56 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 693,671 (2.65 MB)
#  Trainable params: 693,671 (2.65 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_12.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - loss: 0.2561 - mean_absolute_error: 0.4597 - mean_absolute_percentage_error: 82.9061 - root_mean_squared_error: 0.5024 - val_loss: 0.0564 - val_mean_absolute_error: 0.1990 - val_mean_absolute_percentage_error: 14069816.0000 - val_root_mean_squared_error: 0.2376
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0291 - mean_absolute_error: 0.1345 - mean_absolute_percentage_error: 32.2197 - root_mean_squared_error: 0.1706 - val_loss: 0.0523 - val_mean_absolute_error: 0.1916 - val_mean_absolute_percentage_error: 14798101.0000 - val_root_mean_squared_error: 0.2288
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0244 - mean_absolute_error: 0.1246 - mean_absolute_percentage_error: 31.3124 - root_mean_squared_error: 0.1562 - val_loss: 0.0538 - val_mean_absolute_error: 0.1938 - val_mean_absolute_percentage_error: 14398817.0000 - val_root_mean_squared_error: 0.2320
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0225 - mean_absolute_error: 0.1176 - mean_absolute_percentage_error: 30.0491 - root_mean_squared_error: 0.1499 - val_loss: 0.0516 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 14823715.0000 - val_root_mean_squared_error: 0.2272
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - loss: 0.0213 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 29.3541 - root_mean_squared_error: 0.1459 - val_loss: 0.0526 - val_mean_absolute_error: 0.1943 - val_mean_absolute_percentage_error: 14629553.0000 - val_root_mean_squared_error: 0.2293
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0214 - mean_absolute_error: 0.1144 - mean_absolute_percentage_error: 29.1407 - root_mean_squared_error: 0.1463 - val_loss: 0.0521 - val_mean_absolute_error: 0.1933 - val_mean_absolute_percentage_error: 15311933.0000 - val_root_mean_squared_error: 0.2283
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0227 - mean_absolute_error: 0.1192 - mean_absolute_percentage_error: 31.4179 - root_mean_squared_error: 0.1508 - val_loss: 0.0560 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 13744558.0000 - val_root_mean_squared_error: 0.2366
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0203 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 28.4388 - root_mean_squared_error: 0.1426 - val_loss: 0.0528 - val_mean_absolute_error: 0.1950 - val_mean_absolute_percentage_error: 15016256.0000 - val_root_mean_squared_error: 0.2298
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0202 - mean_absolute_error: 0.1106 - mean_absolute_percentage_error: 28.4093 - root_mean_squared_error: 0.1420 - val_loss: 0.0536 - val_mean_absolute_error: 0.1971 - val_mean_absolute_percentage_error: 14763234.0000 - val_root_mean_squared_error: 0.2314
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0213 - mean_absolute_error: 0.1135 - mean_absolute_percentage_error: 30.8789 - root_mean_squared_error: 0.1457 - val_loss: 0.0538 - val_mean_absolute_error: 0.1974 - val_mean_absolute_percentage_error: 14627339.0000 - val_root_mean_squared_error: 0.2320
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - loss: 0.0202 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 30.2516 - root_mean_squared_error: 0.1420 - val_loss: 0.0566 - val_mean_absolute_error: 0.2014 - val_mean_absolute_percentage_error: 13794985.0000 - val_root_mean_squared_error: 0.2378
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0195 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 28.3517 - root_mean_squared_error: 0.1396 - val_loss: 0.0561 - val_mean_absolute_error: 0.2019 - val_mean_absolute_percentage_error: 14379524.0000 - val_root_mean_squared_error: 0.2368
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0185 - mean_absolute_error: 0.1064 - mean_absolute_percentage_error: 28.5556 - root_mean_squared_error: 0.1361 - val_loss: 0.0559 - val_mean_absolute_error: 0.2010 - val_mean_absolute_percentage_error: 14586902.0000 - val_root_mean_squared_error: 0.2364
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0183 - mean_absolute_error: 0.1047 - mean_absolute_percentage_error: 26.3013 - root_mean_squared_error: 0.1353 - val_loss: 0.0567 - val_mean_absolute_error: 0.2021 - val_mean_absolute_percentage_error: 14440090.0000 - val_root_mean_squared_error: 0.2382
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0196 - mean_absolute_error: 0.1093 - mean_absolute_percentage_error: 28.0243 - root_mean_squared_error: 0.1399 - val_loss: 0.0575 - val_mean_absolute_error: 0.2044 - val_mean_absolute_percentage_error: 13735223.0000 - val_root_mean_squared_error: 0.2397
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0190 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 26.5651 - root_mean_squared_error: 0.1378 - val_loss: 0.0580 - val_mean_absolute_error: 0.2042 - val_mean_absolute_percentage_error: 14680118.0000 - val_root_mean_squared_error: 0.2408
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - loss: 0.0182 - mean_absolute_error: 0.1050 - mean_absolute_percentage_error: 25.3078 - root_mean_squared_error: 0.1350 - val_loss: 0.0568 - val_mean_absolute_error: 0.2032 - val_mean_absolute_percentage_error: 14955864.0000 - val_root_mean_squared_error: 0.2383
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0190 - mean_absolute_error: 0.1065 - mean_absolute_percentage_error: 27.5525 - root_mean_squared_error: 0.1379 - val_loss: 0.0562 - val_mean_absolute_error: 0.2006 - val_mean_absolute_percentage_error: 14820010.0000 - val_root_mean_squared_error: 0.2370
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0181 - mean_absolute_error: 0.1046 - mean_absolute_percentage_error: 26.6678 - root_mean_squared_error: 0.1344 - val_loss: 0.0583 - val_mean_absolute_error: 0.2059 - val_mean_absolute_percentage_error: 14719421.0000 - val_root_mean_squared_error: 0.2414
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0179 - mean_absolute_error: 0.1047 - mean_absolute_percentage_error: 26.0648 - root_mean_squared_error: 0.1339 - val_loss: 0.0572 - val_mean_absolute_error: 0.2029 - val_mean_absolute_percentage_error: 14719206.0000 - val_root_mean_squared_error: 0.2392

# %%
y_pred = model_hybrid_12.predict(x_test)

evaluation_hybrid_12 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_12
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# {'Mean Squared Error: ': np.float64(266.5441483777805),
#  'Mean Absolute Error: ': np.float64(12.834602122404137),
#  'Root Mean Absolute Error: ': 16.32617984642398,
#  'Mean Absolute Percentage Error: ': np.float64(23.03219316799609)}

# %%
loss, mae, mape, rmse = model_hybrid_12.evaluate(x_test, y_test)
print("model hybrid 12")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0212 - mean_absolute_error: 0.1146 - mean_absolute_percentage_error: 29.1675 - root_mean_squared_error: 0.1458
# model hybrid 12
# Mean Square Error: 0.02124873362481594
# Mean Absolute Error: 0.11459465324878693
# Mean Absolute Percentage Error: 29.167478561401367
# Root Mean Squared Error: 0.14576944708824158

# %% [markdown]
# ## model 13 (CNN=1024, 512 LSTM=32, 64)

# %%
lr = 0.0003

model_hybrid_13 = Sequential()
model_hybrid_13.add(Conv1D(filters=1024, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_13.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_13.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_13.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_13.add(Flatten())
model_hybrid_13.add(Dense(7))
model_hybrid_13.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_13.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_57"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_61 (Conv1D)              │ (None, 7, 1024)        │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_62 (Conv1D)              │ (None, 7, 512)         │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_63 (LSTM)                  │ (None, 7, 32)          │        69,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_64 (LSTM)                  │ (None, 7, 64)          │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_57 (Flatten)            │ (None, 448)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 7)              │         3,143 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 629,703 (2.40 MB)
#  Trainable params: 629,703 (2.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_13.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 194ms/step - loss: 0.2342 - mean_absolute_error: 0.4311 - mean_absolute_percentage_error: 77.4188 - root_mean_squared_error: 0.4786 - val_loss: 0.0759 - val_mean_absolute_error: 0.2308 - val_mean_absolute_percentage_error: 11887797.0000 - val_root_mean_squared_error: 0.2754
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0367 - mean_absolute_error: 0.1547 - mean_absolute_percentage_error: 34.1553 - root_mean_squared_error: 0.1910 - val_loss: 0.0540 - val_mean_absolute_error: 0.1922 - val_mean_absolute_percentage_error: 15092725.0000 - val_root_mean_squared_error: 0.2324
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0231 - mean_absolute_error: 0.1188 - mean_absolute_percentage_error: 30.5126 - root_mean_squared_error: 0.1520 - val_loss: 0.0521 - val_mean_absolute_error: 0.1894 - val_mean_absolute_percentage_error: 14771529.0000 - val_root_mean_squared_error: 0.2282
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0217 - mean_absolute_error: 0.1148 - mean_absolute_percentage_error: 29.8332 - root_mean_squared_error: 0.1474 - val_loss: 0.0513 - val_mean_absolute_error: 0.1903 - val_mean_absolute_percentage_error: 14951775.0000 - val_root_mean_squared_error: 0.2264
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 0.0211 - mean_absolute_error: 0.1129 - mean_absolute_percentage_error: 29.8060 - root_mean_squared_error: 0.1451 - val_loss: 0.0533 - val_mean_absolute_error: 0.1940 - val_mean_absolute_percentage_error: 14246356.0000 - val_root_mean_squared_error: 0.2309
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 0.0218 - mean_absolute_error: 0.1151 - mean_absolute_percentage_error: 29.8428 - root_mean_squared_error: 0.1476 - val_loss: 0.0520 - val_mean_absolute_error: 0.1924 - val_mean_absolute_percentage_error: 14723964.0000 - val_root_mean_squared_error: 0.2281
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0196 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 26.8197 - root_mean_squared_error: 0.1400 - val_loss: 0.0542 - val_mean_absolute_error: 0.1973 - val_mean_absolute_percentage_error: 13991586.0000 - val_root_mean_squared_error: 0.2329
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0202 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 27.2585 - root_mean_squared_error: 0.1420 - val_loss: 0.0554 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 13751343.0000 - val_root_mean_squared_error: 0.2353
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0198 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 27.5835 - root_mean_squared_error: 0.1408 - val_loss: 0.0556 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 14029885.0000 - val_root_mean_squared_error: 0.2357
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0185 - mean_absolute_error: 0.1065 - mean_absolute_percentage_error: 27.5678 - root_mean_squared_error: 0.1361 - val_loss: 0.0559 - val_mean_absolute_error: 0.2017 - val_mean_absolute_percentage_error: 14091347.0000 - val_root_mean_squared_error: 0.2364
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0193 - mean_absolute_error: 0.1087 - mean_absolute_percentage_error: 28.8206 - root_mean_squared_error: 0.1389 - val_loss: 0.0541 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 15037094.0000 - val_root_mean_squared_error: 0.2326
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.0205 - mean_absolute_error: 0.1113 - mean_absolute_percentage_error: 29.1585 - root_mean_squared_error: 0.1431 - val_loss: 0.0545 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 15470390.0000 - val_root_mean_squared_error: 0.2336
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0195 - mean_absolute_error: 0.1085 - mean_absolute_percentage_error: 27.3981 - root_mean_squared_error: 0.1395 - val_loss: 0.0541 - val_mean_absolute_error: 0.1958 - val_mean_absolute_percentage_error: 15726647.0000 - val_root_mean_squared_error: 0.2326
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0191 - mean_absolute_error: 0.1080 - mean_absolute_percentage_error: 27.6236 - root_mean_squared_error: 0.1383 - val_loss: 0.0556 - val_mean_absolute_error: 0.2009 - val_mean_absolute_percentage_error: 15246289.0000 - val_root_mean_squared_error: 0.2358
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0187 - mean_absolute_error: 0.1063 - mean_absolute_percentage_error: 27.5895 - root_mean_squared_error: 0.1366 - val_loss: 0.0596 - val_mean_absolute_error: 0.2085 - val_mean_absolute_percentage_error: 14027626.0000 - val_root_mean_squared_error: 0.2441
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0190 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 27.3777 - root_mean_squared_error: 0.1379 - val_loss: 0.0591 - val_mean_absolute_error: 0.2077 - val_mean_absolute_percentage_error: 14523274.0000 - val_root_mean_squared_error: 0.2430
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0196 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 28.6538 - root_mean_squared_error: 0.1401 - val_loss: 0.0548 - val_mean_absolute_error: 0.1983 - val_mean_absolute_percentage_error: 15611206.0000 - val_root_mean_squared_error: 0.2341
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0189 - mean_absolute_error: 0.1067 - mean_absolute_percentage_error: 27.5019 - root_mean_squared_error: 0.1373 - val_loss: 0.0579 - val_mean_absolute_error: 0.2049 - val_mean_absolute_percentage_error: 15016614.0000 - val_root_mean_squared_error: 0.2406
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0181 - mean_absolute_error: 0.1041 - mean_absolute_percentage_error: 26.6658 - root_mean_squared_error: 0.1344 - val_loss: 0.0575 - val_mean_absolute_error: 0.2035 - val_mean_absolute_percentage_error: 15435417.0000 - val_root_mean_squared_error: 0.2397
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0179 - mean_absolute_error: 0.1048 - mean_absolute_percentage_error: 28.2294 - root_mean_squared_error: 0.1338 - val_loss: 0.0559 - val_mean_absolute_error: 0.2001 - val_mean_absolute_percentage_error: 15228875.0000 - val_root_mean_squared_error: 0.2365

# %%
y_pred = model_hybrid_13.predict(x_test)

evaluation_hybrid_13 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_13
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# {'Mean Squared Error: ': np.float64(288.4177258759487),
#  'Mean Absolute Error: ': np.float64(13.257998252401546),
#  'Root Mean Absolute Error: ': 16.982865655593837,
#  'Mean Absolute Percentage Error: ': np.float64(24.435759835557473)}

# %%
loss, mae, mape, rmse = model_hybrid_13.evaluate(x_test, y_test)
print("model hybrid 13")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0230 - mean_absolute_error: 0.1184 - mean_absolute_percentage_error: 31.0755 - root_mean_squared_error: 0.1516
# model hybrid 13
# Mean Square Error: 0.022992482408881187
# Mean Absolute Error: 0.11837499588727951
# Mean Absolute Percentage Error: 31.075515747070312
# Root Mean Squared Error: 0.15163272619247437

# %% [markdown]
# ## model 14 (CNN=1024, 512 LSTM=64, 128)

# %%
lr = 0.0003

model_hybrid_14 = Sequential()
model_hybrid_14.add(Conv1D(filters=1024, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_14.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_14.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_14.add(LSTM(128, activation='relu', return_sequences=True))
model_hybrid_14.add(Flatten())
model_hybrid_14.add(Dense(7))
model_hybrid_14.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_14.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_58"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_63 (Conv1D)              │ (None, 7, 1024)        │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_64 (Conv1D)              │ (None, 7, 512)         │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_65 (LSTM)                  │ (None, 7, 64)          │       147,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_66 (LSTM)                  │ (None, 7, 128)         │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_58 (Flatten)            │ (None, 896)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_58 (Dense)                │ (None, 7)              │         6,279 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 784,775 (2.99 MB)
#  Trainable params: 784,775 (2.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_14.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 195ms/step - loss: 0.2204 - mean_absolute_error: 0.4107 - mean_absolute_percentage_error: 74.6147 - root_mean_squared_error: 0.4626 - val_loss: 0.0661 - val_mean_absolute_error: 0.2177 - val_mean_absolute_percentage_error: 12951584.0000 - val_root_mean_squared_error: 0.2570
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0292 - mean_absolute_error: 0.1340 - mean_absolute_percentage_error: 32.1113 - root_mean_squared_error: 0.1706 - val_loss: 0.0523 - val_mean_absolute_error: 0.1900 - val_mean_absolute_percentage_error: 15297116.0000 - val_root_mean_squared_error: 0.2286
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0221 - mean_absolute_error: 0.1167 - mean_absolute_percentage_error: 29.4476 - root_mean_squared_error: 0.1486 - val_loss: 0.0530 - val_mean_absolute_error: 0.1918 - val_mean_absolute_percentage_error: 14666424.0000 - val_root_mean_squared_error: 0.2303
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0222 - mean_absolute_error: 0.1171 - mean_absolute_percentage_error: 28.8154 - root_mean_squared_error: 0.1490 - val_loss: 0.0535 - val_mean_absolute_error: 0.1949 - val_mean_absolute_percentage_error: 14269246.0000 - val_root_mean_squared_error: 0.2312
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0216 - mean_absolute_error: 0.1143 - mean_absolute_percentage_error: 30.2997 - root_mean_squared_error: 0.1471 - val_loss: 0.0547 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 13955005.0000 - val_root_mean_squared_error: 0.2339
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: 0.0197 - mean_absolute_error: 0.1094 - mean_absolute_percentage_error: 26.7709 - root_mean_squared_error: 0.1403 - val_loss: 0.0594 - val_mean_absolute_error: 0.2049 - val_mean_absolute_percentage_error: 12879222.0000 - val_root_mean_squared_error: 0.2437
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0213 - mean_absolute_error: 0.1149 - mean_absolute_percentage_error: 27.4744 - root_mean_squared_error: 0.1458 - val_loss: 0.0542 - val_mean_absolute_error: 0.1973 - val_mean_absolute_percentage_error: 14234470.0000 - val_root_mean_squared_error: 0.2329
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.0212 - mean_absolute_error: 0.1139 - mean_absolute_percentage_error: 30.7445 - root_mean_squared_error: 0.1457 - val_loss: 0.0537 - val_mean_absolute_error: 0.1961 - val_mean_absolute_percentage_error: 14576941.0000 - val_root_mean_squared_error: 0.2318
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0205 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 29.4335 - root_mean_squared_error: 0.1433 - val_loss: 0.0555 - val_mean_absolute_error: 0.1994 - val_mean_absolute_percentage_error: 13828702.0000 - val_root_mean_squared_error: 0.2357
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0192 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 27.3542 - root_mean_squared_error: 0.1386 - val_loss: 0.0601 - val_mean_absolute_error: 0.2057 - val_mean_absolute_percentage_error: 13037955.0000 - val_root_mean_squared_error: 0.2452
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0215 - mean_absolute_error: 0.1155 - mean_absolute_percentage_error: 27.6437 - root_mean_squared_error: 0.1467 - val_loss: 0.0632 - val_mean_absolute_error: 0.2101 - val_mean_absolute_percentage_error: 12592044.0000 - val_root_mean_squared_error: 0.2514
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0213 - mean_absolute_error: 0.1166 - mean_absolute_percentage_error: 27.0452 - root_mean_squared_error: 0.1460 - val_loss: 0.0571 - val_mean_absolute_error: 0.2011 - val_mean_absolute_percentage_error: 13684801.0000 - val_root_mean_squared_error: 0.2390
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0197 - mean_absolute_error: 0.1098 - mean_absolute_percentage_error: 27.3873 - root_mean_squared_error: 0.1402 - val_loss: 0.0529 - val_mean_absolute_error: 0.1943 - val_mean_absolute_percentage_error: 15113747.0000 - val_root_mean_squared_error: 0.2300
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0195 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 27.4144 - root_mean_squared_error: 0.1394 - val_loss: 0.0596 - val_mean_absolute_error: 0.2053 - val_mean_absolute_percentage_error: 13477287.0000 - val_root_mean_squared_error: 0.2442
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0191 - mean_absolute_error: 0.1071 - mean_absolute_percentage_error: 27.1736 - root_mean_squared_error: 0.1382 - val_loss: 0.0558 - val_mean_absolute_error: 0.1993 - val_mean_absolute_percentage_error: 14695478.0000 - val_root_mean_squared_error: 0.2363
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0180 - mean_absolute_error: 0.1047 - mean_absolute_percentage_error: 27.6754 - root_mean_squared_error: 0.1341 - val_loss: 0.0619 - val_mean_absolute_error: 0.2085 - val_mean_absolute_percentage_error: 13692260.0000 - val_root_mean_squared_error: 0.2487
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - loss: 0.0197 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 27.3260 - root_mean_squared_error: 0.1403 - val_loss: 0.0602 - val_mean_absolute_error: 0.2077 - val_mean_absolute_percentage_error: 13525163.0000 - val_root_mean_squared_error: 0.2454
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0204 - mean_absolute_error: 0.1117 - mean_absolute_percentage_error: 27.5907 - root_mean_squared_error: 0.1428 - val_loss: 0.0628 - val_mean_absolute_error: 0.2115 - val_mean_absolute_percentage_error: 13972486.0000 - val_root_mean_squared_error: 0.2506
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0187 - mean_absolute_error: 0.1067 - mean_absolute_percentage_error: 25.8222 - root_mean_squared_error: 0.1368 - val_loss: 0.0578 - val_mean_absolute_error: 0.2041 - val_mean_absolute_percentage_error: 14713638.0000 - val_root_mean_squared_error: 0.2404
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0188 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 26.5495 - root_mean_squared_error: 0.1370 - val_loss: 0.0610 - val_mean_absolute_error: 0.2101 - val_mean_absolute_percentage_error: 14232195.0000 - val_root_mean_squared_error: 0.2470

# %%
y_pred = model_hybrid_14.predict(x_test)

evaluation_hybrid_14 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_14
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# {'Mean Squared Error: ': np.float64(286.74235388195257),
#  'Mean Absolute Error: ': np.float64(13.61697397426683),
#  'Root Mean Absolute Error: ': 16.933468453980495,
#  'Mean Absolute Percentage Error: ': np.float64(23.53350241163923)}

# %%
loss, mae, mape, rmse = model_hybrid_14.evaluate(x_test, y_test)
print("model hybrid 14")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0229 - mean_absolute_error: 0.1216 - mean_absolute_percentage_error: 29.5631 - root_mean_squared_error: 0.1512
# model hybrid 14
# Mean Square Error: 0.02285892330110073
# Mean Absolute Error: 0.12158012390136719
# Mean Absolute Percentage Error: 29.563093185424805
# Root Mean Squared Error: 0.15119168162345886

# %% [markdown]
# # Model 3 layer CNN > LSTM

# %% [markdown]
# ## model 15 (CNN=16 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_15 = Sequential()
model_hybrid_15.add(Conv1D(filters=16, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_15.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_15.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_15.add(Flatten())
model_hybrid_15.add(Dense(7))
model_hybrid_15.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_15.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_59"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_65 (Conv1D)              │ (None, 7, 16)          │           112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_67 (LSTM)                  │ (None, 7, 64)          │        20,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_68 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_59 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_59 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,839 (136.09 KB)
#  Trainable params: 34,839 (136.09 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_15.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 0.2858 - mean_absolute_error: 0.5041 - mean_absolute_percentage_error: 90.9135 - root_mean_squared_error: 0.5344 - val_loss: 0.1560 - val_mean_absolute_error: 0.3515 - val_mean_absolute_percentage_error: 6017825.0000 - val_root_mean_squared_error: 0.3950
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0849 - mean_absolute_error: 0.2424 - mean_absolute_percentage_error: 45.7056 - root_mean_squared_error: 0.2889 - val_loss: 0.0534 - val_mean_absolute_error: 0.2012 - val_mean_absolute_percentage_error: 13307236.0000 - val_root_mean_squared_error: 0.2310
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0282 - mean_absolute_error: 0.1382 - mean_absolute_percentage_error: 29.0797 - root_mean_squared_error: 0.1679 - val_loss: 0.0519 - val_mean_absolute_error: 0.1921 - val_mean_absolute_percentage_error: 14961973.0000 - val_root_mean_squared_error: 0.2279
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0276 - mean_absolute_error: 0.1285 - mean_absolute_percentage_error: 34.3634 - root_mean_squared_error: 0.1660 - val_loss: 0.0504 - val_mean_absolute_error: 0.1906 - val_mean_absolute_percentage_error: 14605214.0000 - val_root_mean_squared_error: 0.2245
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0240 - mean_absolute_error: 0.1220 - mean_absolute_percentage_error: 31.2931 - root_mean_squared_error: 0.1549 - val_loss: 0.0502 - val_mean_absolute_error: 0.1891 - val_mean_absolute_percentage_error: 14819231.0000 - val_root_mean_squared_error: 0.2241
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0225 - mean_absolute_error: 0.1178 - mean_absolute_percentage_error: 30.3548 - root_mean_squared_error: 0.1498 - val_loss: 0.0498 - val_mean_absolute_error: 0.1870 - val_mean_absolute_percentage_error: 15276232.0000 - val_root_mean_squared_error: 0.2232
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0231 - mean_absolute_error: 0.1193 - mean_absolute_percentage_error: 32.6981 - root_mean_squared_error: 0.1519 - val_loss: 0.0500 - val_mean_absolute_error: 0.1870 - val_mean_absolute_percentage_error: 15302221.0000 - val_root_mean_squared_error: 0.2236
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0225 - mean_absolute_error: 0.1159 - mean_absolute_percentage_error: 30.9235 - root_mean_squared_error: 0.1498 - val_loss: 0.0517 - val_mean_absolute_error: 0.1896 - val_mean_absolute_percentage_error: 14635868.0000 - val_root_mean_squared_error: 0.2273
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0217 - mean_absolute_error: 0.1148 - mean_absolute_percentage_error: 30.6215 - root_mean_squared_error: 0.1472 - val_loss: 0.0521 - val_mean_absolute_error: 0.1899 - val_mean_absolute_percentage_error: 14590088.0000 - val_root_mean_squared_error: 0.2282
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0210 - mean_absolute_error: 0.1133 - mean_absolute_percentage_error: 28.1480 - root_mean_squared_error: 0.1449 - val_loss: 0.0513 - val_mean_absolute_error: 0.1896 - val_mean_absolute_percentage_error: 14748425.0000 - val_root_mean_squared_error: 0.2266
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0211 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 29.1767 - root_mean_squared_error: 0.1452 - val_loss: 0.0528 - val_mean_absolute_error: 0.1926 - val_mean_absolute_percentage_error: 14147139.0000 - val_root_mean_squared_error: 0.2298
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0217 - mean_absolute_error: 0.1154 - mean_absolute_percentage_error: 29.6855 - root_mean_squared_error: 0.1472 - val_loss: 0.0556 - val_mean_absolute_error: 0.1987 - val_mean_absolute_percentage_error: 13167331.0000 - val_root_mean_squared_error: 0.2358
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0208 - mean_absolute_error: 0.1127 - mean_absolute_percentage_error: 27.7927 - root_mean_squared_error: 0.1442 - val_loss: 0.0551 - val_mean_absolute_error: 0.1939 - val_mean_absolute_percentage_error: 14132422.0000 - val_root_mean_squared_error: 0.2347
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0214 - mean_absolute_error: 0.1138 - mean_absolute_percentage_error: 30.0362 - root_mean_squared_error: 0.1463 - val_loss: 0.0530 - val_mean_absolute_error: 0.1918 - val_mean_absolute_percentage_error: 14563640.0000 - val_root_mean_squared_error: 0.2302
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0210 - mean_absolute_error: 0.1129 - mean_absolute_percentage_error: 27.9298 - root_mean_squared_error: 0.1449 - val_loss: 0.0540 - val_mean_absolute_error: 0.1952 - val_mean_absolute_percentage_error: 13777389.0000 - val_root_mean_squared_error: 0.2324
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0200 - mean_absolute_error: 0.1096 - mean_absolute_percentage_error: 27.4728 - root_mean_squared_error: 0.1412 - val_loss: 0.0543 - val_mean_absolute_error: 0.1954 - val_mean_absolute_percentage_error: 13841486.0000 - val_root_mean_squared_error: 0.2330
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0203 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 28.3871 - root_mean_squared_error: 0.1426 - val_loss: 0.0551 - val_mean_absolute_error: 0.1966 - val_mean_absolute_percentage_error: 13477262.0000 - val_root_mean_squared_error: 0.2347
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0227 - mean_absolute_error: 0.1183 - mean_absolute_percentage_error: 32.3932 - root_mean_squared_error: 0.1504 - val_loss: 0.0560 - val_mean_absolute_error: 0.1983 - val_mean_absolute_percentage_error: 13292366.0000 - val_root_mean_squared_error: 0.2367
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0213 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 29.0908 - root_mean_squared_error: 0.1458 - val_loss: 0.0533 - val_mean_absolute_error: 0.1930 - val_mean_absolute_percentage_error: 14380925.0000 - val_root_mean_squared_error: 0.2308
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0205 - mean_absolute_error: 0.1111 - mean_absolute_percentage_error: 27.9372 - root_mean_squared_error: 0.1431 - val_loss: 0.0528 - val_mean_absolute_error: 0.1939 - val_mean_absolute_percentage_error: 14330343.0000 - val_root_mean_squared_error: 0.2297

# %%
y_pred = model_hybrid_15.predict(x_test)

evaluation_hybrid_15 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_15
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# {'Mean Squared Error: ': np.float64(353.5128758538434),
#  'Mean Absolute Error: ': np.float64(14.94358101669623),
#  'Root Mean Absolute Error: ': 18.80193808770371,
#  'Mean Absolute Percentage Error: ': np.float64(27.13061628263254)}

# %%
loss, mae, mape, rmse = model_hybrid_15.evaluate(x_test, y_test)
print("model hybrid 15")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0282 - mean_absolute_error: 0.1334 - mean_absolute_percentage_error: 34.3193 - root_mean_squared_error: 0.1679
# model hybrid 15
# Mean Square Error: 0.028181826695799828
# Mean Absolute Error: 0.13342483341693878
# Mean Absolute Percentage Error: 34.31930923461914
# Root Mean Squared Error: 0.16787444055080414

# %% [markdown]
# ## model 16 (CNN=32 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_16 = Sequential()
model_hybrid_16.add(Conv1D(filters=32, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_16.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_16.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_16.add(Flatten())
model_hybrid_16.add(Dense(7))
model_hybrid_16.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_16.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_60"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_66 (Conv1D)              │ (None, 7, 32)          │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_69 (LSTM)                  │ (None, 7, 64)          │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_70 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_60 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_60 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 39,047 (152.53 KB)
#  Trainable params: 39,047 (152.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_16.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - loss: 0.3133 - mean_absolute_error: 0.5300 - mean_absolute_percentage_error: 95.6103 - root_mean_squared_error: 0.5596 - val_loss: 0.2266 - val_mean_absolute_error: 0.4352 - val_mean_absolute_percentage_error: 4239079.0000 - val_root_mean_squared_error: 0.4760
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1321 - mean_absolute_error: 0.3140 - mean_absolute_percentage_error: 56.8090 - root_mean_squared_error: 0.3602 - val_loss: 0.0576 - val_mean_absolute_error: 0.1944 - val_mean_absolute_percentage_error: 14687711.0000 - val_root_mean_squared_error: 0.2400
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0311 - mean_absolute_error: 0.1445 - mean_absolute_percentage_error: 30.8400 - root_mean_squared_error: 0.1762 - val_loss: 0.0484 - val_mean_absolute_error: 0.1775 - val_mean_absolute_percentage_error: 16216994.0000 - val_root_mean_squared_error: 0.2201
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0252 - mean_absolute_error: 0.1250 - mean_absolute_percentage_error: 33.8983 - root_mean_squared_error: 0.1586 - val_loss: 0.0487 - val_mean_absolute_error: 0.1806 - val_mean_absolute_percentage_error: 15125567.0000 - val_root_mean_squared_error: 0.2207
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0239 - mean_absolute_error: 0.1223 - mean_absolute_percentage_error: 31.6255 - root_mean_squared_error: 0.1545 - val_loss: 0.0491 - val_mean_absolute_error: 0.1814 - val_mean_absolute_percentage_error: 14893193.0000 - val_root_mean_squared_error: 0.2216
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0220 - mean_absolute_error: 0.1172 - mean_absolute_percentage_error: 30.9034 - root_mean_squared_error: 0.1483 - val_loss: 0.0489 - val_mean_absolute_error: 0.1826 - val_mean_absolute_percentage_error: 14933365.0000 - val_root_mean_squared_error: 0.2211
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0212 - mean_absolute_error: 0.1147 - mean_absolute_percentage_error: 28.6763 - root_mean_squared_error: 0.1456 - val_loss: 0.0520 - val_mean_absolute_error: 0.1862 - val_mean_absolute_percentage_error: 14151375.0000 - val_root_mean_squared_error: 0.2281
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0208 - mean_absolute_error: 0.1140 - mean_absolute_percentage_error: 27.5249 - root_mean_squared_error: 0.1441 - val_loss: 0.0516 - val_mean_absolute_error: 0.1871 - val_mean_absolute_percentage_error: 14208342.0000 - val_root_mean_squared_error: 0.2272
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0205 - mean_absolute_error: 0.1133 - mean_absolute_percentage_error: 27.6731 - root_mean_squared_error: 0.1432 - val_loss: 0.0518 - val_mean_absolute_error: 0.1880 - val_mean_absolute_percentage_error: 14211602.0000 - val_root_mean_squared_error: 0.2276
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0200 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 27.0221 - root_mean_squared_error: 0.1412 - val_loss: 0.0513 - val_mean_absolute_error: 0.1887 - val_mean_absolute_percentage_error: 14365993.0000 - val_root_mean_squared_error: 0.2264
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0212 - mean_absolute_error: 0.1124 - mean_absolute_percentage_error: 29.7812 - root_mean_squared_error: 0.1454 - val_loss: 0.0519 - val_mean_absolute_error: 0.1913 - val_mean_absolute_percentage_error: 14195078.0000 - val_root_mean_squared_error: 0.2279
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0215 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 30.6850 - root_mean_squared_error: 0.1468 - val_loss: 0.0539 - val_mean_absolute_error: 0.1933 - val_mean_absolute_percentage_error: 13737249.0000 - val_root_mean_squared_error: 0.2322
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0209 - mean_absolute_error: 0.1132 - mean_absolute_percentage_error: 28.6955 - root_mean_squared_error: 0.1443 - val_loss: 0.0553 - val_mean_absolute_error: 0.1956 - val_mean_absolute_percentage_error: 13397431.0000 - val_root_mean_squared_error: 0.2352
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0204 - mean_absolute_error: 0.1120 - mean_absolute_percentage_error: 28.1220 - root_mean_squared_error: 0.1427 - val_loss: 0.0556 - val_mean_absolute_error: 0.1962 - val_mean_absolute_percentage_error: 13423842.0000 - val_root_mean_squared_error: 0.2357
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0197 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 27.4779 - root_mean_squared_error: 0.1401 - val_loss: 0.0539 - val_mean_absolute_error: 0.1945 - val_mean_absolute_percentage_error: 13863116.0000 - val_root_mean_squared_error: 0.2321
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0198 - mean_absolute_error: 0.1096 - mean_absolute_percentage_error: 28.2461 - root_mean_squared_error: 0.1407 - val_loss: 0.0531 - val_mean_absolute_error: 0.1935 - val_mean_absolute_percentage_error: 14158345.0000 - val_root_mean_squared_error: 0.2305
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0191 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 27.6885 - root_mean_squared_error: 0.1382 - val_loss: 0.0544 - val_mean_absolute_error: 0.1961 - val_mean_absolute_percentage_error: 13850126.0000 - val_root_mean_squared_error: 0.2333
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0194 - mean_absolute_error: 0.1092 - mean_absolute_percentage_error: 26.6309 - root_mean_squared_error: 0.1394 - val_loss: 0.0570 - val_mean_absolute_error: 0.1992 - val_mean_absolute_percentage_error: 13402623.0000 - val_root_mean_squared_error: 0.2387
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0194 - mean_absolute_error: 0.1085 - mean_absolute_percentage_error: 27.4538 - root_mean_squared_error: 0.1393 - val_loss: 0.0544 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 14009373.0000 - val_root_mean_squared_error: 0.2332
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0181 - mean_absolute_error: 0.1055 - mean_absolute_percentage_error: 25.9802 - root_mean_squared_error: 0.1344 - val_loss: 0.0560 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 13633310.0000 - val_root_mean_squared_error: 0.2367

# %%
y_pred = model_hybrid_16.predict(x_test)

evaluation_hybrid_16 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_16
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# {'Mean Squared Error: ': np.float64(351.9614834178192),
#  'Mean Absolute Error: ': np.float64(14.976647630029797),
#  'Root Mean Absolute Error: ': 18.76063654084848,
#  'Mean Absolute Percentage Error: ': np.float64(26.773198328737035)}

# %%
loss, mae, mape, rmse = model_hybrid_16.evaluate(x_test, y_test)
print("model hybrid 16")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0281 - mean_absolute_error: 0.1337 - mean_absolute_percentage_error: 33.7933 - root_mean_squared_error: 0.1675
# model hybrid 16
# Mean Square Error: 0.02805815264582634
# Mean Absolute Error: 0.13372007012367249
# Mean Absolute Percentage Error: 33.79328155517578
# Root Mean Squared Error: 0.16750568151474

# %% [markdown]
# ## model 17 (CNN=64 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_17 = Sequential()
model_hybrid_17.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_17.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_17.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_17.add(Flatten())
model_hybrid_17.add(Dense(7))
model_hybrid_17.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_17.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_61"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_67 (Conv1D)              │ (None, 7, 64)          │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_71 (LSTM)                  │ (None, 7, 64)          │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_72 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_61 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_61 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 47,463 (185.40 KB)
#  Trainable params: 47,463 (185.40 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_17.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.3371 - mean_absolute_error: 0.5533 - mean_absolute_percentage_error: 97.9648 - root_mean_squared_error: 0.5805 - val_loss: 0.2556 - val_mean_absolute_error: 0.4610 - val_mean_absolute_percentage_error: 2744159.0000 - val_root_mean_squared_error: 0.5056
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1800 - mean_absolute_error: 0.3760 - mean_absolute_percentage_error: 65.6055 - root_mean_squared_error: 0.4214 - val_loss: 0.0708 - val_mean_absolute_error: 0.2165 - val_mean_absolute_percentage_error: 15684413.0000 - val_root_mean_squared_error: 0.2661
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0330 - mean_absolute_error: 0.1411 - mean_absolute_percentage_error: 33.7478 - root_mean_squared_error: 0.1810 - val_loss: 0.0531 - val_mean_absolute_error: 0.1917 - val_mean_absolute_percentage_error: 15181515.0000 - val_root_mean_squared_error: 0.2305
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0264 - mean_absolute_error: 0.1270 - mean_absolute_percentage_error: 32.6030 - root_mean_squared_error: 0.1623 - val_loss: 0.0515 - val_mean_absolute_error: 0.1900 - val_mean_absolute_percentage_error: 14406690.0000 - val_root_mean_squared_error: 0.2270
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0224 - mean_absolute_error: 0.1183 - mean_absolute_percentage_error: 29.3725 - root_mean_squared_error: 0.1498 - val_loss: 0.0526 - val_mean_absolute_error: 0.1909 - val_mean_absolute_percentage_error: 14109466.0000 - val_root_mean_squared_error: 0.2294
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0227 - mean_absolute_error: 0.1191 - mean_absolute_percentage_error: 31.2123 - root_mean_squared_error: 0.1508 - val_loss: 0.0541 - val_mean_absolute_error: 0.1937 - val_mean_absolute_percentage_error: 13751400.0000 - val_root_mean_squared_error: 0.2326
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0221 - mean_absolute_error: 0.1169 - mean_absolute_percentage_error: 29.6406 - root_mean_squared_error: 0.1486 - val_loss: 0.0551 - val_mean_absolute_error: 0.1956 - val_mean_absolute_percentage_error: 13600981.0000 - val_root_mean_squared_error: 0.2347
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0221 - mean_absolute_error: 0.1167 - mean_absolute_percentage_error: 30.2039 - root_mean_squared_error: 0.1486 - val_loss: 0.0555 - val_mean_absolute_error: 0.1969 - val_mean_absolute_percentage_error: 13489100.0000 - val_root_mean_squared_error: 0.2357
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0212 - mean_absolute_error: 0.1149 - mean_absolute_percentage_error: 28.1988 - root_mean_squared_error: 0.1457 - val_loss: 0.0548 - val_mean_absolute_error: 0.1969 - val_mean_absolute_percentage_error: 13633740.0000 - val_root_mean_squared_error: 0.2342
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0203 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 27.6130 - root_mean_squared_error: 0.1424 - val_loss: 0.0556 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 13455247.0000 - val_root_mean_squared_error: 0.2358
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0209 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 28.7087 - root_mean_squared_error: 0.1447 - val_loss: 0.0545 - val_mean_absolute_error: 0.1972 - val_mean_absolute_percentage_error: 13827801.0000 - val_root_mean_squared_error: 0.2335
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0215 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 31.9794 - root_mean_squared_error: 0.1466 - val_loss: 0.0544 - val_mean_absolute_error: 0.1978 - val_mean_absolute_percentage_error: 13899670.0000 - val_root_mean_squared_error: 0.2332
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0200 - mean_absolute_error: 0.1099 - mean_absolute_percentage_error: 28.3466 - root_mean_squared_error: 0.1414 - val_loss: 0.0554 - val_mean_absolute_error: 0.1978 - val_mean_absolute_percentage_error: 13737685.0000 - val_root_mean_squared_error: 0.2354
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0204 - mean_absolute_error: 0.1111 - mean_absolute_percentage_error: 29.6450 - root_mean_squared_error: 0.1429 - val_loss: 0.0562 - val_mean_absolute_error: 0.2005 - val_mean_absolute_percentage_error: 13480652.0000 - val_root_mean_squared_error: 0.2371
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0195 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 27.9370 - root_mean_squared_error: 0.1398 - val_loss: 0.0554 - val_mean_absolute_error: 0.1987 - val_mean_absolute_percentage_error: 13809440.0000 - val_root_mean_squared_error: 0.2354
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0197 - mean_absolute_error: 0.1096 - mean_absolute_percentage_error: 27.3718 - root_mean_squared_error: 0.1405 - val_loss: 0.0569 - val_mean_absolute_error: 0.2010 - val_mean_absolute_percentage_error: 13431928.0000 - val_root_mean_squared_error: 0.2385
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0202 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 28.9858 - root_mean_squared_error: 0.1422 - val_loss: 0.0558 - val_mean_absolute_error: 0.2001 - val_mean_absolute_percentage_error: 13748230.0000 - val_root_mean_squared_error: 0.2363
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0191 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 26.5769 - root_mean_squared_error: 0.1380 - val_loss: 0.0567 - val_mean_absolute_error: 0.2008 - val_mean_absolute_percentage_error: 13596516.0000 - val_root_mean_squared_error: 0.2381
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0200 - mean_absolute_error: 0.1100 - mean_absolute_percentage_error: 29.0372 - root_mean_squared_error: 0.1413 - val_loss: 0.0554 - val_mean_absolute_error: 0.1998 - val_mean_absolute_percentage_error: 13962677.0000 - val_root_mean_squared_error: 0.2354
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0190 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 27.6301 - root_mean_squared_error: 0.1379 - val_loss: 0.0544 - val_mean_absolute_error: 0.1979 - val_mean_absolute_percentage_error: 14580372.0000 - val_root_mean_squared_error: 0.2331

# %%
y_pred = model_hybrid_17.predict(x_test)

evaluation_hybrid_17 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_17
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# {'Mean Squared Error: ': np.float64(422.32530408931717),
#  'Mean Absolute Error: ': np.float64(15.953688563132772),
#  'Root Mean Absolute Error: ': 20.550554836532203,
#  'Mean Absolute Percentage Error: ': np.float64(29.503985368979198)}

# %%
loss, mae, mape, rmse = model_hybrid_17.evaluate(x_test, y_test)
print("model hybrid 17")
print("Mean Square E17rror:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0337 - mean_absolute_error: 0.1424 - mean_absolute_percentage_error: 37.4087 - root_mean_squared_error: 0.1835
# model hybrid 17
# Mean Square E17rror: 0.03366750851273537
# Mean Absolute Error: 0.14244364202022552
# Mean Absolute Percentage Error: 37.4086799621582
# Root Mean Squared Error: 0.18348707258701324

# %% [markdown]
# ## model 18 (CNN=128 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_18 = Sequential()
model_hybrid_18.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_18.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_18.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_18.add(Flatten())
model_hybrid_18.add(Dense(7))
model_hybrid_18.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_18.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_62"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_68 (Conv1D)              │ (None, 7, 128)         │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_73 (LSTM)                  │ (None, 7, 64)          │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_74 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_62 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_62 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 64,295 (251.15 KB)
#  Trainable params: 64,295 (251.15 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_18.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 0.3008 - mean_absolute_error: 0.5177 - mean_absolute_percentage_error: 90.5848 - root_mean_squared_error: 0.5475 - val_loss: 0.0886 - val_mean_absolute_error: 0.2538 - val_mean_absolute_percentage_error: 10945373.0000 - val_root_mean_squared_error: 0.2976
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0469 - mean_absolute_error: 0.1706 - mean_absolute_percentage_error: 39.3987 - root_mean_squared_error: 0.2161 - val_loss: 0.0621 - val_mean_absolute_error: 0.2118 - val_mean_absolute_percentage_error: 13009717.0000 - val_root_mean_squared_error: 0.2493
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0267 - mean_absolute_error: 0.1276 - mean_absolute_percentage_error: 29.4629 - root_mean_squared_error: 0.1633 - val_loss: 0.0530 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 14656774.0000 - val_root_mean_squared_error: 0.2302
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0213 - mean_absolute_error: 0.1145 - mean_absolute_percentage_error: 28.5799 - root_mean_squared_error: 0.1460 - val_loss: 0.0516 - val_mean_absolute_error: 0.1887 - val_mean_absolute_percentage_error: 15144345.0000 - val_root_mean_squared_error: 0.2271
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0222 - mean_absolute_error: 0.1165 - mean_absolute_percentage_error: 30.8608 - root_mean_squared_error: 0.1490 - val_loss: 0.0521 - val_mean_absolute_error: 0.1889 - val_mean_absolute_percentage_error: 14921209.0000 - val_root_mean_squared_error: 0.2282
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0224 - mean_absolute_error: 0.1171 - mean_absolute_percentage_error: 29.8525 - root_mean_squared_error: 0.1495 - val_loss: 0.0520 - val_mean_absolute_error: 0.1890 - val_mean_absolute_percentage_error: 14869400.0000 - val_root_mean_squared_error: 0.2279
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0207 - mean_absolute_error: 0.1123 - mean_absolute_percentage_error: 29.3608 - root_mean_squared_error: 0.1437 - val_loss: 0.0510 - val_mean_absolute_error: 0.1873 - val_mean_absolute_percentage_error: 15223293.0000 - val_root_mean_squared_error: 0.2259
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0199 - mean_absolute_error: 0.1104 - mean_absolute_percentage_error: 28.0145 - root_mean_squared_error: 0.1411 - val_loss: 0.0528 - val_mean_absolute_error: 0.1909 - val_mean_absolute_percentage_error: 14532753.0000 - val_root_mean_squared_error: 0.2298
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0213 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 29.4534 - root_mean_squared_error: 0.1460 - val_loss: 0.0529 - val_mean_absolute_error: 0.1919 - val_mean_absolute_percentage_error: 14471538.0000 - val_root_mean_squared_error: 0.2300
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0207 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 29.5023 - root_mean_squared_error: 0.1439 - val_loss: 0.0539 - val_mean_absolute_error: 0.1938 - val_mean_absolute_percentage_error: 14047635.0000 - val_root_mean_squared_error: 0.2321
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0198 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 27.1840 - root_mean_squared_error: 0.1407 - val_loss: 0.0556 - val_mean_absolute_error: 0.1960 - val_mean_absolute_percentage_error: 13766424.0000 - val_root_mean_squared_error: 0.2357
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0211 - mean_absolute_error: 0.1140 - mean_absolute_percentage_error: 28.7183 - root_mean_squared_error: 0.1451 - val_loss: 0.0537 - val_mean_absolute_error: 0.1934 - val_mean_absolute_percentage_error: 14071606.0000 - val_root_mean_squared_error: 0.2317
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0200 - mean_absolute_error: 0.1103 - mean_absolute_percentage_error: 27.5623 - root_mean_squared_error: 0.1415 - val_loss: 0.0536 - val_mean_absolute_error: 0.1945 - val_mean_absolute_percentage_error: 13975246.0000 - val_root_mean_squared_error: 0.2316
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0201 - mean_absolute_error: 0.1113 - mean_absolute_percentage_error: 28.3146 - root_mean_squared_error: 0.1418 - val_loss: 0.0542 - val_mean_absolute_error: 0.1954 - val_mean_absolute_percentage_error: 13916611.0000 - val_root_mean_squared_error: 0.2328
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0216 - mean_absolute_error: 0.1153 - mean_absolute_percentage_error: 30.2832 - root_mean_squared_error: 0.1469 - val_loss: 0.0538 - val_mean_absolute_error: 0.1944 - val_mean_absolute_percentage_error: 13970272.0000 - val_root_mean_squared_error: 0.2319
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0203 - mean_absolute_error: 0.1113 - mean_absolute_percentage_error: 28.6099 - root_mean_squared_error: 0.1425 - val_loss: 0.0545 - val_mean_absolute_error: 0.1956 - val_mean_absolute_percentage_error: 13775168.0000 - val_root_mean_squared_error: 0.2334
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0203 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 28.9107 - root_mean_squared_error: 0.1425 - val_loss: 0.0529 - val_mean_absolute_error: 0.1942 - val_mean_absolute_percentage_error: 14285450.0000 - val_root_mean_squared_error: 0.2299
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0202 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 28.7895 - root_mean_squared_error: 0.1419 - val_loss: 0.0555 - val_mean_absolute_error: 0.1983 - val_mean_absolute_percentage_error: 13489086.0000 - val_root_mean_squared_error: 0.2356
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0210 - mean_absolute_error: 0.1145 - mean_absolute_percentage_error: 28.1779 - root_mean_squared_error: 0.1450 - val_loss: 0.0543 - val_mean_absolute_error: 0.1953 - val_mean_absolute_percentage_error: 13887850.0000 - val_root_mean_squared_error: 0.2330
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0192 - mean_absolute_error: 0.1084 - mean_absolute_percentage_error: 27.4267 - root_mean_squared_error: 0.1387 - val_loss: 0.0526 - val_mean_absolute_error: 0.1929 - val_mean_absolute_percentage_error: 14401734.0000 - val_root_mean_squared_error: 0.2293

# %%
y_pred = model_hybrid_18.predict(x_test)

evaluation_hybrid_18 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_18
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# {'Mean Squared Error: ': np.float64(360.5353105441474),
#  'Mean Absolute Error: ': np.float64(15.216635840279713),
#  'Root Mean Absolute Error: ': 18.987767392301482,
#  'Mean Absolute Percentage Error: ': np.float64(27.356577334010773)}

# %%
loss, mae, mape, rmse = model_hybrid_18.evaluate(x_test, y_test)
print("model hybrid 18")
print("Mean Square E17rror:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0287 - mean_absolute_error: 0.1359 - mean_absolute_percentage_error: 34.5461 - root_mean_squared_error: 0.1695
# model hybrid 18
# Mean Square E17rror: 0.02874165214598179
# Mean Absolute Error: 0.135862797498703
# Mean Absolute Percentage Error: 34.546051025390625
# Root Mean Squared Error: 0.1695336252450943

# %% [markdown]
# ## model 19 (CNN=256 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_19 = Sequential()
model_hybrid_19.add(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_19.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_19.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_19.add(Flatten())
model_hybrid_19.add(Dense(7))
model_hybrid_19.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_19.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_63"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_69 (Conv1D)              │ (None, 7, 256)         │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_75 (LSTM)                  │ (None, 7, 64)          │        82,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_76 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_63 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_63 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 97,959 (382.65 KB)
#  Trainable params: 97,959 (382.65 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_19.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.3037 - mean_absolute_error: 0.5185 - mean_absolute_percentage_error: 91.8652 - root_mean_squared_error: 0.5504 - val_loss: 0.1145 - val_mean_absolute_error: 0.2856 - val_mean_absolute_percentage_error: 11757151.0000 - val_root_mean_squared_error: 0.3384
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0705 - mean_absolute_error: 0.2143 - mean_absolute_percentage_error: 46.7119 - root_mean_squared_error: 0.2632 - val_loss: 0.0551 - val_mean_absolute_error: 0.1977 - val_mean_absolute_percentage_error: 14522072.0000 - val_root_mean_squared_error: 0.2347
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0268 - mean_absolute_error: 0.1276 - mean_absolute_percentage_error: 31.3539 - root_mean_squared_error: 0.1636 - val_loss: 0.0514 - val_mean_absolute_error: 0.1882 - val_mean_absolute_percentage_error: 15011375.0000 - val_root_mean_squared_error: 0.2266
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0234 - mean_absolute_error: 0.1192 - mean_absolute_percentage_error: 32.1681 - root_mean_squared_error: 0.1528 - val_loss: 0.0515 - val_mean_absolute_error: 0.1892 - val_mean_absolute_percentage_error: 14934568.0000 - val_root_mean_squared_error: 0.2269
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0221 - mean_absolute_error: 0.1156 - mean_absolute_percentage_error: 29.2792 - root_mean_squared_error: 0.1487 - val_loss: 0.0517 - val_mean_absolute_error: 0.1905 - val_mean_absolute_percentage_error: 14849918.0000 - val_root_mean_squared_error: 0.2274
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0211 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 28.4871 - root_mean_squared_error: 0.1452 - val_loss: 0.0535 - val_mean_absolute_error: 0.1943 - val_mean_absolute_percentage_error: 14265555.0000 - val_root_mean_squared_error: 0.2312
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0210 - mean_absolute_error: 0.1141 - mean_absolute_percentage_error: 28.3767 - root_mean_squared_error: 0.1450 - val_loss: 0.0558 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 13814098.0000 - val_root_mean_squared_error: 0.2362
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0209 - mean_absolute_error: 0.1129 - mean_absolute_percentage_error: 30.0525 - root_mean_squared_error: 0.1445 - val_loss: 0.0549 - val_mean_absolute_error: 0.1977 - val_mean_absolute_percentage_error: 14057316.0000 - val_root_mean_squared_error: 0.2342
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0209 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 28.3858 - root_mean_squared_error: 0.1446 - val_loss: 0.0521 - val_mean_absolute_error: 0.1929 - val_mean_absolute_percentage_error: 15185980.0000 - val_root_mean_squared_error: 0.2283
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0205 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 28.4026 - root_mean_squared_error: 0.1431 - val_loss: 0.0543 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 14594367.0000 - val_root_mean_squared_error: 0.2330
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0193 - mean_absolute_error: 0.1069 - mean_absolute_percentage_error: 28.6053 - root_mean_squared_error: 0.1390 - val_loss: 0.0556 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 14352278.0000 - val_root_mean_squared_error: 0.2357
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0191 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 28.2161 - root_mean_squared_error: 0.1383 - val_loss: 0.0542 - val_mean_absolute_error: 0.1969 - val_mean_absolute_percentage_error: 14578892.0000 - val_root_mean_squared_error: 0.2329
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0190 - mean_absolute_error: 0.1070 - mean_absolute_percentage_error: 26.7446 - root_mean_squared_error: 0.1377 - val_loss: 0.0590 - val_mean_absolute_error: 0.2047 - val_mean_absolute_percentage_error: 13856422.0000 - val_root_mean_squared_error: 0.2430
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0190 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 27.1447 - root_mean_squared_error: 0.1378 - val_loss: 0.0548 - val_mean_absolute_error: 0.1979 - val_mean_absolute_percentage_error: 14664693.0000 - val_root_mean_squared_error: 0.2342
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0194 - mean_absolute_error: 0.1080 - mean_absolute_percentage_error: 28.4424 - root_mean_squared_error: 0.1393 - val_loss: 0.0543 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 15050431.0000 - val_root_mean_squared_error: 0.2330
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0193 - mean_absolute_error: 0.1074 - mean_absolute_percentage_error: 26.9316 - root_mean_squared_error: 0.1387 - val_loss: 0.0555 - val_mean_absolute_error: 0.1997 - val_mean_absolute_percentage_error: 14852480.0000 - val_root_mean_squared_error: 0.2355
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0192 - mean_absolute_error: 0.1069 - mean_absolute_percentage_error: 27.8679 - root_mean_squared_error: 0.1387 - val_loss: 0.0554 - val_mean_absolute_error: 0.1991 - val_mean_absolute_percentage_error: 14689220.0000 - val_root_mean_squared_error: 0.2353
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0195 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 27.1141 - root_mean_squared_error: 0.1397 - val_loss: 0.0548 - val_mean_absolute_error: 0.1988 - val_mean_absolute_percentage_error: 14929571.0000 - val_root_mean_squared_error: 0.2340
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0183 - mean_absolute_error: 0.1049 - mean_absolute_percentage_error: 26.8588 - root_mean_squared_error: 0.1353 - val_loss: 0.0551 - val_mean_absolute_error: 0.1982 - val_mean_absolute_percentage_error: 15272128.0000 - val_root_mean_squared_error: 0.2348
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0187 - mean_absolute_error: 0.1060 - mean_absolute_percentage_error: 27.5927 - root_mean_squared_error: 0.1367 - val_loss: 0.0548 - val_mean_absolute_error: 0.1988 - val_mean_absolute_percentage_error: 14869139.0000 - val_root_mean_squared_error: 0.2341

# %%
y_pred = model_hybrid_19.predict(x_test)

evaluation_hybrid_19 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_19
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# {'Mean Squared Error: ': np.float64(320.39316870466865),
#  'Mean Absolute Error: ': np.float64(14.109604563031876),
#  'Root Mean Absolute Error: ': 17.899529845911278,
#  'Mean Absolute Percentage Error: ': np.float64(25.83768973632542)}

# %%
loss, mae, mape, rmse = model_hybrid_19.evaluate(x_test, y_test)
print("model hybrid 19")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0255 - mean_absolute_error: 0.1260 - mean_absolute_percentage_error: 32.7662 - root_mean_squared_error: 0.1598
# model hybrid 19
# Mean Square Error: 0.02554154582321644
# Mean Absolute Error: 0.12597860395908356
# Mean Absolute Percentage Error: 32.76620864868164
# Root Mean Squared Error: 0.15981723368167877

# %% [markdown]
# ## model 20 (CNN=512 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_20 = Sequential()
model_hybrid_20.add(Conv1D(filters=512, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_20.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_20.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_20.add(Flatten())
model_hybrid_20.add(Dense(7))
model_hybrid_20.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_20.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_64"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_70 (Conv1D)              │ (None, 7, 512)         │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_77 (LSTM)                  │ (None, 7, 64)          │       147,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_78 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_64 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 165,287 (645.65 KB)
#  Trainable params: 165,287 (645.65 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_20.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - loss: 0.2951 - mean_absolute_error: 0.5085 - mean_absolute_percentage_error: 89.8562 - root_mean_squared_error: 0.5418 - val_loss: 0.0741 - val_mean_absolute_error: 0.2172 - val_mean_absolute_percentage_error: 17206364.0000 - val_root_mean_squared_error: 0.2721
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0502 - mean_absolute_error: 0.1768 - mean_absolute_percentage_error: 42.6602 - root_mean_squared_error: 0.2229 - val_loss: 0.0526 - val_mean_absolute_error: 0.1927 - val_mean_absolute_percentage_error: 14372920.0000 - val_root_mean_squared_error: 0.2293
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0259 - mean_absolute_error: 0.1255 - mean_absolute_percentage_error: 32.6235 - root_mean_squared_error: 0.1608 - val_loss: 0.0539 - val_mean_absolute_error: 0.1943 - val_mean_absolute_percentage_error: 14176785.0000 - val_root_mean_squared_error: 0.2322
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0231 - mean_absolute_error: 0.1190 - mean_absolute_percentage_error: 32.2798 - root_mean_squared_error: 0.1521 - val_loss: 0.0518 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 14652858.0000 - val_root_mean_squared_error: 0.2277
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0222 - mean_absolute_error: 0.1155 - mean_absolute_percentage_error: 31.0598 - root_mean_squared_error: 0.1490 - val_loss: 0.0528 - val_mean_absolute_error: 0.1937 - val_mean_absolute_percentage_error: 14278121.0000 - val_root_mean_squared_error: 0.2298
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0214 - mean_absolute_error: 0.1140 - mean_absolute_percentage_error: 27.7027 - root_mean_squared_error: 0.1464 - val_loss: 0.0520 - val_mean_absolute_error: 0.1917 - val_mean_absolute_percentage_error: 14555775.0000 - val_root_mean_squared_error: 0.2280
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0207 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 28.6713 - root_mean_squared_error: 0.1438 - val_loss: 0.0527 - val_mean_absolute_error: 0.1937 - val_mean_absolute_percentage_error: 14319969.0000 - val_root_mean_squared_error: 0.2296
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0211 - mean_absolute_error: 0.1135 - mean_absolute_percentage_error: 28.9271 - root_mean_squared_error: 0.1451 - val_loss: 0.0536 - val_mean_absolute_error: 0.1952 - val_mean_absolute_percentage_error: 14015030.0000 - val_root_mean_squared_error: 0.2315
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0199 - mean_absolute_error: 0.1100 - mean_absolute_percentage_error: 28.1427 - root_mean_squared_error: 0.1410 - val_loss: 0.0535 - val_mean_absolute_error: 0.1963 - val_mean_absolute_percentage_error: 13973632.0000 - val_root_mean_squared_error: 0.2313
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0202 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 29.0482 - root_mean_squared_error: 0.1422 - val_loss: 0.0564 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 13359484.0000 - val_root_mean_squared_error: 0.2376
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0188 - mean_absolute_error: 0.1070 - mean_absolute_percentage_error: 26.2802 - root_mean_squared_error: 0.1369 - val_loss: 0.0558 - val_mean_absolute_error: 0.1993 - val_mean_absolute_percentage_error: 13448900.0000 - val_root_mean_squared_error: 0.2363
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0196 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 27.1795 - root_mean_squared_error: 0.1399 - val_loss: 0.0545 - val_mean_absolute_error: 0.1985 - val_mean_absolute_percentage_error: 14031285.0000 - val_root_mean_squared_error: 0.2334
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0200 - mean_absolute_error: 0.1089 - mean_absolute_percentage_error: 29.3229 - root_mean_squared_error: 0.1413 - val_loss: 0.0547 - val_mean_absolute_error: 0.1979 - val_mean_absolute_percentage_error: 13969731.0000 - val_root_mean_squared_error: 0.2339
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0187 - mean_absolute_error: 0.1063 - mean_absolute_percentage_error: 27.0151 - root_mean_squared_error: 0.1367 - val_loss: 0.0556 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 13737419.0000 - val_root_mean_squared_error: 0.2357
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0193 - mean_absolute_error: 0.1079 - mean_absolute_percentage_error: 28.1387 - root_mean_squared_error: 0.1389 - val_loss: 0.0559 - val_mean_absolute_error: 0.2000 - val_mean_absolute_percentage_error: 13813599.0000 - val_root_mean_squared_error: 0.2365
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0194 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 27.4082 - root_mean_squared_error: 0.1391 - val_loss: 0.0546 - val_mean_absolute_error: 0.1987 - val_mean_absolute_percentage_error: 14603385.0000 - val_root_mean_squared_error: 0.2336
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0188 - mean_absolute_error: 0.1063 - mean_absolute_percentage_error: 27.7543 - root_mean_squared_error: 0.1372 - val_loss: 0.0554 - val_mean_absolute_error: 0.1988 - val_mean_absolute_percentage_error: 14309290.0000 - val_root_mean_squared_error: 0.2355
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0192 - mean_absolute_error: 0.1086 - mean_absolute_percentage_error: 27.1919 - root_mean_squared_error: 0.1387 - val_loss: 0.0541 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 15023531.0000 - val_root_mean_squared_error: 0.2326
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0193 - mean_absolute_error: 0.1071 - mean_absolute_percentage_error: 28.6019 - root_mean_squared_error: 0.1387 - val_loss: 0.0546 - val_mean_absolute_error: 0.1974 - val_mean_absolute_percentage_error: 14889694.0000 - val_root_mean_squared_error: 0.2337
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0185 - mean_absolute_error: 0.1053 - mean_absolute_percentage_error: 26.2883 - root_mean_squared_error: 0.1358 - val_loss: 0.0588 - val_mean_absolute_error: 0.2059 - val_mean_absolute_percentage_error: 13921077.0000 - val_root_mean_squared_error: 0.2424

# %%
y_pred = model_hybrid_20.predict(x_test)

evaluation_hybrid_20 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_20
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# {'Mean Squared Error: ': np.float64(277.3340576643997),
#  'Mean Absolute Error: ': np.float64(13.322164613373426),
#  'Root Mean Absolute Error: ': 16.653349743051688,
#  'Mean Absolute Percentage Error: ': np.float64(23.60073828402595)}

# %%
loss, mae, mape, rmse = model_hybrid_20.evaluate(x_test, y_test)
print("model hybrid 20")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0221 - mean_absolute_error: 0.1189 - mean_absolute_percentage_error: 29.7837 - root_mean_squared_error: 0.1487
# model hybrid 20
# Mean Square Error: 0.022108901292085648
# Mean Absolute Error: 0.11894790083169937
# Mean Absolute Percentage Error: 29.783672332763672
# Root Mean Squared Error: 0.1486906260251999

# %% [markdown]
# ## model 21 (CNN=300 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_21 = Sequential()
model_hybrid_21.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_21.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_21.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_21.add(Flatten())
model_hybrid_21.add(Dense(7))
model_hybrid_21.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_21.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_65"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_71 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_79 (LSTM)                  │ (None, 7, 64)          │        93,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_80 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_65 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_65 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,531 (427.86 KB)
#  Trainable params: 109,531 (427.86 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_21.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 0.3224 - mean_absolute_error: 0.5379 - mean_absolute_percentage_error: 94.9853 - root_mean_squared_error: 0.5673 - val_loss: 0.1589 - val_mean_absolute_error: 0.3476 - val_mean_absolute_percentage_error: 7296527.5000 - val_root_mean_squared_error: 0.3986
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0889 - mean_absolute_error: 0.2424 - mean_absolute_percentage_error: 46.9308 - root_mean_squared_error: 0.2960 - val_loss: 0.0622 - val_mean_absolute_error: 0.2119 - val_mean_absolute_percentage_error: 13124200.0000 - val_root_mean_squared_error: 0.2495
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0245 - mean_absolute_error: 0.1234 - mean_absolute_percentage_error: 28.4956 - root_mean_squared_error: 0.1565 - val_loss: 0.0570 - val_mean_absolute_error: 0.2027 - val_mean_absolute_percentage_error: 13877120.0000 - val_root_mean_squared_error: 0.2387
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0212 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 28.5377 - root_mean_squared_error: 0.1456 - val_loss: 0.0534 - val_mean_absolute_error: 0.1947 - val_mean_absolute_percentage_error: 14253562.0000 - val_root_mean_squared_error: 0.2310
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0222 - mean_absolute_error: 0.1162 - mean_absolute_percentage_error: 31.8977 - root_mean_squared_error: 0.1488 - val_loss: 0.0519 - val_mean_absolute_error: 0.1919 - val_mean_absolute_percentage_error: 14703898.0000 - val_root_mean_squared_error: 0.2277
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0230 - mean_absolute_error: 0.1174 - mean_absolute_percentage_error: 31.8490 - root_mean_squared_error: 0.1515 - val_loss: 0.0517 - val_mean_absolute_error: 0.1918 - val_mean_absolute_percentage_error: 14712967.0000 - val_root_mean_squared_error: 0.2274
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0209 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 29.7946 - root_mean_squared_error: 0.1445 - val_loss: 0.0520 - val_mean_absolute_error: 0.1933 - val_mean_absolute_percentage_error: 14654813.0000 - val_root_mean_squared_error: 0.2281
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0207 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 28.1426 - root_mean_squared_error: 0.1439 - val_loss: 0.0532 - val_mean_absolute_error: 0.1966 - val_mean_absolute_percentage_error: 14198720.0000 - val_root_mean_squared_error: 0.2306
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0214 - mean_absolute_error: 0.1140 - mean_absolute_percentage_error: 30.2108 - root_mean_squared_error: 0.1461 - val_loss: 0.0546 - val_mean_absolute_error: 0.1987 - val_mean_absolute_percentage_error: 13965085.0000 - val_root_mean_squared_error: 0.2336
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0202 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 27.9392 - root_mean_squared_error: 0.1421 - val_loss: 0.0563 - val_mean_absolute_error: 0.2026 - val_mean_absolute_percentage_error: 13523698.0000 - val_root_mean_squared_error: 0.2373
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0199 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 28.1475 - root_mean_squared_error: 0.1412 - val_loss: 0.0535 - val_mean_absolute_error: 0.1972 - val_mean_absolute_percentage_error: 14705181.0000 - val_root_mean_squared_error: 0.2312
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0212 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 29.7145 - root_mean_squared_error: 0.1454 - val_loss: 0.0563 - val_mean_absolute_error: 0.2023 - val_mean_absolute_percentage_error: 13861686.0000 - val_root_mean_squared_error: 0.2372
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0196 - mean_absolute_error: 0.1095 - mean_absolute_percentage_error: 27.3015 - root_mean_squared_error: 0.1400 - val_loss: 0.0546 - val_mean_absolute_error: 0.1997 - val_mean_absolute_percentage_error: 14362773.0000 - val_root_mean_squared_error: 0.2337
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0193 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 27.4862 - root_mean_squared_error: 0.1391 - val_loss: 0.0548 - val_mean_absolute_error: 0.1998 - val_mean_absolute_percentage_error: 14525604.0000 - val_root_mean_squared_error: 0.2341
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0199 - mean_absolute_error: 0.1095 - mean_absolute_percentage_error: 27.9554 - root_mean_squared_error: 0.1411 - val_loss: 0.0590 - val_mean_absolute_error: 0.2074 - val_mean_absolute_percentage_error: 13674959.0000 - val_root_mean_squared_error: 0.2428
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0201 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 28.5070 - root_mean_squared_error: 0.1416 - val_loss: 0.0562 - val_mean_absolute_error: 0.2024 - val_mean_absolute_percentage_error: 14206590.0000 - val_root_mean_squared_error: 0.2370
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0195 - mean_absolute_error: 0.1084 - mean_absolute_percentage_error: 28.6823 - root_mean_squared_error: 0.1397 - val_loss: 0.0555 - val_mean_absolute_error: 0.2005 - val_mean_absolute_percentage_error: 14955201.0000 - val_root_mean_squared_error: 0.2356
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0191 - mean_absolute_error: 0.1069 - mean_absolute_percentage_error: 28.1614 - root_mean_squared_error: 0.1380 - val_loss: 0.0566 - val_mean_absolute_error: 0.2040 - val_mean_absolute_percentage_error: 14249242.0000 - val_root_mean_squared_error: 0.2379
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0174 - mean_absolute_error: 0.1020 - mean_absolute_percentage_error: 26.0802 - root_mean_squared_error: 0.1320 - val_loss: 0.0604 - val_mean_absolute_error: 0.2113 - val_mean_absolute_percentage_error: 13728343.0000 - val_root_mean_squared_error: 0.2457
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0199 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 27.7578 - root_mean_squared_error: 0.1411 - val_loss: 0.0543 - val_mean_absolute_error: 0.1983 - val_mean_absolute_percentage_error: 14938612.0000 - val_root_mean_squared_error: 0.2330

# %%
y_pred = model_hybrid_21.predict(x_test)

evaluation_21 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_21
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# {'Mean Squared Error: ': np.float64(336.418936132669),
#  'Mean Absolute Error: ': np.float64(14.616225203689265),
#  'Root Mean Absolute Error: ': 18.341726639895956,
#  'Mean Absolute Percentage Error: ': np.float64(26.948818994343327)}

# %%
# loss, mae, mape, rmse = model_hybrid_21.evaluate(x_test, y_test)
# print("model hybrid 21")
# print("Mean Square Error:", loss)
# print("Mean Absolute Error:", mae)
# print("Mean Absolute Percentage Error:", mape)
# print("Root Mean Squared Error:", rmse)

# %% [markdown]
# ## model 22 (CNN=350 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_22 = Sequential()
model_hybrid_22.add(Conv1D(filters=350, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_22.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_22.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_22.add(Flatten())
model_hybrid_22.add(Dense(7))
model_hybrid_22.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_22.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_66"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_72 (Conv1D)              │ (None, 7, 350)         │         2,450 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_81 (LSTM)                  │ (None, 7, 64)          │       106,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_82 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_66 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_66 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 122,681 (479.22 KB)
#  Trainable params: 122,681 (479.22 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_22.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.2506 - mean_absolute_error: 0.4580 - mean_absolute_percentage_error: 80.6196 - root_mean_squared_error: 0.4975 - val_loss: 0.0709 - val_mean_absolute_error: 0.2184 - val_mean_absolute_percentage_error: 17048698.0000 - val_root_mean_squared_error: 0.2663
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0326 - mean_absolute_error: 0.1425 - mean_absolute_percentage_error: 32.5169 - root_mean_squared_error: 0.1803 - val_loss: 0.0544 - val_mean_absolute_error: 0.1964 - val_mean_absolute_percentage_error: 15718237.0000 - val_root_mean_squared_error: 0.2332
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0242 - mean_absolute_error: 0.1215 - mean_absolute_percentage_error: 30.4622 - root_mean_squared_error: 0.1555 - val_loss: 0.0508 - val_mean_absolute_error: 0.1884 - val_mean_absolute_percentage_error: 15614125.0000 - val_root_mean_squared_error: 0.2255
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0198 - mean_absolute_error: 0.1089 - mean_absolute_percentage_error: 26.7910 - root_mean_squared_error: 0.1405 - val_loss: 0.0528 - val_mean_absolute_error: 0.1924 - val_mean_absolute_percentage_error: 14681299.0000 - val_root_mean_squared_error: 0.2299
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0221 - mean_absolute_error: 0.1150 - mean_absolute_percentage_error: 32.1832 - root_mean_squared_error: 0.1485 - val_loss: 0.0517 - val_mean_absolute_error: 0.1912 - val_mean_absolute_percentage_error: 15009496.0000 - val_root_mean_squared_error: 0.2273
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0207 - mean_absolute_error: 0.1113 - mean_absolute_percentage_error: 28.7332 - root_mean_squared_error: 0.1439 - val_loss: 0.0520 - val_mean_absolute_error: 0.1930 - val_mean_absolute_percentage_error: 14684925.0000 - val_root_mean_squared_error: 0.2281
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0212 - mean_absolute_error: 0.1137 - mean_absolute_percentage_error: 28.8600 - root_mean_squared_error: 0.1457 - val_loss: 0.0528 - val_mean_absolute_error: 0.1957 - val_mean_absolute_percentage_error: 14377400.0000 - val_root_mean_squared_error: 0.2297
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0213 - mean_absolute_error: 0.1127 - mean_absolute_percentage_error: 29.1605 - root_mean_squared_error: 0.1458 - val_loss: 0.0537 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 14014024.0000 - val_root_mean_squared_error: 0.2318
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0197 - mean_absolute_error: 0.1101 - mean_absolute_percentage_error: 27.6388 - root_mean_squared_error: 0.1404 - val_loss: 0.0557 - val_mean_absolute_error: 0.1993 - val_mean_absolute_percentage_error: 13569674.0000 - val_root_mean_squared_error: 0.2359
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0187 - mean_absolute_error: 0.1061 - mean_absolute_percentage_error: 25.4540 - root_mean_squared_error: 0.1367 - val_loss: 0.0550 - val_mean_absolute_error: 0.1990 - val_mean_absolute_percentage_error: 13681564.0000 - val_root_mean_squared_error: 0.2346
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0195 - mean_absolute_error: 0.1094 - mean_absolute_percentage_error: 27.5833 - root_mean_squared_error: 0.1396 - val_loss: 0.0534 - val_mean_absolute_error: 0.1974 - val_mean_absolute_percentage_error: 14434178.0000 - val_root_mean_squared_error: 0.2311
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0205 - mean_absolute_error: 0.1118 - mean_absolute_percentage_error: 28.8482 - root_mean_squared_error: 0.1433 - val_loss: 0.0555 - val_mean_absolute_error: 0.1997 - val_mean_absolute_percentage_error: 13609060.0000 - val_root_mean_squared_error: 0.2356
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0187 - mean_absolute_error: 0.1062 - mean_absolute_percentage_error: 26.4798 - root_mean_squared_error: 0.1368 - val_loss: 0.0582 - val_mean_absolute_error: 0.2037 - val_mean_absolute_percentage_error: 13104935.0000 - val_root_mean_squared_error: 0.2412
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0207 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 28.0335 - root_mean_squared_error: 0.1438 - val_loss: 0.0538 - val_mean_absolute_error: 0.1977 - val_mean_absolute_percentage_error: 14500269.0000 - val_root_mean_squared_error: 0.2320
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0208 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 31.1007 - root_mean_squared_error: 0.1440 - val_loss: 0.0544 - val_mean_absolute_error: 0.1992 - val_mean_absolute_percentage_error: 14324929.0000 - val_root_mean_squared_error: 0.2332
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0183 - mean_absolute_error: 0.1058 - mean_absolute_percentage_error: 26.2429 - root_mean_squared_error: 0.1352 - val_loss: 0.0562 - val_mean_absolute_error: 0.2008 - val_mean_absolute_percentage_error: 13710268.0000 - val_root_mean_squared_error: 0.2370
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0201 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 29.3356 - root_mean_squared_error: 0.1419 - val_loss: 0.0550 - val_mean_absolute_error: 0.2013 - val_mean_absolute_percentage_error: 14153479.0000 - val_root_mean_squared_error: 0.2345
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0191 - mean_absolute_error: 0.1073 - mean_absolute_percentage_error: 28.0377 - root_mean_squared_error: 0.1381 - val_loss: 0.0546 - val_mean_absolute_error: 0.1990 - val_mean_absolute_percentage_error: 14343258.0000 - val_root_mean_squared_error: 0.2336
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0193 - mean_absolute_error: 0.1080 - mean_absolute_percentage_error: 28.4869 - root_mean_squared_error: 0.1388 - val_loss: 0.0608 - val_mean_absolute_error: 0.2079 - val_mean_absolute_percentage_error: 12857846.0000 - val_root_mean_squared_error: 0.2466
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0191 - mean_absolute_error: 0.1086 - mean_absolute_percentage_error: 26.8251 - root_mean_squared_error: 0.1380 - val_loss: 0.0554 - val_mean_absolute_error: 0.2007 - val_mean_absolute_percentage_error: 14278474.0000 - val_root_mean_squared_error: 0.2354

# %%
y_pred = model_hybrid_22.predict(x_test)

evaluation_hybrid_22 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_22
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# {'Mean Squared Error: ': np.float64(368.86136982231534),
#  'Mean Absolute Error: ': np.float64(14.678571389645947),
#  'Root Mean Absolute Error: ': 19.205763973930203,
#  'Mean Absolute Percentage Error: ': np.float64(27.41966421844953)}

# %%
loss, mae, mape, rmse = model_hybrid_22.evaluate(x_test, y_test)
print("model hybrid 22")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0294 - mean_absolute_error: 0.1311 - mean_absolute_percentage_error: 34.8716 - root_mean_squared_error: 0.1715
# model hybrid 22
# Mean Square Error: 0.02940540201961994
# Mean Absolute Error: 0.13105866312980652
# Mean Absolute Percentage Error: 34.871620178222656
# Root Mean Squared Error: 0.17148002982139587

# %% [markdown]
# ## model 23 (CNN=320 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_23 = Sequential()
model_hybrid_23.add(Conv1D(filters=320, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_23.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_23.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_23.add(Flatten())
model_hybrid_23.add(Dense(7))
model_hybrid_23.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_23.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_67"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_73 (Conv1D)              │ (None, 7, 320)         │         2,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_83 (LSTM)                  │ (None, 7, 64)          │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_84 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_67 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_67 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 114,791 (448.40 KB)
#  Trainable params: 114,791 (448.40 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_23.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.2832 - mean_absolute_error: 0.4965 - mean_absolute_percentage_error: 87.3345 - root_mean_squared_error: 0.5305 - val_loss: 0.0970 - val_mean_absolute_error: 0.2469 - val_mean_absolute_percentage_error: 16577844.0000 - val_root_mean_squared_error: 0.3115
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0477 - mean_absolute_error: 0.1697 - mean_absolute_percentage_error: 37.5052 - root_mean_squared_error: 0.2164 - val_loss: 0.0548 - val_mean_absolute_error: 0.1942 - val_mean_absolute_percentage_error: 15145208.0000 - val_root_mean_squared_error: 0.2341
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0268 - mean_absolute_error: 0.1281 - mean_absolute_percentage_error: 33.2597 - root_mean_squared_error: 0.1636 - val_loss: 0.0530 - val_mean_absolute_error: 0.1936 - val_mean_absolute_percentage_error: 14512120.0000 - val_root_mean_squared_error: 0.2302
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0219 - mean_absolute_error: 0.1158 - mean_absolute_percentage_error: 29.2261 - root_mean_squared_error: 0.1481 - val_loss: 0.0536 - val_mean_absolute_error: 0.1949 - val_mean_absolute_percentage_error: 14194499.0000 - val_root_mean_squared_error: 0.2315
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0233 - mean_absolute_error: 0.1191 - mean_absolute_percentage_error: 31.1422 - root_mean_squared_error: 0.1525 - val_loss: 0.0519 - val_mean_absolute_error: 0.1932 - val_mean_absolute_percentage_error: 14394108.0000 - val_root_mean_squared_error: 0.2279
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0210 - mean_absolute_error: 0.1124 - mean_absolute_percentage_error: 27.7165 - root_mean_squared_error: 0.1447 - val_loss: 0.0554 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 13511637.0000 - val_root_mean_squared_error: 0.2354
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0214 - mean_absolute_error: 0.1139 - mean_absolute_percentage_error: 29.7379 - root_mean_squared_error: 0.1463 - val_loss: 0.0547 - val_mean_absolute_error: 0.2012 - val_mean_absolute_percentage_error: 13440087.0000 - val_root_mean_squared_error: 0.2339
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0203 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 27.6235 - root_mean_squared_error: 0.1424 - val_loss: 0.0562 - val_mean_absolute_error: 0.2034 - val_mean_absolute_percentage_error: 13143765.0000 - val_root_mean_squared_error: 0.2371
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0207 - mean_absolute_error: 0.1129 - mean_absolute_percentage_error: 27.6377 - root_mean_squared_error: 0.1438 - val_loss: 0.0548 - val_mean_absolute_error: 0.2018 - val_mean_absolute_percentage_error: 13381965.0000 - val_root_mean_squared_error: 0.2340
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0197 - mean_absolute_error: 0.1095 - mean_absolute_percentage_error: 28.3806 - root_mean_squared_error: 0.1405 - val_loss: 0.0567 - val_mean_absolute_error: 0.2050 - val_mean_absolute_percentage_error: 12969881.0000 - val_root_mean_squared_error: 0.2380
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0199 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 27.5214 - root_mean_squared_error: 0.1411 - val_loss: 0.0556 - val_mean_absolute_error: 0.2043 - val_mean_absolute_percentage_error: 13205548.0000 - val_root_mean_squared_error: 0.2358
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0199 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 29.0884 - root_mean_squared_error: 0.1412 - val_loss: 0.0547 - val_mean_absolute_error: 0.2017 - val_mean_absolute_percentage_error: 13763629.0000 - val_root_mean_squared_error: 0.2340
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0190 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 26.7392 - root_mean_squared_error: 0.1378 - val_loss: 0.0571 - val_mean_absolute_error: 0.2049 - val_mean_absolute_percentage_error: 13179007.0000 - val_root_mean_squared_error: 0.2389
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0194 - mean_absolute_error: 0.1086 - mean_absolute_percentage_error: 27.4372 - root_mean_squared_error: 0.1390 - val_loss: 0.0569 - val_mean_absolute_error: 0.2079 - val_mean_absolute_percentage_error: 13146382.0000 - val_root_mean_squared_error: 0.2385
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0182 - mean_absolute_error: 0.1044 - mean_absolute_percentage_error: 25.5817 - root_mean_squared_error: 0.1347 - val_loss: 0.0569 - val_mean_absolute_error: 0.2043 - val_mean_absolute_percentage_error: 13441783.0000 - val_root_mean_squared_error: 0.2385
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0192 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 27.8639 - root_mean_squared_error: 0.1387 - val_loss: 0.0597 - val_mean_absolute_error: 0.2088 - val_mean_absolute_percentage_error: 12976310.0000 - val_root_mean_squared_error: 0.2443
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0190 - mean_absolute_error: 0.1087 - mean_absolute_percentage_error: 26.4125 - root_mean_squared_error: 0.1380 - val_loss: 0.0585 - val_mean_absolute_error: 0.2085 - val_mean_absolute_percentage_error: 13326691.0000 - val_root_mean_squared_error: 0.2418
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0199 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 27.6381 - root_mean_squared_error: 0.1411 - val_loss: 0.0568 - val_mean_absolute_error: 0.2049 - val_mean_absolute_percentage_error: 14334740.0000 - val_root_mean_squared_error: 0.2383
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0191 - mean_absolute_error: 0.1077 - mean_absolute_percentage_error: 27.6821 - root_mean_squared_error: 0.1382 - val_loss: 0.0556 - val_mean_absolute_error: 0.2012 - val_mean_absolute_percentage_error: 14617521.0000 - val_root_mean_squared_error: 0.2358
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0176 - mean_absolute_error: 0.1034 - mean_absolute_percentage_error: 25.5108 - root_mean_squared_error: 0.1324 - val_loss: 0.0575 - val_mean_absolute_error: 0.2069 - val_mean_absolute_percentage_error: 13914718.0000 - val_root_mean_squared_error: 0.2399

# %%
y_pred = model_hybrid_23.predict(x_test)

evaluation_hybrid_23 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_23
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# {'Mean Squared Error: ': np.float64(345.3015008851733),
#  'Mean Absolute Error: ': np.float64(14.241107434642558),
#  'Root Mean Absolute Error: ': 18.5822899795793,
#  'Mean Absolute Percentage Error: ': np.float64(26.651464530052593)}

# %%
loss, mae, mape, rmse = model_hybrid_23.evaluate(x_test, y_test)
print("model hybrid 23")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0275 - mean_absolute_error: 0.1272 - mean_absolute_percentage_error: 33.9161 - root_mean_squared_error: 0.1659
# model hybrid 23
# Mean Square Error: 0.0275272224098444
# Mean Absolute Error: 0.12715274095535278
# Mean Absolute Percentage Error: 33.916099548339844
# Root Mean Squared Error: 0.16591329872608185

# %% [markdown]
# ## model 24 gridsearch & early stopping (CNN=300, LSTM= 64, 32)

# %%
# from keras.callbacks import EarlyStopping
# from sklearn.model_selection import GridSearchCV
# from scikeras.wrappers import KerasRegressor
# from keras.optimizers import Adam

# # 1. Define your model builder function
# def build_model(filters1=300, units1=64, units2=32, kernel_size=1, lr=0.001):
#     model = Sequential()
#     model.add(Input(shape=(7, 11)))
#     model.add(Conv1D(filters=filters1, kernel_size=kernel_size, activation='relu'))
#     model.add(LSTM(units=units1, activation='relu', return_sequences=True))
#     model.add(LSTM(units=units2, activation='relu'))
#     model.add(Flatten())
#     model.add(Dense(7))
#     optimizer = Adam(learning_rate=lr)
#     model.compile(loss='mse', optimizer=optimizer,
#                   metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
#     return model

# # 2. Set up KerasRegressor
# model = KerasRegressor(model=build_model, verbose=0)

# # 3. Define early stopping
# early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# # 4. Grid of parameters
# param_grid = {
#     'model__filters1': [300],
#     'model__units1': [64],
#     'model__units2': [32],
#     'model__kernel_size': [1],
#     'model__lr': [0.0002, 0.0003, 0.0004],
#     'batch_size': [32, 42, 64],
#     'epochs': [50]  # set high epochs so early stopping can interrupt early
# }

# # 5. GridSearchCV with early stopping passed via fit_params
# grid = GridSearchCV(estimator=model, param_grid=param_grid,
#                     scoring='neg_mean_squared_error',
#                     cv=3,
#                     refit=True)

# # 6. Fit with early stopping
# grid_result_cnn = grid.fit(x_train, y_train, callbacks=[early_stop], validation_data=(x_val, y_val))

# %%
# print("Best parameters found: ", grid_result_cnn.best_params_)
# # print("Best MSE: ", -grid_result.best_score_)

# %%
# best_model = grid_result_cnn.best_estimator_
# loss, mae, mape, rmse = best_model.model_.evaluate(x_test, y_test)
# print("Test MSE:", loss)
# print("Test MAE:", mae)
# print("Test MAPE:", mape)
# print("Test RMSE:", rmse)

# %% [markdown]
# ## model 25 (CNN=300 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_25 = Sequential()
model_hybrid_25.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_25.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_25.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_25.add(Flatten())
model_hybrid_25.add(Dense(7))
model_hybrid_25.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_25.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_68"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_74 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_85 (LSTM)                  │ (None, 7, 64)          │        93,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_86 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_68 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_68 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,531 (427.86 KB)
#  Trainable params: 109,531 (427.86 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_25.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=30,
    batch_size=64
)
# Out:
# Epoch 1/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 0.2788 - mean_absolute_error: 0.4960 - mean_absolute_percentage_error: 86.8094 - root_mean_squared_error: 0.5269 - val_loss: 0.0854 - val_mean_absolute_error: 0.2482 - val_mean_absolute_percentage_error: 10852179.0000 - val_root_mean_squared_error: 0.2923
# Epoch 2/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0526 - mean_absolute_error: 0.1810 - mean_absolute_percentage_error: 40.4381 - root_mean_squared_error: 0.2291 - val_loss: 0.0653 - val_mean_absolute_error: 0.2175 - val_mean_absolute_percentage_error: 12180525.0000 - val_root_mean_squared_error: 0.2555
# Epoch 3/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0327 - mean_absolute_error: 0.1472 - mean_absolute_percentage_error: 30.8538 - root_mean_squared_error: 0.1807 - val_loss: 0.0537 - val_mean_absolute_error: 0.1957 - val_mean_absolute_percentage_error: 14968516.0000 - val_root_mean_squared_error: 0.2316
# Epoch 4/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0242 - mean_absolute_error: 0.1205 - mean_absolute_percentage_error: 30.9321 - root_mean_squared_error: 0.1555 - val_loss: 0.0543 - val_mean_absolute_error: 0.1969 - val_mean_absolute_percentage_error: 14132287.0000 - val_root_mean_squared_error: 0.2329
# Epoch 5/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0218 - mean_absolute_error: 0.1158 - mean_absolute_percentage_error: 29.0840 - root_mean_squared_error: 0.1476 - val_loss: 0.0519 - val_mean_absolute_error: 0.1918 - val_mean_absolute_percentage_error: 14725494.0000 - val_root_mean_squared_error: 0.2278
# Epoch 6/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0232 - mean_absolute_error: 0.1189 - mean_absolute_percentage_error: 30.6906 - root_mean_squared_error: 0.1524 - val_loss: 0.0523 - val_mean_absolute_error: 0.1923 - val_mean_absolute_percentage_error: 14588927.0000 - val_root_mean_squared_error: 0.2288
# Epoch 7/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0216 - mean_absolute_error: 0.1137 - mean_absolute_percentage_error: 31.3598 - root_mean_squared_error: 0.1470 - val_loss: 0.0536 - val_mean_absolute_error: 0.1951 - val_mean_absolute_percentage_error: 14185390.0000 - val_root_mean_squared_error: 0.2315
# Epoch 8/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0218 - mean_absolute_error: 0.1156 - mean_absolute_percentage_error: 29.6317 - root_mean_squared_error: 0.1475 - val_loss: 0.0520 - val_mean_absolute_error: 0.1927 - val_mean_absolute_percentage_error: 14557348.0000 - val_root_mean_squared_error: 0.2280
# Epoch 9/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0220 - mean_absolute_error: 0.1152 - mean_absolute_percentage_error: 30.1972 - root_mean_squared_error: 0.1483 - val_loss: 0.0531 - val_mean_absolute_error: 0.1953 - val_mean_absolute_percentage_error: 14173034.0000 - val_root_mean_squared_error: 0.2304
# Epoch 10/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0222 - mean_absolute_error: 0.1166 - mean_absolute_percentage_error: 32.4447 - root_mean_squared_error: 0.1490 - val_loss: 0.0526 - val_mean_absolute_error: 0.1947 - val_mean_absolute_percentage_error: 14301169.0000 - val_root_mean_squared_error: 0.2294
# Epoch 11/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0209 - mean_absolute_error: 0.1123 - mean_absolute_percentage_error: 28.8453 - root_mean_squared_error: 0.1445 - val_loss: 0.0534 - val_mean_absolute_error: 0.1964 - val_mean_absolute_percentage_error: 14044823.0000 - val_root_mean_squared_error: 0.2311
# Epoch 12/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0208 - mean_absolute_error: 0.1129 - mean_absolute_percentage_error: 29.6126 - root_mean_squared_error: 0.1442 - val_loss: 0.0532 - val_mean_absolute_error: 0.1962 - val_mean_absolute_percentage_error: 14132729.0000 - val_root_mean_squared_error: 0.2306
# Epoch 13/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0195 - mean_absolute_error: 0.1087 - mean_absolute_percentage_error: 27.6269 - root_mean_squared_error: 0.1395 - val_loss: 0.0549 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 13644265.0000 - val_root_mean_squared_error: 0.2342
# Epoch 14/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0209 - mean_absolute_error: 0.1125 - mean_absolute_percentage_error: 29.0866 - root_mean_squared_error: 0.1444 - val_loss: 0.0559 - val_mean_absolute_error: 0.2016 - val_mean_absolute_percentage_error: 13375286.0000 - val_root_mean_squared_error: 0.2363
# Epoch 15/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0203 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 28.0382 - root_mean_squared_error: 0.1424 - val_loss: 0.0552 - val_mean_absolute_error: 0.2005 - val_mean_absolute_percentage_error: 13541033.0000 - val_root_mean_squared_error: 0.2350
# Epoch 16/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0193 - mean_absolute_error: 0.1084 - mean_absolute_percentage_error: 26.6847 - root_mean_squared_error: 0.1388 - val_loss: 0.0546 - val_mean_absolute_error: 0.1993 - val_mean_absolute_percentage_error: 13786801.0000 - val_root_mean_squared_error: 0.2338
# Epoch 17/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0196 - mean_absolute_error: 0.1094 - mean_absolute_percentage_error: 27.5495 - root_mean_squared_error: 0.1401 - val_loss: 0.0550 - val_mean_absolute_error: 0.2005 - val_mean_absolute_percentage_error: 13620370.0000 - val_root_mean_squared_error: 0.2345
# Epoch 18/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0201 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 28.2324 - root_mean_squared_error: 0.1418 - val_loss: 0.0543 - val_mean_absolute_error: 0.1992 - val_mean_absolute_percentage_error: 13809030.0000 - val_root_mean_squared_error: 0.2331
# Epoch 19/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0198 - mean_absolute_error: 0.1100 - mean_absolute_percentage_error: 29.1240 - root_mean_squared_error: 0.1408 - val_loss: 0.0542 - val_mean_absolute_error: 0.1990 - val_mean_absolute_percentage_error: 14064171.0000 - val_root_mean_squared_error: 0.2327
# Epoch 20/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0191 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 27.2979 - root_mean_squared_error: 0.1381 - val_loss: 0.0550 - val_mean_absolute_error: 0.2007 - val_mean_absolute_percentage_error: 13689449.0000 - val_root_mean_squared_error: 0.2344
# Epoch 21/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0192 - mean_absolute_error: 0.1079 - mean_absolute_percentage_error: 26.7542 - root_mean_squared_error: 0.1385 - val_loss: 0.0563 - val_mean_absolute_error: 0.2021 - val_mean_absolute_percentage_error: 13405507.0000 - val_root_mean_squared_error: 0.2372
# Epoch 22/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0193 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 26.7267 - root_mean_squared_error: 0.1388 - val_loss: 0.0564 - val_mean_absolute_error: 0.2032 - val_mean_absolute_percentage_error: 13336799.0000 - val_root_mean_squared_error: 0.2375
# Epoch 23/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0194 - mean_absolute_error: 0.1093 - mean_absolute_percentage_error: 28.3191 - root_mean_squared_error: 0.1393 - val_loss: 0.0549 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 13902394.0000 - val_root_mean_squared_error: 0.2344
# Epoch 24/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0192 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 27.8764 - root_mean_squared_error: 0.1387 - val_loss: 0.0558 - val_mean_absolute_error: 0.2026 - val_mean_absolute_percentage_error: 13540555.0000 - val_root_mean_squared_error: 0.2362
# Epoch 25/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0196 - mean_absolute_error: 0.1092 - mean_absolute_percentage_error: 27.5651 - root_mean_squared_error: 0.1398 - val_loss: 0.0554 - val_mean_absolute_error: 0.2013 - val_mean_absolute_percentage_error: 13717350.0000 - val_root_mean_squared_error: 0.2354
# Epoch 26/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0182 - mean_absolute_error: 0.1049 - mean_absolute_percentage_error: 27.0912 - root_mean_squared_error: 0.1349 - val_loss: 0.0567 - val_mean_absolute_error: 0.2036 - val_mean_absolute_percentage_error: 13413053.0000 - val_root_mean_squared_error: 0.2380
# Epoch 27/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0186 - mean_absolute_error: 0.1066 - mean_absolute_percentage_error: 25.9139 - root_mean_squared_error: 0.1364 - val_loss: 0.0593 - val_mean_absolute_error: 0.2070 - val_mean_absolute_percentage_error: 12980814.0000 - val_root_mean_squared_error: 0.2435
# Epoch 28/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0192 - mean_absolute_error: 0.1089 - mean_absolute_percentage_error: 27.8815 - root_mean_squared_error: 0.1386 - val_loss: 0.0559 - val_mean_absolute_error: 0.2020 - val_mean_absolute_percentage_error: 13790872.0000 - val_root_mean_squared_error: 0.2363
# Epoch 29/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0191 - mean_absolute_error: 0.1077 - mean_absolute_percentage_error: 28.2529 - root_mean_squared_error: 0.1382 - val_loss: 0.0555 - val_mean_absolute_error: 0.2021 - val_mean_absolute_percentage_error: 13727526.0000 - val_root_mean_squared_error: 0.2357
# Epoch 30/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0198 - mean_absolute_error: 0.1101 - mean_absolute_percentage_error: 28.8167 - root_mean_squared_error: 0.1408 - val_loss: 0.0550 - val_mean_absolute_error: 0.2008 - val_mean_absolute_percentage_error: 14162228.0000 - val_root_mean_squared_error: 0.2345

# %%
y_pred = model_hybrid_25.predict(x_test)

evaluation_hybrid_25 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_25
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# {'Mean Squared Error: ': np.float64(393.01347593562076),
#  'Mean Absolute Error: ': np.float64(15.011197187462633),
#  'Root Mean Absolute Error: ': 19.824567484200525,
#  'Mean Absolute Percentage Error: ': np.float64(28.4413327335505)}

# %%
loss, mae, mape, rmse = model_hybrid_25.evaluate(x_test, y_test)
print("model hybrid 25")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0313 - mean_absolute_error: 0.1340 - mean_absolute_percentage_error: 36.2400 - root_mean_squared_error: 0.1770
# model hybrid 25
# Mean Square Error: 0.03133079409599304
# Mean Absolute Error: 0.13402853906154633
# Mean Absolute Percentage Error: 36.23999786376953
# Root Mean Squared Error: 0.17700506746768951

# %% [markdown]
# ## model 26 (CNN=300 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_26 = Sequential()
model_hybrid_26.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_26.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_26.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_26.add(Flatten())
model_hybrid_26.add(Dense(7))
model_hybrid_26.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_26.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_69"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_75 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_87 (LSTM)                  │ (None, 7, 64)          │        93,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_88 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_69 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_69 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,531 (427.86 KB)
#  Trainable params: 109,531 (427.86 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_26.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=64
)
# Out:
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 0.3218 - mean_absolute_error: 0.5381 - mean_absolute_percentage_error: 94.8600 - root_mean_squared_error: 0.5670 - val_loss: 0.2085 - val_mean_absolute_error: 0.4027 - val_mean_absolute_percentage_error: 5694891.0000 - val_root_mean_squared_error: 0.4566
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1447 - mean_absolute_error: 0.3130 - mean_absolute_percentage_error: 58.5948 - root_mean_squared_error: 0.3797 - val_loss: 0.0743 - val_mean_absolute_error: 0.2284 - val_mean_absolute_percentage_error: 12697804.0000 - val_root_mean_squared_error: 0.2726
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0364 - mean_absolute_error: 0.1542 - mean_absolute_percentage_error: 35.1181 - root_mean_squared_error: 0.1905 - val_loss: 0.0562 - val_mean_absolute_error: 0.1975 - val_mean_absolute_percentage_error: 14836739.0000 - val_root_mean_squared_error: 0.2370
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0265 - mean_absolute_error: 0.1283 - mean_absolute_percentage_error: 31.8707 - root_mean_squared_error: 0.1628 - val_loss: 0.0516 - val_mean_absolute_error: 0.1884 - val_mean_absolute_percentage_error: 15412694.0000 - val_root_mean_squared_error: 0.2272
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0235 - mean_absolute_error: 0.1200 - mean_absolute_percentage_error: 30.6494 - root_mean_squared_error: 0.1533 - val_loss: 0.0514 - val_mean_absolute_error: 0.1880 - val_mean_absolute_percentage_error: 15105813.0000 - val_root_mean_squared_error: 0.2267
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0228 - mean_absolute_error: 0.1174 - mean_absolute_percentage_error: 32.0952 - root_mean_squared_error: 0.1509 - val_loss: 0.0517 - val_mean_absolute_error: 0.1897 - val_mean_absolute_percentage_error: 14983811.0000 - val_root_mean_squared_error: 0.2273
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0223 - mean_absolute_error: 0.1159 - mean_absolute_percentage_error: 31.2826 - root_mean_squared_error: 0.1492 - val_loss: 0.0523 - val_mean_absolute_error: 0.1920 - val_mean_absolute_percentage_error: 14694871.0000 - val_root_mean_squared_error: 0.2286
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0212 - mean_absolute_error: 0.1133 - mean_absolute_percentage_error: 29.0669 - root_mean_squared_error: 0.1457 - val_loss: 0.0530 - val_mean_absolute_error: 0.1936 - val_mean_absolute_percentage_error: 14487986.0000 - val_root_mean_squared_error: 0.2303
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0210 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 28.3084 - root_mean_squared_error: 0.1448 - val_loss: 0.0553 - val_mean_absolute_error: 0.1980 - val_mean_absolute_percentage_error: 13875276.0000 - val_root_mean_squared_error: 0.2352
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0210 - mean_absolute_error: 0.1141 - mean_absolute_percentage_error: 28.0917 - root_mean_squared_error: 0.1449 - val_loss: 0.0533 - val_mean_absolute_error: 0.1947 - val_mean_absolute_percentage_error: 14473579.0000 - val_root_mean_squared_error: 0.2308
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0206 - mean_absolute_error: 0.1115 - mean_absolute_percentage_error: 28.2095 - root_mean_squared_error: 0.1437 - val_loss: 0.0574 - val_mean_absolute_error: 0.2015 - val_mean_absolute_percentage_error: 13436678.0000 - val_root_mean_squared_error: 0.2397
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0214 - mean_absolute_error: 0.1153 - mean_absolute_percentage_error: 27.1191 - root_mean_squared_error: 0.1463 - val_loss: 0.0565 - val_mean_absolute_error: 0.2006 - val_mean_absolute_percentage_error: 13616872.0000 - val_root_mean_squared_error: 0.2377
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0204 - mean_absolute_error: 0.1130 - mean_absolute_percentage_error: 28.3009 - root_mean_squared_error: 0.1429 - val_loss: 0.0558 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 13863471.0000 - val_root_mean_squared_error: 0.2363
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0213 - mean_absolute_error: 0.1149 - mean_absolute_percentage_error: 28.6767 - root_mean_squared_error: 0.1458 - val_loss: 0.0547 - val_mean_absolute_error: 0.1975 - val_mean_absolute_percentage_error: 14141124.0000 - val_root_mean_squared_error: 0.2338
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0213 - mean_absolute_error: 0.1142 - mean_absolute_percentage_error: 29.3356 - root_mean_squared_error: 0.1460 - val_loss: 0.0551 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 14137510.0000 - val_root_mean_squared_error: 0.2347
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0199 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 27.6954 - root_mean_squared_error: 0.1410 - val_loss: 0.0544 - val_mean_absolute_error: 0.1980 - val_mean_absolute_percentage_error: 14506798.0000 - val_root_mean_squared_error: 0.2332
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0205 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 29.9195 - root_mean_squared_error: 0.1432 - val_loss: 0.0543 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 14573638.0000 - val_root_mean_squared_error: 0.2330
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0189 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 27.6704 - root_mean_squared_error: 0.1374 - val_loss: 0.0555 - val_mean_absolute_error: 0.2004 - val_mean_absolute_percentage_error: 14240909.0000 - val_root_mean_squared_error: 0.2357
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0200 - mean_absolute_error: 0.1106 - mean_absolute_percentage_error: 28.5208 - root_mean_squared_error: 0.1415 - val_loss: 0.0559 - val_mean_absolute_error: 0.2003 - val_mean_absolute_percentage_error: 14361354.0000 - val_root_mean_squared_error: 0.2363
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0196 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 27.7850 - root_mean_squared_error: 0.1400 - val_loss: 0.0549 - val_mean_absolute_error: 0.1999 - val_mean_absolute_percentage_error: 14771578.0000 - val_root_mean_squared_error: 0.2344

# %%
y_pred = model_hybrid_26.predict(x_test)

evaluation_hybrid_26 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_26
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# {'Mean Squared Error: ': np.float64(409.9505542328133),
#  'Mean Absolute Error: ': np.float64(15.554531175263076),
#  'Root Mean Absolute Error: ': 20.247235718310126,
#  'Mean Absolute Percentage Error: ': np.float64(29.115850689134337)}

# %%
loss, mae, mape, rmse = model_hybrid_26.evaluate(x_test, y_test)
print("model hybrid 26")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0327 - mean_absolute_error: 0.1389 - mean_absolute_percentage_error: 37.0046 - root_mean_squared_error: 0.1808
# model hybrid 26
# Mean Square Error: 0.03268100693821907
# Mean Absolute Error: 0.13887974619865417
# Mean Absolute Percentage Error: 37.00458908081055
# Root Mean Squared Error: 0.1807788908481598

# %% [markdown]
# ## model 27 (CNN=300 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_27 = Sequential()
model_hybrid_27.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_27.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_27.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_27.add(Flatten())
model_hybrid_27.add(Dense(7))
model_hybrid_27.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_27.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_70"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_76 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_89 (LSTM)                  │ (None, 7, 64)          │        93,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_90 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_70 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_70 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,531 (427.86 KB)
#  Trainable params: 109,531 (427.86 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_27.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=40,
    batch_size=64
)
# Out:
# Epoch 1/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 0.3279 - mean_absolute_error: 0.5437 - mean_absolute_percentage_error: 95.5064 - root_mean_squared_error: 0.5723 - val_loss: 0.2058 - val_mean_absolute_error: 0.4055 - val_mean_absolute_percentage_error: 4603568.5000 - val_root_mean_squared_error: 0.4537
# Epoch 2/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1287 - mean_absolute_error: 0.3032 - mean_absolute_percentage_error: 55.3897 - root_mean_squared_error: 0.3568 - val_loss: 0.0649 - val_mean_absolute_error: 0.2180 - val_mean_absolute_percentage_error: 13868003.0000 - val_root_mean_squared_error: 0.2547
# Epoch 3/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0319 - mean_absolute_error: 0.1407 - mean_absolute_percentage_error: 32.3439 - root_mean_squared_error: 0.1786 - val_loss: 0.0559 - val_mean_absolute_error: 0.1985 - val_mean_absolute_percentage_error: 15086513.0000 - val_root_mean_squared_error: 0.2364
# Epoch 4/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0264 - mean_absolute_error: 0.1283 - mean_absolute_percentage_error: 31.1908 - root_mean_squared_error: 0.1625 - val_loss: 0.0540 - val_mean_absolute_error: 0.1942 - val_mean_absolute_percentage_error: 14593272.0000 - val_root_mean_squared_error: 0.2323
# Epoch 5/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0212 - mean_absolute_error: 0.1134 - mean_absolute_percentage_error: 28.0448 - root_mean_squared_error: 0.1456 - val_loss: 0.0536 - val_mean_absolute_error: 0.1930 - val_mean_absolute_percentage_error: 14625400.0000 - val_root_mean_squared_error: 0.2315
# Epoch 6/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0224 - mean_absolute_error: 0.1159 - mean_absolute_percentage_error: 29.4358 - root_mean_squared_error: 0.1495 - val_loss: 0.0536 - val_mean_absolute_error: 0.1930 - val_mean_absolute_percentage_error: 14540513.0000 - val_root_mean_squared_error: 0.2316
# Epoch 7/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0219 - mean_absolute_error: 0.1147 - mean_absolute_percentage_error: 29.8715 - root_mean_squared_error: 0.1480 - val_loss: 0.0533 - val_mean_absolute_error: 0.1931 - val_mean_absolute_percentage_error: 14584813.0000 - val_root_mean_squared_error: 0.2309
# Epoch 8/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0208 - mean_absolute_error: 0.1123 - mean_absolute_percentage_error: 28.1510 - root_mean_squared_error: 0.1441 - val_loss: 0.0543 - val_mean_absolute_error: 0.1958 - val_mean_absolute_percentage_error: 14228551.0000 - val_root_mean_squared_error: 0.2330
# Epoch 9/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0205 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 28.9000 - root_mean_squared_error: 0.1432 - val_loss: 0.0563 - val_mean_absolute_error: 0.1998 - val_mean_absolute_percentage_error: 13703369.0000 - val_root_mean_squared_error: 0.2372
# Epoch 10/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0202 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 26.7837 - root_mean_squared_error: 0.1420 - val_loss: 0.0560 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 13913633.0000 - val_root_mean_squared_error: 0.2367
# Epoch 11/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0200 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 27.4775 - root_mean_squared_error: 0.1412 - val_loss: 0.0558 - val_mean_absolute_error: 0.1989 - val_mean_absolute_percentage_error: 13861103.0000 - val_root_mean_squared_error: 0.2362
# Epoch 12/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0190 - mean_absolute_error: 0.1077 - mean_absolute_percentage_error: 26.8765 - root_mean_squared_error: 0.1377 - val_loss: 0.0591 - val_mean_absolute_error: 0.2046 - val_mean_absolute_percentage_error: 13192213.0000 - val_root_mean_squared_error: 0.2430
# Epoch 13/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0204 - mean_absolute_error: 0.1119 - mean_absolute_percentage_error: 26.9023 - root_mean_squared_error: 0.1429 - val_loss: 0.0577 - val_mean_absolute_error: 0.2018 - val_mean_absolute_percentage_error: 13547289.0000 - val_root_mean_squared_error: 0.2403
# Epoch 14/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0197 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 27.5525 - root_mean_squared_error: 0.1402 - val_loss: 0.0599 - val_mean_absolute_error: 0.2065 - val_mean_absolute_percentage_error: 13035488.0000 - val_root_mean_squared_error: 0.2447
# Epoch 15/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0203 - mean_absolute_error: 0.1124 - mean_absolute_percentage_error: 27.4295 - root_mean_squared_error: 0.1423 - val_loss: 0.0579 - val_mean_absolute_error: 0.2027 - val_mean_absolute_percentage_error: 13543339.0000 - val_root_mean_squared_error: 0.2407
# Epoch 16/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0195 - mean_absolute_error: 0.1092 - mean_absolute_percentage_error: 28.1987 - root_mean_squared_error: 0.1396 - val_loss: 0.0583 - val_mean_absolute_error: 0.2037 - val_mean_absolute_percentage_error: 13477251.0000 - val_root_mean_squared_error: 0.2415
# Epoch 17/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0214 - mean_absolute_error: 0.1153 - mean_absolute_percentage_error: 29.1651 - root_mean_squared_error: 0.1463 - val_loss: 0.0552 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 14289117.0000 - val_root_mean_squared_error: 0.2350
# Epoch 18/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0199 - mean_absolute_error: 0.1103 - mean_absolute_percentage_error: 27.7666 - root_mean_squared_error: 0.1409 - val_loss: 0.0558 - val_mean_absolute_error: 0.2004 - val_mean_absolute_percentage_error: 14222989.0000 - val_root_mean_squared_error: 0.2361
# Epoch 19/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0197 - mean_absolute_error: 0.1094 - mean_absolute_percentage_error: 28.1276 - root_mean_squared_error: 0.1403 - val_loss: 0.0556 - val_mean_absolute_error: 0.1991 - val_mean_absolute_percentage_error: 14386658.0000 - val_root_mean_squared_error: 0.2358
# Epoch 20/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0199 - mean_absolute_error: 0.1104 - mean_absolute_percentage_error: 28.7679 - root_mean_squared_error: 0.1410 - val_loss: 0.0556 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 14442995.0000 - val_root_mean_squared_error: 0.2359
# Epoch 21/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0193 - mean_absolute_error: 0.1082 - mean_absolute_percentage_error: 27.4004 - root_mean_squared_error: 0.1388 - val_loss: 0.0567 - val_mean_absolute_error: 0.2020 - val_mean_absolute_percentage_error: 14199165.0000 - val_root_mean_squared_error: 0.2382
# Epoch 22/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0198 - mean_absolute_error: 0.1095 - mean_absolute_percentage_error: 28.2014 - root_mean_squared_error: 0.1407 - val_loss: 0.0554 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 14752064.0000 - val_root_mean_squared_error: 0.2353
# Epoch 23/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0205 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 29.1484 - root_mean_squared_error: 0.1430 - val_loss: 0.0596 - val_mean_absolute_error: 0.2059 - val_mean_absolute_percentage_error: 13620808.0000 - val_root_mean_squared_error: 0.2441
# Epoch 24/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0199 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 26.7428 - root_mean_squared_error: 0.1411 - val_loss: 0.0580 - val_mean_absolute_error: 0.2034 - val_mean_absolute_percentage_error: 14146340.0000 - val_root_mean_squared_error: 0.2408
# Epoch 25/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0195 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 27.5495 - root_mean_squared_error: 0.1396 - val_loss: 0.0577 - val_mean_absolute_error: 0.2031 - val_mean_absolute_percentage_error: 14217558.0000 - val_root_mean_squared_error: 0.2401
# Epoch 26/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0193 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 27.3269 - root_mean_squared_error: 0.1388 - val_loss: 0.0568 - val_mean_absolute_error: 0.2012 - val_mean_absolute_percentage_error: 14522411.0000 - val_root_mean_squared_error: 0.2382
# Epoch 27/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0184 - mean_absolute_error: 0.1059 - mean_absolute_percentage_error: 26.7666 - root_mean_squared_error: 0.1358 - val_loss: 0.0569 - val_mean_absolute_error: 0.2025 - val_mean_absolute_percentage_error: 14542687.0000 - val_root_mean_squared_error: 0.2385
# Epoch 28/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0181 - mean_absolute_error: 0.1048 - mean_absolute_percentage_error: 26.0077 - root_mean_squared_error: 0.1343 - val_loss: 0.0555 - val_mean_absolute_error: 0.1993 - val_mean_absolute_percentage_error: 15157049.0000 - val_root_mean_squared_error: 0.2355
# Epoch 29/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0197 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 30.3381 - root_mean_squared_error: 0.1402 - val_loss: 0.0573 - val_mean_absolute_error: 0.2018 - val_mean_absolute_percentage_error: 14891799.0000 - val_root_mean_squared_error: 0.2394
# Epoch 30/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0188 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 26.8664 - root_mean_squared_error: 0.1370 - val_loss: 0.0571 - val_mean_absolute_error: 0.2024 - val_mean_absolute_percentage_error: 14843533.0000 - val_root_mean_squared_error: 0.2389
# Epoch 31/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0181 - mean_absolute_error: 0.1045 - mean_absolute_percentage_error: 26.4090 - root_mean_squared_error: 0.1345 - val_loss: 0.0586 - val_mean_absolute_error: 0.2053 - val_mean_absolute_percentage_error: 14569555.0000 - val_root_mean_squared_error: 0.2420
# Epoch 32/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0190 - mean_absolute_error: 0.1071 - mean_absolute_percentage_error: 26.9653 - root_mean_squared_error: 0.1377 - val_loss: 0.0552 - val_mean_absolute_error: 0.1990 - val_mean_absolute_percentage_error: 15493396.0000 - val_root_mean_squared_error: 0.2349
# Epoch 33/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0187 - mean_absolute_error: 0.1061 - mean_absolute_percentage_error: 27.4246 - root_mean_squared_error: 0.1367 - val_loss: 0.0555 - val_mean_absolute_error: 0.1984 - val_mean_absolute_percentage_error: 15946072.0000 - val_root_mean_squared_error: 0.2356
# Epoch 34/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0186 - mean_absolute_error: 0.1050 - mean_absolute_percentage_error: 27.3319 - root_mean_squared_error: 0.1365 - val_loss: 0.0567 - val_mean_absolute_error: 0.2006 - val_mean_absolute_percentage_error: 15328051.0000 - val_root_mean_squared_error: 0.2380
# Epoch 35/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0173 - mean_absolute_error: 0.1026 - mean_absolute_percentage_error: 25.4321 - root_mean_squared_error: 0.1317 - val_loss: 0.0564 - val_mean_absolute_error: 0.2010 - val_mean_absolute_percentage_error: 15483418.0000 - val_root_mean_squared_error: 0.2374
# Epoch 36/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0175 - mean_absolute_error: 0.1028 - mean_absolute_percentage_error: 26.4024 - root_mean_squared_error: 0.1323 - val_loss: 0.0562 - val_mean_absolute_error: 0.2004 - val_mean_absolute_percentage_error: 15848469.0000 - val_root_mean_squared_error: 0.2371
# Epoch 37/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0175 - mean_absolute_error: 0.1023 - mean_absolute_percentage_error: 26.3789 - root_mean_squared_error: 0.1322 - val_loss: 0.0564 - val_mean_absolute_error: 0.2007 - val_mean_absolute_percentage_error: 15657484.0000 - val_root_mean_squared_error: 0.2375
# Epoch 38/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0180 - mean_absolute_error: 0.1050 - mean_absolute_percentage_error: 26.3563 - root_mean_squared_error: 0.1343 - val_loss: 0.0573 - val_mean_absolute_error: 0.2035 - val_mean_absolute_percentage_error: 15416450.0000 - val_root_mean_squared_error: 0.2394
# Epoch 39/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0175 - mean_absolute_error: 0.1021 - mean_absolute_percentage_error: 25.4566 - root_mean_squared_error: 0.1323 - val_loss: 0.0586 - val_mean_absolute_error: 0.2059 - val_mean_absolute_percentage_error: 14937748.0000 - val_root_mean_squared_error: 0.2420
# Epoch 40/40
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0171 - mean_absolute_error: 0.1016 - mean_absolute_percentage_error: 25.0511 - root_mean_squared_error: 0.1309 - val_loss: 0.0590 - val_mean_absolute_error: 0.2073 - val_mean_absolute_percentage_error: 15104217.0000 - val_root_mean_squared_error: 0.2430

# %%
y_pred = model_hybrid_27.predict(x_test)

evaluation_hybrid_27 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_27
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# {'Mean Squared Error: ': np.float64(277.32177746283327),
#  'Mean Absolute Error: ': np.float64(12.84862239993348),
#  'Root Mean Absolute Error: ': 16.65298103832564,
#  'Mean Absolute Percentage Error: ': np.float64(23.80616432817356)}

# %%
loss, mae, mape, rmse = model_hybrid_27.evaluate(x_test, y_test)
print("model hybrid 27")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0221 - mean_absolute_error: 0.1147 - mean_absolute_percentage_error: 30.3095 - root_mean_squared_error: 0.1487
# model hybrid 27
# Mean Square Error: 0.0221079234033823
# Mean Absolute Error: 0.11471984535455704
# Mean Absolute Percentage Error: 30.309520721435547
# Root Mean Squared Error: 0.14868733286857605

# %% [markdown]
# ## model 28 (CNN=300 LSTM=64, 32)

# %%
lr = 0.0003

model_hybrid_28 = Sequential()
model_hybrid_28.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_28.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_28.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_28.add(Flatten())
model_hybrid_28.add(Dense(7))
model_hybrid_28.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_28.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_71"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_77 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_91 (LSTM)                  │ (None, 7, 64)          │        93,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_92 (LSTM)                  │ (None, 7, 32)          │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_71 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_71 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,531 (427.86 KB)
#  Trainable params: 109,531 (427.86 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_28.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=40,
    batch_size=42
)
# Out:
# Epoch 1/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.3022 - mean_absolute_error: 0.5163 - mean_absolute_percentage_error: 91.6659 - root_mean_squared_error: 0.5490 - val_loss: 0.1209 - val_mean_absolute_error: 0.2888 - val_mean_absolute_percentage_error: 13564192.0000 - val_root_mean_squared_error: 0.3476
# Epoch 2/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0651 - mean_absolute_error: 0.1979 - mean_absolute_percentage_error: 41.8110 - root_mean_squared_error: 0.2531 - val_loss: 0.0528 - val_mean_absolute_error: 0.1925 - val_mean_absolute_percentage_error: 15921965.0000 - val_root_mean_squared_error: 0.2299
# Epoch 3/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0243 - mean_absolute_error: 0.1218 - mean_absolute_percentage_error: 30.2422 - root_mean_squared_error: 0.1560 - val_loss: 0.0528 - val_mean_absolute_error: 0.1917 - val_mean_absolute_percentage_error: 15383220.0000 - val_root_mean_squared_error: 0.2298
# Epoch 4/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0232 - mean_absolute_error: 0.1179 - mean_absolute_percentage_error: 30.5557 - root_mean_squared_error: 0.1521 - val_loss: 0.0520 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 14971555.0000 - val_root_mean_squared_error: 0.2281
# Epoch 5/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0216 - mean_absolute_error: 0.1143 - mean_absolute_percentage_error: 28.6529 - root_mean_squared_error: 0.1471 - val_loss: 0.0520 - val_mean_absolute_error: 0.1912 - val_mean_absolute_percentage_error: 14876030.0000 - val_root_mean_squared_error: 0.2280
# Epoch 6/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0217 - mean_absolute_error: 0.1147 - mean_absolute_percentage_error: 30.2897 - root_mean_squared_error: 0.1472 - val_loss: 0.0541 - val_mean_absolute_error: 0.1964 - val_mean_absolute_percentage_error: 14121990.0000 - val_root_mean_squared_error: 0.2327
# Epoch 7/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0215 - mean_absolute_error: 0.1147 - mean_absolute_percentage_error: 28.9521 - root_mean_squared_error: 0.1467 - val_loss: 0.0533 - val_mean_absolute_error: 0.1956 - val_mean_absolute_percentage_error: 14328746.0000 - val_root_mean_squared_error: 0.2309
# Epoch 8/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0212 - mean_absolute_error: 0.1140 - mean_absolute_percentage_error: 30.3110 - root_mean_squared_error: 0.1454 - val_loss: 0.0541 - val_mean_absolute_error: 0.1972 - val_mean_absolute_percentage_error: 14145518.0000 - val_root_mean_squared_error: 0.2325
# Epoch 9/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0198 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 27.3226 - root_mean_squared_error: 0.1406 - val_loss: 0.0566 - val_mean_absolute_error: 0.2015 - val_mean_absolute_percentage_error: 13504385.0000 - val_root_mean_squared_error: 0.2379
# Epoch 10/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0207 - mean_absolute_error: 0.1120 - mean_absolute_percentage_error: 29.2922 - root_mean_squared_error: 0.1437 - val_loss: 0.0547 - val_mean_absolute_error: 0.1985 - val_mean_absolute_percentage_error: 14021863.0000 - val_root_mean_squared_error: 0.2338
# Epoch 11/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0193 - mean_absolute_error: 0.1084 - mean_absolute_percentage_error: 27.5071 - root_mean_squared_error: 0.1387 - val_loss: 0.0572 - val_mean_absolute_error: 0.2019 - val_mean_absolute_percentage_error: 13424765.0000 - val_root_mean_squared_error: 0.2392
# Epoch 12/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0201 - mean_absolute_error: 0.1104 - mean_absolute_percentage_error: 28.2828 - root_mean_squared_error: 0.1418 - val_loss: 0.0597 - val_mean_absolute_error: 0.2058 - val_mean_absolute_percentage_error: 12958176.0000 - val_root_mean_squared_error: 0.2444
# Epoch 13/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0200 - mean_absolute_error: 0.1115 - mean_absolute_percentage_error: 27.6957 - root_mean_squared_error: 0.1414 - val_loss: 0.0538 - val_mean_absolute_error: 0.1976 - val_mean_absolute_percentage_error: 14556766.0000 - val_root_mean_squared_error: 0.2320
# Epoch 14/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0191 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 26.8673 - root_mean_squared_error: 0.1381 - val_loss: 0.0568 - val_mean_absolute_error: 0.2029 - val_mean_absolute_percentage_error: 13665940.0000 - val_root_mean_squared_error: 0.2383
# Epoch 15/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0197 - mean_absolute_error: 0.1096 - mean_absolute_percentage_error: 27.9388 - root_mean_squared_error: 0.1402 - val_loss: 0.0530 - val_mean_absolute_error: 0.1950 - val_mean_absolute_percentage_error: 14887298.0000 - val_root_mean_squared_error: 0.2303
# Epoch 16/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0190 - mean_absolute_error: 0.1077 - mean_absolute_percentage_error: 27.1418 - root_mean_squared_error: 0.1379 - val_loss: 0.0553 - val_mean_absolute_error: 0.2005 - val_mean_absolute_percentage_error: 14025956.0000 - val_root_mean_squared_error: 0.2351
# Epoch 17/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0201 - mean_absolute_error: 0.1102 - mean_absolute_percentage_error: 28.4934 - root_mean_squared_error: 0.1417 - val_loss: 0.0537 - val_mean_absolute_error: 0.1966 - val_mean_absolute_percentage_error: 14688298.0000 - val_root_mean_squared_error: 0.2318
# Epoch 18/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0182 - mean_absolute_error: 0.1051 - mean_absolute_percentage_error: 25.6388 - root_mean_squared_error: 0.1350 - val_loss: 0.0555 - val_mean_absolute_error: 0.2007 - val_mean_absolute_percentage_error: 14098586.0000 - val_root_mean_squared_error: 0.2357
# Epoch 19/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0186 - mean_absolute_error: 0.1060 - mean_absolute_percentage_error: 25.7066 - root_mean_squared_error: 0.1364 - val_loss: 0.0549 - val_mean_absolute_error: 0.1999 - val_mean_absolute_percentage_error: 14516322.0000 - val_root_mean_squared_error: 0.2343
# Epoch 20/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0197 - mean_absolute_error: 0.1093 - mean_absolute_percentage_error: 27.6972 - root_mean_squared_error: 0.1404 - val_loss: 0.0550 - val_mean_absolute_error: 0.1997 - val_mean_absolute_percentage_error: 14864306.0000 - val_root_mean_squared_error: 0.2345
# Epoch 21/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0194 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 28.5854 - root_mean_squared_error: 0.1392 - val_loss: 0.0606 - val_mean_absolute_error: 0.2092 - val_mean_absolute_percentage_error: 13158830.0000 - val_root_mean_squared_error: 0.2463
# Epoch 22/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0202 - mean_absolute_error: 0.1118 - mean_absolute_percentage_error: 26.7336 - root_mean_squared_error: 0.1420 - val_loss: 0.0543 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 14786131.0000 - val_root_mean_squared_error: 0.2331
# Epoch 23/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0194 - mean_absolute_error: 0.1067 - mean_absolute_percentage_error: 29.3027 - root_mean_squared_error: 0.1392 - val_loss: 0.0570 - val_mean_absolute_error: 0.2029 - val_mean_absolute_percentage_error: 13940383.0000 - val_root_mean_squared_error: 0.2387
# Epoch 24/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0180 - mean_absolute_error: 0.1047 - mean_absolute_percentage_error: 25.9170 - root_mean_squared_error: 0.1341 - val_loss: 0.0589 - val_mean_absolute_error: 0.2076 - val_mean_absolute_percentage_error: 13707146.0000 - val_root_mean_squared_error: 0.2427
# Epoch 25/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0189 - mean_absolute_error: 0.1080 - mean_absolute_percentage_error: 26.7416 - root_mean_squared_error: 0.1375 - val_loss: 0.0556 - val_mean_absolute_error: 0.2006 - val_mean_absolute_percentage_error: 14858947.0000 - val_root_mean_squared_error: 0.2358
# Epoch 26/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0192 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 27.7645 - root_mean_squared_error: 0.1385 - val_loss: 0.0548 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 14837404.0000 - val_root_mean_squared_error: 0.2341
# Epoch 27/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0195 - mean_absolute_error: 0.1087 - mean_absolute_percentage_error: 27.4302 - root_mean_squared_error: 0.1396 - val_loss: 0.0603 - val_mean_absolute_error: 0.2105 - val_mean_absolute_percentage_error: 13410721.0000 - val_root_mean_squared_error: 0.2456
# Epoch 28/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0176 - mean_absolute_error: 0.1031 - mean_absolute_percentage_error: 24.7009 - root_mean_squared_error: 0.1325 - val_loss: 0.0564 - val_mean_absolute_error: 0.2033 - val_mean_absolute_percentage_error: 14456333.0000 - val_root_mean_squared_error: 0.2376
# Epoch 29/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0177 - mean_absolute_error: 0.1034 - mean_absolute_percentage_error: 25.8833 - root_mean_squared_error: 0.1332 - val_loss: 0.0581 - val_mean_absolute_error: 0.2075 - val_mean_absolute_percentage_error: 13926706.0000 - val_root_mean_squared_error: 0.2410
# Epoch 30/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0184 - mean_absolute_error: 0.1063 - mean_absolute_percentage_error: 27.5409 - root_mean_squared_error: 0.1356 - val_loss: 0.0569 - val_mean_absolute_error: 0.2043 - val_mean_absolute_percentage_error: 14595933.0000 - val_root_mean_squared_error: 0.2386
# Epoch 31/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0178 - mean_absolute_error: 0.1043 - mean_absolute_percentage_error: 27.3154 - root_mean_squared_error: 0.1335 - val_loss: 0.0587 - val_mean_absolute_error: 0.2094 - val_mean_absolute_percentage_error: 13993175.0000 - val_root_mean_squared_error: 0.2423
# Epoch 32/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0174 - mean_absolute_error: 0.1027 - mean_absolute_percentage_error: 25.7825 - root_mean_squared_error: 0.1319 - val_loss: 0.0582 - val_mean_absolute_error: 0.2080 - val_mean_absolute_percentage_error: 14172582.0000 - val_root_mean_squared_error: 0.2413
# Epoch 33/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0172 - mean_absolute_error: 0.1029 - mean_absolute_percentage_error: 27.0039 - root_mean_squared_error: 0.1313 - val_loss: 0.0561 - val_mean_absolute_error: 0.2014 - val_mean_absolute_percentage_error: 15204716.0000 - val_root_mean_squared_error: 0.2369
# Epoch 34/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0180 - mean_absolute_error: 0.1045 - mean_absolute_percentage_error: 27.6862 - root_mean_squared_error: 0.1342 - val_loss: 0.0602 - val_mean_absolute_error: 0.2131 - val_mean_absolute_percentage_error: 13727729.0000 - val_root_mean_squared_error: 0.2453
# Epoch 35/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0173 - mean_absolute_error: 0.1025 - mean_absolute_percentage_error: 26.3637 - root_mean_squared_error: 0.1315 - val_loss: 0.0589 - val_mean_absolute_error: 0.2102 - val_mean_absolute_percentage_error: 14373283.0000 - val_root_mean_squared_error: 0.2427
# Epoch 36/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0167 - mean_absolute_error: 0.1006 - mean_absolute_percentage_error: 24.9849 - root_mean_squared_error: 0.1292 - val_loss: 0.0589 - val_mean_absolute_error: 0.2071 - val_mean_absolute_percentage_error: 15144449.0000 - val_root_mean_squared_error: 0.2427
# Epoch 37/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0178 - mean_absolute_error: 0.1042 - mean_absolute_percentage_error: 26.9226 - root_mean_squared_error: 0.1333 - val_loss: 0.0589 - val_mean_absolute_error: 0.2070 - val_mean_absolute_percentage_error: 15018297.0000 - val_root_mean_squared_error: 0.2427
# Epoch 38/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0175 - mean_absolute_error: 0.1039 - mean_absolute_percentage_error: 26.2662 - root_mean_squared_error: 0.1322 - val_loss: 0.0622 - val_mean_absolute_error: 0.2188 - val_mean_absolute_percentage_error: 13431948.0000 - val_root_mean_squared_error: 0.2493
# Epoch 39/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0172 - mean_absolute_error: 0.1027 - mean_absolute_percentage_error: 26.2455 - root_mean_squared_error: 0.1312 - val_loss: 0.0624 - val_mean_absolute_error: 0.2172 - val_mean_absolute_percentage_error: 13422531.0000 - val_root_mean_squared_error: 0.2498
# Epoch 40/40
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0171 - mean_absolute_error: 0.1023 - mean_absolute_percentage_error: 26.5824 - root_mean_squared_error: 0.1308 - val_loss: 0.0582 - val_mean_absolute_error: 0.2080 - val_mean_absolute_percentage_error: 14695314.0000 - val_root_mean_squared_error: 0.2413

# %%
y_pred = model_hybrid_28.predict(x_test)

evaluation_hybrid_28 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_28
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# {'Mean Squared Error: ': np.float64(315.36387699583975),
#  'Mean Absolute Error: ': np.float64(13.398618737045599),
#  'Root Mean Absolute Error: ': 17.758487463628196,
#  'Mean Absolute Percentage Error: ': np.float64(25.422659256965158)}

# %%
loss, mae, mape, rmse = model_hybrid_28.evaluate(x_test, y_test)
print("model hybrid 28")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0251 - mean_absolute_error: 0.1196 - mean_absolute_percentage_error: 32.4592 - root_mean_squared_error: 0.1586
# model hybrid 28
# Mean Square Error: 0.025140613317489624
# Mean Absolute Error: 0.11963052302598953
# Mean Absolute Percentage Error: 32.459205627441406
# Root Mean Squared Error: 0.1585579216480255

# %% [markdown]
# ## model 29 (CNN=300 LSTM=32, 32)

# %%
lr = 0.0003

model_hybrid_29 = Sequential()
model_hybrid_29.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_29.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_29.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_29.add(Flatten())
model_hybrid_29.add(Dense(7))
model_hybrid_29.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_29.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_72"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_78 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_93 (LSTM)                  │ (None, 7, 32)          │        42,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_94 (LSTM)                  │ (None, 7, 32)          │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_72 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_72 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,619 (213.36 KB)
#  Trainable params: 54,619 (213.36 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_29.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 0.3142 - mean_absolute_error: 0.5310 - mean_absolute_percentage_error: 93.9163 - root_mean_squared_error: 0.5600 - val_loss: 0.1263 - val_mean_absolute_error: 0.3136 - val_mean_absolute_percentage_error: 7957017.5000 - val_root_mean_squared_error: 0.3554
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0604 - mean_absolute_error: 0.1973 - mean_absolute_percentage_error: 40.2846 - root_mean_squared_error: 0.2449 - val_loss: 0.0699 - val_mean_absolute_error: 0.2266 - val_mean_absolute_percentage_error: 11634530.0000 - val_root_mean_squared_error: 0.2644
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0293 - mean_absolute_error: 0.1380 - mean_absolute_percentage_error: 29.5946 - root_mean_squared_error: 0.1710 - val_loss: 0.0530 - val_mean_absolute_error: 0.1943 - val_mean_absolute_percentage_error: 14499971.0000 - val_root_mean_squared_error: 0.2303
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0230 - mean_absolute_error: 0.1183 - mean_absolute_percentage_error: 28.6184 - root_mean_squared_error: 0.1516 - val_loss: 0.0518 - val_mean_absolute_error: 0.1909 - val_mean_absolute_percentage_error: 14998830.0000 - val_root_mean_squared_error: 0.2275
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0218 - mean_absolute_error: 0.1144 - mean_absolute_percentage_error: 29.9343 - root_mean_squared_error: 0.1475 - val_loss: 0.0517 - val_mean_absolute_error: 0.1904 - val_mean_absolute_percentage_error: 15049114.0000 - val_root_mean_squared_error: 0.2274
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0230 - mean_absolute_error: 0.1173 - mean_absolute_percentage_error: 32.9104 - root_mean_squared_error: 0.1514 - val_loss: 0.0520 - val_mean_absolute_error: 0.1912 - val_mean_absolute_percentage_error: 14922752.0000 - val_root_mean_squared_error: 0.2281
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0213 - mean_absolute_error: 0.1132 - mean_absolute_percentage_error: 28.5865 - root_mean_squared_error: 0.1458 - val_loss: 0.0535 - val_mean_absolute_error: 0.1948 - val_mean_absolute_percentage_error: 14469062.0000 - val_root_mean_squared_error: 0.2312
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0204 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 28.4261 - root_mean_squared_error: 0.1427 - val_loss: 0.0531 - val_mean_absolute_error: 0.1938 - val_mean_absolute_percentage_error: 14743778.0000 - val_root_mean_squared_error: 0.2304
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0207 - mean_absolute_error: 0.1115 - mean_absolute_percentage_error: 29.0118 - root_mean_squared_error: 0.1438 - val_loss: 0.0556 - val_mean_absolute_error: 0.1998 - val_mean_absolute_percentage_error: 14077233.0000 - val_root_mean_squared_error: 0.2358
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0209 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 28.0677 - root_mean_squared_error: 0.1445 - val_loss: 0.0549 - val_mean_absolute_error: 0.1978 - val_mean_absolute_percentage_error: 14570877.0000 - val_root_mean_squared_error: 0.2343
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0198 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 28.0615 - root_mean_squared_error: 0.1407 - val_loss: 0.0553 - val_mean_absolute_error: 0.1989 - val_mean_absolute_percentage_error: 14370796.0000 - val_root_mean_squared_error: 0.2351
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0187 - mean_absolute_error: 0.1066 - mean_absolute_percentage_error: 26.7898 - root_mean_squared_error: 0.1366 - val_loss: 0.0582 - val_mean_absolute_error: 0.2041 - val_mean_absolute_percentage_error: 13840206.0000 - val_root_mean_squared_error: 0.2412
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0193 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 27.0282 - root_mean_squared_error: 0.1391 - val_loss: 0.0574 - val_mean_absolute_error: 0.2025 - val_mean_absolute_percentage_error: 14204765.0000 - val_root_mean_squared_error: 0.2395
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0197 - mean_absolute_error: 0.1096 - mean_absolute_percentage_error: 27.2846 - root_mean_squared_error: 0.1404 - val_loss: 0.0595 - val_mean_absolute_error: 0.2064 - val_mean_absolute_percentage_error: 13837079.0000 - val_root_mean_squared_error: 0.2438
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0195 - mean_absolute_error: 0.1093 - mean_absolute_percentage_error: 27.3038 - root_mean_squared_error: 0.1395 - val_loss: 0.0549 - val_mean_absolute_error: 0.1979 - val_mean_absolute_percentage_error: 15074143.0000 - val_root_mean_squared_error: 0.2342
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0188 - mean_absolute_error: 0.1061 - mean_absolute_percentage_error: 26.5129 - root_mean_squared_error: 0.1370 - val_loss: 0.0591 - val_mean_absolute_error: 0.2058 - val_mean_absolute_percentage_error: 14104373.0000 - val_root_mean_squared_error: 0.2431
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0185 - mean_absolute_error: 0.1067 - mean_absolute_percentage_error: 27.0309 - root_mean_squared_error: 0.1360 - val_loss: 0.0559 - val_mean_absolute_error: 0.2007 - val_mean_absolute_percentage_error: 14902097.0000 - val_root_mean_squared_error: 0.2363
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0182 - mean_absolute_error: 0.1045 - mean_absolute_percentage_error: 26.8959 - root_mean_squared_error: 0.1349 - val_loss: 0.0590 - val_mean_absolute_error: 0.2067 - val_mean_absolute_percentage_error: 14288141.0000 - val_root_mean_squared_error: 0.2430
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0183 - mean_absolute_error: 0.1061 - mean_absolute_percentage_error: 26.9960 - root_mean_squared_error: 0.1354 - val_loss: 0.0548 - val_mean_absolute_error: 0.1988 - val_mean_absolute_percentage_error: 15322958.0000 - val_root_mean_squared_error: 0.2341
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0178 - mean_absolute_error: 0.1031 - mean_absolute_percentage_error: 27.1482 - root_mean_squared_error: 0.1335 - val_loss: 0.0572 - val_mean_absolute_error: 0.2026 - val_mean_absolute_percentage_error: 14760708.0000 - val_root_mean_squared_error: 0.2391

# %%
y_pred = model_hybrid_29.predict(x_test)

evaluation_hybrid_29 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_29
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# {'Mean Squared Error: ': np.float64(297.27619761704227),
#  'Mean Absolute Error: ': np.float64(13.860039964014168),
#  'Root Mean Absolute Error: ': 17.24169938309569,
#  'Mean Absolute Percentage Error: ': np.float64(24.62770722976006)}

# %%
loss, mae, mape, rmse = model_hybrid_29.evaluate(x_test, y_test)
print("model hybrid 29")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0237 - mean_absolute_error: 0.1238 - mean_absolute_percentage_error: 31.0907 - root_mean_squared_error: 0.1539
# model hybrid 29
# Mean Square Error: 0.023698674514889717
# Mean Absolute Error: 0.12375034391880035
# Mean Absolute Percentage Error: 31.09072494506836
# Root Mean Squared Error: 0.153943732380867

# %% [markdown]
# ## model 30 (CNN=300 LSTM=16, 32)

# %%
lr = 0.0003

model_hybrid_30 = Sequential()
model_hybrid_30.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_30.add(LSTM(16, activation='relu', return_sequences=True))
model_hybrid_30.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_30.add(Flatten())
model_hybrid_30.add(Dense(7))
model_hybrid_30.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_30.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_73"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_79 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_95 (LSTM)                  │ (None, 7, 16)          │        20,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_96 (LSTM)                  │ (None, 7, 32)          │         6,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_73 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_73 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,235 (118.11 KB)
#  Trainable params: 30,235 (118.11 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_30.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - loss: 0.3324 - mean_absolute_error: 0.5498 - mean_absolute_percentage_error: 97.1339 - root_mean_squared_error: 0.5764 - val_loss: 0.2397 - val_mean_absolute_error: 0.4469 - val_mean_absolute_percentage_error: 3553183.7500 - val_root_mean_squared_error: 0.4896
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1508 - mean_absolute_error: 0.3372 - mean_absolute_percentage_error: 59.7356 - root_mean_squared_error: 0.3846 - val_loss: 0.0553 - val_mean_absolute_error: 0.1947 - val_mean_absolute_percentage_error: 16212682.0000 - val_root_mean_squared_error: 0.2353
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0254 - mean_absolute_error: 0.1257 - mean_absolute_percentage_error: 30.1462 - root_mean_squared_error: 0.1595 - val_loss: 0.0531 - val_mean_absolute_error: 0.1932 - val_mean_absolute_percentage_error: 15285109.0000 - val_root_mean_squared_error: 0.2304
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0242 - mean_absolute_error: 0.1210 - mean_absolute_percentage_error: 31.0710 - root_mean_squared_error: 0.1555 - val_loss: 0.0530 - val_mean_absolute_error: 0.1884 - val_mean_absolute_percentage_error: 14890291.0000 - val_root_mean_squared_error: 0.2303
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0238 - mean_absolute_error: 0.1210 - mean_absolute_percentage_error: 30.9330 - root_mean_squared_error: 0.1542 - val_loss: 0.0512 - val_mean_absolute_error: 0.1856 - val_mean_absolute_percentage_error: 15529071.0000 - val_root_mean_squared_error: 0.2263
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0228 - mean_absolute_error: 0.1176 - mean_absolute_percentage_error: 31.7824 - root_mean_squared_error: 0.1507 - val_loss: 0.0530 - val_mean_absolute_error: 0.1885 - val_mean_absolute_percentage_error: 14924170.0000 - val_root_mean_squared_error: 0.2302
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0221 - mean_absolute_error: 0.1170 - mean_absolute_percentage_error: 31.1932 - root_mean_squared_error: 0.1486 - val_loss: 0.0522 - val_mean_absolute_error: 0.1875 - val_mean_absolute_percentage_error: 15178841.0000 - val_root_mean_squared_error: 0.2285
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0213 - mean_absolute_error: 0.1135 - mean_absolute_percentage_error: 29.0554 - root_mean_squared_error: 0.1459 - val_loss: 0.0539 - val_mean_absolute_error: 0.1903 - val_mean_absolute_percentage_error: 14696648.0000 - val_root_mean_squared_error: 0.2321
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0216 - mean_absolute_error: 0.1150 - mean_absolute_percentage_error: 29.6151 - root_mean_squared_error: 0.1469 - val_loss: 0.0545 - val_mean_absolute_error: 0.1913 - val_mean_absolute_percentage_error: 14561814.0000 - val_root_mean_squared_error: 0.2334
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0221 - mean_absolute_error: 0.1165 - mean_absolute_percentage_error: 29.5593 - root_mean_squared_error: 0.1486 - val_loss: 0.0548 - val_mean_absolute_error: 0.1923 - val_mean_absolute_percentage_error: 14465717.0000 - val_root_mean_squared_error: 0.2340
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0223 - mean_absolute_error: 0.1168 - mean_absolute_percentage_error: 30.7406 - root_mean_squared_error: 0.1492 - val_loss: 0.0529 - val_mean_absolute_error: 0.1893 - val_mean_absolute_percentage_error: 15022604.0000 - val_root_mean_squared_error: 0.2301
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0218 - mean_absolute_error: 0.1152 - mean_absolute_percentage_error: 30.1088 - root_mean_squared_error: 0.1477 - val_loss: 0.0529 - val_mean_absolute_error: 0.1904 - val_mean_absolute_percentage_error: 14935957.0000 - val_root_mean_squared_error: 0.2300
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0201 - mean_absolute_error: 0.1099 - mean_absolute_percentage_error: 27.6350 - root_mean_squared_error: 0.1419 - val_loss: 0.0528 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 15000477.0000 - val_root_mean_squared_error: 0.2297
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0220 - mean_absolute_error: 0.1158 - mean_absolute_percentage_error: 31.5468 - root_mean_squared_error: 0.1483 - val_loss: 0.0539 - val_mean_absolute_error: 0.1922 - val_mean_absolute_percentage_error: 14671090.0000 - val_root_mean_squared_error: 0.2322
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0211 - mean_absolute_error: 0.1133 - mean_absolute_percentage_error: 29.8314 - root_mean_squared_error: 0.1454 - val_loss: 0.0587 - val_mean_absolute_error: 0.1999 - val_mean_absolute_percentage_error: 13674703.0000 - val_root_mean_squared_error: 0.2422
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0216 - mean_absolute_error: 0.1165 - mean_absolute_percentage_error: 29.1009 - root_mean_squared_error: 0.1468 - val_loss: 0.0552 - val_mean_absolute_error: 0.1943 - val_mean_absolute_percentage_error: 14385419.0000 - val_root_mean_squared_error: 0.2350
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0202 - mean_absolute_error: 0.1111 - mean_absolute_percentage_error: 27.9139 - root_mean_squared_error: 0.1422 - val_loss: 0.0536 - val_mean_absolute_error: 0.1934 - val_mean_absolute_percentage_error: 14806933.0000 - val_root_mean_squared_error: 0.2316
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0192 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 28.3514 - root_mean_squared_error: 0.1387 - val_loss: 0.0523 - val_mean_absolute_error: 0.1914 - val_mean_absolute_percentage_error: 15373107.0000 - val_root_mean_squared_error: 0.2287
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0198 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 28.3763 - root_mean_squared_error: 0.1407 - val_loss: 0.0523 - val_mean_absolute_error: 0.1917 - val_mean_absolute_percentage_error: 15635220.0000 - val_root_mean_squared_error: 0.2287
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0194 - mean_absolute_error: 0.1079 - mean_absolute_percentage_error: 26.8941 - root_mean_squared_error: 0.1392 - val_loss: 0.0535 - val_mean_absolute_error: 0.1940 - val_mean_absolute_percentage_error: 15008889.0000 - val_root_mean_squared_error: 0.2313

# %%
y_pred = model_hybrid_30.predict(x_test)

evaluation_hybrid_30 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_30
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# {'Mean Squared Error: ': np.float64(382.7946677114502),
#  'Mean Absolute Error: ': np.float64(15.25731592762227),
#  'Root Mean Absolute Error: ': 19.565139092565893,
#  'Mean Absolute Percentage Error: ': np.float64(27.925584648514512)}

# %%
loss, mae, mape, rmse = model_hybrid_30.evaluate(x_test, y_test)
print("model hybrid 30")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0305 - mean_absolute_error: 0.1362 - mean_absolute_percentage_error: 35.3614 - root_mean_squared_error: 0.1747
# model hybrid 30
# Mean Square Error: 0.030516156926751137
# Mean Absolute Error: 0.13622602820396423
# Mean Absolute Percentage Error: 35.361427307128906
# Root Mean Squared Error: 0.17468874156475067

# %% [markdown]
# ## model 31 (CNN=300 LSTM=8, 32)

# %%
lr = 0.0003

model_hybrid_31 = Sequential()
model_hybrid_31.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_31.add(LSTM(8, activation='relu', return_sequences=True))
model_hybrid_31.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_31.add(Flatten())
model_hybrid_31.add(Dense(7))
model_hybrid_31.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_31.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_74"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_80 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_97 (LSTM)                  │ (None, 7, 8)           │         9,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_98 (LSTM)                  │ (None, 7, 32)          │         5,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_74 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_74 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,811 (73.48 KB)
#  Trainable params: 18,811 (73.48 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_31.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.3085 - mean_absolute_error: 0.5233 - mean_absolute_percentage_error: 92.2402 - root_mean_squared_error: 0.5548 - val_loss: 0.1381 - val_mean_absolute_error: 0.3273 - val_mean_absolute_percentage_error: 8457777.0000 - val_root_mean_squared_error: 0.3716
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0834 - mean_absolute_error: 0.2330 - mean_absolute_percentage_error: 45.3722 - root_mean_squared_error: 0.2870 - val_loss: 0.0555 - val_mean_absolute_error: 0.2007 - val_mean_absolute_percentage_error: 13660956.0000 - val_root_mean_squared_error: 0.2356
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0264 - mean_absolute_error: 0.1279 - mean_absolute_percentage_error: 30.5216 - root_mean_squared_error: 0.1625 - val_loss: 0.0535 - val_mean_absolute_error: 0.1917 - val_mean_absolute_percentage_error: 14420988.0000 - val_root_mean_squared_error: 0.2313
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0238 - mean_absolute_error: 0.1211 - mean_absolute_percentage_error: 29.3263 - root_mean_squared_error: 0.1543 - val_loss: 0.0522 - val_mean_absolute_error: 0.1897 - val_mean_absolute_percentage_error: 14740523.0000 - val_root_mean_squared_error: 0.2286
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0215 - mean_absolute_error: 0.1146 - mean_absolute_percentage_error: 29.7805 - root_mean_squared_error: 0.1467 - val_loss: 0.0544 - val_mean_absolute_error: 0.1938 - val_mean_absolute_percentage_error: 14160471.0000 - val_root_mean_squared_error: 0.2332
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0227 - mean_absolute_error: 0.1184 - mean_absolute_percentage_error: 28.5215 - root_mean_squared_error: 0.1506 - val_loss: 0.0533 - val_mean_absolute_error: 0.1913 - val_mean_absolute_percentage_error: 14489830.0000 - val_root_mean_squared_error: 0.2309
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0208 - mean_absolute_error: 0.1126 - mean_absolute_percentage_error: 29.0119 - root_mean_squared_error: 0.1442 - val_loss: 0.0520 - val_mean_absolute_error: 0.1905 - val_mean_absolute_percentage_error: 14877218.0000 - val_root_mean_squared_error: 0.2281
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0216 - mean_absolute_error: 0.1141 - mean_absolute_percentage_error: 29.0998 - root_mean_squared_error: 0.1469 - val_loss: 0.0520 - val_mean_absolute_error: 0.1903 - val_mean_absolute_percentage_error: 14921299.0000 - val_root_mean_squared_error: 0.2281
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0220 - mean_absolute_error: 0.1150 - mean_absolute_percentage_error: 30.1526 - root_mean_squared_error: 0.1483 - val_loss: 0.0530 - val_mean_absolute_error: 0.1923 - val_mean_absolute_percentage_error: 14594890.0000 - val_root_mean_squared_error: 0.2303
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0206 - mean_absolute_error: 0.1120 - mean_absolute_percentage_error: 28.4727 - root_mean_squared_error: 0.1437 - val_loss: 0.0552 - val_mean_absolute_error: 0.1966 - val_mean_absolute_percentage_error: 13975767.0000 - val_root_mean_squared_error: 0.2349
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0201 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 28.2332 - root_mean_squared_error: 0.1417 - val_loss: 0.0554 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 14032879.0000 - val_root_mean_squared_error: 0.2354
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0194 - mean_absolute_error: 0.1079 - mean_absolute_percentage_error: 27.5520 - root_mean_squared_error: 0.1391 - val_loss: 0.0560 - val_mean_absolute_error: 0.1974 - val_mean_absolute_percentage_error: 14003610.0000 - val_root_mean_squared_error: 0.2367
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0202 - mean_absolute_error: 0.1108 - mean_absolute_percentage_error: 29.0247 - root_mean_squared_error: 0.1420 - val_loss: 0.0533 - val_mean_absolute_error: 0.1944 - val_mean_absolute_percentage_error: 14866688.0000 - val_root_mean_squared_error: 0.2309
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0204 - mean_absolute_error: 0.1099 - mean_absolute_percentage_error: 28.0383 - root_mean_squared_error: 0.1427 - val_loss: 0.0534 - val_mean_absolute_error: 0.1932 - val_mean_absolute_percentage_error: 14835484.0000 - val_root_mean_squared_error: 0.2311
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0197 - mean_absolute_error: 0.1098 - mean_absolute_percentage_error: 28.5151 - root_mean_squared_error: 0.1404 - val_loss: 0.0552 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 14325675.0000 - val_root_mean_squared_error: 0.2349
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0200 - mean_absolute_error: 0.1103 - mean_absolute_percentage_error: 27.7480 - root_mean_squared_error: 0.1415 - val_loss: 0.0549 - val_mean_absolute_error: 0.1958 - val_mean_absolute_percentage_error: 14497327.0000 - val_root_mean_squared_error: 0.2343
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0204 - mean_absolute_error: 0.1101 - mean_absolute_percentage_error: 28.3178 - root_mean_squared_error: 0.1429 - val_loss: 0.0547 - val_mean_absolute_error: 0.1959 - val_mean_absolute_percentage_error: 14525548.0000 - val_root_mean_squared_error: 0.2338
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0206 - mean_absolute_error: 0.1122 - mean_absolute_percentage_error: 28.5887 - root_mean_squared_error: 0.1434 - val_loss: 0.0575 - val_mean_absolute_error: 0.2001 - val_mean_absolute_percentage_error: 14053484.0000 - val_root_mean_squared_error: 0.2398
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0186 - mean_absolute_error: 0.1063 - mean_absolute_percentage_error: 26.5966 - root_mean_squared_error: 0.1364 - val_loss: 0.0555 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 14722877.0000 - val_root_mean_squared_error: 0.2356
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0186 - mean_absolute_error: 0.1058 - mean_absolute_percentage_error: 27.3405 - root_mean_squared_error: 0.1364 - val_loss: 0.0563 - val_mean_absolute_error: 0.1982 - val_mean_absolute_percentage_error: 14530477.0000 - val_root_mean_squared_error: 0.2373

# %%
y_pred = model_hybrid_31.predict(x_test)

evaluation_hybrid_31 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_31
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# {'Mean Squared Error: ': np.float64(325.0771063030899),
#  'Mean Absolute Error: ': np.float64(14.741983024441467),
#  'Root Mean Absolute Error: ': 18.029894794565216,
#  'Mean Absolute Percentage Error: ': np.float64(25.575844323843413)}

# %%
loss, mae, mape, rmse = model_hybrid_31.evaluate(x_test, y_test)
print("model hybrid 31")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0259 - mean_absolute_error: 0.1316 - mean_absolute_percentage_error: 32.0986 - root_mean_squared_error: 0.1610
# model hybrid 31
# Mean Square Error: 0.02591494843363762
# Mean Absolute Error: 0.13162484765052795
# Mean Absolute Percentage Error: 32.098609924316406
# Root Mean Squared Error: 0.1609812080860138

# %% [markdown]
# ## model 32 (CNN=300 LSTM=80, 32)

# %%
lr = 0.0003

model_hybrid_32 = Sequential()
model_hybrid_32.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_32.add(LSTM(80, activation='relu', return_sequences=True))
model_hybrid_32.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_32.add(Flatten())
model_hybrid_32.add(Dense(7))
model_hybrid_32.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_32.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_75"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_81 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_99 (LSTM)                  │ (None, 7, 80)          │       121,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_100 (LSTM)                 │ (None, 7, 32)          │        14,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_75 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_75 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 140,059 (547.11 KB)
#  Trainable params: 140,059 (547.11 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_32.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 0.2934 - mean_absolute_error: 0.5085 - mean_absolute_percentage_error: 90.9654 - root_mean_squared_error: 0.5409 - val_loss: 0.1005 - val_mean_absolute_error: 0.2632 - val_mean_absolute_percentage_error: 13807096.0000 - val_root_mean_squared_error: 0.3170
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0573 - mean_absolute_error: 0.1887 - mean_absolute_percentage_error: 40.2236 - root_mean_squared_error: 0.2381 - val_loss: 0.0549 - val_mean_absolute_error: 0.1944 - val_mean_absolute_percentage_error: 15721834.0000 - val_root_mean_squared_error: 0.2344
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0286 - mean_absolute_error: 0.1315 - mean_absolute_percentage_error: 34.2827 - root_mean_squared_error: 0.1690 - val_loss: 0.0517 - val_mean_absolute_error: 0.1900 - val_mean_absolute_percentage_error: 15020937.0000 - val_root_mean_squared_error: 0.2274
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0215 - mean_absolute_error: 0.1137 - mean_absolute_percentage_error: 29.0257 - root_mean_squared_error: 0.1467 - val_loss: 0.0521 - val_mean_absolute_error: 0.1906 - val_mean_absolute_percentage_error: 14640954.0000 - val_root_mean_squared_error: 0.2283
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0226 - mean_absolute_error: 0.1166 - mean_absolute_percentage_error: 29.3118 - root_mean_squared_error: 0.1504 - val_loss: 0.0532 - val_mean_absolute_error: 0.1937 - val_mean_absolute_percentage_error: 14187647.0000 - val_root_mean_squared_error: 0.2308
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0213 - mean_absolute_error: 0.1131 - mean_absolute_percentage_error: 30.1170 - root_mean_squared_error: 0.1459 - val_loss: 0.0527 - val_mean_absolute_error: 0.1934 - val_mean_absolute_percentage_error: 14366217.0000 - val_root_mean_squared_error: 0.2295
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0204 - mean_absolute_error: 0.1111 - mean_absolute_percentage_error: 28.0117 - root_mean_squared_error: 0.1430 - val_loss: 0.0564 - val_mean_absolute_error: 0.2000 - val_mean_absolute_percentage_error: 13409922.0000 - val_root_mean_squared_error: 0.2374
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0204 - mean_absolute_error: 0.1114 - mean_absolute_percentage_error: 27.5327 - root_mean_squared_error: 0.1427 - val_loss: 0.0560 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 13440767.0000 - val_root_mean_squared_error: 0.2367
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0205 - mean_absolute_error: 0.1119 - mean_absolute_percentage_error: 28.6492 - root_mean_squared_error: 0.1430 - val_loss: 0.0539 - val_mean_absolute_error: 0.1971 - val_mean_absolute_percentage_error: 14110073.0000 - val_root_mean_squared_error: 0.2322
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0199 - mean_absolute_error: 0.1094 - mean_absolute_percentage_error: 28.1605 - root_mean_squared_error: 0.1410 - val_loss: 0.0566 - val_mean_absolute_error: 0.2014 - val_mean_absolute_percentage_error: 13572978.0000 - val_root_mean_squared_error: 0.2378
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0197 - mean_absolute_error: 0.1096 - mean_absolute_percentage_error: 26.8281 - root_mean_squared_error: 0.1404 - val_loss: 0.0565 - val_mean_absolute_error: 0.2021 - val_mean_absolute_percentage_error: 13719896.0000 - val_root_mean_squared_error: 0.2376
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0195 - mean_absolute_error: 0.1083 - mean_absolute_percentage_error: 28.2865 - root_mean_squared_error: 0.1397 - val_loss: 0.0588 - val_mean_absolute_error: 0.2058 - val_mean_absolute_percentage_error: 13303511.0000 - val_root_mean_squared_error: 0.2426
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0192 - mean_absolute_error: 0.1080 - mean_absolute_percentage_error: 27.3407 - root_mean_squared_error: 0.1387 - val_loss: 0.0578 - val_mean_absolute_error: 0.2042 - val_mean_absolute_percentage_error: 13692822.0000 - val_root_mean_squared_error: 0.2403
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0193 - mean_absolute_error: 0.1081 - mean_absolute_percentage_error: 26.8629 - root_mean_squared_error: 0.1389 - val_loss: 0.0576 - val_mean_absolute_error: 0.2046 - val_mean_absolute_percentage_error: 13875218.0000 - val_root_mean_squared_error: 0.2400
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0197 - mean_absolute_error: 0.1092 - mean_absolute_percentage_error: 29.4142 - root_mean_squared_error: 0.1404 - val_loss: 0.0556 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 14632309.0000 - val_root_mean_squared_error: 0.2358
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0190 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 28.2527 - root_mean_squared_error: 0.1380 - val_loss: 0.0562 - val_mean_absolute_error: 0.2026 - val_mean_absolute_percentage_error: 14592789.0000 - val_root_mean_squared_error: 0.2371
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0193 - mean_absolute_error: 0.1082 - mean_absolute_percentage_error: 27.9114 - root_mean_squared_error: 0.1387 - val_loss: 0.0586 - val_mean_absolute_error: 0.2077 - val_mean_absolute_percentage_error: 13535656.0000 - val_root_mean_squared_error: 0.2421
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0188 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 27.5329 - root_mean_squared_error: 0.1372 - val_loss: 0.0570 - val_mean_absolute_error: 0.2041 - val_mean_absolute_percentage_error: 14576970.0000 - val_root_mean_squared_error: 0.2388
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0187 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 27.0791 - root_mean_squared_error: 0.1368 - val_loss: 0.0565 - val_mean_absolute_error: 0.2034 - val_mean_absolute_percentage_error: 14659700.0000 - val_root_mean_squared_error: 0.2377
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0186 - mean_absolute_error: 0.1061 - mean_absolute_percentage_error: 27.8984 - root_mean_squared_error: 0.1364 - val_loss: 0.0608 - val_mean_absolute_error: 0.2110 - val_mean_absolute_percentage_error: 13595357.0000 - val_root_mean_squared_error: 0.2466

# %%
y_pred = model_hybrid_32.predict(x_test)

evaluation_hybrid_32 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_32
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# {'Mean Squared Error: ': np.float64(293.4747813972425),
#  'Mean Absolute Error: ': np.float64(13.871171698278308),
#  'Root Mean Absolute Error: ': 17.13110566768072,
#  'Mean Absolute Percentage Error: ': np.float64(23.885885503652602)}

# %%
loss, mae, mape, rmse = model_hybrid_32.evaluate(x_test, y_test)
print("model hybrid 32")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0234 - mean_absolute_error: 0.1238 - mean_absolute_percentage_error: 29.9915 - root_mean_squared_error: 0.1530
# model hybrid 32
# Mean Square Error: 0.023395629599690437
# Mean Absolute Error: 0.12384974956512451
# Mean Absolute Percentage Error: 29.991456985473633
# Root Mean Squared Error: 0.1529563069343567

# %% [markdown]
# ## model 33 (CNN=300 LSTM=80, 32)

# %%
lr = 0.0003

model_hybrid_33 = Sequential()
model_hybrid_33.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_33.add(LSTM(100, activation='relu', return_sequences=True))
model_hybrid_33.add(LSTM(32, activation='relu', return_sequences=True))
model_hybrid_33.add(Flatten())
model_hybrid_33.add(Dense(7))
model_hybrid_33.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_33.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_76"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_82 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_101 (LSTM)                 │ (None, 7, 100)         │       160,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_102 (LSTM)                 │ (None, 7, 32)          │        17,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_76 (Flatten)            │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_76 (Dense)                │ (None, 7)              │         1,575 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 181,099 (707.42 KB)
#  Trainable params: 181,099 (707.42 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_33.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 0.2831 - mean_absolute_error: 0.4936 - mean_absolute_percentage_error: 87.1445 - root_mean_squared_error: 0.5303 - val_loss: 0.0698 - val_mean_absolute_error: 0.2139 - val_mean_absolute_percentage_error: 16321793.0000 - val_root_mean_squared_error: 0.2642
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0346 - mean_absolute_error: 0.1450 - mean_absolute_percentage_error: 33.9234 - root_mean_squared_error: 0.1853 - val_loss: 0.0535 - val_mean_absolute_error: 0.1923 - val_mean_absolute_percentage_error: 15277342.0000 - val_root_mean_squared_error: 0.2313
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0235 - mean_absolute_error: 0.1205 - mean_absolute_percentage_error: 29.1756 - root_mean_squared_error: 0.1532 - val_loss: 0.0537 - val_mean_absolute_error: 0.1935 - val_mean_absolute_percentage_error: 14542503.0000 - val_root_mean_squared_error: 0.2316
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0224 - mean_absolute_error: 0.1162 - mean_absolute_percentage_error: 29.1211 - root_mean_squared_error: 0.1497 - val_loss: 0.0521 - val_mean_absolute_error: 0.1908 - val_mean_absolute_percentage_error: 14848721.0000 - val_root_mean_squared_error: 0.2283
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0213 - mean_absolute_error: 0.1132 - mean_absolute_percentage_error: 28.7805 - root_mean_squared_error: 0.1459 - val_loss: 0.0535 - val_mean_absolute_error: 0.1947 - val_mean_absolute_percentage_error: 14310649.0000 - val_root_mean_squared_error: 0.2313
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0203 - mean_absolute_error: 0.1103 - mean_absolute_percentage_error: 27.1583 - root_mean_squared_error: 0.1423 - val_loss: 0.0573 - val_mean_absolute_error: 0.2011 - val_mean_absolute_percentage_error: 13478666.0000 - val_root_mean_squared_error: 0.2394
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0211 - mean_absolute_error: 0.1136 - mean_absolute_percentage_error: 28.3922 - root_mean_squared_error: 0.1452 - val_loss: 0.0556 - val_mean_absolute_error: 0.1977 - val_mean_absolute_percentage_error: 13838039.0000 - val_root_mean_squared_error: 0.2358
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0210 - mean_absolute_error: 0.1137 - mean_absolute_percentage_error: 29.5747 - root_mean_squared_error: 0.1450 - val_loss: 0.0577 - val_mean_absolute_error: 0.2023 - val_mean_absolute_percentage_error: 13325364.0000 - val_root_mean_squared_error: 0.2403
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0206 - mean_absolute_error: 0.1125 - mean_absolute_percentage_error: 28.4687 - root_mean_squared_error: 0.1435 - val_loss: 0.0553 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 13845199.0000 - val_root_mean_squared_error: 0.2352
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0201 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 29.5736 - root_mean_squared_error: 0.1419 - val_loss: 0.0545 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 14127148.0000 - val_root_mean_squared_error: 0.2334
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0206 - mean_absolute_error: 0.1117 - mean_absolute_percentage_error: 29.4482 - root_mean_squared_error: 0.1434 - val_loss: 0.0542 - val_mean_absolute_error: 0.1969 - val_mean_absolute_percentage_error: 14185514.0000 - val_root_mean_squared_error: 0.2329
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0195 - mean_absolute_error: 0.1084 - mean_absolute_percentage_error: 27.2088 - root_mean_squared_error: 0.1397 - val_loss: 0.0538 - val_mean_absolute_error: 0.1963 - val_mean_absolute_percentage_error: 14376663.0000 - val_root_mean_squared_error: 0.2320
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0204 - mean_absolute_error: 0.1120 - mean_absolute_percentage_error: 27.6418 - root_mean_squared_error: 0.1428 - val_loss: 0.0557 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 13797997.0000 - val_root_mean_squared_error: 0.2361
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0204 - mean_absolute_error: 0.1115 - mean_absolute_percentage_error: 28.5632 - root_mean_squared_error: 0.1429 - val_loss: 0.0543 - val_mean_absolute_error: 0.1976 - val_mean_absolute_percentage_error: 14441053.0000 - val_root_mean_squared_error: 0.2330
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0206 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 28.7519 - root_mean_squared_error: 0.1434 - val_loss: 0.0548 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 14168995.0000 - val_root_mean_squared_error: 0.2340
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0207 - mean_absolute_error: 0.1123 - mean_absolute_percentage_error: 29.4998 - root_mean_squared_error: 0.1439 - val_loss: 0.0561 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 13920654.0000 - val_root_mean_squared_error: 0.2368
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0187 - mean_absolute_error: 0.1066 - mean_absolute_percentage_error: 26.3313 - root_mean_squared_error: 0.1367 - val_loss: 0.0580 - val_mean_absolute_error: 0.2035 - val_mean_absolute_percentage_error: 13422534.0000 - val_root_mean_squared_error: 0.2409
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0196 - mean_absolute_error: 0.1094 - mean_absolute_percentage_error: 27.5656 - root_mean_squared_error: 0.1401 - val_loss: 0.0564 - val_mean_absolute_error: 0.2014 - val_mean_absolute_percentage_error: 13847603.0000 - val_root_mean_squared_error: 0.2374
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0197 - mean_absolute_error: 0.1087 - mean_absolute_percentage_error: 27.5021 - root_mean_squared_error: 0.1402 - val_loss: 0.0579 - val_mean_absolute_error: 0.2030 - val_mean_absolute_percentage_error: 13618570.0000 - val_root_mean_squared_error: 0.2405
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0202 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 29.4460 - root_mean_squared_error: 0.1421 - val_loss: 0.0544 - val_mean_absolute_error: 0.1976 - val_mean_absolute_percentage_error: 14967390.0000 - val_root_mean_squared_error: 0.2333

# %%
y_pred = model_hybrid_33.predict(x_test)

evaluation_hybrid_33 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_33
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# {'Mean Squared Error: ': np.float64(418.45545035074355),
#  'Mean Absolute Error: ': np.float64(15.595797324667172),
#  'Root Mean Absolute Error: ': 20.456183670243664,
#  'Mean Absolute Percentage Error: ': np.float64(29.401618414276047)}

# %%
loss, mae, mape, rmse = model_hybrid_33.evaluate(x_test, y_test)
print("model hybrid 33")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0334 - mean_absolute_error: 0.1392 - mean_absolute_percentage_error: 37.3973 - root_mean_squared_error: 0.1826
# model hybrid 33
# Mean Square Error: 0.03335901349782944
# Mean Absolute Error: 0.13924819231033325
# Mean Absolute Percentage Error: 37.39730453491211
# Root Mean Squared Error: 0.18264450132846832

# %% [markdown]
# ## model 34 (CNN=300 LSTM=64, 8)

# %%
lr = 0.0003

model_hybrid_34 = Sequential()
model_hybrid_34.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_34.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_34.add(LSTM(8, activation='relu', return_sequences=True))
model_hybrid_34.add(Flatten())
model_hybrid_34.add(Dense(7))
model_hybrid_34.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_34.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_77"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_83 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_103 (LSTM)                 │ (None, 7, 64)          │        93,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_104 (LSTM)                 │ (None, 7, 8)           │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_77 (Flatten)            │ (None, 56)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_77 (Dense)                │ (None, 7)              │           399 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 98,275 (383.89 KB)
#  Trainable params: 98,275 (383.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_34.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 0.3107 - mean_absolute_error: 0.5242 - mean_absolute_percentage_error: 93.6148 - root_mean_squared_error: 0.5571 - val_loss: 0.1801 - val_mean_absolute_error: 0.3543 - val_mean_absolute_percentage_error: 8663014.0000 - val_root_mean_squared_error: 0.4244
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.1098 - mean_absolute_error: 0.2581 - mean_absolute_percentage_error: 48.9312 - root_mean_squared_error: 0.3291 - val_loss: 0.0734 - val_mean_absolute_error: 0.2325 - val_mean_absolute_percentage_error: 12466362.0000 - val_root_mean_squared_error: 0.2710
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0308 - mean_absolute_error: 0.1376 - mean_absolute_percentage_error: 31.0891 - root_mean_squared_error: 0.1753 - val_loss: 0.0548 - val_mean_absolute_error: 0.1951 - val_mean_absolute_percentage_error: 15935480.0000 - val_root_mean_squared_error: 0.2340
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0232 - mean_absolute_error: 0.1188 - mean_absolute_percentage_error: 30.7873 - root_mean_squared_error: 0.1524 - val_loss: 0.0570 - val_mean_absolute_error: 0.2000 - val_mean_absolute_percentage_error: 14734520.0000 - val_root_mean_squared_error: 0.2387
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0209 - mean_absolute_error: 0.1113 - mean_absolute_percentage_error: 28.4371 - root_mean_squared_error: 0.1444 - val_loss: 0.0544 - val_mean_absolute_error: 0.1965 - val_mean_absolute_percentage_error: 15942369.0000 - val_root_mean_squared_error: 0.2333
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0204 - mean_absolute_error: 0.1108 - mean_absolute_percentage_error: 27.0707 - root_mean_squared_error: 0.1428 - val_loss: 0.0563 - val_mean_absolute_error: 0.1980 - val_mean_absolute_percentage_error: 14833226.0000 - val_root_mean_squared_error: 0.2372
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0211 - mean_absolute_error: 0.1133 - mean_absolute_percentage_error: 27.9667 - root_mean_squared_error: 0.1451 - val_loss: 0.0575 - val_mean_absolute_error: 0.1987 - val_mean_absolute_percentage_error: 14762983.0000 - val_root_mean_squared_error: 0.2398
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0221 - mean_absolute_error: 0.1160 - mean_absolute_percentage_error: 27.6814 - root_mean_squared_error: 0.1485 - val_loss: 0.0548 - val_mean_absolute_error: 0.1969 - val_mean_absolute_percentage_error: 15682255.0000 - val_root_mean_squared_error: 0.2341
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0200 - mean_absolute_error: 0.1103 - mean_absolute_percentage_error: 28.4985 - root_mean_squared_error: 0.1415 - val_loss: 0.0562 - val_mean_absolute_error: 0.1990 - val_mean_absolute_percentage_error: 15037700.0000 - val_root_mean_squared_error: 0.2372
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0207 - mean_absolute_error: 0.1126 - mean_absolute_percentage_error: 28.7383 - root_mean_squared_error: 0.1440 - val_loss: 0.0573 - val_mean_absolute_error: 0.1986 - val_mean_absolute_percentage_error: 14857242.0000 - val_root_mean_squared_error: 0.2394
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0193 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 26.7584 - root_mean_squared_error: 0.1389 - val_loss: 0.0546 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 16168439.0000 - val_root_mean_squared_error: 0.2337
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0207 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 30.2216 - root_mean_squared_error: 0.1439 - val_loss: 0.0564 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 15420289.0000 - val_root_mean_squared_error: 0.2376
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0190 - mean_absolute_error: 0.1067 - mean_absolute_percentage_error: 27.0635 - root_mean_squared_error: 0.1376 - val_loss: 0.0585 - val_mean_absolute_error: 0.2008 - val_mean_absolute_percentage_error: 14582849.0000 - val_root_mean_squared_error: 0.2419
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0190 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 26.0775 - root_mean_squared_error: 0.1378 - val_loss: 0.0552 - val_mean_absolute_error: 0.1962 - val_mean_absolute_percentage_error: 15916791.0000 - val_root_mean_squared_error: 0.2350
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0185 - mean_absolute_error: 0.1056 - mean_absolute_percentage_error: 26.5840 - root_mean_squared_error: 0.1359 - val_loss: 0.0577 - val_mean_absolute_error: 0.2003 - val_mean_absolute_percentage_error: 14828783.0000 - val_root_mean_squared_error: 0.2401
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0192 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 25.9257 - root_mean_squared_error: 0.1384 - val_loss: 0.0554 - val_mean_absolute_error: 0.1973 - val_mean_absolute_percentage_error: 15988660.0000 - val_root_mean_squared_error: 0.2354
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0191 - mean_absolute_error: 0.1082 - mean_absolute_percentage_error: 27.2506 - root_mean_squared_error: 0.1381 - val_loss: 0.0567 - val_mean_absolute_error: 0.1995 - val_mean_absolute_percentage_error: 15067127.0000 - val_root_mean_squared_error: 0.2381
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0188 - mean_absolute_error: 0.1073 - mean_absolute_percentage_error: 26.2531 - root_mean_squared_error: 0.1372 - val_loss: 0.0581 - val_mean_absolute_error: 0.2020 - val_mean_absolute_percentage_error: 14490313.0000 - val_root_mean_squared_error: 0.2410
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0197 - mean_absolute_error: 0.1104 - mean_absolute_percentage_error: 26.9866 - root_mean_squared_error: 0.1404 - val_loss: 0.0546 - val_mean_absolute_error: 0.1951 - val_mean_absolute_percentage_error: 15825674.0000 - val_root_mean_squared_error: 0.2337
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0204 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 29.5888 - root_mean_squared_error: 0.1427 - val_loss: 0.0562 - val_mean_absolute_error: 0.1978 - val_mean_absolute_percentage_error: 15362399.0000 - val_root_mean_squared_error: 0.2370

# %%
y_pred = model_hybrid_34.predict(x_test)

evaluation_hybrid_34 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_34
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# {'Mean Squared Error: ': np.float64(306.3274912982016),
#  'Mean Absolute Error: ': np.float64(13.860484901739627),
#  'Root Mean Absolute Error: ': 17.502213897053185,
#  'Mean Absolute Percentage Error: ': np.float64(24.29744241692736)}

# %%
loss, mae, mape, rmse = model_hybrid_34.evaluate(x_test, y_test)
print("model hybrid 34")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0244 - mean_absolute_error: 0.1238 - mean_absolute_percentage_error: 30.5712 - root_mean_squared_error: 0.1563
# model hybrid 34
# Mean Square Error: 0.0244202371686697
# Mean Absolute Error: 0.12375432252883911
# Mean Absolute Percentage Error: 30.571216583251953
# Root Mean Squared Error: 0.15626975893974304

# %% [markdown]
# ## model 35 (CNN=300 LSTM=64, 16)

# %%
lr = 0.0003

model_hybrid_35 = Sequential()
model_hybrid_35.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_35.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_35.add(LSTM(8, activation='relu', return_sequences=True))
model_hybrid_35.add(Flatten())
model_hybrid_35.add(Dense(7))
model_hybrid_35.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_35.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_78"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_84 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_105 (LSTM)                 │ (None, 7, 64)          │        93,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_106 (LSTM)                 │ (None, 7, 8)           │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_78 (Flatten)            │ (None, 56)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_78 (Dense)                │ (None, 7)              │           399 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 98,275 (383.89 KB)
#  Trainable params: 98,275 (383.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_35.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.3245 - mean_absolute_error: 0.5368 - mean_absolute_percentage_error: 94.5208 - root_mean_squared_error: 0.5692 - val_loss: 0.2047 - val_mean_absolute_error: 0.3816 - val_mean_absolute_percentage_error: 7995347.0000 - val_root_mean_squared_error: 0.4524
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1536 - mean_absolute_error: 0.3147 - mean_absolute_percentage_error: 58.2897 - root_mean_squared_error: 0.3905 - val_loss: 0.1004 - val_mean_absolute_error: 0.2651 - val_mean_absolute_percentage_error: 10353694.0000 - val_root_mean_squared_error: 0.3169
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0589 - mean_absolute_error: 0.1880 - mean_absolute_percentage_error: 38.8347 - root_mean_squared_error: 0.2423 - val_loss: 0.0701 - val_mean_absolute_error: 0.2254 - val_mean_absolute_percentage_error: 11955863.0000 - val_root_mean_squared_error: 0.2647
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0313 - mean_absolute_error: 0.1372 - mean_absolute_percentage_error: 32.9220 - root_mean_squared_error: 0.1768 - val_loss: 0.0555 - val_mean_absolute_error: 0.2038 - val_mean_absolute_percentage_error: 13391366.0000 - val_root_mean_squared_error: 0.2356
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0240 - mean_absolute_error: 0.1208 - mean_absolute_percentage_error: 29.7682 - root_mean_squared_error: 0.1547 - val_loss: 0.0524 - val_mean_absolute_error: 0.1955 - val_mean_absolute_percentage_error: 14448627.0000 - val_root_mean_squared_error: 0.2289
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0221 - mean_absolute_error: 0.1157 - mean_absolute_percentage_error: 28.9676 - root_mean_squared_error: 0.1485 - val_loss: 0.0544 - val_mean_absolute_error: 0.2007 - val_mean_absolute_percentage_error: 13987094.0000 - val_root_mean_squared_error: 0.2332
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0216 - mean_absolute_error: 0.1145 - mean_absolute_percentage_error: 29.5848 - root_mean_squared_error: 0.1470 - val_loss: 0.0565 - val_mean_absolute_error: 0.2027 - val_mean_absolute_percentage_error: 13726481.0000 - val_root_mean_squared_error: 0.2376
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0204 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 27.8664 - root_mean_squared_error: 0.1427 - val_loss: 0.0555 - val_mean_absolute_error: 0.2001 - val_mean_absolute_percentage_error: 14016418.0000 - val_root_mean_squared_error: 0.2357
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0207 - mean_absolute_error: 0.1129 - mean_absolute_percentage_error: 29.7077 - root_mean_squared_error: 0.1439 - val_loss: 0.0568 - val_mean_absolute_error: 0.2016 - val_mean_absolute_percentage_error: 13990132.0000 - val_root_mean_squared_error: 0.2382
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0200 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 28.3697 - root_mean_squared_error: 0.1413 - val_loss: 0.0602 - val_mean_absolute_error: 0.2069 - val_mean_absolute_percentage_error: 13408206.0000 - val_root_mean_squared_error: 0.2453
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0207 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 27.0179 - root_mean_squared_error: 0.1438 - val_loss: 0.0556 - val_mean_absolute_error: 0.1999 - val_mean_absolute_percentage_error: 14372332.0000 - val_root_mean_squared_error: 0.2357
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0186 - mean_absolute_error: 0.1062 - mean_absolute_percentage_error: 26.1964 - root_mean_squared_error: 0.1365 - val_loss: 0.0551 - val_mean_absolute_error: 0.1997 - val_mean_absolute_percentage_error: 14662186.0000 - val_root_mean_squared_error: 0.2347
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0183 - mean_absolute_error: 0.1055 - mean_absolute_percentage_error: 26.1594 - root_mean_squared_error: 0.1351 - val_loss: 0.0550 - val_mean_absolute_error: 0.1983 - val_mean_absolute_percentage_error: 15026411.0000 - val_root_mean_squared_error: 0.2344
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0191 - mean_absolute_error: 0.1062 - mean_absolute_percentage_error: 28.2175 - root_mean_squared_error: 0.1382 - val_loss: 0.0565 - val_mean_absolute_error: 0.2011 - val_mean_absolute_percentage_error: 14520278.0000 - val_root_mean_squared_error: 0.2378
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0185 - mean_absolute_error: 0.1067 - mean_absolute_percentage_error: 25.7316 - root_mean_squared_error: 0.1362 - val_loss: 0.0571 - val_mean_absolute_error: 0.2021 - val_mean_absolute_percentage_error: 14429564.0000 - val_root_mean_squared_error: 0.2390
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0188 - mean_absolute_error: 0.1065 - mean_absolute_percentage_error: 25.9389 - root_mean_squared_error: 0.1371 - val_loss: 0.0574 - val_mean_absolute_error: 0.2034 - val_mean_absolute_percentage_error: 14421303.0000 - val_root_mean_squared_error: 0.2397
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0189 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 27.5835 - root_mean_squared_error: 0.1376 - val_loss: 0.0572 - val_mean_absolute_error: 0.2026 - val_mean_absolute_percentage_error: 14559620.0000 - val_root_mean_squared_error: 0.2391
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0197 - mean_absolute_error: 0.1101 - mean_absolute_percentage_error: 28.5806 - root_mean_squared_error: 0.1404 - val_loss: 0.0566 - val_mean_absolute_error: 0.2009 - val_mean_absolute_percentage_error: 14886210.0000 - val_root_mean_squared_error: 0.2379
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0191 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 26.6644 - root_mean_squared_error: 0.1383 - val_loss: 0.0571 - val_mean_absolute_error: 0.2042 - val_mean_absolute_percentage_error: 14810038.0000 - val_root_mean_squared_error: 0.2390
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0194 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 27.8012 - root_mean_squared_error: 0.1390 - val_loss: 0.0565 - val_mean_absolute_error: 0.2016 - val_mean_absolute_percentage_error: 15390937.0000 - val_root_mean_squared_error: 0.2377

# %%
y_pred = model_hybrid_35.predict(x_test)

evaluation_hybrid_35 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_35
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# {'Mean Squared Error: ': np.float64(337.43783792733757),
#  'Mean Absolute Error: ': np.float64(14.289937895171496),
#  'Root Mean Absolute Error: ': 18.369481155637946,
#  'Mean Absolute Percentage Error: ': np.float64(26.462778739628412)}

# %%
loss, mae, mape, rmse = model_hybrid_35.evaluate(x_test, y_test)
print("model hybrid 35")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0269 - mean_absolute_error: 0.1276 - mean_absolute_percentage_error: 33.6132 - root_mean_squared_error: 0.1640
# model hybrid 35
# Mean Square Error: 0.026900338008999825
# Mean Absolute Error: 0.12758873403072357
# Mean Absolute Percentage Error: 33.61317825317383
# Root Mean Squared Error: 0.16401322185993195

# %% [markdown]
# ## model 36 (CNN=300 LSTM=64, 64)

# %%
lr = 0.0003

model_hybrid_36 = Sequential()
model_hybrid_36.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_36.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_36.add(LSTM(64, activation='relu'))
model_hybrid_36.add(Flatten())
model_hybrid_36.add(Dense(7))
model_hybrid_36.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_36.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_79"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_85 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_107 (LSTM)                 │ (None, 7, 64)          │        93,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_108 (LSTM)                 │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_79 (Flatten)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_79 (Dense)                │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 129,019 (503.98 KB)
#  Trainable params: 129,019 (503.98 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_36.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.2702 - mean_absolute_error: 0.4791 - mean_absolute_percentage_error: 84.0928 - root_mean_squared_error: 0.5168 - val_loss: 0.0761 - val_mean_absolute_error: 0.2308 - val_mean_absolute_percentage_error: 14413624.0000 - val_root_mean_squared_error: 0.2759
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0391 - mean_absolute_error: 0.1582 - mean_absolute_percentage_error: 34.2537 - root_mean_squared_error: 0.1973 - val_loss: 0.0535 - val_mean_absolute_error: 0.1975 - val_mean_absolute_percentage_error: 14342047.0000 - val_root_mean_squared_error: 0.2313
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0249 - mean_absolute_error: 0.1233 - mean_absolute_percentage_error: 30.6456 - root_mean_squared_error: 0.1576 - val_loss: 0.0519 - val_mean_absolute_error: 0.1946 - val_mean_absolute_percentage_error: 14610999.0000 - val_root_mean_squared_error: 0.2278
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0219 - mean_absolute_error: 0.1159 - mean_absolute_percentage_error: 28.7802 - root_mean_squared_error: 0.1478 - val_loss: 0.0515 - val_mean_absolute_error: 0.1930 - val_mean_absolute_percentage_error: 14584333.0000 - val_root_mean_squared_error: 0.2269
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0211 - mean_absolute_error: 0.1132 - mean_absolute_percentage_error: 30.5599 - root_mean_squared_error: 0.1454 - val_loss: 0.0517 - val_mean_absolute_error: 0.1934 - val_mean_absolute_percentage_error: 14414983.0000 - val_root_mean_squared_error: 0.2275
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0212 - mean_absolute_error: 0.1140 - mean_absolute_percentage_error: 29.0158 - root_mean_squared_error: 0.1455 - val_loss: 0.0518 - val_mean_absolute_error: 0.1943 - val_mean_absolute_percentage_error: 14358148.0000 - val_root_mean_squared_error: 0.2277
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0210 - mean_absolute_error: 0.1121 - mean_absolute_percentage_error: 28.6681 - root_mean_squared_error: 0.1448 - val_loss: 0.0520 - val_mean_absolute_error: 0.1939 - val_mean_absolute_percentage_error: 14337882.0000 - val_root_mean_squared_error: 0.2281
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0212 - mean_absolute_error: 0.1138 - mean_absolute_percentage_error: 28.7173 - root_mean_squared_error: 0.1456 - val_loss: 0.0546 - val_mean_absolute_error: 0.1989 - val_mean_absolute_percentage_error: 13725543.0000 - val_root_mean_squared_error: 0.2336
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0201 - mean_absolute_error: 0.1111 - mean_absolute_percentage_error: 28.1915 - root_mean_squared_error: 0.1419 - val_loss: 0.0548 - val_mean_absolute_error: 0.1990 - val_mean_absolute_percentage_error: 13674223.0000 - val_root_mean_squared_error: 0.2341
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0204 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 28.5910 - root_mean_squared_error: 0.1429 - val_loss: 0.0530 - val_mean_absolute_error: 0.1957 - val_mean_absolute_percentage_error: 14341813.0000 - val_root_mean_squared_error: 0.2301
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0189 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 26.7363 - root_mean_squared_error: 0.1376 - val_loss: 0.0557 - val_mean_absolute_error: 0.2003 - val_mean_absolute_percentage_error: 13739649.0000 - val_root_mean_squared_error: 0.2360
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0190 - mean_absolute_error: 0.1078 - mean_absolute_percentage_error: 26.2108 - root_mean_squared_error: 0.1378 - val_loss: 0.0538 - val_mean_absolute_error: 0.1968 - val_mean_absolute_percentage_error: 14276008.0000 - val_root_mean_squared_error: 0.2319
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0196 - mean_absolute_error: 0.1088 - mean_absolute_percentage_error: 28.7618 - root_mean_squared_error: 0.1398 - val_loss: 0.0527 - val_mean_absolute_error: 0.1953 - val_mean_absolute_percentage_error: 14898110.0000 - val_root_mean_squared_error: 0.2295
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0192 - mean_absolute_error: 0.1082 - mean_absolute_percentage_error: 29.3945 - root_mean_squared_error: 0.1385 - val_loss: 0.0552 - val_mean_absolute_error: 0.1989 - val_mean_absolute_percentage_error: 14205218.0000 - val_root_mean_squared_error: 0.2350
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0187 - mean_absolute_error: 0.1074 - mean_absolute_percentage_error: 26.4687 - root_mean_squared_error: 0.1368 - val_loss: 0.0539 - val_mean_absolute_error: 0.1971 - val_mean_absolute_percentage_error: 14712938.0000 - val_root_mean_squared_error: 0.2321
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0191 - mean_absolute_error: 0.1072 - mean_absolute_percentage_error: 28.5476 - root_mean_squared_error: 0.1382 - val_loss: 0.0563 - val_mean_absolute_error: 0.2010 - val_mean_absolute_percentage_error: 14023533.0000 - val_root_mean_squared_error: 0.2373
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0209 - mean_absolute_error: 0.1130 - mean_absolute_percentage_error: 28.4522 - root_mean_squared_error: 0.1444 - val_loss: 0.0534 - val_mean_absolute_error: 0.1961 - val_mean_absolute_percentage_error: 15347518.0000 - val_root_mean_squared_error: 0.2311
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0204 - mean_absolute_error: 0.1104 - mean_absolute_percentage_error: 29.5472 - root_mean_squared_error: 0.1427 - val_loss: 0.0541 - val_mean_absolute_error: 0.1977 - val_mean_absolute_percentage_error: 14953612.0000 - val_root_mean_squared_error: 0.2327
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0196 - mean_absolute_error: 0.1087 - mean_absolute_percentage_error: 28.0013 - root_mean_squared_error: 0.1399 - val_loss: 0.0549 - val_mean_absolute_error: 0.1989 - val_mean_absolute_percentage_error: 14652899.0000 - val_root_mean_squared_error: 0.2342
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0197 - mean_absolute_error: 0.1087 - mean_absolute_percentage_error: 29.1633 - root_mean_squared_error: 0.1401 - val_loss: 0.0545 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 15295915.0000 - val_root_mean_squared_error: 0.2334

# %%
y_pred = model_hybrid_36.predict(x_test)

evaluation_hybrid_36 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_36
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# {'Mean Squared Error: ': np.float64(339.03365748635804),
#  'Mean Absolute Error: ': np.float64(14.711404761489556),
#  'Root Mean Absolute Error: ': 18.412866628701735,
#  'Mean Absolute Percentage Error: ': np.float64(26.490348768924264)}

# %%
loss, mae, mape, rmse = model_hybrid_36.evaluate(x_test, y_test)
print("model hybrid 36")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0270 - mean_absolute_error: 0.1314 - mean_absolute_percentage_error: 33.4467 - root_mean_squared_error: 0.1644
# model hybrid 36
# Mean Square Error: 0.027027552947402
# Mean Absolute Error: 0.13135182857513428
# Mean Absolute Percentage Error: 33.446720123291016
# Root Mean Squared Error: 0.1644005924463272

# %% [markdown]
# ## model 37 (CNN=300 LSTM=64, 128)

# %%
lr = 0.0003

model_hybrid_37 = Sequential()
model_hybrid_37.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_37.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_37.add(LSTM(128, activation='relu'))
model_hybrid_37.add(Flatten())
model_hybrid_37.add(Dense(7))
model_hybrid_37.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_37.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_80"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_86 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_109 (LSTM)                 │ (None, 7, 64)          │        93,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_110 (LSTM)                 │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_80 (Flatten)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_80 (Dense)                │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 195,259 (762.73 KB)
#  Trainable params: 195,259 (762.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_37.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 0.2745 - mean_absolute_error: 0.4862 - mean_absolute_percentage_error: 87.3706 - root_mean_squared_error: 0.5222 - val_loss: 0.0689 - val_mean_absolute_error: 0.2061 - val_mean_absolute_percentage_error: 17897054.0000 - val_root_mean_squared_error: 0.2625
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0387 - mean_absolute_error: 0.1576 - mean_absolute_percentage_error: 36.6051 - root_mean_squared_error: 0.1958 - val_loss: 0.0554 - val_mean_absolute_error: 0.1932 - val_mean_absolute_percentage_error: 16241372.0000 - val_root_mean_squared_error: 0.2354
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0259 - mean_absolute_error: 0.1242 - mean_absolute_percentage_error: 31.3863 - root_mean_squared_error: 0.1608 - val_loss: 0.0517 - val_mean_absolute_error: 0.1873 - val_mean_absolute_percentage_error: 15888552.0000 - val_root_mean_squared_error: 0.2273
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0215 - mean_absolute_error: 0.1142 - mean_absolute_percentage_error: 29.8204 - root_mean_squared_error: 0.1467 - val_loss: 0.0527 - val_mean_absolute_error: 0.1900 - val_mean_absolute_percentage_error: 15141881.0000 - val_root_mean_squared_error: 0.2297
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0206 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 27.7015 - root_mean_squared_error: 0.1434 - val_loss: 0.0518 - val_mean_absolute_error: 0.1888 - val_mean_absolute_percentage_error: 15372573.0000 - val_root_mean_squared_error: 0.2276
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0208 - mean_absolute_error: 0.1118 - mean_absolute_percentage_error: 28.7741 - root_mean_squared_error: 0.1441 - val_loss: 0.0531 - val_mean_absolute_error: 0.1919 - val_mean_absolute_percentage_error: 14834778.0000 - val_root_mean_squared_error: 0.2304
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0221 - mean_absolute_error: 0.1171 - mean_absolute_percentage_error: 30.5688 - root_mean_squared_error: 0.1485 - val_loss: 0.0558 - val_mean_absolute_error: 0.1963 - val_mean_absolute_percentage_error: 14164609.0000 - val_root_mean_squared_error: 0.2362
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0209 - mean_absolute_error: 0.1143 - mean_absolute_percentage_error: 28.4128 - root_mean_squared_error: 0.1445 - val_loss: 0.0529 - val_mean_absolute_error: 0.1923 - val_mean_absolute_percentage_error: 14954942.0000 - val_root_mean_squared_error: 0.2300
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0198 - mean_absolute_error: 0.1097 - mean_absolute_percentage_error: 30.0085 - root_mean_squared_error: 0.1407 - val_loss: 0.0534 - val_mean_absolute_error: 0.1949 - val_mean_absolute_percentage_error: 14666588.0000 - val_root_mean_squared_error: 0.2312
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0204 - mean_absolute_error: 0.1113 - mean_absolute_percentage_error: 28.3630 - root_mean_squared_error: 0.1428 - val_loss: 0.0552 - val_mean_absolute_error: 0.1960 - val_mean_absolute_percentage_error: 14213946.0000 - val_root_mean_squared_error: 0.2350
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0193 - mean_absolute_error: 0.1091 - mean_absolute_percentage_error: 26.8640 - root_mean_squared_error: 0.1390 - val_loss: 0.0549 - val_mean_absolute_error: 0.1966 - val_mean_absolute_percentage_error: 14295055.0000 - val_root_mean_squared_error: 0.2344
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0201 - mean_absolute_error: 0.1115 - mean_absolute_percentage_error: 28.6573 - root_mean_squared_error: 0.1418 - val_loss: 0.0554 - val_mean_absolute_error: 0.1979 - val_mean_absolute_percentage_error: 14110138.0000 - val_root_mean_squared_error: 0.2354
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0200 - mean_absolute_error: 0.1107 - mean_absolute_percentage_error: 29.6086 - root_mean_squared_error: 0.1412 - val_loss: 0.0532 - val_mean_absolute_error: 0.1948 - val_mean_absolute_percentage_error: 15105774.0000 - val_root_mean_squared_error: 0.2306
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0199 - mean_absolute_error: 0.1093 - mean_absolute_percentage_error: 28.3522 - root_mean_squared_error: 0.1411 - val_loss: 0.0554 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 14275380.0000 - val_root_mean_squared_error: 0.2354
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0202 - mean_absolute_error: 0.1112 - mean_absolute_percentage_error: 27.6123 - root_mean_squared_error: 0.1421 - val_loss: 0.0553 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 14282258.0000 - val_root_mean_squared_error: 0.2351
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0195 - mean_absolute_error: 0.1092 - mean_absolute_percentage_error: 28.1224 - root_mean_squared_error: 0.1397 - val_loss: 0.0544 - val_mean_absolute_error: 0.1967 - val_mean_absolute_percentage_error: 14594838.0000 - val_root_mean_squared_error: 0.2332
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0200 - mean_absolute_error: 0.1106 - mean_absolute_percentage_error: 27.3611 - root_mean_squared_error: 0.1414 - val_loss: 0.0556 - val_mean_absolute_error: 0.1981 - val_mean_absolute_percentage_error: 14274120.0000 - val_root_mean_squared_error: 0.2358
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0196 - mean_absolute_error: 0.1098 - mean_absolute_percentage_error: 27.3840 - root_mean_squared_error: 0.1401 - val_loss: 0.0555 - val_mean_absolute_error: 0.1993 - val_mean_absolute_percentage_error: 14453429.0000 - val_root_mean_squared_error: 0.2357
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0190 - mean_absolute_error: 0.1065 - mean_absolute_percentage_error: 27.4348 - root_mean_squared_error: 0.1379 - val_loss: 0.0534 - val_mean_absolute_error: 0.1947 - val_mean_absolute_percentage_error: 15441255.0000 - val_root_mean_squared_error: 0.2311
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0187 - mean_absolute_error: 0.1068 - mean_absolute_percentage_error: 27.7921 - root_mean_squared_error: 0.1369 - val_loss: 0.0545 - val_mean_absolute_error: 0.1976 - val_mean_absolute_percentage_error: 14871497.0000 - val_root_mean_squared_error: 0.2335

# %%
y_pred = model_hybrid_37.predict(x_test)

evaluation_hybrid_37 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_37
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# {'Mean Squared Error: ': np.float64(354.4829828682073),
#  'Mean Absolute Error: ': np.float64(14.625278648065061),
#  'Root Mean Absolute Error: ': 18.82771847219432,
#  'Mean Absolute Percentage Error: ': np.float64(27.09405022614645)}

# %%
loss, mae, mape, rmse = model_hybrid_37.evaluate(x_test, y_test)
print("model hybrid 37")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0283 - mean_absolute_error: 0.1306 - mean_absolute_percentage_error: 34.3921 - root_mean_squared_error: 0.1681
# model hybrid 37
# Mean Square Error: 0.0282591599971056
# Mean Absolute Error: 0.13058283925056458
# Mean Absolute Percentage Error: 34.392127990722656
# Root Mean Squared Error: 0.1681046038866043

# %% [markdown]
# ## model 38 (CNN=300 LSTM=64, 256)

# %%
lr = 0.0003

model_hybrid_38 = Sequential()
model_hybrid_38.add(Conv1D(filters=300, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_38.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_38.add(LSTM(256, activation='relu'))
model_hybrid_38.add(Flatten())
model_hybrid_38.add(Dense(7))
model_hybrid_38.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_38.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_81"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_87 (Conv1D)              │ (None, 7, 300)         │         2,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_111 (LSTM)                 │ (None, 7, 64)          │        93,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_112 (LSTM)                 │ (None, 256)            │       328,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_81 (Flatten)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_81 (Dense)                │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 426,043 (1.63 MB)
#  Trainable params: 426,043 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_38.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 0.2676 - mean_absolute_error: 0.4764 - mean_absolute_percentage_error: 85.3828 - root_mean_squared_error: 0.5146 - val_loss: 0.0506 - val_mean_absolute_error: 0.1861 - val_mean_absolute_percentage_error: 16014190.0000 - val_root_mean_squared_error: 0.2249
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0328 - mean_absolute_error: 0.1476 - mean_absolute_percentage_error: 33.1290 - root_mean_squared_error: 0.1810 - val_loss: 0.0504 - val_mean_absolute_error: 0.1837 - val_mean_absolute_percentage_error: 17379506.0000 - val_root_mean_squared_error: 0.2245
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0219 - mean_absolute_error: 0.1154 - mean_absolute_percentage_error: 28.6297 - root_mean_squared_error: 0.1477 - val_loss: 0.0509 - val_mean_absolute_error: 0.1854 - val_mean_absolute_percentage_error: 15837313.0000 - val_root_mean_squared_error: 0.2256
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0199 - mean_absolute_error: 0.1092 - mean_absolute_percentage_error: 27.9090 - root_mean_squared_error: 0.1410 - val_loss: 0.0516 - val_mean_absolute_error: 0.1876 - val_mean_absolute_percentage_error: 15409604.0000 - val_root_mean_squared_error: 0.2272
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0201 - mean_absolute_error: 0.1105 - mean_absolute_percentage_error: 27.6480 - root_mean_squared_error: 0.1419 - val_loss: 0.0526 - val_mean_absolute_error: 0.1901 - val_mean_absolute_percentage_error: 15031185.0000 - val_root_mean_squared_error: 0.2292
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0202 - mean_absolute_error: 0.1108 - mean_absolute_percentage_error: 28.2031 - root_mean_squared_error: 0.1422 - val_loss: 0.0533 - val_mean_absolute_error: 0.1928 - val_mean_absolute_percentage_error: 14856472.0000 - val_root_mean_squared_error: 0.2309
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0195 - mean_absolute_error: 0.1090 - mean_absolute_percentage_error: 27.1905 - root_mean_squared_error: 0.1396 - val_loss: 0.0548 - val_mean_absolute_error: 0.1955 - val_mean_absolute_percentage_error: 14465762.0000 - val_root_mean_squared_error: 0.2340
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0202 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 28.1091 - root_mean_squared_error: 0.1419 - val_loss: 0.0547 - val_mean_absolute_error: 0.1959 - val_mean_absolute_percentage_error: 14468845.0000 - val_root_mean_squared_error: 0.2338
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0207 - mean_absolute_error: 0.1108 - mean_absolute_percentage_error: 28.4816 - root_mean_squared_error: 0.1439 - val_loss: 0.0541 - val_mean_absolute_error: 0.1966 - val_mean_absolute_percentage_error: 14738055.0000 - val_root_mean_squared_error: 0.2325
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0188 - mean_absolute_error: 0.1065 - mean_absolute_percentage_error: 27.3183 - root_mean_squared_error: 0.1370 - val_loss: 0.0534 - val_mean_absolute_error: 0.1948 - val_mean_absolute_percentage_error: 15012566.0000 - val_root_mean_squared_error: 0.2312
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0204 - mean_absolute_error: 0.1109 - mean_absolute_percentage_error: 27.6717 - root_mean_squared_error: 0.1428 - val_loss: 0.0544 - val_mean_absolute_error: 0.1970 - val_mean_absolute_percentage_error: 14510450.0000 - val_root_mean_squared_error: 0.2333
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0192 - mean_absolute_error: 0.1084 - mean_absolute_percentage_error: 27.9266 - root_mean_squared_error: 0.1384 - val_loss: 0.0545 - val_mean_absolute_error: 0.1982 - val_mean_absolute_percentage_error: 14623405.0000 - val_root_mean_squared_error: 0.2334
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0203 - mean_absolute_error: 0.1101 - mean_absolute_percentage_error: 28.4243 - root_mean_squared_error: 0.1424 - val_loss: 0.0568 - val_mean_absolute_error: 0.2005 - val_mean_absolute_percentage_error: 13987513.0000 - val_root_mean_squared_error: 0.2383
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0190 - mean_absolute_error: 0.1080 - mean_absolute_percentage_error: 25.5806 - root_mean_squared_error: 0.1380 - val_loss: 0.0550 - val_mean_absolute_error: 0.1999 - val_mean_absolute_percentage_error: 14360510.0000 - val_root_mean_squared_error: 0.2346
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0189 - mean_absolute_error: 0.1061 - mean_absolute_percentage_error: 26.3979 - root_mean_squared_error: 0.1374 - val_loss: 0.0547 - val_mean_absolute_error: 0.1982 - val_mean_absolute_percentage_error: 14701166.0000 - val_root_mean_squared_error: 0.2339
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0183 - mean_absolute_error: 0.1051 - mean_absolute_percentage_error: 26.3537 - root_mean_squared_error: 0.1351 - val_loss: 0.0569 - val_mean_absolute_error: 0.2021 - val_mean_absolute_percentage_error: 13973183.0000 - val_root_mean_squared_error: 0.2386
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0202 - mean_absolute_error: 0.1104 - mean_absolute_percentage_error: 26.7337 - root_mean_squared_error: 0.1419 - val_loss: 0.0557 - val_mean_absolute_error: 0.1987 - val_mean_absolute_percentage_error: 14527777.0000 - val_root_mean_squared_error: 0.2360
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0192 - mean_absolute_error: 0.1075 - mean_absolute_percentage_error: 27.6141 - root_mean_squared_error: 0.1384 - val_loss: 0.0553 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 14722415.0000 - val_root_mean_squared_error: 0.2352
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0194 - mean_absolute_error: 0.1084 - mean_absolute_percentage_error: 28.9400 - root_mean_squared_error: 0.1392 - val_loss: 0.0573 - val_mean_absolute_error: 0.2043 - val_mean_absolute_percentage_error: 14064984.0000 - val_root_mean_squared_error: 0.2395
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0186 - mean_absolute_error: 0.1066 - mean_absolute_percentage_error: 27.2434 - root_mean_squared_error: 0.1363 - val_loss: 0.0556 - val_mean_absolute_error: 0.2002 - val_mean_absolute_percentage_error: 14782131.0000 - val_root_mean_squared_error: 0.2358

# %%
y_pred = model_hybrid_38.predict(x_test)

evaluation_hybrid_38 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_38
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# {'Mean Squared Error: ': np.float64(355.4543093060602),
#  'Mean Absolute Error: ': np.float64(14.533910362087951),
#  'Root Mean Absolute Error: ': 18.85349594388426,
#  'Mean Absolute Percentage Error: ': np.float64(27.01287068115001)}

# %%
loss, mae, mape, rmse = model_hybrid_38.evaluate(x_test, y_test)
print("model hybrid 38")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0283 - mean_absolute_error: 0.1298 - mean_absolute_percentage_error: 34.3201 - root_mean_squared_error: 0.1683
# model hybrid 38
# Mean Square Error: 0.028336599469184875
# Mean Absolute Error: 0.129767045378685
# Mean Absolute Percentage Error: 34.320064544677734
# Root Mean Squared Error: 0.16833478212356567

# %% [markdown]
# ## model 39 (CNN=32 LSTM=64, 16)

# %%
lr = 0.0003

model_hybrid_39 = Sequential()
model_hybrid_39.add(Conv1D(filters=32, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_39.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_39.add(LSTM(16, activation='relu'))
model_hybrid_39.add(Flatten())
model_hybrid_39.add(Dense(7))
model_hybrid_39.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_39.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_82"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_88 (Conv1D)              │ (None, 7, 32)          │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_113 (LSTM)                 │ (None, 7, 64)          │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_114 (LSTM)                 │ (None, 16)             │         5,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_82 (Flatten)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_82 (Dense)                │ (None, 7)              │           119 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,359 (118.59 KB)
#  Trainable params: 30,359 (118.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_39.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.3240 - mean_absolute_error: 0.5402 - mean_absolute_percentage_error: 96.8131 - root_mean_squared_error: 0.5691 - val_loss: 0.2368 - val_mean_absolute_error: 0.4405 - val_mean_absolute_percentage_error: 3376017.5000 - val_root_mean_squared_error: 0.4867
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1879 - mean_absolute_error: 0.3826 - mean_absolute_percentage_error: 67.2289 - root_mean_squared_error: 0.4325 - val_loss: 0.1212 - val_mean_absolute_error: 0.2881 - val_mean_absolute_percentage_error: 10910440.0000 - val_root_mean_squared_error: 0.3481
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0863 - mean_absolute_error: 0.2363 - mean_absolute_percentage_error: 44.7377 - root_mean_squared_error: 0.2937 - val_loss: 0.0869 - val_mean_absolute_error: 0.2430 - val_mean_absolute_percentage_error: 12814337.0000 - val_root_mean_squared_error: 0.2948
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0500 - mean_absolute_error: 0.1792 - mean_absolute_percentage_error: 37.2125 - root_mean_squared_error: 0.2234 - val_loss: 0.0653 - val_mean_absolute_error: 0.2149 - val_mean_absolute_percentage_error: 13109952.0000 - val_root_mean_squared_error: 0.2555
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0312 - mean_absolute_error: 0.1395 - mean_absolute_percentage_error: 33.1349 - root_mean_squared_error: 0.1767 - val_loss: 0.0604 - val_mean_absolute_error: 0.2086 - val_mean_absolute_percentage_error: 12907710.0000 - val_root_mean_squared_error: 0.2459
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0257 - mean_absolute_error: 0.1265 - mean_absolute_percentage_error: 30.9227 - root_mean_squared_error: 0.1604 - val_loss: 0.0573 - val_mean_absolute_error: 0.2039 - val_mean_absolute_percentage_error: 13160711.0000 - val_root_mean_squared_error: 0.2394
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0239 - mean_absolute_error: 0.1211 - mean_absolute_percentage_error: 28.9823 - root_mean_squared_error: 0.1546 - val_loss: 0.0549 - val_mean_absolute_error: 0.1996 - val_mean_absolute_percentage_error: 13601518.0000 - val_root_mean_squared_error: 0.2344
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0216 - mean_absolute_error: 0.1144 - mean_absolute_percentage_error: 28.5695 - root_mean_squared_error: 0.1470 - val_loss: 0.0543 - val_mean_absolute_error: 0.1985 - val_mean_absolute_percentage_error: 13697101.0000 - val_root_mean_squared_error: 0.2329
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0209 - mean_absolute_error: 0.1120 - mean_absolute_percentage_error: 28.3044 - root_mean_squared_error: 0.1445 - val_loss: 0.0521 - val_mean_absolute_error: 0.1934 - val_mean_absolute_percentage_error: 14611206.0000 - val_root_mean_squared_error: 0.2283
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0219 - mean_absolute_error: 0.1152 - mean_absolute_percentage_error: 29.9749 - root_mean_squared_error: 0.1481 - val_loss: 0.0529 - val_mean_absolute_error: 0.1952 - val_mean_absolute_percentage_error: 14135779.0000 - val_root_mean_squared_error: 0.2299
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0206 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 29.4188 - root_mean_squared_error: 0.1436 - val_loss: 0.0534 - val_mean_absolute_error: 0.1962 - val_mean_absolute_percentage_error: 13903119.0000 - val_root_mean_squared_error: 0.2312
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0210 - mean_absolute_error: 0.1123 - mean_absolute_percentage_error: 29.4479 - root_mean_squared_error: 0.1449 - val_loss: 0.0560 - val_mean_absolute_error: 0.2003 - val_mean_absolute_percentage_error: 13343468.0000 - val_root_mean_squared_error: 0.2367
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0227 - mean_absolute_error: 0.1184 - mean_absolute_percentage_error: 30.2132 - root_mean_squared_error: 0.1507 - val_loss: 0.0547 - val_mean_absolute_error: 0.1979 - val_mean_absolute_percentage_error: 13634418.0000 - val_root_mean_squared_error: 0.2340
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0215 - mean_absolute_error: 0.1147 - mean_absolute_percentage_error: 29.6070 - root_mean_squared_error: 0.1467 - val_loss: 0.0531 - val_mean_absolute_error: 0.1956 - val_mean_absolute_percentage_error: 14035107.0000 - val_root_mean_squared_error: 0.2305
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0211 - mean_absolute_error: 0.1131 - mean_absolute_percentage_error: 28.4281 - root_mean_squared_error: 0.1452 - val_loss: 0.0524 - val_mean_absolute_error: 0.1937 - val_mean_absolute_percentage_error: 14442536.0000 - val_root_mean_squared_error: 0.2289
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0207 - mean_absolute_error: 0.1116 - mean_absolute_percentage_error: 29.2167 - root_mean_squared_error: 0.1437 - val_loss: 0.0552 - val_mean_absolute_error: 0.1993 - val_mean_absolute_percentage_error: 13534296.0000 - val_root_mean_squared_error: 0.2349
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0213 - mean_absolute_error: 0.1144 - mean_absolute_percentage_error: 29.4250 - root_mean_squared_error: 0.1461 - val_loss: 0.0547 - val_mean_absolute_error: 0.1982 - val_mean_absolute_percentage_error: 13688245.0000 - val_root_mean_squared_error: 0.2338
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0194 - mean_absolute_error: 0.1082 - mean_absolute_percentage_error: 26.3228 - root_mean_squared_error: 0.1393 - val_loss: 0.0545 - val_mean_absolute_error: 0.2001 - val_mean_absolute_percentage_error: 13521580.0000 - val_root_mean_squared_error: 0.2334
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0204 - mean_absolute_error: 0.1110 - mean_absolute_percentage_error: 27.6817 - root_mean_squared_error: 0.1427 - val_loss: 0.0546 - val_mean_absolute_error: 0.1994 - val_mean_absolute_percentage_error: 13614090.0000 - val_root_mean_squared_error: 0.2337
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0201 - mean_absolute_error: 0.1106 - mean_absolute_percentage_error: 29.9244 - root_mean_squared_error: 0.1419 - val_loss: 0.0544 - val_mean_absolute_error: 0.1990 - val_mean_absolute_percentage_error: 14519273.0000 - val_root_mean_squared_error: 0.2332

# %%
y_pred = model_hybrid_39.predict(x_test)

evaluation_hybrid_39 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_39
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# {'Mean Squared Error: ': np.float64(472.83891055577885),
#  'Mean Absolute Error: ': np.float64(17.531496787557796),
#  'Root Mean Absolute Error: ': 21.744859405288846,
#  'Mean Absolute Percentage Error: ': np.float64(32.15752125252407)}

# %%
loss, mae, mape, rmse = model_hybrid_39.evaluate(x_test, y_test)
print("model hybrid 39")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0377 - mean_absolute_error: 0.1565 - mean_absolute_percentage_error: 40.6359 - root_mean_squared_error: 0.1942
# model hybrid 39
# Mean Square Error: 0.03769442439079285
# Mean Absolute Error: 0.1565312147140503
# Mean Absolute Percentage Error: 40.635860443115234
# Root Mean Squared Error: 0.19415052235126495

# %% [markdown]
# ## model 40 (CNN=32 LSTM=64, 64)

# %%
lr = 0.0003

model_hybrid_40 = Sequential()
model_hybrid_40.add(Conv1D(filters=32, kernel_size=1, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
model_hybrid_40.add(LSTM(64, activation='relu', return_sequences=True))
model_hybrid_40.add(LSTM(64, activation='relu'))
model_hybrid_40.add(Flatten())
model_hybrid_40.add(Dense(7))
model_hybrid_40.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
model_hybrid_40.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_83"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_89 (Conv1D)              │ (None, 7, 32)          │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_115 (LSTM)                 │ (None, 7, 64)          │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_116 (LSTM)                 │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_83 (Flatten)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_83 (Dense)                │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,535 (228.65 KB)
#  Trainable params: 58,535 (228.65 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hybrid_40.fit(
    x_train,
    y_train,
    validation_data=(x_val ,y_val),
    epochs=20,
    batch_size=42
)
# Out:
# Epoch 1/20

# %%
y_pred = model_hybrid_40.predict(x_test)

evaluation_hybrid_40 = evaluate_preds(scaler_y.inverse_transform(y_test), scaler_y.inverse_transform(y_pred))
evaluation_hybrid_40

# %%
loss, mae, mape, rmse = model_hybrid_40.evaluate(x_test, y_test)
print("model hybrid 40")
print("Mean Square Error:", loss)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)
print("Root Mean Squared Error:", rmse)

# %% [markdown]
# ## model 24 gridsearch & early stopping (CNN=300, LSTM= 64, 32)

# %%
# from keras.callbacks import EarlyStopping
# from sklearn.model_selection import GridSearchCV
# from scikeras.wrappers import KerasRegressor
# from keras.optimizers import Adam

# # 1. Define your model builder function
# def build_model(filters1=300, units1=64, units2=32, kernel_size=1, lr=0.001):
#     model = Sequential()
#     model.add(Input(shape=(7, 11)))
#     model.add(Conv1D(filters=filters1, kernel_size=kernel_size, activation='relu'))
#     model.add(LSTM(units=units1, activation='relu', return_sequences=True))
#     model.add(LSTM(units=units2, activation='relu'))
#     model.add(Flatten())
#     model.add(Dense(7))
#     optimizer = Adam(learning_rate=lr)
#     model.compile(loss='mse', optimizer=optimizer,
#                   metrics=[metrics.MeanAbsoluteError(), metrics.MeanAbsolutePercentageError(), metrics.RootMeanSquaredError()])
#     return model

# # 2. Set up KerasRegressor
# model = KerasRegressor(model=build_model, verbose=0)

# # 3. Define early stopping
# early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# # 4. Grid of parameters
# param_grid = {
#     'model__filters1': [128, 300],
#     'model__units1': [64, 128],
#     'model__units2': [32, 64, 128, 256],
#     'model__kernel_size': [1],
#     'model__lr': [0.0003],
#     'batch_size': [42],
#     'epochs': [20]  # set high epochs so early stopping can interrupt early
# }

# # 5. GridSearchCV with early stopping passed via fit_params
# grid = GridSearchCV(estimator=model, param_grid=param_grid,
#                     scoring='neg_mean_squared_error',
#                     cv=3,
#                     refit=True)

# # 6. Fit with early stopping
# grid_result_cnn = grid.fit(x_train, y_train, callbacks=[early_stop], validation_data=(x_val, y_val))

# %%
# print("Best parameters found: ", grid_result_cnn.best_params_)
# # print("Best MSE: ", -grid_result.best_score_)

# %%
# best_model = grid_result_cnn.best_estimator_
# loss, mae, mape, rmse = best_model.model_.evaluate(x_test, y_test)
# print("Test MSE:", loss)
# print("Test MAE:", mae)
# print("Test MAPE:", mape)
# print("Test RMSE:", rmse)

# %%
evaluation_cnn_1, evaluation_cnn_2, evaluation_cnn_3, evaluation_cnn_4, evaluation_cnn_5, evaluation_cnn_6, evaluation_cnn_7, evaluation_cnn_8, evaluation_cnn_9, evaluation_cnn_10, evaluation_cnn_11, evaluation_cnn_12, evaluation_cnn_13, evaluation_cnn_14, evaluation_cnn_15, evaluation_cnn_16, evaluation_cnn_17, evaluation_cnn_18, evaluation_cnn_19, evaluation_cnn_20
# Out:
# ({'Mean Squared Error: ': np.float64(308.99187142125805),
#   'Mean Absolute Error: ': np.float64(13.681984979279187),
#   'Root Mean Absolute Error: ': 17.578164620382246,
#   'Mean Absolute Percentage Error: ': np.float64(24.58539616498866)},
#  {'Mean Squared Error: ': np.float64(308.7728270587435),
#   'Mean Absolute Error: ': np.float64(13.709325790405273),
#   'Root Mean Absolute Error: ': 17.571932934618875,
#   'Mean Absolute Percentage Error: ': np.float64(24.22289758217828)},
#  {'Mean Squared Error: ': np.float64(323.158230720397),
#   'Mean Absolute Error: ': np.float64(14.176996386781031),
#   'Root Mean Absolute Error: ': 17.976602313017803,
#   'Mean Absolute Percentage Error: ': np.float64(25.360192021301597)},
#  {'Mean Squared Error: ': np.float64(313.0978174914591),
#   'Mean Absolute Error: ': np.float64(13.376624593929368),
#   'Root Mean Absolute Error: ': 17.694570282757905,
#   'Mean Absolute Percentage Error: ': np.float64(24.57933044941292)},
#  {'Mean Squared Error: ': np.float64(355.96332819572086),
#   'Mean Absolute Error: ': np.float64(14.09022483047174),
#   'Root Mean Absolute Error: ': 18.86699043821565,
#   'Mean Absolute Percentage Error: ': np.float64(26.77810370094048)},
#  {'Mean Squared Error: ': np.float64(297.0202223430667),
#   'Mean Absolute Error: ': np.float64(13.155551307055415),
#   'Root Mean Absolute Error: ': 17.23427463930718,
#   'Mean Absolute Percentage Error: ': np.float64(24.11833917255041)},
#  {'Mean Squared Error: ': np.float64(356.9247375561596),
#   'Mean Absolute Error: ': np.float64(14.048584607182718),
#   'Root Mean Absolute Error: ': 18.89245186724475,
#   'Mean Absolute Percentage Error: ': np.float64(26.568739400143286)},
#  {'Mean Squared Error: ': np.float64(322.05384081145246),
#   'Mean Absolute Error: ': np.float64(13.293174685264121),
#   'Root Mean Absolute Error: ': 17.945858597778276,
#   'Mean Absolute Percentage Error: ': np.float64(25.151665031733785)},
#  {'Mean Squared Error: ': np.float64(248.00585235838474),
#   'Mean Absolute Error: ': np.float64(12.346905435834612),
#   'Root Mean Absolute Error: ': 15.748201559491951,
#   'Mean Absolute Percentage Error: ': np.float64(21.917377992616142)},
#  {'Mean Squared Error: ': np.float64(309.8490671182868),
#   'Mean Absolute Error: ': np.float64(12.92501332808514),
#   'Root Mean Absolute Error: ': 17.60253013399741,
#   'Mean Absolute Percentage Error: ': np.float64(24.48451157723588)},
#  {'Mean Squared Error: ': np.float64(407.9019675863541),
#   'Mean Absolute Error: ': np.float64(15.284369468688965),
#   'Root Mean Absolute Error: ': 20.196583067102072,
#   'Mean Absolute Percentage Error: ': np.float64(29.218351574776964)},
#  {'Mean Squared Error: ': np.float64(320.5368921308092),
#   'Mean Absolute Error: ': np.float64(14.266113845669494),
#   'Root Mean Absolute Error: ': 17.90354412206726,
#   'Mean Absolute Percentage Error: ': np.float64(25.274283338217508)},
#  {'Mean Squared Error: ': np.float64(623.7250012213093),
#   'Mean Absolute Error: ': np.float64(19.00586840571189),
#   'Root Mean Absolute Error: ': 24.974487006169102,
#   'Mean Absolute Percentage Error: ': np.float64(35.72098593041443)},
#  {'Mean Squared Error: ': np.float64(326.3614521036704),
#   'Mean Absolute Error: ': np.float64(13.501906550660424),
#   'Root Mean Absolute Error: ': 18.065476802555487,
#   'Mean Absolute Percentage Error: ': np.float64(25.21498846913357)},
#  {'Mean Squared Error: ': np.float64(262.3581179722084),
#   'Mean Absolute Error: ': np.float64(12.571553716854172),
#   'Root Mean Absolute Error: ': 16.197472579764053,
#   'Mean Absolute Percentage Error: ': np.float64(22.314289338570518)},
#  {'Mean Squared Error: ': np.float64(355.5798910350058),
#   'Mean Absolute Error: ': np.float64(14.188494098429777),
#   'Root Mean Absolute Error: ': 18.856826112445482,
#   'Mean Absolute Percentage Error: ': np.float64(26.8978685202793)},
#  {'Mean Squared Error: ': np.float64(386.56729889748334),
#   'Mean Absolute Error: ': np.float64(14.146349303576411),
#   'Root Mean Absolute Error: ': 19.661314780489207,
#   'Mean Absolute Percentage Error: ': np.float64(27.17288654530953)},
#  {'Mean Squared Error: ': np.float64(313.784171152303),
#   'Mean Absolute Error: ': np.float64(13.686381456803302),
#   'Root Mean Absolute Error: ': 17.713954136564286,
#   'Mean Absolute Percentage Error: ': np.float64(24.85618467718476)},
#  {'Mean Squared Error: ': np.float64(600.5764414323583),
#   'Mean Absolute Error: ': np.float64(18.096356450294962),
#   'Root Mean Absolute Error: ': 24.506661164515215,
#   'Mean Absolute Percentage Error: ': np.float64(34.04964176969604)},
#  {'Mean Squared Error: ': np.float64(307.8782494393687),
#   'Mean Absolute Error: ': np.float64(13.23758481473339),
#   'Root Mean Absolute Error: ': 17.546459740909807,
#   'Mean Absolute Percentage Error: ': np.float64(24.71139895319035)})

# %%
evaluation_lstm_1, evaluation_lstm_2, evaluation_lstm_3, evaluation_lstm_4, evaluation_lstm_5, evaluation_lstm_6, evaluation_lstm_7, evaluation_lstm_8, evaluation_lstm_9, evaluation_lstm_10, evaluation_lstm_11, evaluation_lstm_12, evaluation_lstm_13, evaluation_lstm_14, evaluation_lstm_15, evaluation_lstm_16, evaluation_lstm_17, evaluation_lstm_18, evaluation_lstm_19, evaluation_lstm_20, evaluation_lstm_21, evaluation_lstm_22, evaluation_lstm_23, evaluation_lstm_24, evaluation_lstm_25
# Out:
# ({'Mean Squared Error: ': np.float64(340.11774836036926),
#   'Mean Absolute Error: ': np.float64(14.84447903535804),
#   'Root Mean Absolute Error: ': 18.44228153890861,
#   'Mean Absolute Percentage Error: ': np.float64(23.803440264229536)},
#  {'Mean Squared Error: ': np.float64(392.0863969822591),
#   'Mean Absolute Error: ': np.float64(16.510735317152374),
#   'Root Mean Absolute Error: ': 19.801171606302972,
#   'Mean Absolute Percentage Error: ': np.float64(27.492623217690426)},
#  {'Mean Squared Error: ': np.float64(395.8629015229882),
#   'Mean Absolute Error: ': np.float64(15.105303316700216),
#   'Root Mean Absolute Error: ': 19.896303715087086,
#   'Mean Absolute Percentage Error: ': np.float64(28.91552608709616)},
#  {'Mean Squared Error: ': np.float64(385.0995006265619),
#   'Mean Absolute Error: ': np.float64(14.782673660589724),
#   'Root Mean Absolute Error: ': 19.623952217292057,
#   'Mean Absolute Percentage Error: ': np.float64(28.017642150445106)},
#  {'Mean Squared Error: ': np.float64(324.7721261971295),
#   'Mean Absolute Error: ': np.float64(13.977943595574827),
#   'Root Mean Absolute Error: ': 18.021435186941396,
#   'Mean Absolute Percentage Error: ': np.float64(25.840499978600956)},
#  {'Mean Squared Error: ': np.float64(340.19115233959553),
#   'Mean Absolute Error: ': np.float64(14.633661114439672),
#   'Root Mean Absolute Error: ': 18.444271531822437,
#   'Mean Absolute Percentage Error: ': np.float64(22.943267627097597)},
#  {'Mean Squared Error: ': np.float64(388.7641676932649),
#   'Mean Absolute Error: ': np.float64(16.76678328611413),
#   'Root Mean Absolute Error: ': 19.717103430607267,
#   'Mean Absolute Percentage Error: ': np.float64(27.62630369072231)},
#  {'Mean Squared Error: ': np.float64(316.5355930347165),
#   'Mean Absolute Error: ': np.float64(14.23902614749208),
#   'Root Mean Absolute Error: ': 17.79144718775616,
#   'Mean Absolute Percentage Error: ': np.float64(25.42743128179052)},
#  {'Mean Squared Error: ': np.float64(379.76451502489266),
#   'Mean Absolute Error: ': np.float64(15.208665283358826),
#   'Root Mean Absolute Error: ': 19.48754769140778,
#   'Mean Absolute Percentage Error: ': np.float64(27.620088164244827)},
#  {'Mean Squared Error: ': np.float64(407.9362081373832),
#   'Mean Absolute Error: ': np.float64(15.009092642336475),
#   'Root Mean Absolute Error: ': 20.19743073109506,
#   'Mean Absolute Percentage Error: ': np.float64(28.816592599477563)},
#  {'Mean Squared Error: ': np.float64(301.9662657849719),
#   'Mean Absolute Error: ': np.float64(13.733981658001335),
#   'Root Mean Absolute Error: ': 17.377176576906038,
#   'Mean Absolute Percentage Error: ': np.float64(24.452698227640965)},
#  {'Mean Squared Error: ': np.float64(271.98071853461926),
#   'Mean Absolute Error: ': np.float64(13.213419174661443),
#   'Root Mean Absolute Error: ': 16.491837936828606,
#   'Mean Absolute Percentage Error: ': np.float64(23.168551997855385)},
#  {'Mean Squared Error: ': np.float64(321.657629135667),
#   'Mean Absolute Error: ': np.float64(13.947566986083984),
#   'Root Mean Absolute Error: ': 17.934816116583605,
#   'Mean Absolute Percentage Error: ': np.float64(25.885039068633287)},
#  {'Mean Squared Error: ': np.float64(336.93133774970903),
#   'Mean Absolute Error: ': np.float64(15.04144080804319),
#   'Root Mean Absolute Error: ': 18.35568951986574,
#   'Mean Absolute Percentage Error: ': np.float64(25.902786676580003)},
#  {'Mean Squared Error: ': np.float64(321.99200746362897),
#   'Mean Absolute Error: ': np.float64(13.920665118159082),
#   'Root Mean Absolute Error: ': 17.944135740225246,
#   'Mean Absolute Percentage Error: ': np.float64(25.754616371782816)},
#  {'Mean Squared Error: ': np.float64(466.82663771646855),
#   'Mean Absolute Error: ': np.float64(16.250607957645336),
#   'Root Mean Absolute Error: ': 21.606171287770273,
#   'Mean Absolute Percentage Error: ': np.float64(31.161397248350614)},
#  {'Mean Squared Error: ': np.float64(353.5499715529387),
#   'Mean Absolute Error: ': np.float64(14.611112711380937),
#   'Root Mean Absolute Error: ': 18.802924547871235,
#   'Mean Absolute Percentage Error: ': np.float64(27.375874587516353)},
#  {'Mean Squared Error: ': np.float64(430.8832270191488),
#   'Mean Absolute Error: ': np.float64(17.273792111143774),
#   'Root Mean Absolute Error: ': 20.757726923224247,
#   'Mean Absolute Percentage Error: ': np.float64(29.58385066397657)},
#  {'Mean Squared Error: ': np.float64(401.08763956785367),
#   'Mean Absolute Error: ': np.float64(16.457443937963372),
#   'Root Mean Absolute Error: ': 20.02717253053595,
#   'Mean Absolute Percentage Error: ': np.float64(27.461652576503997)},
#  {'Mean Squared Error: ': np.float64(505.48421103464335),
#   'Mean Absolute Error: ': np.float64(16.546811006507095),
#   'Root Mean Absolute Error: ': 22.48297602708866,
#   'Mean Absolute Percentage Error: ': np.float64(32.24402781983183)},
#  {'Mean Squared Error: ': np.float64(295.41889165762313),
#   'Mean Absolute Error: ': np.float64(13.529825093794841),
#   'Root Mean Absolute Error: ': 17.187754119070448,
#   'Mean Absolute Percentage Error: ': np.float64(24.716833615875313)},
#  {'Mean Squared Error: ': np.float64(371.5288416056039),
#   'Mean Absolute Error: ': np.float64(14.506794637563276),
#   'Root Mean Absolute Error: ': 19.275083439653482,
#   'Mean Absolute Percentage Error: ': np.float64(27.581209227944818)},
#  {'Mean Squared Error: ': np.float64(419.47515755431897),
#   'Mean Absolute Error: ': np.float64(15.502510946624133),
#   'Root Mean Absolute Error: ': 20.481092684579085,
#   'Mean Absolute Percentage Error: ': np.float64(29.37209014553771)},
#  {'Mean Squared Error: ': np.float64(298.2663526506554),
#   'Mean Absolute Error: ': np.float64(13.852951497447734),
#   'Root Mean Absolute Error: ': 17.270389475939893,
#   'Mean Absolute Percentage Error: ': np.float64(24.072552732877288)},
#  {'Mean Squared Error: ': np.float64(316.91277572113967),
#   'Mean Absolute Error: ': np.float64(14.169352570358587),
#   'Root Mean Absolute Error: ': 17.802044144455426,
#   'Mean Absolute Percentage Error: ': np.float64(25.577514425098176)})

# %%
evaluation_hybrid_1, evaluation_hybrid_2, evaluation_hybrid_3, evaluation_hybrid_4, evaluation_hybrid_5, evaluation_hybrid_6, evaluation_hybrid_7, evaluation_hybrid_8,  evaluation_hybrid_9, evaluation_hybrid_10, evaluation_hybrid_11, evaluation_hybrid_12, evaluation_hybrid_13, evaluation_hybrid_14, evaluation_hybrid_15, evaluation_hybrid_16,  evaluation_hybrid_17, evaluation_hybrid_18, evaluation_hybrid_19, evaluation_hybrid_20, evaluation_21, evaluation_hybrid_22, evaluation_hybrid_23,
# Out:
# ({'Mean Squared Error: ': np.float64(368.07719860158966),
#   'Mean Absolute Error: ': np.float64(14.585360215634719),
#   'Root Mean Absolute Error: ': 19.185338115383573,
#   'Mean Absolute Percentage Error: ': np.float64(27.464497393851005)},
#  {'Mean Squared Error: ': np.float64(327.6028594153596),
#   'Mean Absolute Error: ': np.float64(14.298462225466361),
#   'Root Mean Absolute Error: ': 18.099802745205807,
#   'Mean Absolute Percentage Error: ': np.float64(25.68796351144772)},
#  {'Mean Squared Error: ': np.float64(315.60906852084565),
#   'Mean Absolute Error: ': np.float64(14.145307190564212),
#   'Root Mean Absolute Error: ': 17.76538962479702,
#   'Mean Absolute Percentage Error: ': np.float64(25.504562203188776)},
#  {'Mean Squared Error: ': np.float64(409.30828164831024),
#   'Mean Absolute Error: ': np.float64(16.674587288681344),
#   'Root Mean Absolute Error: ': 20.231368753703006,
#   'Mean Absolute Percentage Error: ': np.float64(27.921256943160245)},
#  {'Mean Squared Error: ': np.float64(278.67293421442804),
#   'Mean Absolute Error: ': np.float64(12.875939797381966),
#   'Root Mean Absolute Error: ': 16.693499759320332,
#   'Mean Absolute Percentage Error: ': np.float64(23.449496326932877)},
#  {'Mean Squared Error: ': np.float64(281.63863413084306),
#   'Mean Absolute Error: ': np.float64(13.404991266678792),
#   'Root Mean Absolute Error: ': 16.782092662443592,
#   'Mean Absolute Percentage Error: ': np.float64(23.61762003946376)},
#  {'Mean Squared Error: ': np.float64(298.72962497714514),
#   'Mean Absolute Error: ': np.float64(13.601172836459414),
#   'Root Mean Absolute Error: ': 17.283796601937468,
#   'Mean Absolute Percentage Error: ': np.float64(24.964750144738453)},
#  {'Mean Squared Error: ': np.float64(297.3300744137226),
#   'Mean Absolute Error: ': np.float64(13.170095774592186),
#   'Root Mean Absolute Error: ': 17.2432617104109,
#   'Mean Absolute Percentage Error: ': np.float64(24.34830239326961)},
#  {'Mean Squared Error: ': np.float64(351.1029415015795),
#   'Mean Absolute Error: ': np.float64(14.309362645051916),
#   'Root Mean Absolute Error: ': 18.737741099224834,
#   'Mean Absolute Percentage Error: ': np.float64(26.9330533094466)},
#  {'Mean Squared Error: ': np.float64(336.56983218861296),
#   'Mean Absolute Error: ': np.float64(14.560619198546119),
#   'Root Mean Absolute Error: ': 18.345839642507862,
#   'Mean Absolute Percentage Error: ': np.float64(26.094718172552483)},
#  {'Mean Squared Error: ': np.float64(357.2811472876997),
#   'Mean Absolute Error: ': np.float64(14.423620379700955),
#   'Root Mean Absolute Error: ': 18.901882109665685,
#   'Mean Absolute Percentage Error: ': np.float64(27.190408651718467)},
#  {'Mean Squared Error: ': np.float64(266.5441483777805),
#   'Mean Absolute Error: ': np.float64(12.834602122404137),
#   'Root Mean Absolute Error: ': 16.32617984642398,
#   'Mean Absolute Percentage Error: ': np.float64(23.03219316799609)},
#  {'Mean Squared Error: ': np.float64(288.4177258759487),
#   'Mean Absolute Error: ': np.float64(13.257998252401546),
#   'Root Mean Absolute Error: ': 16.982865655593837,
#   'Mean Absolute Percentage Error: ': np.float64(24.435759835557473)},
#  {'Mean Squared Error: ': np.float64(286.74235388195257),
#   'Mean Absolute Error: ': np.float64(13.61697397426683),
#   'Root Mean Absolute Error: ': 16.933468453980495,
#   'Mean Absolute Percentage Error: ': np.float64(23.53350241163923)},
#  {'Mean Squared Error: ': np.float64(353.5128758538434),
#   'Mean Absolute Error: ': np.float64(14.94358101669623),
#   'Root Mean Absolute Error: ': 18.80193808770371,
#   'Mean Absolute Percentage Error: ': np.float64(27.13061628263254)},
#  {'Mean Squared Error: ': np.float64(351.9614834178192),
#   'Mean Absolute Error: ': np.float64(14.976647630029797),
#   'Root Mean Absolute Error: ': 18.76063654084848,
#   'Mean Absolute Percentage Error: ': np.float64(26.773198328737035)},
#  {'Mean Squared Error: ': np.float64(422.32530408931717),
#   'Mean Absolute Error: ': np.float64(15.953688563132772),
#   'Root Mean Absolute Error: ': 20.550554836532203,
#   'Mean Absolute Percentage Error: ': np.float64(29.503985368979198)},
#  {'Mean Squared Error: ': np.float64(360.5353105441474),
#   'Mean Absolute Error: ': np.float64(15.216635840279713),
#   'Root Mean Absolute Error: ': 18.987767392301482,
#   'Mean Absolute Percentage Error: ': np.float64(27.356577334010773)},
#  {'Mean Squared Error: ': np.float64(320.39316870466865),
#   'Mean Absolute Error: ': np.float64(14.109604563031876),
#   'Root Mean Absolute Error: ': 17.899529845911278,
#   'Mean Absolute Percentage Error: ': np.float64(25.83768973632542)},
#  {'Mean Squared Error: ': np.float64(277.3340576643997),
#   'Mean Absolute Error: ': np.float64(13.322164613373426),
#   'Root Mean Absolute Error: ': 16.653349743051688,
#   'Mean Absolute Percentage Error: ': np.float64(23.60073828402595)},
#  {'Mean Squared Error: ': np.float64(336.418936132669),
#   'Mean Absolute Error: ': np.float64(14.616225203689265),
#   'Root Mean Absolute Error: ': 18.341726639895956,
#   'Mean Absolute Percentage Error: ': np.float64(26.948818994343327)},
#  {'Mean Squared Error: ': np.float64(368.86136982231534),
#   'Mean Absolute Error: ': np.float64(14.678571389645947),
#   'Root Mean Absolute Error: ': 19.205763973930203,
#   'Mean Absolute Percentage Error: ': np.float64(27.41966421844953)},
#  {'Mean Squared Error: ': np.float64(345.3015008851733),
#   'Mean Absolute Error: ': np.float64(14.241107434642558),
#   'Root Mean Absolute Error: ': 18.5822899795793,
#   'Mean Absolute Percentage Error: ': np.float64(26.651464530052593)})

# %%
evaluation_hybrid_25, evaluation_hybrid_26, evaluation_hybrid_27, evaluation_hybrid_28, evaluation_hybrid_29, evaluation_hybrid_30, evaluation_hybrid_31, evaluation_hybrid_32, evaluation_hybrid_33, evaluation_hybrid_34, evaluation_hybrid_35, evaluation_hybrid_36, evaluation_hybrid_37, evaluation_hybrid_38, evaluation_hybrid_39, evaluation_hybrid_40
# Out:
# ({'Mean Squared Error: ': np.float64(393.01347593562076),
#   'Mean Absolute Error: ': np.float64(15.011197187462633),
#   'Root Mean Absolute Error: ': 19.824567484200525,
#   'Mean Absolute Percentage Error: ': np.float64(28.4413327335505)},
#  {'Mean Squared Error: ': np.float64(409.9505542328133),
#   'Mean Absolute Error: ': np.float64(15.554531175263076),
#   'Root Mean Absolute Error: ': 20.247235718310126,
#   'Mean Absolute Percentage Error: ': np.float64(29.115850689134337)},
#  {'Mean Squared Error: ': np.float64(277.32177746283327),
#   'Mean Absolute Error: ': np.float64(12.84862239993348),
#   'Root Mean Absolute Error: ': 16.65298103832564,
#   'Mean Absolute Percentage Error: ': np.float64(23.80616432817356)},
#  {'Mean Squared Error: ': np.float64(315.36387699583975),
#   'Mean Absolute Error: ': np.float64(13.398618737045599),
#   'Root Mean Absolute Error: ': 17.758487463628196,
#   'Mean Absolute Percentage Error: ': np.float64(25.422659256965158)},
#  {'Mean Squared Error: ': np.float64(297.27619761704227),
#   'Mean Absolute Error: ': np.float64(13.860039964014168),
#   'Root Mean Absolute Error: ': 17.24169938309569,
#   'Mean Absolute Percentage Error: ': np.float64(24.62770722976006)},
#  {'Mean Squared Error: ': np.float64(382.7946677114502),
#   'Mean Absolute Error: ': np.float64(15.25731592762227),
#   'Root Mean Absolute Error: ': 19.565139092565893,
#   'Mean Absolute Percentage Error: ': np.float64(27.925584648514512)},
#  {'Mean Squared Error: ': np.float64(325.0771063030899),
#   'Mean Absolute Error: ': np.float64(14.741983024441467),
#   'Root Mean Absolute Error: ': 18.029894794565216,
#   'Mean Absolute Percentage Error: ': np.float64(25.575844323843413)},
#  {'Mean Squared Error: ': np.float64(293.4747813972425),
#   'Mean Absolute Error: ': np.float64(13.871171698278308),
#   'Root Mean Absolute Error: ': 17.13110566768072,
#   'Mean Absolute Percentage Error: ': np.float64(23.885885503652602)},
#  {'Mean Squared Error: ': np.float64(418.45545035074355),
#   'Mean Absolute Error: ': np.float64(15.595797324667172),
#   'Root Mean Absolute Error: ': 20.456183670243664,
#   'Mean Absolute Percentage Error: ': np.float64(29.401618414276047)},
#  {'Mean Squared Error: ': np.float64(306.3274912982016),
#   'Mean Absolute Error: ': np.float64(13.860484901739627),
#   'Root Mean Absolute Error: ': 17.502213897053185,
#   'Mean Absolute Percentage Error: ': np.float64(24.29744241692736)},
#  {'Mean Squared Error: ': np.float64(337.43783792733757),
#   'Mean Absolute Error: ': np.float64(14.289937895171496),
#   'Root Mean Absolute Error: ': 18.369481155637946,
#   'Mean Absolute Percentage Error: ': np.float64(26.462778739628412)},
#  {'Mean Squared Error: ': np.float64(339.03365748635804),
#   'Mean Absolute Error: ': np.float64(14.711404761489556),
#   'Root Mean Absolute Error: ': 18.412866628701735,
#   'Mean Absolute Percentage Error: ': np.float64(26.490348768924264)},
#  {'Mean Squared Error: ': np.float64(354.4829828682073),
#   'Mean Absolute Error: ': np.float64(14.625278648065061),
#   'Root Mean Absolute Error: ': 18.82771847219432,
#   'Mean Absolute Percentage Error: ': np.float64(27.09405022614645)},
#  {'Mean Squared Error: ': np.float64(355.4543093060602),
#   'Mean Absolute Error: ': np.float64(14.533910362087951),
#   'Root Mean Absolute Error: ': 18.85349594388426,
#   'Mean Absolute Percentage Error: ': np.float64(27.01287068115001)},
#  {'Mean Squared Error: ': np.float64(472.83891055577885),
#   'Mean Absolute Error: ': np.float64(17.531496787557796),
#   'Root Mean Absolute Error: ': 21.744859405288846,
#   'Mean Absolute Percentage Error: ': np.float64(32.15752125252407)},
#  {'Mean Squared Error: ': np.float64(365.36490446016643),
#   'Mean Absolute Error: ': np.float64(15.745322499956403),
#   'Root Mean Absolute Error: ': 19.114520775059113,
#   'Mean Absolute Percentage Error: ': np.float64(25.843487329085864)})

# %%
model_hybrid_12.save("Pol_Hybrid_Model_12.keras")
